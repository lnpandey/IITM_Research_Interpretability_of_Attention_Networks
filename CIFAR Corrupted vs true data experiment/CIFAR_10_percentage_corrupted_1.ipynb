# %%
import torch
import torch.nn as nn
import torch.nn.functional as F


class Block(nn.Module):
    '''expand + depthwise + pointwise + squeeze-excitation'''

    def __init__(self, in_planes, out_planes, expansion, stride):
        super(Block, self).__init__()
        self.stride = stride

        planes = expansion * in_planes
        self.conv1 = nn.Conv2d(
            in_planes, planes, kernel_size=1, stride=1, padding=0, bias=False)
        self.bn1 = nn.BatchNorm2d(planes)
        self.conv2 = nn.Conv2d(planes, planes, kernel_size=3,
                               stride=stride, padding=1, groups=planes, bias=False)
        self.bn2 = nn.BatchNorm2d(planes)
        self.conv3 = nn.Conv2d(
            planes, out_planes, kernel_size=1, stride=1, padding=0, bias=False)
        self.bn3 = nn.BatchNorm2d(out_planes)

        self.shortcut = nn.Sequential()
        if stride == 1 and in_planes != out_planes:
            self.shortcut = nn.Sequential(
                nn.Conv2d(in_planes, out_planes, kernel_size=1,
                          stride=1, padding=0, bias=False),
                nn.BatchNorm2d(out_planes),
            )

        # SE layers
        self.fc1 = nn.Conv2d(out_planes, out_planes//16, kernel_size=1)
        self.fc2 = nn.Conv2d(out_planes//16, out_planes, kernel_size=1)

    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = F.relu(self.bn2(self.conv2(out)))
        out = self.bn3(self.conv3(out))
        shortcut = self.shortcut(x) if self.stride == 1 else out
        # Squeeze-Excitation
        w = F.avg_pool2d(out, out.size(2))
        w = F.relu(self.fc1(w))
        w = self.fc2(w).sigmoid()
        out = out * w + shortcut
        return out


class EfficientNet(nn.Module):
    def __init__(self, cfg, num_classes=10):
        super(EfficientNet, self).__init__()
        self.cfg = cfg
        self.conv1 = nn.Conv2d(3, 32, kernel_size=3,
                               stride=1, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(32)
        self.layers = self._make_layers(in_planes=32)
        self.linear = nn.Linear(cfg[-1][1], num_classes)

    def _make_layers(self, in_planes):
        layers = []
        for expansion, out_planes, num_blocks, stride in self.cfg:
            strides = [stride] + [1]*(num_blocks-1)
            for stride in strides:
                layers.append(Block(in_planes, out_planes, expansion, stride))
                in_planes = out_planes
        return nn.Sequential(*layers)

    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = self.layers(out)
        out = out.view(out.size(0), -1)
        out = self.linear(out)
        return out


def EfficientNetB0():
    # (expansion, out_planes, num_blocks, stride)
    cfg = [(1,  16, 1, 2),
           (6,  24, 2, 1),
           (6,  40, 2, 2),
           (6,  80, 3, 2),
           (6, 112, 3, 1),
           (6, 192, 4, 2),
           (6, 320, 1, 2)]
    return EfficientNet(cfg)


def test():
    net = EfficientNetB0()
    x = torch.randn(2, 3, 32, 32)
    y = net(x)
    print(y.shape)

# %%
import os
import sys
import time
import math

import torch.nn as nn
import torch.nn.init as init


def get_mean_and_std(dataset):
    '''Compute the mean and std value of dataset.'''
    dataloader = torch.utils.data.DataLoader(dataset, batch_size=1, shuffle=True, num_workers=2)
    mean = torch.zeros(3)
    std = torch.zeros(3)
    print('==> Computing mean and std..')
    for inputs, targets in dataloader:
        for i in range(3):
            mean[i] += inputs[:,i,:,:].mean()
            std[i] += inputs[:,i,:,:].std()
    mean.div_(len(dataset))
    std.div_(len(dataset))
    return mean, std

def init_params(net):
    '''Init layer parameters.'''
    for m in net.modules():
        if isinstance(m, nn.Conv2d):
            init.kaiming_normal(m.weight, mode='fan_out')
            if m.bias:
                init.constant(m.bias, 0)
        elif isinstance(m, nn.BatchNorm2d):
            init.constant(m.weight, 1)
            init.constant(m.bias, 0)
        elif isinstance(m, nn.Linear):
            init.normal(m.weight, std=1e-3)
            if m.bias:
                init.constant(m.bias, 0)


# _, term_width = os.popen('stty size', 'r').read().split()
term_width = 80
term_width = int(term_width)

TOTAL_BAR_LENGTH = 65.
last_time = time.time()
begin_time = last_time
def progress_bar(current, total, msg=None):
    global last_time, begin_time
    if current == 0:
        begin_time = time.time()  # Reset for new bar.

    cur_len = int(TOTAL_BAR_LENGTH*current/total)
    rest_len = int(TOTAL_BAR_LENGTH - cur_len) - 1

    sys.stdout.write(' [')
    for i in range(cur_len):
        sys.stdout.write('=')
    sys.stdout.write('>')
    for i in range(rest_len):
        sys.stdout.write('.')
    sys.stdout.write(']')

    cur_time = time.time()
    step_time = cur_time - last_time
    last_time = cur_time
    tot_time = cur_time - begin_time

    L = []
    L.append('  Step: %s' % format_time(step_time))
    L.append(' | Tot: %s' % format_time(tot_time))
    if msg:
        L.append(' | ' + msg)

    msg = ''.join(L)
    sys.stdout.write(msg)
    for i in range(term_width-int(TOTAL_BAR_LENGTH)-len(msg)-3):
        sys.stdout.write(' ')

    # Go back to the center of the bar.
    for i in range(term_width-int(TOTAL_BAR_LENGTH/2)+2):
        sys.stdout.write('\b')
    sys.stdout.write(' %d/%d ' % (current+1, total))

    if current < total-1:
        sys.stdout.write('\r')
    else:
        sys.stdout.write('\n')
    sys.stdout.flush()

def format_time(seconds):
    days = int(seconds / 3600/24)
    seconds = seconds - days*3600*24
    hours = int(seconds / 3600)
    seconds = seconds - hours*3600
    minutes = int(seconds / 60)
    seconds = seconds - minutes*60
    secondsf = int(seconds)
    seconds = seconds - secondsf
    millis = int(seconds*1000)

    f = ''
    i = 1
    if days > 0:
        f += str(days) + 'D'
        i += 1
    if hours > 0 and i <= 2:
        f += str(hours) + 'h'
        i += 1
    if minutes > 0 and i <= 2:
        f += str(minutes) + 'm'
        i += 1
    if secondsf > 0 and i <= 2:
        f += str(secondsf) + 's'
        i += 1
    if millis > 0 and i <= 2:
        f += str(millis) + 'ms'
        i += 1
    if f == '':
        f = '0ms'
    return f

# %%
'''Train CIFAR10 with PyTorch.'''
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import torch.backends.cudnn as cudnn

import torchvision
import torchvision.transforms as transforms

import os
import argparse
import numpy as np
from torch.utils.data import Dataset, DataLoader

# from models import *
# from utils import progress_bar


# parser = argparse.ArgumentParser(description='PyTorch CIFAR10 Training')
# parser.add_argument('--lr', default=0.1, type=float, help='learning rate')
# parser.add_argument('--resume', '-r', action='store_true', help='resume from checkpoint')
# args = parser.parse_args()

lr = 0.01

device = 'cuda' if torch.cuda.is_available() else 'cpu'
best_acc = 0  # best test accuracy
start_epoch = 0  # start from epoch 0 or last checkpoint epoch

# Data
print('==> Preparing data..')
transform_train = transforms.Compose([
    transforms.RandomCrop(32, padding=4),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010)),
])

transform_test = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010)),
])

trainset = torchvision.datasets.CIFAR10(root='./data', train=True, download=True, transform=transform_train)
testset = torchvision.datasets.CIFAR10(root='./data', train=False, download=True, transform=transform_test)


# trainset.targets***************************************************************
import random
length = len(trainset.targets)
percentage_corruption = 10
n = length*percentage_corruption/100
corrupt_classes = np.random.randint(0,10,int(n))

corrupt_idx = random.sample(range(0,length), int(n))
a = np.array(trainset.targets)
a[corrupt_idx] = corrupt_classes
trainset.targets = list(a)

class CustomizeDataset(Dataset):
    """MosaicDataset dataset."""

    def __init__(self, dataset, corrupt):
        """
        Args:
            csv_file (string): Path to the csv file with annotations.
            root_dir (string): Directory with all the images.
            transform (callable, optional): Optional transform to be applied
                on a sample.
        """
        self.data = dataset.data
        self.data= np.rollaxis(self.data, 3,1)
        self.data =  np.float32(self.data)
#         print(self.data.dtype)
        #print(self.data.shape)
        self.label = dataset.targets
        self.corrupt_idx = corrupt
        self.indicator = torch.zeros(len(self.label)).byte()
        k = len(self.label)
        for i in range(k):
          if i in self.corrupt_idx :
            self.indicator[i]=1

    def __len__(self):
        return len(self.label)

    def __getitem__(self, idx):
#       print(self.data[idx].shape)
      return self.data[idx] , self.label[idx], self.indicator[idx]


train_data = CustomizeDataset(trainset,corrupt_idx)
trainloader = DataLoader( train_data, batch_size= 128,shuffle= False, num_workers=2)


#**********************************************************************************

testloader = torch.utils.data.DataLoader(testset, batch_size=100, shuffle=False, num_workers=2)
# trainloader = torch.utils.data.DataLoader(trainset, batch_size=128, shuffle=False, num_workers=2)

classes = ('plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck')

# Model
print('==> Building model..')
# net = VGG('VGG19')
# net = ResNet18()
# net = PreActResNet18()
# net = GoogLeNet()
# net = DenseNet121()
# net = ResNeXt29_2x64d()
# net = MobileNet()
# net = MobileNetV2()
# net = DPN92()
# net = ShuffleNetG2()
# net = SENet18()
# net = ShuffleNetV2(1)
net = EfficientNetB0()
net = net.to(device)
if device == 'cuda':
    net = torch.nn.DataParallel(net)
    cudnn.benchmark = True

# if args.resume:
#     # Load checkpoint.
#     print('==> Resuming from checkpoint..')
#     assert os.path.isdir('checkpoint'), 'Error: no checkpoint directory found!'
#     checkpoint = torch.load('./checkpoint/ckpt.pth')
#     net.load_state_dict(checkpoint['net'])
#     best_acc = checkpoint['acc']
#     start_epoch = checkpoint['epoch']

criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(net.parameters(), lr, momentum=0.9, weight_decay=5e-4)
# optimizer = optim.SGD(net.parameters(), lr=args.lr, momentum=0.9, weight_decay=5e-4)

train_acc =[]
test_acc=[]
epoch_list=[]
# Training
def train(epoch):
    print('\nEpoch: %d' % epoch)
    net.train()
    
    train_loss = 0
    tl=0
    train_corrupt_loss = 0
    tcl=0
    train_true_loss = 0
    ttl=0
    
    correct = 0
    true_correct=0
    corrupt_correct=0
    
    total = 0
    corrupt_total = 0
    true_total=0
    
    for batch_idx, (inputs, targets, indicator ) in enumerate(trainloader):
#         batch_corrupt_loss , batch_true_loss, batch_total_loss = 0,0,0
        inputs, targets, indicator = inputs.to(device), targets.to(device), indicator.to(device)
#         print(inputs,targets.size(),indicator.size())
        optimizer.zero_grad()
        outputs = net(inputs)
        loss = criterion(outputs, targets)
        batch_total_loss = loss.item()
        tl += loss.item()
        train_loss += batch_total_loss*len(indicator)
        
        _, predicted = outputs.max(1)
        total += targets.size(0)
        correct += predicted.eq(targets).sum().item()
#         print(indicator.size)
#         print(sum(~indicator),sum(indicator))
#         ***************************************************************
        corrupt_out = (outputs[indicator])
        loss_corrupt = criterion(corrupt_out, targets[indicator])
        batch_corrupt_loss = loss_corrupt.item()
        tcl += loss_corrupt.item()
        train_corrupt_loss += batch_corrupt_loss*(sum(indicator).item())
       
        _, predict_corrupt = corrupt_out.max(1)
        corrupt_total += targets[indicator].size(0)
        corrupt_correct += predict_corrupt.eq(targets[indicator]).sum().item()
        
        true_out = (outputs[~indicator])
        loss_true = criterion(true_out, targets[~indicator])
        batch_true_loss = loss_true.item()
        ttl += loss_true.item()
        train_true_loss += batch_true_loss*(sum(~indicator).item())
        
        _, predict_true = true_out.max(1)
        true_total += targets[~indicator].size(0)
        true_correct += predict_true.eq(targets[~indicator]).sum().item()
        
#         ****************************************************************************
        loss.backward()
        optimizer.step()
        

#         progress_bar(batch_idx, len(trainloader), 'Loss: %.3f | Acc: %.3f%% (%d/%d)'
#             % (train_loss/(batch_idx+1), 100.*correct/total, correct, total))
    
    print("corrupt_loss", train_corrupt_loss, tcl)
    print("true loss", train_true_loss, ttl)
    print("Train loss of full data", train_loss, tl)
    print("total_corrupt, total_true and total_data respectively are :  ",corrupt_total, true_total, total)
    print("Train accuracy on corrupted train-data", corrupt_correct/corrupt_total )
    print("Train accuracy on un-corrupted train-data", true_correct/true_total)
    print("Train accuracy on full train-data ", correct/total )
    train_acc.append(train_loss)

def test(epoch):
    global best_acc
#     net.eval()
    test_loss = 0
    correct = 0
    total = 0
    with torch.no_grad():
        for batch_idx, (inputs, targets) in enumerate(testloader):
            inputs, targets = inputs.to(device), targets.to(device)
            outputs = net(inputs)
            loss = criterion(outputs, targets)

            test_loss += loss.item()
            _, predicted = outputs.max(1)
            total += targets.size(0)
            correct += predicted.eq(targets).sum().item()

#             progress_bar(batch_idx, len(testloader), 'Loss: %.3f | Acc: %.3f%% (%d/%d)'
#                 % (test_loss/(batch_idx+1), 100.*correct/total, correct, total))
    print("test accuracy ", correct/total , test_loss)
    test_acc.append(test_loss)

    # Save checkpoint.
#     acc = 100.*correct/total
#     if acc > best_acc:
#         print('Saving..')
#         state = {
#             'net': net.state_dict(),
#             'acc': acc,
#             'epoch': epoch,
#         }
#         if not os.path.isdir('checkpoint'):
#             os.mkdir('checkpoint')
#         torch.save(state, './checkpoint/ckpt.pth')
#         best_acc = acc


for epoch in range(start_epoch, start_epoch+170):
    epoch_list.append(epoch)
    train(epoch)
    test(epoch)
# Out:
# ==> Preparing data..
# Files already downloaded and verified
# Files already downloaded and verified
# ==> Building model..
#
# Epoch: 0
# corrupt_loss 15464.679995417595 1209.4400079250336
# true loss 71016.23705005646 617.195858836174
# Train loss of full data 86480.91597366333 676.1586798429489
# total_corrupt, total_true and total_data respectively are :   5000 45000 50000
# Train accuracy on corrupted train-data 0.0926
# Train accuracy on un-corrupted train-data 0.43233333333333335
# Train accuracy on full train-data  0.39836
# test accuracy  0.5088 137.9361857175827
#
# Epoch: 1
# corrupt_loss 16828.213594198227 1314.8855493068695
# true loss 55244.09697389603 479.9511198401451
# Train loss of full data 72072.31063652039 563.5409697294235
# total_corrupt, total_true and total_data respectively are :   5000 45000 50000
# Train accuracy on corrupted train-data 0.099
# Train accuracy on un-corrupted train-data 0.5731555555555555
# Train accuracy on full train-data  0.52574
# test accuracy  0.5648 124.18820321559906
#
# Epoch: 2
# corrupt_loss 17023.988381147385 1330.1565862894058
# true loss 47645.022448301315 413.85342395305634
# Train loss of full data 64669.01000595093 505.6520035266876
# total_corrupt, total_true and total_data respectively are :   5000 45000 50000
# Train accuracy on corrupted train-data 0.1134
# Train accuracy on un-corrupted train-data 0.6390666666666667
# Train accuracy on full train-data  0.5865
# test accuracy  0.5847 119.31954860687256
#
# Epoch: 3
# corrupt_loss 16889.55519402027 1318.73801279068
# true loss 42281.24592936039 367.1915384531021
# Train loss of full data 59170.80147743225 462.6367076039314
# total_corrupt, total_true and total_data respectively are :   5000 45000 50000
# Train accuracy on corrupted train-data 0.1226
# Train accuracy on un-corrupted train-data 0.6839333333333333
# Train accuracy on full train-data  0.6278
# test accuracy  0.6001 118.91031628847122
#
# Epoch: 4
# corrupt_loss 16525.019451260567 1289.2420312166214
# true loss 38103.737851560116 330.9096581339836
# Train loss of full data 54628.75726509094 427.1261396408081
# total_corrupt, total_true and total_data respectively are :   5000 45000 50000
# Train accuracy on corrupted train-data 0.135
# Train accuracy on un-corrupted train-data 0.7181111111111111
# Train accuracy on full train-data  0.6598
# test accuracy  0.6053 117.90393698215485
#
# Epoch: 5
# corrupt_loss 15910.40663766861 1239.845483660698
# true loss 34758.51506602764 301.84958612918854
# Train loss of full data 50668.92157649994 396.1597846150398
# total_corrupt, total_true and total_data respectively are :   5000 45000 50000
# Train accuracy on corrupted train-data 0.1552
# Train accuracy on un-corrupted train-data 0.7433777777777778
# Train accuracy on full train-data  0.68456
# test accuracy  0.6024 120.56876689195633
#
# Epoch: 6
# corrupt_loss 15441.144167423248 1204.3335361480713
# true loss 32316.43709206581 280.70733404159546
# Train loss of full data 47757.58133792877 373.35383599996567
# total_corrupt, total_true and total_data respectively are :   5000 45000 50000
# Train accuracy on corrupted train-data 0.1696
# Train accuracy on un-corrupted train-data 0.7623777777777778
# Train accuracy on full train-data  0.7031
# test accuracy  0.6024 124.08429753780365
#
# Epoch: 7
# corrupt_loss 14719.181820631027 1146.961216211319
# true loss 30004.270055890083 260.59497660398483
# Train loss of full data 44723.45177650452 349.6575826406479
# total_corrupt, total_true and total_data respectively are :   5000 45000 50000
# Train accuracy on corrupted train-data 0.1906
# Train accuracy on un-corrupted train-data 0.7766444444444445
# Train accuracy on full train-data  0.71804
# test accuracy  0.6056 123.17694479227066
#
# Epoch: 8
# corrupt_loss 13943.459766745567 1088.086893439293
# true loss 27841.55074429512 241.7688348889351
# Train loss of full data 41785.010663986206 326.639097571373
# total_corrupt, total_true and total_data respectively are :   5000 45000 50000
# Train accuracy on corrupted train-data 0.2174
# Train accuracy on un-corrupted train-data 0.7952888888888889
# Train accuracy on full train-data  0.7375
# test accuracy  0.5989 128.88198900222778
#
# Epoch: 9
# corrupt_loss 13243.720415711403 1034.9419839382172
# true loss 26212.599624961615 227.61499187350273
# Train loss of full data 39456.32006072998 308.44030660390854
# total_corrupt, total_true and total_data respectively are :   5000 45000 50000
# Train accuracy on corrupted train-data 0.2436
# Train accuracy on un-corrupted train-data 0.8073555555555556
# Train accuracy on full train-data  0.75098
# test accuracy  0.5976 131.1329836845398
#
# Epoch: 10
# corrupt_loss 12288.315083801746 956.937892973423
# true loss 24371.182155519724 211.65201312303543
# Train loss of full data 36659.4971370697 286.59665301442146
# total_corrupt, total_true and total_data respectively are :   5000 45000 50000
# Train accuracy on corrupted train-data 0.2764
# Train accuracy on un-corrupted train-data 0.8194666666666667
# Train accuracy on full train-data  0.76516
# test accuracy  0.6011 135.0918914079666
#
# Epoch: 11
# corrupt_loss 11578.262217104435 898.1331289410591
# true loss 22812.464182972908 198.0613795220852
# Train loss of full data 34390.726390361786 268.8217912018299
# total_corrupt, total_true and total_data respectively are :   5000 45000 50000
# Train accuracy on corrupted train-data 0.3062
# Train accuracy on un-corrupted train-data 0.8305111111111111
# Train accuracy on full train-data  0.77808
# test accuracy  0.5931 140.73654961585999
#
# Epoch: 12
# corrupt_loss 10809.995600938797 843.6111671924591
# true loss 21079.610827326775 183.01820582151413
# Train loss of full data 31889.60667514801 249.30334120988846
# total_corrupt, total_true and total_data respectively are :   5000 45000 50000
# Train accuracy on corrupted train-data 0.3404
# Train accuracy on un-corrupted train-data 0.8455555555555555
# Train accuracy on full train-data  0.79504
# test accuracy  0.5918 145.5871958732605
#
# Epoch: 13
# corrupt_loss 10120.256716549397 788.8961101770401
# true loss 19769.582381665707 171.66123667359352
# Train loss of full data 29889.839175224304 233.6604706943035
# total_corrupt, total_true and total_data respectively are :   5000 45000 50000
# Train accuracy on corrupted train-data 0.3622
# Train accuracy on un-corrupted train-data 0.8518444444444444
# Train accuracy on full train-data  0.80288
# test accuracy  0.6018 145.04965221881866
#
# Epoch: 14
# corrupt_loss 9074.549192547798 705.0399498939514
# true loss 18410.220960199833 159.90450656414032
# Train loss of full data 27484.770109653473 214.84327042102814
# total_corrupt, total_true and total_data respectively are :   5000 45000 50000
# Train accuracy on corrupted train-data 0.4144
# Train accuracy on un-corrupted train-data 0.8614888888888889
# Train accuracy on full train-data  0.81678
# test accuracy  0.5972 149.91050720214844
#
# Epoch: 15
# corrupt_loss 8428.418533682823 654.2096436917782
# true loss 17361.44033525884 150.7270433306694
# Train loss of full data 25789.859005451202 201.59597826004028
# total_corrupt, total_true and total_data respectively are :   5000 45000 50000
# Train accuracy on corrupted train-data 0.4526
# Train accuracy on un-corrupted train-data 0.8680444444444444
# Train accuracy on full train-data  0.8265
# test accuracy  0.5967 153.9835946559906
#
# Epoch: 16
# corrupt_loss 7831.87514141202 610.2408538758755
# true loss 16169.079568430781 140.42466373741627
# Train loss of full data 24000.954540729523 187.61304645240307
# total_corrupt, total_true and total_data respectively are :   5000 45000 50000
# Train accuracy on corrupted train-data 0.481
# Train accuracy on un-corrupted train-data 0.8796
# Train accuracy on full train-data  0.83974
# test accuracy  0.5903 158.77428168058395
#
# Epoch: 17
# corrupt_loss 6928.1912115216255 538.5528041422367
# true loss 14653.133597880602 127.20504027605057
# Train loss of full data 21581.32483625412 168.68651941418648
# total_corrupt, total_true and total_data respectively are :   5000 45000 50000
# Train accuracy on corrupted train-data 0.5244
# Train accuracy on un-corrupted train-data 0.8896888888888889
# Train accuracy on full train-data  0.85316
# test accuracy  0.6062 161.16914796829224
#
# Epoch: 18
# corrupt_loss 6417.062927946448 499.42024667561054
# true loss 14342.289668753743 124.5276674926281
# Train loss of full data 20759.352716207504 162.27410367131233
# total_corrupt, total_true and total_data respectively are :   5000 45000 50000
# Train accuracy on corrupted train-data 0.5596
# Train accuracy on un-corrupted train-data 0.8904222222222222
# Train accuracy on full train-data  0.85734
# test accuracy  0.6025 160.64180147647858
#
# Epoch: 19
# corrupt_loss 5852.063988223672 454.50213661789894
# true loss 13075.820857256651 113.53794625401497
# Train loss of full data 18927.8848361969 147.93938891589642
# total_corrupt, total_true and total_data respectively are :   5000 45000 50000
# Train accuracy on corrupted train-data 0.5916
# Train accuracy on un-corrupted train-data 0.8996222222222222
# Train accuracy on full train-data  0.86882
# test accuracy  0.5976 171.2879478931427
#
# Epoch: 20
# corrupt_loss 5359.30103610456 417.0812587887049
# true loss 12672.419258266687 110.071756914258
# Train loss of full data 18031.720479011536 140.9789177030325
# total_corrupt, total_true and total_data respectively are :   5000 45000 50000
# Train accuracy on corrupted train-data 0.6222
# Train accuracy on un-corrupted train-data 0.9026666666666666
# Train accuracy on full train-data  0.87462
# test accuracy  0.5992 170.36347007751465
#
# Epoch: 21
# corrupt_loss 5129.16480704397 398.9120542779565
# true loss 11831.324092201889 102.7635647431016
# Train loss of full data 16960.488834381104 132.5632905215025
# total_corrupt, total_true and total_data respectively are :   5000 45000 50000
# Train accuracy on corrupted train-data 0.6366
# Train accuracy on un-corrupted train-data 0.9093777777777777
# Train accuracy on full train-data  0.8821
# test accuracy  0.6085 167.55450224876404
#
# Epoch: 22
# corrupt_loss 4575.130750209093 355.8860113918781
# true loss 11265.498006880283 97.767439506948
# Train loss of full data 15840.628759145737 123.80622889101505
# total_corrupt, total_true and total_data respectively are :   5000 45000 50000
# Train accuracy on corrupted train-data 0.6746
# Train accuracy on un-corrupted train-data 0.9158666666666667
# Train accuracy on full train-data  0.89174
# test accuracy  0.5984 173.34721982479095
#
# Epoch: 23
# corrupt_loss 4246.533965587616 330.3381771892309
# true loss 10449.347333580256 90.76523930579424
# Train loss of full data 14695.881296157837 114.92617626488209
# total_corrupt, total_true and total_data respectively are :   5000 45000 50000
# Train accuracy on corrupted train-data 0.7004
# Train accuracy on un-corrupted train-data 0.9212222222222223
# Train accuracy on full train-data  0.89914
# test accuracy  0.6002 179.3733389377594
#
# Epoch: 24
# corrupt_loss 3924.6276035904884 308.64307329058647
# true loss 9920.331772498786 86.12931419909
# Train loss of full data 13844.959465742111 108.23669403791428
# total_corrupt, total_true and total_data respectively are :   5000 45000 50000
# Train accuracy on corrupted train-data 0.718
# Train accuracy on un-corrupted train-data 0.9237333333333333
# Train accuracy on full train-data  0.90316
# test accuracy  0.6086 179.716934800148
#
# Epoch: 25
# corrupt_loss 3541.696762301028 276.37271047383547
# true loss 9150.827003575861 79.4930550083518
# Train loss of full data 12692.523683071136 99.22650349140167
# total_corrupt, total_true and total_data respectively are :   5000 45000 50000
# Train accuracy on corrupted train-data 0.751
# Train accuracy on un-corrupted train-data 0.9306444444444445
# Train accuracy on full train-data  0.91268
# test accuracy  0.6081 183.4784473180771
#
# Epoch: 26
# corrupt_loss 3502.5124686434865 274.6574829220772
# true loss 9109.31605682522 79.09926868975163
# Train loss of full data 12611.828498125076 98.62151806801558
# total_corrupt, total_true and total_data respectively are :   5000 45000 50000
# Train accuracy on corrupted train-data 0.7468
# Train accuracy on un-corrupted train-data 0.9314888888888889
# Train accuracy on full train-data  0.91302
# test accuracy  0.6017 189.81637966632843
#
# Epoch: 27
# corrupt_loss 3311.677904319018 255.798577491194
# true loss 8715.294058457017 75.70755183696747
# Train loss of full data 12026.971997022629 94.00393961369991
# total_corrupt, total_true and total_data respectively are :   5000 45000 50000
# Train accuracy on corrupted train-data 0.766
# Train accuracy on un-corrupted train-data 0.9340666666666667
# Train accuracy on full train-data  0.91726
# test accuracy  0.5944 192.00978922843933
#
# Epoch: 28
# corrupt_loss 3078.5313305035233 240.78203179687262
# true loss 7894.256932687014 68.55822685733438
# Train loss of full data 10972.788305282593 85.7850347533822
# total_corrupt, total_true and total_data respectively are :   5000 45000 50000
# Train accuracy on corrupted train-data 0.7824
# Train accuracy on un-corrupted train-data 0.9392888888888888
# Train accuracy on full train-data  0.9236
# test accuracy  0.6146 182.6640272140503
#
# Epoch: 29
# corrupt_loss 3005.2398321703076 236.06105994805694
# true loss 7943.978910226375 69.01302599534392
# Train loss of full data 10949.218694448471 85.600093126297
# total_corrupt, total_true and total_data respectively are :   5000 45000 50000
# Train accuracy on corrupted train-data 0.782
# Train accuracy on un-corrupted train-data 0.9408
# Train accuracy on full train-data  0.92492
# test accuracy  0.6071 187.53393507003784
#
# Epoch: 30
# corrupt_loss 2907.399514036253 226.7768071582541
# true loss 7312.901882492006 63.52122646570206
# Train loss of full data 10220.30139374733 79.89059393107891
# total_corrupt, total_true and total_data respectively are :   5000 45000 50000
# Train accuracy on corrupted train-data 0.792
# Train accuracy on un-corrupted train-data 0.9438888888888889
# Train accuracy on full train-data  0.9287
# test accuracy  0.6066 189.76346373558044
#
# Epoch: 31
# corrupt_loss 2798.245124064386 218.44272277131677
# true loss 7373.547889411449 64.06218204647303
# Train loss of full data 10171.792932271957 79.5274592936039
# total_corrupt, total_true and total_data respectively are :   5000 45000 50000
# Train accuracy on corrupted train-data 0.7974
# Train accuracy on un-corrupted train-data 0.9438888888888889
# Train accuracy on full train-data  0.92924
# test accuracy  0.6134 188.30618125200272
#
# Epoch: 32
# corrupt_loss 2928.26566988416 227.2806881275028
# true loss 7285.031966794282 63.196062948554754
# Train loss of full data 10213.297681093216 79.81896743923426
# total_corrupt, total_true and total_data respectively are :   5000 45000 50000
# Train accuracy on corrupted train-data 0.7916
# Train accuracy on un-corrupted train-data 0.9443777777777778
# Train accuracy on full train-data  0.9291
# test accuracy  0.6109 186.7233043909073
#
# Epoch: 33
# corrupt_loss 2439.2278747102246 188.29120611120015
# true loss 6503.465902000666 56.495659060776234
# Train loss of full data 8942.69390821457 69.92321376502514
# total_corrupt, total_true and total_data respectively are :   5000 45000 50000
# Train accuracy on corrupted train-data 0.8278
# Train accuracy on un-corrupted train-data 0.9503555555555555
# Train accuracy on full train-data  0.9381
# test accuracy  0.6128 191.95585691928864
#
# Epoch: 34
# corrupt_loss 2351.29555779323 183.6571399755776
# true loss 6613.580738991499 57.40521142631769
# Train loss of full data 8964.876311898232 70.07480446621776
# total_corrupt, total_true and total_data respectively are :   5000 45000 50000
# Train accuracy on corrupted train-data 0.8306
# Train accuracy on un-corrupted train-data 0.9506222222222223
# Train accuracy on full train-data  0.93862
# test accuracy  0.5988 199.8862625360489
#
# Epoch: 35
# corrupt_loss 2573.1832401305437 202.1227620318532
# true loss 6671.6952095627785 57.94154879823327
# Train loss of full data 9244.878437519073 72.27369666472077
# total_corrupt, total_true and total_data respectively are :   5000 45000 50000
# Train accuracy on corrupted train-data 0.8136
# Train accuracy on un-corrupted train-data 0.9486222222222223
# Train accuracy on full train-data  0.93512
# test accuracy  0.6114 191.78275501728058
#
# Epoch: 36
# corrupt_loss 2349.382354753092 184.70504608936608
# true loss 6286.438656285405 54.56336345896125
# Train loss of full data 8635.820934176445 67.50815483182669
# total_corrupt, total_true and total_data respectively are :   5000 45000 50000
# Train accuracy on corrupted train-data 0.8334
# Train accuracy on un-corrupted train-data 0.9529555555555556
# Train accuracy on full train-data  0.941
# test accuracy  0.6213 186.76568639278412
#
# Epoch: 37
# corrupt_loss 2142.5341200754046 166.47495155781507
# true loss 5790.422327727079 50.330908104777336
# Train loss of full data 7932.956436872482 62.01875648275018
# total_corrupt, total_true and total_data respectively are :   5000 45000 50000
# Train accuracy on corrupted train-data 0.8512
# Train accuracy on un-corrupted train-data 0.9550888888888889
# Train accuracy on full train-data  0.9447
# test accuracy  0.6098 192.7375636100769
#
# Epoch: 38
# corrupt_loss 2208.919208770618 173.1455070208758
# true loss 5785.496846064925 50.256285928189754
# Train loss of full data 7994.416089177132 62.48945162817836
# total_corrupt, total_true and total_data respectively are :   5000 45000 50000
# Train accuracy on corrupted train-data 0.8416
# Train accuracy on un-corrupted train-data 0.9559333333333333
# Train accuracy on full train-data  0.9445
# test accuracy  0.6202 196.55206048488617
#
# Epoch: 39
# corrupt_loss 2346.6828653318807 185.2316752159968
# true loss 6289.15094345808 54.65157479047775
# Train loss of full data 8635.833714485168 67.60406322032213
# total_corrupt, total_true and total_data respectively are :   5000 45000 50000
# Train accuracy on corrupted train-data 0.8368
# Train accuracy on un-corrupted train-data 0.9524
# Train accuracy on full train-data  0.94084
# test accuracy  0.6179 194.60935628414154
#
# Epoch: 40
# corrupt_loss 2271.9592510797083 177.0652815774083
# true loss 5827.888295929879 50.61768615245819
# Train loss of full data 8099.847553491592 63.309012077748775
# total_corrupt, total_true and total_data respectively are :   5000 45000 50000
# Train accuracy on corrupted train-data 0.8366
# Train accuracy on un-corrupted train-data 0.9561777777777778
# Train accuracy on full train-data  0.94422
# test accuracy  0.6236 187.78022134304047
#
# Epoch: 41
# corrupt_loss 2026.7198968566954 160.45997604355216
# true loss 5727.635005250573 49.76213367655873
# Train loss of full data 7754.355029821396 60.615398690104485
# total_corrupt, total_true and total_data respectively are :   5000 45000 50000
# Train accuracy on corrupted train-data 0.855
# Train accuracy on un-corrupted train-data 0.9563777777777778
# Train accuracy on full train-data  0.94624
# test accuracy  0.626 190.72574174404144
#
# Epoch: 42
# corrupt_loss 2132.125257602893 166.20921972487122
# true loss 5707.483239080757 49.54700927063823
# Train loss of full data 7839.608446478844 61.29051936045289
# total_corrupt, total_true and total_data respectively are :   5000 45000 50000
# Train accuracy on corrupted train-data 0.8508
# Train accuracy on un-corrupted train-data 0.9577111111111111
# Train accuracy on full train-data  0.94702
# test accuracy  0.6204 189.6721851825714
#
# Epoch: 43
# corrupt_loss 2151.286742148921 168.02497368957847
# true loss 5955.39027063176 51.73634937405586
# Train loss of full data 8106.676827907562 63.37341397628188
# total_corrupt, total_true and total_data respectively are :   5000 45000 50000
# Train accuracy on corrupted train-data 0.8464
# Train accuracy on un-corrupted train-data 0.9561333333333333
# Train accuracy on full train-data  0.94516
# test accuracy  0.6226 187.63189601898193
#
# Epoch: 44
# corrupt_loss 2165.1391356922686 171.73548779822886
# true loss 6062.649061534554 52.6515528857708
# Train loss of full data 8227.788224577904 64.32351306453347
# total_corrupt, total_true and total_data respectively are :   5000 45000 50000
# Train accuracy on corrupted train-data 0.8496
# Train accuracy on un-corrupted train-data 0.9544666666666667
# Train accuracy on full train-data  0.94398
# test accuracy  0.617 194.25866067409515
#
# Epoch: 45
# corrupt_loss 2110.932535144035 162.83923701988533
# true loss 5367.806148424745 46.645266368985176
# Train loss of full data 7478.738640785217 58.49778861552477
# total_corrupt, total_true and total_data respectively are :   5000 45000 50000
# Train accuracy on corrupted train-data 0.8466
# Train accuracy on un-corrupted train-data 0.9599333333333333
# Train accuracy on full train-data  0.9486
# test accuracy  0.6207 192.09530198574066
#
# Epoch: 46
# corrupt_loss 1881.1968406541273 147.963051664643
# true loss 5149.5523004718125 44.80754649825394
# Train loss of full data 7030.749165058136 54.99871064722538
# total_corrupt, total_true and total_data respectively are :   5000 45000 50000
# Train accuracy on corrupted train-data 0.8706
# Train accuracy on un-corrupted train-data 0.9614
# Train accuracy on full train-data  0.95232
# test accuracy  0.624 194.2909051179886
#
# Epoch: 47
# corrupt_loss 2093.5710455607623 164.42050695978105
# true loss 5790.303160071373 50.314053166657686
# Train loss of full data 7883.874178171158 61.64974705502391
# total_corrupt, total_true and total_data respectively are :   5000 45000 50000
# Train accuracy on corrupted train-data 0.8512
# Train accuracy on un-corrupted train-data 0.9560888888888889
# Train accuracy on full train-data  0.9456
# test accuracy  0.6211 190.76002252101898
#
# Epoch: 48
# corrupt_loss 2358.0161654772237 179.97497531864792
# true loss 6440.01732186228 55.9694563485682
# Train loss of full data 8798.033487796783 68.76926150545478
# total_corrupt, total_true and total_data respectively are :   5000 45000 50000
# Train accuracy on corrupted train-data 0.8348
# Train accuracy on un-corrupted train-data 0.9519777777777778
# Train accuracy on full train-data  0.94026
# test accuracy  0.6244 187.42404222488403
#
# Epoch: 49
# corrupt_loss 1921.6121336109936 150.09554729796946
# true loss 5277.10278734006 45.80682902596891
# Train loss of full data 7198.714878082275 56.28459167480469
# total_corrupt, total_true and total_data respectively are :   5000 45000 50000
# Train accuracy on corrupted train-data 0.8634
# Train accuracy on un-corrupted train-data 0.9602888888888889
# Train accuracy on full train-data  0.9506
# test accuracy  0.6322 185.8721318244934
#
# Epoch: 50
# corrupt_loss 1831.4156999420375 143.12519359774888
# true loss 4943.986803073436 42.91778087988496
# Train loss of full data 6775.402466535568 52.95950287953019
# total_corrupt, total_true and total_data respectively are :   5000 45000 50000
# Train accuracy on corrupted train-data 0.8718
# Train accuracy on un-corrupted train-data 0.9631333333333333
# Train accuracy on full train-data  0.954
# test accuracy  0.6246 190.9285351037979
#
# Epoch: 51
# corrupt_loss 1873.8169641681015 146.29794541560113
# true loss 5087.84821036458 44.174570184201
# Train loss of full data 6961.6651775836945 54.423657193779945
# total_corrupt, total_true and total_data respectively are :   5000 45000 50000
# Train accuracy on corrupted train-data 0.8656
# Train accuracy on un-corrupted train-data 0.9612666666666667
# Train accuracy on full train-data  0.9517
# test accuracy  0.6265 193.27197587490082
#
# Epoch: 52
# corrupt_loss 2115.497119870037 166.46662969328463
# true loss 5771.775146178901 50.086513850837946
# Train loss of full data 7887.272287726402 61.64718500897288
# total_corrupt, total_true and total_data respectively are :   5000 45000 50000
# Train accuracy on corrupted train-data 0.8534
# Train accuracy on un-corrupted train-data 0.9555555555555556
# Train accuracy on full train-data  0.94534
# test accuracy  0.634 184.94394755363464
#
# Epoch: 53
# corrupt_loss 2105.7899794671685 167.51319347135723
# true loss 5540.8787605166435 48.11808659136295
# Train loss of full data 7646.668835401535 59.784821309149265
# total_corrupt, total_true and total_data respectively are :   5000 45000 50000
# Train accuracy on corrupted train-data 0.8566
# Train accuracy on un-corrupted train-data 0.958
# Train accuracy on full train-data  0.94786
# test accuracy  0.6252 185.10960054397583
#
# Epoch: 54
# corrupt_loss 1768.8482770733535 137.04588951915503
# true loss 4878.0237343180925 42.376500675454736
# Train loss of full data 6646.872024774551 51.95760476216674
# total_corrupt, total_true and total_data respectively are :   5000 45000 50000
# Train accuracy on corrupted train-data 0.8764
# Train accuracy on un-corrupted train-data 0.9629555555555556
# Train accuracy on full train-data  0.9543
# test accuracy  0.636 188.70424115657806
#
# Epoch: 55
# corrupt_loss 2058.207650459837 158.13515016576275
# true loss 5522.472826253623 47.990526005625725
# Train loss of full data 7580.680474281311 59.25953059643507
# total_corrupt, total_true and total_data respectively are :   5000 45000 50000
# Train accuracy on corrupted train-data 0.8562
# Train accuracy on un-corrupted train-data 0.9586666666666667
# Train accuracy on full train-data  0.94842
# test accuracy  0.631 183.40569758415222
#
# Epoch: 56
# corrupt_loss 2068.9125104588456 161.48026974545792
# true loss 5519.752644944936 47.94215661659837
# Train loss of full data 7588.665153980255 59.34085354954004
# total_corrupt, total_true and total_data respectively are :   5000 45000 50000
# Train accuracy on corrupted train-data 0.852
# Train accuracy on un-corrupted train-data 0.9582222222222222
# Train accuracy on full train-data  0.9476
# test accuracy  0.6296 183.1718007326126
#
# Epoch: 57
# corrupt_loss 1900.169332598336 146.86109017394483
# true loss 5138.766112763435 44.65645554289222
# Train loss of full data 7038.935405254364 55.05277721583843
# total_corrupt, total_true and total_data respectively are :   5000 45000 50000
# Train accuracy on corrupted train-data 0.862
# Train accuracy on un-corrupted train-data 0.9609111111111112
# Train accuracy on full train-data  0.95102
# test accuracy  0.638 180.27992314100266
#
# Epoch: 58
# corrupt_loss 1807.625575054437 140.26377292908728
# true loss 5048.270822696388 43.84933393076062
# Train loss of full data 6855.896447181702 53.61432382464409
# total_corrupt, total_true and total_data respectively are :   5000 45000 50000
# Train accuracy on corrupted train-data 0.8688
# Train accuracy on un-corrupted train-data 0.9616666666666667
# Train accuracy on full train-data  0.95238
# test accuracy  0.6351 185.64742875099182
#
# Epoch: 59
# corrupt_loss 1898.9422169411555 147.46681365650147
# true loss 4950.256363581866 43.016141725704074
# Train loss of full data 6849.198523640633 53.55263240635395
# total_corrupt, total_true and total_data respectively are :   5000 45000 50000
# Train accuracy on corrupted train-data 0.87
# Train accuracy on un-corrupted train-data 0.9634666666666667
# Train accuracy on full train-data  0.95412
# test accuracy  0.6402 183.4659892320633
#
# Epoch: 60
# corrupt_loss 2084.888771560043 160.81600196566433
# true loss 5670.691043909639 49.20073106698692
# Train loss of full data 7755.579809188843 60.630141511559486
# total_corrupt, total_true and total_data respectively are :   5000 45000 50000
# Train accuracy on corrupted train-data 0.8574
# Train accuracy on un-corrupted train-data 0.9579111111111112
# Train accuracy on full train-data  0.94786
# test accuracy  0.6369 182.72199523448944
#
# Epoch: 61
# corrupt_loss 1970.6494495905936 151.20551270619035
# true loss 5473.681152764708 47.55908624082804
# Train loss of full data 7444.33056473732 58.18444385007024
# total_corrupt, total_true and total_data respectively are :   5000 45000 50000
# Train accuracy on corrupted train-data 0.8588
# Train accuracy on un-corrupted train-data 0.9601111111111111
# Train accuracy on full train-data  0.94998
# test accuracy  0.6387 178.6756585240364
#
# Epoch: 62
# corrupt_loss 1771.2650384381413 138.95665620453656
# true loss 4927.884917002171 42.86223313957453
# Train loss of full data 6699.150002837181 52.375775549560785
# total_corrupt, total_true and total_data respectively are :   5000 45000 50000
# Train accuracy on corrupted train-data 0.8752
# Train accuracy on un-corrupted train-data 0.9628666666666666
# Train accuracy on full train-data  0.9541
# test accuracy  0.6329 184.14669132232666
#
# Epoch: 63
# corrupt_loss 1711.6771822539158 134.13254037639126
# true loss 4639.681744210422 40.305499674752355
# Train loss of full data 6351.3588790893555 49.64256992191076
# total_corrupt, total_true and total_data respectively are :   5000 45000 50000
# Train accuracy on corrupted train-data 0.8804
# Train accuracy on un-corrupted train-data 0.9663555555555555
# Train accuracy on full train-data  0.95776
# test accuracy  0.6358 185.1511298418045
#
# Epoch: 64
# corrupt_loss 1745.3405469302088 136.29299565404654
# true loss 4812.2892229724675 41.77103446982801
# Train loss of full data 6557.629744410515 51.2642525434494
# total_corrupt, total_true and total_data respectively are :   5000 45000 50000
# Train accuracy on corrupted train-data 0.8778
# Train accuracy on un-corrupted train-data 0.9637111111111111
# Train accuracy on full train-data  0.95512
# test accuracy  0.6309 189.48628544807434
#
# Epoch: 65
# corrupt_loss 2494.0383056290448 196.45076017081738
# true loss 6340.0774988383055 55.041343953460455
# Train loss of full data 8834.115780115128 69.07526024803519
# total_corrupt, total_true and total_data respectively are :   5000 45000 50000
# Train accuracy on corrupted train-data 0.8334
# Train accuracy on un-corrupted train-data 0.9508
# Train accuracy on full train-data  0.93906
# test accuracy  0.6335 178.60515582561493
#
# Epoch: 66
# corrupt_loss 2099.3738661576062 162.30059795174748
# true loss 5654.717790938914 49.15343622863293
# Train loss of full data 7754.091693162918 60.622376315295696
# total_corrupt, total_true and total_data respectively are :   5000 45000 50000
# Train accuracy on corrupted train-data 0.848
# Train accuracy on un-corrupted train-data 0.9572222222222222
# Train accuracy on full train-data  0.9463
# test accuracy  0.6282 185.20068669319153
#
# Epoch: 67
# corrupt_loss 1568.8322652648203 122.05564897367731
# true loss 4446.2101415563375 38.59057585708797
# Train loss of full data 6015.042389154434 47.0213204883039
# total_corrupt, total_true and total_data respectively are :   5000 45000 50000
# Train accuracy on corrupted train-data 0.8862
# Train accuracy on un-corrupted train-data 0.9666888888888889
# Train accuracy on full train-data  0.95864
# test accuracy  0.6339 188.80323737859726
#
# Epoch: 68
# corrupt_loss 1587.588359751273 122.90953052858822
# true loss 4423.441582323983 38.391116147860885
# Train loss of full data 6011.0299680233 46.99684473127127
# total_corrupt, total_true and total_data respectively are :   5000 45000 50000
# Train accuracy on corrupted train-data 0.887
# Train accuracy on un-corrupted train-data 0.9681111111111111
# Train accuracy on full train-data  0.96
# test accuracy  0.6347 190.5042815208435
#
# Epoch: 69
# corrupt_loss 1964.4182277517393 154.5248531801626
# true loss 5586.295119103044 48.51058295369148
# Train loss of full data 7550.713390827179 59.03337248042226
# total_corrupt, total_true and total_data respectively are :   5000 45000 50000
# Train accuracy on corrupted train-data 0.8646
# Train accuracy on un-corrupted train-data 0.9574888888888888
# Train accuracy on full train-data  0.9482
# test accuracy  0.6227 188.75642496347427
#
# Epoch: 70
# corrupt_loss 2485.3472551964223 194.65687043964863
# true loss 6385.464239072055 55.472272131592035
# Train loss of full data 8870.811500549316 69.3283094279468
# total_corrupt, total_true and total_data respectively are :   5000 45000 50000
# Train accuracy on corrupted train-data 0.8334
# Train accuracy on un-corrupted train-data 0.9519777777777778
# Train accuracy on full train-data  0.94012
# test accuracy  0.6352 179.6688438653946
#
# Epoch: 71
# corrupt_loss 1956.1836626566947 152.1012890804559
# true loss 5294.00861428678 46.01391324400902
# Train loss of full data 7250.192298769951 56.6828653588891
# total_corrupt, total_true and total_data respectively are :   5000 45000 50000
# Train accuracy on corrupted train-data 0.8592
# Train accuracy on un-corrupted train-data 0.9599777777777778
# Train accuracy on full train-data  0.9499
# test accuracy  0.6382 182.3841736316681
#
# Epoch: 72
# corrupt_loss 1637.8172889919952 126.32533132843673
# true loss 4603.961557466537 39.97342684492469
# Train loss of full data 6241.778814792633 48.787867065519094
# total_corrupt, total_true and total_data respectively are :   5000 45000 50000
# Train accuracy on corrupted train-data 0.882
# Train accuracy on un-corrupted train-data 0.9664222222222222
# Train accuracy on full train-data  0.95798
# test accuracy  0.6439 183.53719627857208
#
# Epoch: 73
# corrupt_loss 1677.5076643638313 131.0612235609442
# true loss 4509.699048852548 39.171379048377275
# Train loss of full data 6187.206752181053 48.36603823304176
# total_corrupt, total_true and total_data respectively are :   5000 45000 50000
# Train accuracy on corrupted train-data 0.878
# Train accuracy on un-corrupted train-data 0.9665111111111111
# Train accuracy on full train-data  0.95766
# test accuracy  0.6378 186.3834969997406
#
# Epoch: 74
# corrupt_loss 1999.8451719218865 154.65064911730587
# true loss 5241.051907263696 45.48040531389415
# Train loss of full data 7240.897080421448 56.5982550829649
# total_corrupt, total_true and total_data respectively are :   5000 45000 50000
# Train accuracy on corrupted train-data 0.859
# Train accuracy on un-corrupted train-data 0.9606222222222223
# Train accuracy on full train-data  0.95046
# test accuracy  0.6432 183.994926571846
#
# Epoch: 75
# corrupt_loss 2045.5894951708615 160.98394307494164
# true loss 5505.88738649711 47.81509802117944
# Train loss of full data 7551.476856470108 59.04648230969906
# total_corrupt, total_true and total_data respectively are :   5000 45000 50000
# Train accuracy on corrupted train-data 0.8498
# Train accuracy on un-corrupted train-data 0.9582222222222222
# Train accuracy on full train-data  0.94738
# test accuracy  0.6233 190.8337038755417
#
# Epoch: 76
# corrupt_loss 2162.910659697838 166.67427500057966
# true loss 5476.4722780920565 47.5643388107419
# Train loss of full data 7639.382905900478 59.69152796640992
# total_corrupt, total_true and total_data respectively are :   5000 45000 50000
# Train accuracy on corrupted train-data 0.8524
# Train accuracy on un-corrupted train-data 0.9591333333333333
# Train accuracy on full train-data  0.94846
# test accuracy  0.6363 183.2390285730362
#
# Epoch: 77
# corrupt_loss 1828.3165612164885 141.4097583172843
# true loss 5167.397185729817 44.93354762531817
# Train loss of full data 6995.71372461319 54.74147476628423
# total_corrupt, total_true and total_data respectively are :   5000 45000 50000
# Train accuracy on corrupted train-data 0.8748
# Train accuracy on un-corrupted train-data 0.9623555555555555
# Train accuracy on full train-data  0.9536
# test accuracy  0.6452 174.90541642904282
#
# Epoch: 78
# corrupt_loss 1804.6232831776142 141.2990932930261
# true loss 4632.848654519767 40.195718232542276
# Train loss of full data 6437.471932888031 50.31150649860501
# total_corrupt, total_true and total_data respectively are :   5000 45000 50000
# Train accuracy on corrupted train-data 0.874
# Train accuracy on un-corrupted train-data 0.9651777777777778
# Train accuracy on full train-data  0.95606
# test accuracy  0.6371 185.82044327259064
#
# Epoch: 79
# corrupt_loss 1691.521107034292 132.10915364837274
# true loss 4551.366267371923 39.56399217620492
# Train loss of full data 6242.887336850166 48.79789212718606
# total_corrupt, total_true and total_data respectively are :   5000 45000 50000
# Train accuracy on corrupted train-data 0.8848
# Train accuracy on un-corrupted train-data 0.9659333333333333
# Train accuracy on full train-data  0.95782
# test accuracy  0.6356 184.21993815898895
#
# Epoch: 80
# corrupt_loss 1876.484782602638 144.1372383814305
# true loss 5035.224662903696 43.711756996810436
# Train loss of full data 6911.709487974644 54.01114830002189
# total_corrupt, total_true and total_data respectively are :   5000 45000 50000
# Train accuracy on corrupted train-data 0.8674
# Train accuracy on un-corrupted train-data 0.9622
# Train accuracy on full train-data  0.95272
# test accuracy  0.6404 182.27822124958038
#
# Epoch: 81
# corrupt_loss 2313.356449631043 179.24778885487467
# true loss 5673.669318892062 49.238445691764355
# Train loss of full data 7987.025710701942 62.428829703480005
# total_corrupt, total_true and total_data respectively are :   5000 45000 50000
# Train accuracy on corrupted train-data 0.8392
# Train accuracy on un-corrupted train-data 0.9565111111111111
# Train accuracy on full train-data  0.94478
# test accuracy  0.6444 175.99453461170197
#
# Epoch: 82
# corrupt_loss 1781.9732086583972 138.02704708185047
# true loss 4827.357320677489 41.97876316122711
# Train loss of full data 6609.330485582352 51.659992437809706
# total_corrupt, total_true and total_data respectively are :   5000 45000 50000
# Train accuracy on corrupted train-data 0.878
# Train accuracy on un-corrupted train-data 0.964
# Train accuracy on full train-data  0.9554
# test accuracy  0.6406 182.04586684703827
#
# Epoch: 83
# corrupt_loss 1526.0824545715004 116.61054834257811
# true loss 4289.922106940299 37.22789521329105
# Train loss of full data 5816.004566073418 45.467060359194875
# total_corrupt, total_true and total_data respectively are :   5000 45000 50000
# Train accuracy on corrupted train-data 0.8942
# Train accuracy on un-corrupted train-data 0.9694
# Train accuracy on full train-data  0.96188
# test accuracy  0.6417 184.68146133422852
#
# Epoch: 84
# corrupt_loss 1462.0928619122133 114.19093336444348
# true loss 4011.449448570609 34.823267394676805
# Train loss of full data 5473.542361021042 42.79474101215601
# total_corrupt, total_true and total_data respectively are :   5000 45000 50000
# Train accuracy on corrupted train-data 0.8964
# Train accuracy on un-corrupted train-data 0.9702222222222222
# Train accuracy on full train-data  0.96284
# test accuracy  0.6464 182.18430376052856
#
# Epoch: 85
# corrupt_loss 1840.9290583087131 145.4538840064779
# true loss 4752.518895626068 41.24895974062383
# Train loss of full data 6593.447951674461 51.55370135977864
# total_corrupt, total_true and total_data respectively are :   5000 45000 50000
# Train accuracy on corrupted train-data 0.8722
# Train accuracy on un-corrupted train-data 0.9642
# Train accuracy on full train-data  0.955
# test accuracy  0.6402 183.44446921348572
#
# Epoch: 86
# corrupt_loss 2796.5034853741527 217.1336736213416
# true loss 6950.077883966267 60.365684270858765
# Train loss of full data 9746.581357002258 76.20889346674085
# total_corrupt, total_true and total_data respectively are :   5000 45000 50000
# Train accuracy on corrupted train-data 0.8066
# Train accuracy on un-corrupted train-data 0.9468222222222222
# Train accuracy on full train-data  0.9328
# test accuracy  0.6358 176.2011777162552
#
# Epoch: 87
# corrupt_loss 2220.7721899040043 174.0006102193147
# true loss 6047.643072519451 52.55373911187053
# Train loss of full data 8268.41522705555 64.6213883087039
# total_corrupt, total_true and total_data respectively are :   5000 45000 50000
# Train accuracy on corrupted train-data 0.8414
# Train accuracy on un-corrupted train-data 0.9539333333333333
# Train accuracy on full train-data  0.94268
# test accuracy  0.6397 174.82101213932037
#
# Epoch: 88
# corrupt_loss 1451.9719632198103 113.42419314943254
# true loss 3998.571433737874 34.78411776013672
# Train loss of full data 5450.5433614254 42.62468521669507
# total_corrupt, total_true and total_data respectively are :   5000 45000 50000
# Train accuracy on corrupted train-data 0.8976
# Train accuracy on un-corrupted train-data 0.9711111111111111
# Train accuracy on full train-data  0.96376
# test accuracy  0.658 173.4110643863678
#
# Epoch: 89
# corrupt_loss 1031.62110623857 80.04986053751782
# true loss 3052.992295606062 26.517340722493827
# Train loss of full data 4084.613407254219 31.926961543038487
# total_corrupt, total_true and total_data respectively are :   5000 45000 50000
# Train accuracy on corrupted train-data 0.9322
# Train accuracy on un-corrupted train-data 0.9776
# Train accuracy on full train-data  0.97306
# test accuracy  0.6488 182.21454578638077
#
# Epoch: 90
# corrupt_loss 1351.300860108342 107.25769647350535
# true loss 3626.199229504913 31.47082736901939
# Train loss of full data 4977.500064253807 38.90837223082781
# total_corrupt, total_true and total_data respectively are :   5000 45000 50000
# Train accuracy on corrupted train-data 0.9084
# Train accuracy on un-corrupted train-data 0.9726
# Train accuracy on full train-data  0.96618
# test accuracy  0.6365 193.92580324411392
#
# Epoch: 91
# corrupt_loss 2586.723273771815 204.25640834961087
# true loss 6385.89831610769 55.36628086678684
# Train loss of full data 8972.62157201767 70.20138007774949
# total_corrupt, total_true and total_data respectively are :   5000 45000 50000
# Train accuracy on corrupted train-data 0.8252
# Train accuracy on un-corrupted train-data 0.9519777777777778
# Train accuracy on full train-data  0.9393
# test accuracy  0.6261 187.62550884485245
#
# Epoch: 92
# corrupt_loss 2850.24250797648 220.08985745813698
# true loss 6979.046498037875 60.66386168822646
# Train loss of full data 9829.289127230644 76.81535320356488
# total_corrupt, total_true and total_data respectively are :   5000 45000 50000
# Train accuracy on corrupted train-data 0.8138
# Train accuracy on un-corrupted train-data 0.9461111111111111
# Train accuracy on full train-data  0.93288
# test accuracy  0.6382 172.6767876148224
#
# Epoch: 93
# corrupt_loss 1519.6393868634477 117.62819392699748
# true loss 4125.942492568865 35.85436088219285
# Train loss of full data 5645.581883907318 44.135597456246614
# total_corrupt, total_true and total_data respectively are :   5000 45000 50000
# Train accuracy on corrupted train-data 0.8976
# Train accuracy on un-corrupted train-data 0.9704222222222222
# Train accuracy on full train-data  0.96314
# test accuracy  0.6548 171.00548243522644
#
# Epoch: 94
# corrupt_loss 922.9401572104543 71.19545528874733
# true loss 2738.109296460636 23.800796103663743
# Train loss of full data 3661.049475878477 28.60575496405363
# total_corrupt, total_true and total_data respectively are :   5000 45000 50000
# Train accuracy on corrupted train-data 0.9334
# Train accuracy on un-corrupted train-data 0.9810444444444445
# Train accuracy on full train-data  0.97628
# test accuracy  0.6544 183.0812165737152
#
# Epoch: 95
# corrupt_loss 859.1147641646676 65.95098610175774
# true loss 2481.9276244388893 21.553474992979318
# Train loss of full data 3341.042400121689 26.12355493567884
# total_corrupt, total_true and total_data respectively are :   5000 45000 50000
# Train accuracy on corrupted train-data 0.9388
# Train accuracy on un-corrupted train-data 0.9824222222222222
# Train accuracy on full train-data  0.97806
# test accuracy  0.6531 186.39952635765076
#
# Epoch: 96
# corrupt_loss 1657.115426922217 130.61019842559472
# true loss 4413.044407397509 38.33371229469776
# Train loss of full data 6070.159871578217 47.477650701999664
# total_corrupt, total_true and total_data respectively are :   5000 45000 50000
# Train accuracy on corrupted train-data 0.8864
# Train accuracy on un-corrupted train-data 0.9673555555555555
# Train accuracy on full train-data  0.95926
# test accuracy  0.6281 193.29972422122955
#
# Epoch: 97
# corrupt_loss 4391.564297195524 342.33847603946924
# true loss 9753.168281689286 84.6452014297247
# Train loss of full data 14144.73251581192 110.55299960821867
# total_corrupt, total_true and total_data respectively are :   5000 45000 50000
# Train accuracy on corrupted train-data 0.7162
# Train accuracy on un-corrupted train-data 0.9250444444444444
# Train accuracy on full train-data  0.90416
# test accuracy  0.6452 158.15427881479263
#
# Epoch: 98
# corrupt_loss 2052.4778901441023 159.51593287102878
# true loss 5546.722760813311 48.16018489934504
# Train loss of full data 7599.20055770874 59.39640560746193
# total_corrupt, total_true and total_data respectively are :   5000 45000 50000
# Train accuracy on corrupted train-data 0.8468
# Train accuracy on un-corrupted train-data 0.9597111111111111
# Train accuracy on full train-data  0.94842
# test accuracy  0.651 163.4124236702919
#
# Epoch: 99
# corrupt_loss 902.3088115369319 69.87718174624024
# true loss 2625.174512088299 22.84543119650334
# Train loss of full data 3527.4833184480667 27.60346531867981
# total_corrupt, total_true and total_data respectively are :   5000 45000 50000
# Train accuracy on corrupted train-data 0.9378
# Train accuracy on un-corrupted train-data 0.9822666666666666
# Train accuracy on full train-data  0.97782
# test accuracy  0.6513 174.5187439918518
#
# Epoch: 100
# corrupt_loss 526.8673699682113 41.625454620458186
# true loss 1627.4492428386584 14.135543577373028
# Train loss of full data 2154.316620141268 16.83817809075117
# total_corrupt, total_true and total_data respectively are :   5000 45000 50000
# Train accuracy on corrupted train-data 0.968
# Train accuracy on un-corrupted train-data 0.99
# Train accuracy on full train-data  0.9878
# test accuracy  0.6684 172.98172235488892
#
# Epoch: 101
# corrupt_loss 384.9673026042292 28.96357205719687
# true loss 1058.0206485390663 9.191526812734082
# Train loss of full data 1442.9879577234387 11.2753596608527
# total_corrupt, total_true and total_data respectively are :   5000 45000 50000
# Train accuracy on corrupted train-data 0.98
# Train accuracy on un-corrupted train-data 0.9938666666666667
# Train accuracy on full train-data  0.99248
# test accuracy  0.667 178.14304888248444
#
# Epoch: 102
# corrupt_loss 247.1715785502456 18.922181412228383
# true loss 824.11730961781 7.170075818663463
# Train loss of full data 1071.2888851463795 8.380122801288962
# total_corrupt, total_true and total_data respectively are :   5000 45000 50000
# Train accuracy on corrupted train-data 0.9864
# Train accuracy on un-corrupted train-data 0.9953555555555555
# Train accuracy on full train-data  0.99446
# test accuracy  0.6719 181.05412185192108
#
# Epoch: 103
# corrupt_loss 230.76368176343385 17.732692312449217
# true loss 704.990233729477 6.123499594512396
# Train loss of full data 935.7539231479168 7.319182455539703
# total_corrupt, total_true and total_data respectively are :   5000 45000 50000
# Train accuracy on corrupted train-data 0.9854
# Train accuracy on un-corrupted train-data 0.9966444444444444
# Train accuracy on full train-data  0.99552
# test accuracy  0.6686 186.23532724380493
#
# Epoch: 104
# corrupt_loss 200.79289268134744 15.726920643850463
# true loss 631.5887991951313 5.500519805587828
# Train loss of full data 832.3816931247711 6.515776863321662
# total_corrupt, total_true and total_data respectively are :   5000 45000 50000
# Train accuracy on corrupted train-data 0.9892
# Train accuracy on un-corrupted train-data 0.9965555555555555
# Train accuracy on full train-data  0.99582
# test accuracy  0.6667 185.11468744277954
#
# Epoch: 105
# corrupt_loss 422.6120516763185 32.177958357846364
# true loss 1207.7936084808316 10.473602487007156
# Train loss of full data 1630.4056714177132 12.751516098156571
# total_corrupt, total_true and total_data respectively are :   5000 45000 50000
# Train accuracy on corrupted train-data 0.9762
# Train accuracy on un-corrupted train-data 0.9921333333333333
# Train accuracy on full train-data  0.99054
# test accuracy  0.652 197.91672217845917
#
# Epoch: 106
# corrupt_loss 7450.662413464859 591.0391357433982
# true loss 15232.154818152077 132.0861739544198
# Train loss of full data 22682.817147016525 177.362722216174
# total_corrupt, total_true and total_data respectively are :   5000 45000 50000
# Train accuracy on corrupted train-data 0.6004
# Train accuracy on un-corrupted train-data 0.8890222222222223
# Train accuracy on full train-data  0.86016
# test accuracy  0.6443 132.10759311914444
#
# Epoch: 107
# corrupt_loss 3160.7296467013657 241.77731239423156
# true loss 7472.096146766096 64.89520678669214
# Train loss of full data 10632.825880110264 83.08679487556219
# total_corrupt, total_true and total_data respectively are :   5000 45000 50000
# Train accuracy on corrupted train-data 0.7808
# Train accuracy on un-corrupted train-data 0.9476222222222223
# Train accuracy on full train-data  0.93094
# test accuracy  0.6626 148.3569619655609
#
# Epoch: 108
# corrupt_loss 867.7527988366783 66.6671159346588
# true loss 2463.5035081449896 21.413199592381716
# Train loss of full data 3331.256301701069 26.032655688002706
# total_corrupt, total_true and total_data respectively are :   5000 45000 50000
# Train accuracy on corrupted train-data 0.9404
# Train accuracy on un-corrupted train-data 0.9846888888888888
# Train accuracy on full train-data  0.98026
# test accuracy  0.6627 162.9258644580841
#
# Epoch: 109
# corrupt_loss 628.458597520832 48.207830905681476
# true loss 1926.5635548671708 16.732497836463153
# Train loss of full data 2555.0221339464188 19.972850374877453
# total_corrupt, total_true and total_data respectively are :   5000 45000 50000
# Train accuracy on corrupted train-data 0.9584
# Train accuracy on un-corrupted train-data 0.9879777777777777
# Train accuracy on full train-data  0.98502
# ...
# true loss 11812.111919283867 102.62991734221578
# Train loss of full data 17479.204587697983 136.61992593854666
# total_corrupt, total_true and total_data respectively are :   5000 45000 50000
# Train accuracy on corrupted train-data 0.6576
# Train accuracy on un-corrupted train-data 0.9123777777777777
# Train accuracy on full train-data  0.8869
# test accuracy  0.6476 148.91269832849503
#
# Epoch: 133
# corrupt_loss 1323.8009348050691 103.3746916395612
# true loss 3722.6739598475397 32.38654190674424
# Train loss of full data 5046.474867790937 39.43668112717569
# total_corrupt, total_true and total_data respectively are :   5000 45000 50000
# Train accuracy on corrupted train-data 0.9114
# Train accuracy on un-corrupted train-data 0.9752666666666666
# Train accuracy on full train-data  0.96888
# test accuracy  0.6644 158.56451523303986
#
# Epoch: 134
# corrupt_loss 441.75590764242224 33.90553797665052
# true loss 1466.5740566588938 12.74067999701947
# Train loss of full data 1908.3299649953842 14.928143190219998
# total_corrupt, total_true and total_data respectively are :   5000 45000 50000
# Train accuracy on corrupted train-data 0.9746
# Train accuracy on un-corrupted train-data 0.9917111111111111
# Train accuracy on full train-data  0.99
# test accuracy  0.6816 157.2091782093048
#
# Epoch: 135
# corrupt_loss 224.5697525073192 17.709334827319253
# true loss 678.9812524280278 5.887998831341974
# Train loss of full data 903.5510022565722 7.0605708505027
# total_corrupt, total_true and total_data respectively are :   5000 45000 50000
# Train accuracy on corrupted train-data 0.988
# Train accuracy on un-corrupted train-data 0.9970444444444444
# Train accuracy on full train-data  0.99614
# test accuracy  0.6832 162.5495427250862
#
# Epoch: 136
# corrupt_loss 82.7717344565317 6.627567868534243
# true loss 251.9881437846925 2.1893816315568984
# Train loss of full data 334.7598786316812 2.6160296841990203
# total_corrupt, total_true and total_data respectively are :   5000 45000 50000
# Train accuracy on corrupted train-data 0.9974
# Train accuracy on un-corrupted train-data 0.9994888888888889
# Train accuracy on full train-data  0.99928
# test accuracy  0.6863 162.39655935764313
#
# Epoch: 137
# corrupt_loss 51.41091006909846 3.358792729646666
# true loss 107.82732222025516 0.9338666214025579
# Train loss of full data 159.2382283192128 1.2443761139875278
# total_corrupt, total_true and total_data respectively are :   5000 45000 50000
# Train accuracy on corrupted train-data 0.9994
# Train accuracy on un-corrupted train-data 0.9998666666666667
# Train accuracy on full train-data  0.99982
# test accuracy  0.6916 158.60001516342163
#
# Epoch: 138
# corrupt_loss 10.350975973036839 0.7743693147785962
# true loss 48.65864564146614 0.4228243116522208
# Train loss of full data 59.00962162017822 0.46124815568327904
# total_corrupt, total_true and total_data respectively are :   5000 45000 50000
# Train accuracy on corrupted train-data 0.9998
# Train accuracy on un-corrupted train-data 1.0
# Train accuracy on full train-data  0.99998
# test accuracy  0.6934 155.59612041711807
#
# Epoch: 139
# corrupt_loss 7.653147211385658 0.5958076576353051
# true loss 41.93928687029984 0.36427322612144053
# Train loss of full data 49.59243392944336 0.3876728117465973
# total_corrupt, total_true and total_data respectively are :   5000 45000 50000
# Train accuracy on corrupted train-data 1.0
# Train accuracy on un-corrupted train-data 1.0
# Train accuracy on full train-data  1.0
# test accuracy  0.6947 152.7938333749771
#
# Epoch: 140
# corrupt_loss 7.455716135998955 0.580505797668593
# true loss 41.078443523612805 0.35678647784516215
# Train loss of full data 48.53415965847671 0.3794067337876186
# total_corrupt, total_true and total_data respectively are :   5000 45000 50000
# Train accuracy on corrupted train-data 1.0
# Train accuracy on un-corrupted train-data 1.0
# Train accuracy on full train-data  1.0
# test accuracy  0.6949 150.3102480173111
#
# Epoch: 141
# corrupt_loss 7.50134324922692 0.5840960590285249
# true loss 41.520239430712536 0.3606209379504435
# Train loss of full data 49.02158260252327 0.383219133305829
# total_corrupt, total_true and total_data respectively are :   5000 45000 50000
# Train accuracy on corrupted train-data 1.0
# Train accuracy on un-corrupted train-data 1.0
# Train accuracy on full train-data  1.0
# test accuracy  0.6946 148.06960129737854
#
# Epoch: 142
# corrupt_loss 7.6511058759642765 0.5958423083066009
# true loss 42.47409023641376 0.368905222741887
# Train loss of full data 50.125195978209376 0.391846964485012
# total_corrupt, total_true and total_data respectively are :   5000 45000 50000
# Train accuracy on corrupted train-data 1.0
# Train accuracy on un-corrupted train-data 1.0
# Train accuracy on full train-data  1.0
# test accuracy  0.6958 146.0357426404953
#
# Epoch: 143
# corrupt_loss 7.84599066170631 0.6110902681830339
# true loss 43.63082120503532 0.37895243405364454
# Train loss of full data 51.47681188583374 0.4024133235216141
# total_corrupt, total_true and total_data respectively are :   5000 45000 50000
# Train accuracy on corrupted train-data 1.0
# Train accuracy on un-corrupted train-data 1.0
# Train accuracy on full train-data  1.0
# test accuracy  0.6973 144.18212378025055
#
# Epoch: 144
# corrupt_loss 8.05130433436716 0.627141920151189
# true loss 44.845514775719494 0.3895022554206662
# Train loss of full data 52.896819116547704 0.41351443680468947
# total_corrupt, total_true and total_data respectively are :   5000 45000 50000
# Train accuracy on corrupted train-data 1.0
# Train accuracy on un-corrupted train-data 1.0
# Train accuracy on full train-data  1.0
# test accuracy  0.6976 142.50541746616364
#
# Epoch: 145
# corrupt_loss 8.25022030324908 0.6426730355597101
# true loss 46.02448038762668 0.3997423445689492
# Train loss of full data 54.2747006425634 0.4242865748819895
# total_corrupt, total_true and total_data respectively are :   5000 45000 50000
# Train accuracy on corrupted train-data 1.0
# Train accuracy on un-corrupted train-data 1.0
# Train accuracy on full train-data  1.0
# test accuracy  0.6982 140.98916745185852
#
# Epoch: 146
# corrupt_loss 8.440116870449856 0.6575268597225659
# true loss 47.12172372668283 0.40927515766816214
# Train loss of full data 55.56184053607285 0.4343503281706944
# total_corrupt, total_true and total_data respectively are :   5000 45000 50000
# Train accuracy on corrupted train-data 1.0
# Train accuracy on un-corrupted train-data 1.0
# Train accuracy on full train-data  1.0
# test accuracy  0.6982 139.63574200868607
#
# Epoch: 147
# corrupt_loss 8.610818386136089 0.6708584455191158
# true loss 48.11192084744107 0.41787847911473364
# Train loss of full data 56.722739218734205 0.4434278823318891
# total_corrupt, total_true and total_data respectively are :   5000 45000 50000
# Train accuracy on corrupted train-data 1.0
# Train accuracy on un-corrupted train-data 1.0
# Train accuracy on full train-data  1.0
# test accuracy  0.6982 138.4039872288704
#
# Epoch: 148
# corrupt_loss 8.76109267375432 0.6826939136954024
# true loss 48.9706464218325 0.4253407926298678
# Train loss of full data 57.7317390460521 0.45131780358497053
# total_corrupt, total_true and total_data respectively are :   5000 45000 50000
# Train accuracy on corrupted train-data 1.0
# Train accuracy on un-corrupted train-data 1.0
# Train accuracy on full train-data  1.0
# test accuracy  0.6976 137.3043646812439
#
# Epoch: 149
# corrupt_loss 8.889492032467388 0.6927661119261757
# true loss 49.71302797208773 0.43179412483004853
# Train loss of full data 58.602519989944994 0.45812732429476455
# total_corrupt, total_true and total_data respectively are :   5000 45000 50000
# Train accuracy on corrupted train-data 1.0
# Train accuracy on un-corrupted train-data 1.0
# Train accuracy on full train-data  1.0
# test accuracy  0.6987 136.30540388822556
#
# Epoch: 150
# corrupt_loss 8.99877118569566 0.7013432782841846
# true loss 50.32756864960538 0.4371360322111286
# Train loss of full data 59.32633972261101 0.46378854737849906
# total_corrupt, total_true and total_data respectively are :   5000 45000 50000
# Train accuracy on corrupted train-data 1.0
# Train accuracy on un-corrupted train-data 1.0
# Train accuracy on full train-data  1.0
# test accuracy  0.6988 135.38838237524033
#
# Epoch: 151
# corrupt_loss 9.089747440128122 0.7085304987267591
# true loss 50.83083018171601 0.44151198666077107
# Train loss of full data 59.920577524229884 0.46843630296643823
# total_corrupt, total_true and total_data respectively are :   5000 45000 50000
# Train accuracy on corrupted train-data 1.0
# Train accuracy on un-corrupted train-data 1.0
# Train accuracy on full train-data  1.0
# test accuracy  0.7002 134.55045795440674
#
# Epoch: 152
# corrupt_loss 9.165226951648947 0.7145124794333242
# true loss 51.22803217335604 0.44496786344097927
# Train loss of full data 60.393259048461914 0.47213465720415115
# total_corrupt, total_true and total_data respectively are :   5000 45000 50000
# Train accuracy on corrupted train-data 1.0
# Train accuracy on un-corrupted train-data 1.0
# Train accuracy on full train-data  1.0
# test accuracy  0.7002 133.78691083192825
#
# Epoch: 153
# corrupt_loss 9.22234534996096 0.7189688360085711
# true loss 51.54086493217619 0.44769183988682926
# Train loss of full data 60.76321029663086 0.4750293828547001
# total_corrupt, total_true and total_data respectively are :   5000 45000 50000
# Train accuracy on corrupted train-data 1.0
# Train accuracy on un-corrupted train-data 1.0
# Train accuracy on full train-data  1.0
# test accuracy  0.7005 133.07920771837234
#
# Epoch: 154
# corrupt_loss 9.266236300521996 0.7224315889761783
# true loss 51.78237872442696 0.44979527266696095
# Train loss of full data 61.04861498065293 0.4772631950909272
# total_corrupt, total_true and total_data respectively are :   5000 45000 50000
# Train accuracy on corrupted train-data 1.0
# Train accuracy on un-corrupted train-data 1.0
# Train accuracy on full train-data  1.0
# test accuracy  0.7002 132.43925142288208
#
# Epoch: 155
# corrupt_loss 9.300449370697606 0.725132321647834
# true loss 51.963233538670465 0.4513724513235502
# Train loss of full data 61.263682844117284 0.4789469667011872
# total_corrupt, total_true and total_data respectively are :   5000 45000 50000
# Train accuracy on corrupted train-data 1.0
# Train accuracy on un-corrupted train-data 1.0
# Train accuracy on full train-data  1.0
# test accuracy  0.7001 131.81700694561005
#
# Epoch: 156
# corrupt_loss 9.324169165513013 0.7271053635631688
# true loss 52.09692289785016 0.45253786933608353
# Train loss of full data 61.421092035248876 0.4801794976228848
# total_corrupt, total_true and total_data respectively are :   5000 45000 50000
# Train accuracy on corrupted train-data 1.0
# Train accuracy on un-corrupted train-data 1.0
# Train accuracy on full train-data  1.0
# test accuracy  0.7004 131.24962943792343
#
# Epoch: 157
# corrupt_loss 9.343156321672723 0.7286468055099249
# true loss 52.19517074665055 0.45339417993091047
# Train loss of full data 61.53832721710205 0.4810973219573498
# total_corrupt, total_true and total_data respectively are :   5000 45000 50000
# Train accuracy on corrupted train-data 1.0
# Train accuracy on un-corrupted train-data 1.0
# Train accuracy on full train-data  1.0
# test accuracy  0.7009 130.71629983186722
#
# Epoch: 158
# corrupt_loss 9.363827690365724 0.7303961364086717
# true loss 52.26509993849322 0.4540037838742137
# Train loss of full data 61.62892770767212 0.4818071164190769
# total_corrupt, total_true and total_data respectively are :   5000 45000 50000
# Train accuracy on corrupted train-data 1.0
# Train accuracy on un-corrupted train-data 1.0
# Train accuracy on full train-data  1.0
# test accuracy  0.7006 130.20563793182373
#
# Epoch: 159
# corrupt_loss 9.374600890267175 0.731326139473822
# true loss 52.31975888868328 0.4544793237000704
# Train loss of full data 61.694359777495265 0.48231932369526476
# total_corrupt, total_true and total_data respectively are :   5000 45000 50000
# Train accuracy on corrupted train-data 1.0
# Train accuracy on un-corrupted train-data 1.0
# Train accuracy on full train-data  1.0
# test accuracy  0.7011 129.72618424892426
#
# Epoch: 160
# corrupt_loss 9.388879290199839 0.7324617867125198
# true loss 52.35727682209108 0.4548081971006468
# Train loss of full data 61.74615621753037 0.48272564413491637
# total_corrupt, total_true and total_data respectively are :   5000 45000 50000
# Train accuracy on corrupted train-data 1.0
# Train accuracy on un-corrupted train-data 1.0
# Train accuracy on full train-data  1.0
# test accuracy  0.7019 129.24704664945602
#
# Epoch: 161
# corrupt_loss 9.401334271766245 0.733442930970341
# true loss 52.39210363815073 0.45511338533833623
# Train loss of full data 61.79343795590103 0.4830968923633918
# total_corrupt, total_true and total_data respectively are :   5000 45000 50000
# Train accuracy on corrupted train-data 1.0
# Train accuracy on un-corrupted train-data 1.0
# Train accuracy on full train-data  1.0
# test accuracy  0.702 128.78724133968353
#
# Epoch: 162
# corrupt_loss 9.41388081968762 0.7345115219941363
# true loss 52.42143489612499 0.45537008909741417
# Train loss of full data 61.83531570620835 0.48342592420522124
# total_corrupt, total_true and total_data respectively are :   5000 45000 50000
# Train accuracy on corrupted train-data 1.0
# Train accuracy on un-corrupted train-data 1.0
# Train accuracy on full train-data  1.0
# test accuracy  0.7016 128.3585056066513
#
# Epoch: 163
# corrupt_loss 9.429725658439565 0.735816667729523
# true loss 52.451894714846276 0.45563485170714557
# Train loss of full data 61.881620408035815 0.48378919513197616
# total_corrupt, total_true and total_data respectively are :   5000 45000 50000
# Train accuracy on corrupted train-data 1.0
# Train accuracy on un-corrupted train-data 1.0
# Train accuracy on full train-data  1.0
# test accuracy  0.7017 127.9488742351532
#
# Epoch: 164
# corrupt_loss 9.449110982066486 0.7374522018362768
# true loss 52.484130912227556 0.45591647666879
# Train loss of full data 61.93324184603989 0.4841945372754708
# total_corrupt, total_true and total_data respectively are :   5000 45000 50000
# Train accuracy on corrupted train-data 1.0
# Train accuracy on un-corrupted train-data 1.0
# Train accuracy on full train-data  1.0
# test accuracy  0.7019 127.55568885803223
#
# Epoch: 165
# corrupt_loss 9.466372023918666 0.7389374379999936
# true loss 52.52123163302895 0.4562395055545494
# Train loss of full data 61.98760366626084 0.48462096008006483
# total_corrupt, total_true and total_data respectively are :   5000 45000 50000
# Train accuracy on corrupted train-data 1.0
# Train accuracy on un-corrupted train-data 1.0
# Train accuracy on full train-data  1.0
# test accuracy  0.702 127.16659641265869
#
# Epoch: 166
# corrupt_loss 9.49052764091175 0.7409131546737626
# true loss 52.55253929353785 0.4565100830513984
# Train loss of full data 62.043066980317235 0.4850550271803513
# total_corrupt, total_true and total_data respectively are :   5000 45000 50000
# Train accuracy on corrupted train-data 1.0
# Train accuracy on un-corrupted train-data 1.0
# Train accuracy on full train-data  1.0
# test accuracy  0.7026 126.80978208780289
#
# Epoch: 167
# corrupt_loss 9.515315533266403 0.742896352079697
# true loss 52.585598498990294 0.4567963306908496
# Train loss of full data 62.100914001464844 0.4855075962841511
# total_corrupt, total_true and total_data respectively are :   5000 45000 50000
# Train accuracy on corrupted train-data 1.0
# Train accuracy on un-corrupted train-data 1.0
# Train accuracy on full train-data  1.0
# test accuracy  0.7028 126.44539225101471
#
# Epoch: 168
# corrupt_loss 9.542114253505133 0.7450732062570751
# true loss 52.62380084203323 0.4571289738523774
# Train loss of full data 62.165915010496974 0.4860162123804912
# total_corrupt, total_true and total_data respectively are :   5000 45000 50000
# Train accuracy on corrupted train-data 1.0
# Train accuracy on un-corrupted train-data 1.0
# Train accuracy on full train-data  1.0
# test accuracy  0.7024 126.10537457466125
#
# Epoch: 169
# corrupt_loss 9.572298536426388 0.7474401962244883
# true loss 52.66480683651753 0.457485310616903
# Train loss of full data 62.23710536863655 0.48657311795977876
# total_corrupt, total_true and total_data respectively are :   5000 45000 50000
# Train accuracy on corrupted train-data 1.0
# Train accuracy on un-corrupted train-data 1.0
# Train accuracy on full train-data  1.0
# test accuracy  0.7022 125.77821969985962

# %%
testset = torchvision.datasets.CIFAR10(root='./data', train=False, download=True, transform=transform_test)
import random
length = len(testset.targets)
percentage_corruption = 10
n = length*percentage_corruption/100
corrupt_classes = np.random.randint(0,10,int(n))
# print(np.unique(corrupt_idx))
corrupt_idx = random.sample(range(0,length), int(n))
print(len(corrupt_idx) , len(np.unique(corrupt_idx)))
print(corrupt_idx)
print(len(corrupt_classes))

st1 = testset.targets
a = np.array(testset.targets)
a[corrupt_idx] = corrupt_classes
testset.targets = list(a)
st2 = testset.targets

print(st1 == st2)
# Out:
# Files already downloaded and verified
# 1000 1000
# [7915, 7136, 319, 1036, 1797, 59, 9825, 1139, 2767, 4998, 5790, 1414, 9622, 3574, 5439, 3966, 5412, 2004, 3942, 6438, 2096, 7689, 1894, 9979, 3000, 3311, 2138, 4536, 9586, 290, 8778, 5082, 6629, 3768, 4443, 4588, 2584, 4821, 4960, 6491, 6281, 2736, 6960, 9690, 4656, 41, 3940, 9153, 9638, 9738, 9592, 3611, 5921, 2151, 6035, 3809, 2349, 5617, 6506, 9929, 6631, 5650, 9635, 8885, 763, 1546, 194, 2311, 4790, 6071, 5524, 8468, 6673, 5677, 9989, 8150, 9056, 2418, 6766, 9291, 4279, 5033, 4874, 5725, 6607, 4779, 2623, 8924, 4789, 8013, 207, 7740, 245, 5058, 7165, 2433, 9476, 5671, 7632, 5759, 8819, 651, 7036, 8176, 7188, 5899, 1913, 165, 1807, 6294, 8618, 7434, 1308, 5239, 4304, 2575, 4130, 1438, 5607, 5297, 5624, 2121, 3688, 4556, 125, 2535, 1355, 3184, 3569, 7241, 1826, 3133, 5780, 7134, 8654, 5900, 7399, 910, 1609, 8031, 7725, 4776, 5913, 7279, 9843, 20, 2528, 1970, 8586, 6091, 8062, 63, 2974, 9448, 5765, 2071, 6705, 3248, 8668, 7156, 5293, 4926, 4180, 1535, 836, 6106, 2351, 5304, 7116, 456, 5084, 2570, 8080, 3082, 7780, 7680, 5641, 1114, 6730, 8126, 2023, 9171, 9925, 8937, 8786, 3108, 4364, 3372, 1554, 4332, 512, 3067, 4679, 2375, 7072, 5469, 399, 1381, 7062, 1226, 7944, 3752, 9886, 83, 7710, 886, 7991, 2192, 3793, 8465, 499, 2221, 8839, 2507, 9831, 2785, 8147, 2898, 7568, 2390, 7747, 9863, 9761, 472, 6004, 3889, 3842, 4424, 6736, 7199, 3462, 8189, 9289, 2967, 4627, 401, 963, 5509, 3138, 3972, 1215, 9784, 8804, 8781, 4744, 8195, 615, 263, 1424, 253, 4481, 7490, 3324, 256, 9617, 6421, 1390, 3001, 4224, 1056, 4770, 2046, 5653, 8431, 7766, 5632, 7106, 7487, 9674, 4266, 4632, 6382, 3546, 3304, 4500, 7191, 6155, 7522, 4578, 3950, 6235, 2315, 2176, 3172, 8422, 8800, 1617, 8090, 5979, 9531, 9606, 2160, 357, 2713, 2061, 331, 7464, 9, 6063, 8539, 4510, 2438, 5717, 420, 8215, 8493, 1710, 6659, 2761, 7905, 7161, 2419, 5783, 5504, 7404, 3424, 1982, 5622, 4008, 9902, 3627, 5727, 2544, 4408, 5065, 881, 9252, 5422, 5958, 1410, 2962, 7906, 8574, 7860, 8241, 1435, 9331, 7639, 3064, 2617, 9279, 8326, 3504, 5853, 8945, 9765, 7772, 829, 629, 4006, 660, 9965, 2186, 7550, 4959, 6609, 9682, 2177, 8541, 2873, 7602, 4717, 5810, 8568, 275, 3014, 3397, 1640, 3664, 6805, 9496, 2709, 832, 4238, 3308, 5668, 2806, 3288, 2893, 8182, 6496, 8079, 6706, 9678, 5012, 4041, 7350, 7681, 4549, 982, 2772, 7127, 2968, 1329, 4791, 6704, 6748, 200, 7242, 7699, 2238, 4176, 3743, 9644, 2724, 6917, 2904, 9360, 4168, 7436, 2383, 6858, 6139, 8068, 2293, 6215, 5050, 2722, 5282, 6009, 8784, 4802, 4342, 2589, 2314, 3155, 8814, 9421, 466, 6249, 796, 3787, 8918, 5062, 313, 7439, 6517, 3264, 56, 9578, 9987, 4496, 9582, 1501, 6859, 3603, 7852, 3410, 6889, 2054, 4291, 2254, 4879, 6317, 6597, 7599, 4758, 7508, 582, 8404, 8977, 4016, 1115, 4562, 4019, 4953, 4399, 1881, 9267, 8489, 4763, 8722, 9002, 8340, 3710, 7395, 7009, 6483, 1966, 8823, 5552, 8990, 8003, 9107, 2674, 8020, 4993, 8659, 3995, 8140, 280, 6993, 6579, 3902, 588, 4343, 8317, 597, 5115, 3386, 8344, 5178, 9727, 5791, 6202, 4273, 5213, 8766, 5542, 9225, 2953, 9567, 958, 2867, 9626, 3549, 4274, 5403, 4558, 7299, 7850, 4555, 7897, 8159, 1125, 7270, 1259, 1475, 390, 2578, 2458, 7545, 6620, 4528, 1483, 7048, 1527, 747, 6123, 1346, 5591, 6033, 2921, 3049, 6152, 4331, 6011, 876, 9012, 2972, 3732, 638, 1200, 1333, 9894, 3690, 8399, 6533, 2499, 4402, 9640, 2147, 4181, 3012, 4385, 7558, 5052, 5418, 5420, 6168, 1199, 7882, 9698, 3604, 3114, 842, 8096, 1386, 9228, 1107, 3069, 8688, 7336, 2141, 5481, 149, 1661, 5322, 7572, 7718, 2411, 1564, 8614, 4982, 8186, 9449, 4409, 119, 8587, 527, 3532, 2980, 8643, 1246, 4565, 7582, 8884, 8446, 352, 6243, 8837, 3457, 6084, 2814, 6495, 4873, 6325, 5536, 2758, 4091, 6415, 3693, 460, 8154, 8728, 4161, 4875, 8543, 7866, 4585, 6984, 428, 6416, 4219, 8319, 5777, 6130, 2517, 4193, 2294, 7528, 8180, 8289, 9523, 1687, 5059, 799, 181, 2485, 3360, 7984, 9402, 6843, 7786, 3023, 5512, 3542, 5187, 4204, 3342, 7652, 1505, 3715, 7190, 1334, 2234, 1756, 2049, 8638, 5313, 7623, 3810, 3837, 6987, 4205, 9057, 8891, 9736, 1 ...
# 1000
# False

# %%
test_data = CustomizeDataset(testset,corrupt_idx)
testloader = DataLoader( test_data, batch_size= 100,shuffle= False, num_workers=2)

# testloader = torch.utils.data.DataLoader(testset, batch_size=100, shuffle=False, num_workers=2)
global best_acc

test_loss = 0
tl=0
test_corrupt_loss = 0
tcl=0
test_true_loss = 0
ttl=0

correct = 0
true_correct=0
corrupt_correct=0

total = 0
corrupt_total = 0
true_total=0
with torch.no_grad():
    for batch_idx, (inputs, targets, indicator) in enumerate(testloader):
        inputs, targets, indicator = inputs.to(device), targets.to(device), indicator.to(device)
        outputs = net(inputs)
        loss = criterion(outputs, targets)
        batch_total_loss = loss.item()
        tl += batch_total_loss
        test_loss += batch_total_loss*len(indicator)

#         test_loss += loss.item()
        _, predicted = outputs.max(1)
        total += targets.size(0)
        correct += predicted.eq(targets).sum().item()
#         ***************************************************************************
        corrupt_out = (outputs[indicator])
        loss_corrupt = criterion(corrupt_out, targets[indicator])
        batch_corrupt_loss = loss_corrupt.item()
        tcl += loss_corrupt.item()
        test_corrupt_loss += batch_corrupt_loss*(sum(indicator).item())
       
        _, predict_corrupt = corrupt_out.max(1)
        corrupt_total += targets[indicator].size(0)
        corrupt_correct += predict_corrupt.eq(targets[indicator]).sum().item()
        
        true_out = (outputs[~indicator])
        loss_true = criterion(true_out, targets[~indicator])
        batch_true_loss = loss_true.item()
        ttl += loss_true.item()
        test_true_loss += batch_true_loss*(sum(~indicator).item())
        
        _, predict_true = true_out.max(1)
        true_total += targets[~indicator].size(0)
        true_correct += predict_true.eq(targets[~indicator]).sum().item()
#         *****************************************************************************

#             progress_bar(batch_idx, len(testloader), 'Loss: %.3f | Acc: %.3f%% (%d/%d)'
#                 % (test_loss/(batch_idx+1), 100.*correct/total, correct, total))

print("corrupt_loss", test_corrupt_loss, tcl)
print("true loss", test_true_loss, ttl)
print("Test loss of full data", test_loss, tl)
print("total_corrupt, total_true and total_data respectively are :  ",corrupt_total, true_total, total)
print("Test accuracy on corrupted train-data", corrupt_correct/corrupt_total )
print("Test accuracy on un-corrupted train-data", true_correct/true_total)
print("test accuracy on full test-data", correct/total)
print(correct, total)
# Out:
# corrupt_loss 7536.210190296173 759.8516936302185
# true loss 10285.424175202847 114.29510074853897
# Test loss of full data 17821.634590625763 178.21634590625763
# total_corrupt, total_true and total_data respectively are :   1000 9000 10000
# Test accuracy on corrupted train-data 0.116
# Test accuracy on un-corrupted train-data 0.7224444444444444
# test accuracy on full test-data 0.6618
# 6618 10000
