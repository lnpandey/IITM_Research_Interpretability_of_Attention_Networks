# %%
import torch
import torch.nn as nn
import torch.nn.functional as F


class Block(nn.Module):
    '''expand + depthwise + pointwise + squeeze-excitation'''

    def __init__(self, in_planes, out_planes, expansion, stride):
        super(Block, self).__init__()
        self.stride = stride

        planes = expansion * in_planes
        self.conv1 = nn.Conv2d(
            in_planes, planes, kernel_size=1, stride=1, padding=0, bias=False)
        self.bn1 = nn.BatchNorm2d(planes)
        self.conv2 = nn.Conv2d(planes, planes, kernel_size=3,
                               stride=stride, padding=1, groups=planes, bias=False)
        self.bn2 = nn.BatchNorm2d(planes)
        self.conv3 = nn.Conv2d(
            planes, out_planes, kernel_size=1, stride=1, padding=0, bias=False)
        self.bn3 = nn.BatchNorm2d(out_planes)

        self.shortcut = nn.Sequential()
        if stride == 1 and in_planes != out_planes:
            self.shortcut = nn.Sequential(
                nn.Conv2d(in_planes, out_planes, kernel_size=1,
                          stride=1, padding=0, bias=False),
                nn.BatchNorm2d(out_planes),
            )

        # SE layers
        self.fc1 = nn.Conv2d(out_planes, out_planes//16, kernel_size=1)
        self.fc2 = nn.Conv2d(out_planes//16, out_planes, kernel_size=1)

    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = F.relu(self.bn2(self.conv2(out)))
        out = self.bn3(self.conv3(out))
        shortcut = self.shortcut(x) if self.stride == 1 else out
        # Squeeze-Excitation
        w = F.avg_pool2d(out, out.size(2))
        w = F.relu(self.fc1(w))
        w = self.fc2(w).sigmoid()
        out = out * w + shortcut
        return out


class EfficientNet(nn.Module):
    def __init__(self, cfg, num_classes=10):
        super(EfficientNet, self).__init__()
        self.cfg = cfg
        self.conv1 = nn.Conv2d(3, 32, kernel_size=3,
                               stride=1, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(32)
        self.layers = self._make_layers(in_planes=32)
        self.linear = nn.Linear(cfg[-1][1], num_classes)

    def _make_layers(self, in_planes):
        layers = []
        for expansion, out_planes, num_blocks, stride in self.cfg:
            strides = [stride] + [1]*(num_blocks-1)
            for stride in strides:
                layers.append(Block(in_planes, out_planes, expansion, stride))
                in_planes = out_planes
        return nn.Sequential(*layers)

    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = self.layers(out)
        out = out.view(out.size(0), -1)
        out = self.linear(out)
        return out


def EfficientNetB0():
    # (expansion, out_planes, num_blocks, stride)
    cfg = [(1,  16, 1, 2),
           (6,  24, 2, 1),
           (6,  40, 2, 2),
           (6,  80, 3, 2),
           (6, 112, 3, 1),
           (6, 192, 4, 2),
           (6, 320, 1, 2)]
    return EfficientNet(cfg)


def test():
    net = EfficientNetB0()
    x = torch.randn(2, 3, 32, 32)
    y = net(x)
    print(y.shape)

# %%
import os
import sys
import time
import math

import torch.nn as nn
import torch.nn.init as init


def get_mean_and_std(dataset):
    '''Compute the mean and std value of dataset.'''
    dataloader = torch.utils.data.DataLoader(dataset, batch_size=1, shuffle=True, num_workers=2)
    mean = torch.zeros(3)
    std = torch.zeros(3)
    print('==> Computing mean and std..')
    for inputs, targets in dataloader:
        for i in range(3):
            mean[i] += inputs[:,i,:,:].mean()
            std[i] += inputs[:,i,:,:].std()
    mean.div_(len(dataset))
    std.div_(len(dataset))
    return mean, std

def init_params(net):
    '''Init layer parameters.'''
    for m in net.modules():
        if isinstance(m, nn.Conv2d):
            init.kaiming_normal(m.weight, mode='fan_out')
            if m.bias:
                init.constant(m.bias, 0)
        elif isinstance(m, nn.BatchNorm2d):
            init.constant(m.weight, 1)
            init.constant(m.bias, 0)
        elif isinstance(m, nn.Linear):
            init.normal(m.weight, std=1e-3)
            if m.bias:
                init.constant(m.bias, 0)


# _, term_width = os.popen('stty size', 'r').read().split()
term_width = 80
term_width = int(term_width)

TOTAL_BAR_LENGTH = 65.
last_time = time.time()
begin_time = last_time
def progress_bar(current, total, msg=None):
    global last_time, begin_time
    if current == 0:
        begin_time = time.time()  # Reset for new bar.

    cur_len = int(TOTAL_BAR_LENGTH*current/total)
    rest_len = int(TOTAL_BAR_LENGTH - cur_len) - 1

    sys.stdout.write(' [')
    for i in range(cur_len):
        sys.stdout.write('=')
    sys.stdout.write('>')
    for i in range(rest_len):
        sys.stdout.write('.')
    sys.stdout.write(']')

    cur_time = time.time()
    step_time = cur_time - last_time
    last_time = cur_time
    tot_time = cur_time - begin_time

    L = []
    L.append('  Step: %s' % format_time(step_time))
    L.append(' | Tot: %s' % format_time(tot_time))
    if msg:
        L.append(' | ' + msg)

    msg = ''.join(L)
    sys.stdout.write(msg)
    for i in range(term_width-int(TOTAL_BAR_LENGTH)-len(msg)-3):
        sys.stdout.write(' ')

    # Go back to the center of the bar.
    for i in range(term_width-int(TOTAL_BAR_LENGTH/2)+2):
        sys.stdout.write('\b')
    sys.stdout.write(' %d/%d ' % (current+1, total))

    if current < total-1:
        sys.stdout.write('\r')
    else:
        sys.stdout.write('\n')
    sys.stdout.flush()

def format_time(seconds):
    days = int(seconds / 3600/24)
    seconds = seconds - days*3600*24
    hours = int(seconds / 3600)
    seconds = seconds - hours*3600
    minutes = int(seconds / 60)
    seconds = seconds - minutes*60
    secondsf = int(seconds)
    seconds = seconds - secondsf
    millis = int(seconds*1000)

    f = ''
    i = 1
    if days > 0:
        f += str(days) + 'D'
        i += 1
    if hours > 0 and i <= 2:
        f += str(hours) + 'h'
        i += 1
    if minutes > 0 and i <= 2:
        f += str(minutes) + 'm'
        i += 1
    if secondsf > 0 and i <= 2:
        f += str(secondsf) + 's'
        i += 1
    if millis > 0 and i <= 2:
        f += str(millis) + 'ms'
        i += 1
    if f == '':
        f = '0ms'
    return f

# %%
'''Train CIFAR10 with PyTorch.'''
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import torch.backends.cudnn as cudnn

import torchvision
import torchvision.transforms as transforms

import os
import argparse
import numpy as np
from torch.utils.data import Dataset, DataLoader

# from models import *
# from utils import progress_bar


# parser = argparse.ArgumentParser(description='PyTorch CIFAR10 Training')
# parser.add_argument('--lr', default=0.1, type=float, help='learning rate')
# parser.add_argument('--resume', '-r', action='store_true', help='resume from checkpoint')
# args = parser.parse_args()

lr = 0.01

device = 'cuda' if torch.cuda.is_available() else 'cpu'
best_acc = 0  # best test accuracy
start_epoch = 0  # start from epoch 0 or last checkpoint epoch

# Data
print('==> Preparing data..')
transform_train = transforms.Compose([
    transforms.RandomCrop(32, padding=4),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010)),
])

transform_test = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010)),
])

trainset = torchvision.datasets.CIFAR10(root='./data', train=True, download=True, transform=transform_train)
testset = torchvision.datasets.CIFAR10(root='./data', train=False, download=True, transform=transform_test)


# trainset.targets***************************************************************
import random
length = len(trainset.targets)
percentage_corruption = 20
n = length*percentage_corruption/100
corrupt_classes = np.random.randint(0,10,int(n))

corrupt_idx = random.sample(range(0,length), int(n))
a = np.array(trainset.targets)
a[corrupt_idx] = corrupt_classes
trainset.targets = list(a)

class CustomizeDataset(Dataset):
    """MosaicDataset dataset."""

    def __init__(self, dataset, corrupt):
        """
        Args:
            csv_file (string): Path to the csv file with annotations.
            root_dir (string): Directory with all the images.
            transform (callable, optional): Optional transform to be applied
                on a sample.
        """
        self.data = dataset.data
        self.data= np.rollaxis(self.data, 3,1)
        self.data =  np.float32(self.data)
#         print(self.data.dtype)
        #print(self.data.shape)
        self.label = dataset.targets
        self.corrupt_idx = corrupt
        self.indicator = torch.zeros(len(self.label)).byte()
        k = len(self.label)
        for i in range(k):
          if i in self.corrupt_idx :
            self.indicator[i]=1

    def __len__(self):
        return len(self.label)

    def __getitem__(self, idx):
#       print(self.data[idx].shape)
      return self.data[idx] , self.label[idx], self.indicator[idx]


train_data = CustomizeDataset(trainset,corrupt_idx)
trainloader = DataLoader( train_data, batch_size= 128,shuffle= False, num_workers=2)


#**********************************************************************************

testloader = torch.utils.data.DataLoader(testset, batch_size=100, shuffle=False, num_workers=2)
# trainloader = torch.utils.data.DataLoader(trainset, batch_size=128, shuffle=False, num_workers=2)

classes = ('plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck')

# Model
print('==> Building model..')
# net = VGG('VGG19')
# net = ResNet18()
# net = PreActResNet18()
# net = GoogLeNet()
# net = DenseNet121()
# net = ResNeXt29_2x64d()
# net = MobileNet()
# net = MobileNetV2()
# net = DPN92()
# net = ShuffleNetG2()
# net = SENet18()
# net = ShuffleNetV2(1)
net = EfficientNetB0()
net = net.to(device)
if device == 'cuda':
    net = torch.nn.DataParallel(net)
    cudnn.benchmark = True

# if args.resume:
#     # Load checkpoint.
#     print('==> Resuming from checkpoint..')
#     assert os.path.isdir('checkpoint'), 'Error: no checkpoint directory found!'
#     checkpoint = torch.load('./checkpoint/ckpt.pth')
#     net.load_state_dict(checkpoint['net'])
#     best_acc = checkpoint['acc']
#     start_epoch = checkpoint['epoch']

criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(net.parameters(), lr, momentum=0.9, weight_decay=5e-4)
# optimizer = optim.SGD(net.parameters(), lr=args.lr, momentum=0.9, weight_decay=5e-4)

train_acc =[]
test_acc=[]
epoch_list=[]
# Training
def train(epoch):
    print('\nEpoch: %d' % epoch)
    net.train()
    
    train_loss = 0
    tl=0
    train_corrupt_loss = 0
    tcl=0
    train_true_loss = 0
    ttl=0
    
    correct = 0
    true_correct=0
    corrupt_correct=0
    
    total = 0
    corrupt_total = 0
    true_total=0
    
    for batch_idx, (inputs, targets, indicator ) in enumerate(trainloader):
#         batch_corrupt_loss , batch_true_loss, batch_total_loss = 0,0,0
        inputs, targets, indicator = inputs.to(device), targets.to(device), indicator.to(device)
#         print(inputs,targets.size(),indicator.size())
        optimizer.zero_grad()
        outputs = net(inputs)
        loss = criterion(outputs, targets)
        batch_total_loss = loss.item()
        tl += loss.item()
        train_loss += batch_total_loss*len(indicator)
        
        _, predicted = outputs.max(1)
        total += targets.size(0)
        correct += predicted.eq(targets).sum().item()
#         print(indicator.size)
#         print(sum(~indicator),sum(indicator))
#         ***************************************************************
        corrupt_out = (outputs[indicator])
        loss_corrupt = criterion(corrupt_out, targets[indicator])
        batch_corrupt_loss = loss_corrupt.item()
        tcl += loss_corrupt.item()
        train_corrupt_loss += batch_corrupt_loss*(sum(indicator).item())
       
        _, predict_corrupt = corrupt_out.max(1)
        corrupt_total += targets[indicator].size(0)
        corrupt_correct += predict_corrupt.eq(targets[indicator]).sum().item()
        
        true_out = (outputs[~indicator])
        loss_true = criterion(true_out, targets[~indicator])
        batch_true_loss = loss_true.item()
        ttl += loss_true.item()
        train_true_loss += batch_true_loss*(sum(~indicator).item())
        
        _, predict_true = true_out.max(1)
        true_total += targets[~indicator].size(0)
        true_correct += predict_true.eq(targets[~indicator]).sum().item()
        
#         ****************************************************************************
        loss.backward()
        optimizer.step()
        

#         progress_bar(batch_idx, len(trainloader), 'Loss: %.3f | Acc: %.3f%% (%d/%d)'
#             % (train_loss/(batch_idx+1), 100.*correct/total, correct, total))
    
    print("corrupt_loss", train_corrupt_loss, tcl)
    print("true loss", train_true_loss, ttl)
    print("Train loss of full data", train_loss, tl)
    print("total_corrupt, total_true and total_data respectively are :  ",corrupt_total, true_total, total)
    print("Train accuracy on corrupted train-data", corrupt_correct/corrupt_total )
    print("Train accuracy on un-corrupted train-data", true_correct/true_total)
    print("Train accuracy on full train-data ", correct/total )
    train_acc.append(train_loss)

def test(epoch):
    global best_acc
#     net.eval()
    test_loss = 0
    correct = 0
    total = 0
    with torch.no_grad():
        for batch_idx, (inputs, targets) in enumerate(testloader):
            inputs, targets = inputs.to(device), targets.to(device)
            outputs = net(inputs)
            loss = criterion(outputs, targets)

            test_loss += loss.item()
            _, predicted = outputs.max(1)
            total += targets.size(0)
            correct += predicted.eq(targets).sum().item()

#             progress_bar(batch_idx, len(testloader), 'Loss: %.3f | Acc: %.3f%% (%d/%d)'
#                 % (test_loss/(batch_idx+1), 100.*correct/total, correct, total))
    print("test accuracy ", correct/total , test_loss)
    test_acc.append(test_loss)

    # Save checkpoint.
#     acc = 100.*correct/total
#     if acc > best_acc:
#         print('Saving..')
#         state = {
#             'net': net.state_dict(),
#             'acc': acc,
#             'epoch': epoch,
#         }
#         if not os.path.isdir('checkpoint'):
#             os.mkdir('checkpoint')
#         torch.save(state, './checkpoint/ckpt.pth')
#         best_acc = acc


for epoch in range(start_epoch, start_epoch+190):
    epoch_list.append(epoch)
    train(epoch)
    test(epoch)
# Out:
# ==> Preparing data..
# Files already downloaded and verified
# Files already downloaded and verified
# ==> Building model..
#
# Epoch: 0
# corrupt_loss 28096.131820440292 1100.010405778885
# true loss 67217.7278585434 657.1909539699554
# Train loss of full data 95313.8602142334 745.3332959413528
# total_corrupt, total_true and total_data respectively are :   10000 40000 50000
# Train accuracy on corrupted train-data 0.1054
# Train accuracy on un-corrupted train-data 0.401525
# Train accuracy on full train-data  0.3423
# test accuracy  0.5034 143.36290431022644
#
# Epoch: 1
# corrupt_loss 29602.928953170776 1157.8604819774628
# true loss 54003.84726810455 527.8338800668716
# Train loss of full data 83606.77616882324 653.7905292510986
# total_corrupt, total_true and total_data respectively are :   10000 40000 50000
# Train accuracy on corrupted train-data 0.1097
# Train accuracy on un-corrupted train-data 0.5408
# Train accuracy on full train-data  0.45458
# test accuracy  0.5596 128.88817656040192
#
# Epoch: 2
# corrupt_loss 29782.339606046677 1164.91921377182
# true loss 47812.97600018978 467.3404589891434
# Train loss of full data 77595.31508636475 606.7588282823563
# total_corrupt, total_true and total_data respectively are :   10000 40000 50000
# Train accuracy on corrupted train-data 0.1189
# Train accuracy on un-corrupted train-data 0.602775
# Train accuracy on full train-data  0.506
# test accuracy  0.5867 123.21173965930939
#
# Epoch: 3
# corrupt_loss 29510.146591424942 1154.1186742782593
# true loss 43225.137876331806 422.4868332147598
# Train loss of full data 72735.2844657898 568.7222646474838
# total_corrupt, total_true and total_data respectively are :   10000 40000 50000
# Train accuracy on corrupted train-data 0.132
# Train accuracy on un-corrupted train-data 0.650525
# Train accuracy on full train-data  0.54682
# test accuracy  0.5957 120.41907328367233
#
# Epoch: 4
# corrupt_loss 28962.73328280449 1132.852058172226
# true loss 39827.395055532455 389.2438875436783
# Train loss of full data 68790.12775039673 537.8427890539169
# total_corrupt, total_true and total_data respectively are :   10000 40000 50000
# Train accuracy on corrupted train-data 0.1417
# Train accuracy on un-corrupted train-data 0.6811
# Train accuracy on full train-data  0.57322
# test accuracy  0.5917 120.60875833034515
#
# Epoch: 5
# corrupt_loss 28243.74571800232 1104.0713448524475
# true loss 37068.58328419924 362.2868468761444
# Train loss of full data 65312.32925796509 510.6590887308121
# total_corrupt, total_true and total_data respectively are :   10000 40000 50000
# Train accuracy on corrupted train-data 0.16
# Train accuracy on un-corrupted train-data 0.7073
# Train accuracy on full train-data  0.59784
# test accuracy  0.5945 122.18852949142456
#
# Epoch: 6
# corrupt_loss 27392.376502990723 1070.4493927955627
# true loss 34767.28924423456 339.7510322332382
# Train loss of full data 62159.66559791565 485.9629683494568
# total_corrupt, total_true and total_data respectively are :   10000 40000 50000
# Train accuracy on corrupted train-data 0.1754
# Train accuracy on un-corrupted train-data 0.72515
# Train accuracy on full train-data  0.6152
# test accuracy  0.5959 123.110611140728
#
# Epoch: 7
# corrupt_loss 26441.62586915493 1032.9627867937088
# true loss 32823.25643789768 320.6493975520134
# Train loss of full data 59264.882170677185 463.32914423942566
# total_corrupt, total_true and total_data respectively are :   10000 40000 50000
# Train accuracy on corrupted train-data 0.1947
# Train accuracy on un-corrupted train-data 0.74185
# Train accuracy on full train-data  0.63242
# test accuracy  0.5976 123.26720422506332
#
# Epoch: 8
# corrupt_loss 25476.27042233944 996.5247782468796
# true loss 31162.950847238302 304.4612025618553
# Train loss of full data 56639.221029281616 442.75246596336365
# total_corrupt, total_true and total_data respectively are :   10000 40000 50000
# Train accuracy on corrupted train-data 0.2142
# Train accuracy on un-corrupted train-data 0.753125
# Train accuracy on full train-data  0.64534
# test accuracy  0.589 127.64463824033737
#
# Epoch: 9
# corrupt_loss 24459.008908987045 956.1195040941238
# true loss 29293.023536771536 286.2719738185406
# Train loss of full data 53752.0324382782 420.21051079034805
# total_corrupt, total_true and total_data respectively are :   10000 40000 50000
# Train accuracy on corrupted train-data 0.235
# Train accuracy on un-corrupted train-data 0.76725
# Train accuracy on full train-data  0.6608
# test accuracy  0.5781 133.14252907037735
#
# Epoch: 10
# corrupt_loss 23515.683084726334 918.3003636598587
# true loss 28039.93785083294 273.96574091911316
# Train loss of full data 51555.620306015015 403.02266216278076
# total_corrupt, total_true and total_data respectively are :   10000 40000 50000
# Train accuracy on corrupted train-data 0.2616
# Train accuracy on un-corrupted train-data 0.7753
# Train accuracy on full train-data  0.67256
# test accuracy  0.5872 134.76372957229614
#
# Epoch: 11
# corrupt_loss 22365.03941011429 873.0068122148514
# true loss 26222.278489649296 256.2883830368519
# Train loss of full data 48587.31786823273 379.7879328727722
# total_corrupt, total_true and total_data respectively are :   10000 40000 50000
# Train accuracy on corrupted train-data 0.2884
# Train accuracy on un-corrupted train-data 0.790875
# Train accuracy on full train-data  0.69038
# test accuracy  0.5806 139.44670248031616
#
# Epoch: 12
# corrupt_loss 21260.394354462624 830.2704113721848
# true loss 25017.18424323201 244.5158873796463
# Train loss of full data 46277.57906341553 361.7482398748398
# total_corrupt, total_true and total_data respectively are :   10000 40000 50000
# Train accuracy on corrupted train-data 0.3075
# Train accuracy on un-corrupted train-data 0.798025
# Train accuracy on full train-data  0.69992
# test accuracy  0.5717 146.74377405643463
#
# Epoch: 13
# corrupt_loss 20090.20753991604 784.642990231514
# true loss 23783.876745671034 232.4569998383522
# Train loss of full data 43874.084478378296 342.9587012529373
# total_corrupt, total_true and total_data respectively are :   10000 40000 50000
# Train accuracy on corrupted train-data 0.3396
# Train accuracy on un-corrupted train-data 0.806175
# Train accuracy on full train-data  0.71286
# test accuracy  0.5725 149.89190185070038
#
# Epoch: 14
# corrupt_loss 19038.55450874567 744.1033312082291
# true loss 22566.601129204035 220.48146823048592
# Train loss of full data 41605.155844688416 325.24831026792526
# total_corrupt, total_true and total_data respectively are :   10000 40000 50000
# Train accuracy on corrupted train-data 0.3708
# Train accuracy on un-corrupted train-data 0.8173
# Train accuracy on full train-data  0.728
# test accuracy  0.5625 154.3813135623932
#
# Epoch: 15
# corrupt_loss 17796.64733070135 696.1986554265022
# true loss 21306.990054547787 208.14274567365646
# Train loss of full data 39103.63747882843 305.6842747926712
# total_corrupt, total_true and total_data respectively are :   10000 40000 50000
# Train accuracy on corrupted train-data 0.4083
# Train accuracy on un-corrupted train-data 0.825225
# Train accuracy on full train-data  0.74184
# test accuracy  0.5546 158.07292211055756
#
# Epoch: 16
# corrupt_loss 16916.590327620506 660.5550503134727
# true loss 20417.12469407916 199.53081661462784
# Train loss of full data 37333.715072155 291.82628735899925
# total_corrupt, total_true and total_data respectively are :   10000 40000 50000
# Train accuracy on corrupted train-data 0.4265
# Train accuracy on un-corrupted train-data 0.831275
# Train accuracy on full train-data  0.75032
# test accuracy  0.5568 160.99193668365479
#
# Epoch: 17
# corrupt_loss 15603.590414762497 611.6091569662094
# true loss 19339.50507938862 188.9634224176407
# Train loss of full data 34943.09575986862 273.15945211052895
# total_corrupt, total_true and total_data respectively are :   10000 40000 50000
# Train accuracy on corrupted train-data 0.4674
# Train accuracy on un-corrupted train-data 0.840325
# Train accuracy on full train-data  0.76574
# test accuracy  0.5598 162.6785900592804
#
# Epoch: 18
# corrupt_loss 14954.51847755909 584.5640386343002
# true loss 18750.287334561348 183.20422685146332
# Train loss of full data 33704.80588102341 263.4915707409382
# total_corrupt, total_true and total_data respectively are :   10000 40000 50000
# Train accuracy on corrupted train-data 0.4851
# Train accuracy on un-corrupted train-data 0.844925
# Train accuracy on full train-data  0.77296
# test accuracy  0.5547 169.59824097156525
#
# Epoch: 19
# corrupt_loss 14219.36849296093 555.2779580950737
# true loss 17743.28673017025 173.45499989390373
# Train loss of full data 31962.65526151657 249.87096619606018
# total_corrupt, total_true and total_data respectively are :   10000 40000 50000
# Train accuracy on corrupted train-data 0.5068
# Train accuracy on un-corrupted train-data 0.85215
# Train accuracy on full train-data  0.78308
# test accuracy  0.5626 168.30335652828217
#
# Epoch: 20
# corrupt_loss 13047.290498435497 507.99367994070053
# true loss 16936.660831093788 165.50280244648457
# Train loss of full data 29983.95147228241 234.37325996160507
# total_corrupt, total_true and total_data respectively are :   10000 40000 50000
# Train accuracy on corrupted train-data 0.5493
# Train accuracy on un-corrupted train-data 0.858375
# Train accuracy on full train-data  0.79656
# test accuracy  0.5645 168.7862479686737
#
# Epoch: 21
# corrupt_loss 12346.803510189056 481.9314368069172
# true loss 16175.701380074024 157.91591322422028
# Train loss of full data 28522.504821300507 222.9838320016861
# total_corrupt, total_true and total_data respectively are :   10000 40000 50000
# Train accuracy on corrupted train-data 0.5682
# Train accuracy on un-corrupted train-data 0.86425
# Train accuracy on full train-data  0.80504
# test accuracy  0.5657 169.33897757530212
#
# Epoch: 22
# corrupt_loss 11350.439610749483 442.2339455783367
# true loss 15285.651666477323 149.47043500840664
# Train loss of full data 26636.091506004333 208.2716388106346
# total_corrupt, total_true and total_data respectively are :   10000 40000 50000
# Train accuracy on corrupted train-data 0.6002
# Train accuracy on un-corrupted train-data 0.8721
# Train accuracy on full train-data  0.81772
# test accuracy  0.5688 172.43406748771667
#
# Epoch: 23
# corrupt_loss 10721.393622875214 419.4129928648472
# true loss 14462.922788739204 141.35640020668507
# Train loss of full data 25184.3164563179 196.90770575404167
# total_corrupt, total_true and total_data respectively are :   10000 40000 50000
# Train accuracy on corrupted train-data 0.6232
# Train accuracy on un-corrupted train-data 0.8782
# Train accuracy on full train-data  0.8272
# test accuracy  0.5557 184.76503765583038
#
# Epoch: 24
# corrupt_loss 10016.320651233196 390.9146568477154
# true loss 13571.00728701055 132.61731651425362
# Train loss of full data 23587.32810306549 184.39100894331932
# total_corrupt, total_true and total_data respectively are :   10000 40000 50000
# Train accuracy on corrupted train-data 0.6466
# Train accuracy on un-corrupted train-data 0.885825
# Train accuracy on full train-data  0.83798
# test accuracy  0.5594 184.72892129421234
#
# Epoch: 25
# corrupt_loss 9320.588389754295 363.9757071137428
# true loss 13072.017216414213 127.65266072750092
# Train loss of full data 22392.605251789093 175.04488848149776
# total_corrupt, total_true and total_data respectively are :   10000 40000 50000
# Train accuracy on corrupted train-data 0.6691
# Train accuracy on un-corrupted train-data 0.889975
# Train accuracy on full train-data  0.8458
# test accuracy  0.5485 191.9251410961151
#
# Epoch: 26
# corrupt_loss 8737.979413837194 341.5275844633579
# true loss 12217.597178578377 119.30425703525543
# Train loss of full data 20955.576556682587 163.82369722425938
# total_corrupt, total_true and total_data respectively are :   10000 40000 50000
# Train accuracy on corrupted train-data 0.6896
# Train accuracy on un-corrupted train-data 0.896375
# Train accuracy on full train-data  0.85502
# test accuracy  0.5617 191.62278199195862
#
# Epoch: 27
# corrupt_loss 8466.67120307684 330.6331986784935
# true loss 11887.643415406346 116.25018692016602
# Train loss of full data 20354.314631938934 159.15769515931606
# total_corrupt, total_true and total_data respectively are :   10000 40000 50000
# Train accuracy on corrupted train-data 0.6977
# Train accuracy on un-corrupted train-data 0.89925
# Train accuracy on full train-data  0.85894
# test accuracy  0.5702 189.27282559871674
#
# Epoch: 28
# corrupt_loss 7883.760676667094 307.9375257641077
# true loss 11330.166587285697 110.7409745529294
# Train loss of full data 19213.927369594574 150.18412443995476
# total_corrupt, total_true and total_data respectively are :   10000 40000 50000
# Train accuracy on corrupted train-data 0.7198
# Train accuracy on un-corrupted train-data 0.903875
# Train accuracy on full train-data  0.86706
# test accuracy  0.5651 193.68269896507263
#
# Epoch: 29
# corrupt_loss 7406.905142605305 289.22038197517395
# true loss 10573.510052189231 103.33233305811882
# Train loss of full data 17980.415152072906 140.55463515222073
# total_corrupt, total_true and total_data respectively are :   10000 40000 50000
# Train accuracy on corrupted train-data 0.7381
# Train accuracy on un-corrupted train-data 0.91055
# Train accuracy on full train-data  0.87606
# test accuracy  0.5612 202.58037173748016
#
# Epoch: 30
# corrupt_loss 6814.999748572707 265.1774189323187
# true loss 10276.220865085721 100.25188571214676
# Train loss of full data 17091.220596313477 133.60926586389542
# total_corrupt, total_true and total_data respectively are :   10000 40000 50000
# Train accuracy on corrupted train-data 0.7597
# Train accuracy on un-corrupted train-data 0.9144
# Train accuracy on full train-data  0.88346
# test accuracy  0.5629 200.58063113689423
#
# Epoch: 31
# corrupt_loss 6884.535767734051 269.1999851614237
# true loss 10239.994117453694 100.01908347010612
# Train loss of full data 17124.5299077034 133.85069540143013
# total_corrupt, total_true and total_data respectively are :   10000 40000 50000
# Train accuracy on corrupted train-data 0.7515
# Train accuracy on un-corrupted train-data 0.91295
# Train accuracy on full train-data  0.88066
# test accuracy  0.5504 208.54288709163666
#
# Epoch: 32
# corrupt_loss 6259.8399739563465 245.29206079244614
# true loss 9375.929368406534 91.49989555776119
# Train loss of full data 15635.769322872162 122.20929412543774
# total_corrupt, total_true and total_data respectively are :   10000 40000 50000
# Train accuracy on corrupted train-data 0.7742
# Train accuracy on un-corrupted train-data 0.9209
# Train accuracy on full train-data  0.89156
# test accuracy  0.5593 209.11210596561432
#
# Epoch: 33
# corrupt_loss 6217.121477119625 242.9211162701249
# true loss 9376.839572511613 91.65854234993458
# Train loss of full data 15593.961099147797 121.90901485085487
# total_corrupt, total_true and total_data respectively are :   10000 40000 50000
# Train accuracy on corrupted train-data 0.777
# Train accuracy on un-corrupted train-data 0.91975
# Train accuracy on full train-data  0.8912
# test accuracy  0.5685 201.44916009902954
#
# Epoch: 34
# corrupt_loss 5875.239124879241 229.8585592508316
# true loss 8600.668827690184 84.05763483792543
# Train loss of full data 14475.908052921295 113.18560074269772
# total_corrupt, total_true and total_data respectively are :   10000 40000 50000
# Train accuracy on corrupted train-data 0.795
# Train accuracy on un-corrupted train-data 0.927
# Train accuracy on full train-data  0.9006
# test accuracy  0.5579 212.51442408561707
#
# Epoch: 35
# corrupt_loss 5765.866019561887 225.73420359939337
# true loss 8593.159186460078 83.90680758655071
# Train loss of full data 14359.025198698044 112.24519310891628
# total_corrupt, total_true and total_data respectively are :   10000 40000 50000
# Train accuracy on corrupted train-data 0.7937
# Train accuracy on un-corrupted train-data 0.926975
# Train accuracy on full train-data  0.90032
# test accuracy  0.5572 211.59448671340942
#
# Epoch: 36
# corrupt_loss 5464.581123813987 215.03227927535772
# true loss 8300.2710005939 81.10349702090025
# Train loss of full data 13764.85221171379 107.59655567258596
# total_corrupt, total_true and total_data respectively are :   10000 40000 50000
# Train accuracy on corrupted train-data 0.8063
# Train accuracy on un-corrupted train-data 0.929775
# Train accuracy on full train-data  0.90508
# test accuracy  0.5557 212.35537958145142
#
# Epoch: 37
# corrupt_loss 5762.594233110547 225.1555941104889
# true loss 8572.923425026238 83.71211939305067
# Train loss of full data 14335.517599105835 112.05898188054562
# total_corrupt, total_true and total_data respectively are :   10000 40000 50000
# Train accuracy on corrupted train-data 0.7978
# Train accuracy on un-corrupted train-data 0.92595
# Train accuracy on full train-data  0.90032
# test accuracy  0.5703 205.80984115600586
#
# Epoch: 38
# corrupt_loss 4959.755259662867 192.3097362294793
# true loss 7598.789708003402 74.32148440182209
# Train loss of full data 12558.545024633408 98.17235372960567
# total_corrupt, total_true and total_data respectively are :   10000 40000 50000
# Train accuracy on corrupted train-data 0.8238
# Train accuracy on un-corrupted train-data 0.935375
# Train accuracy on full train-data  0.91306
# test accuracy  0.5715 211.48918652534485
#
# Epoch: 39
# corrupt_loss 4965.0763887912035 193.70149771869183
# true loss 7692.392771445215 75.20416221395135
# Train loss of full data 12657.469013929367 98.95015747100115
# total_corrupt, total_true and total_data respectively are :   10000 40000 50000
# Train accuracy on corrupted train-data 0.8248
# Train accuracy on un-corrupted train-data 0.9349
# Train accuracy on full train-data  0.91288
# test accuracy  0.5725 210.11871945858002
#
# Epoch: 40
# corrupt_loss 5247.514603495598 205.32637098431587
# true loss 7702.789086177945 75.17524962127209
# Train loss of full data 12950.303674936295 101.23627562820911
# total_corrupt, total_true and total_data respectively are :   10000 40000 50000
# Train accuracy on corrupted train-data 0.8153
# Train accuracy on un-corrupted train-data 0.9342
# Train accuracy on full train-data  0.91042
# test accuracy  0.5755 209.37699902057648
#
# Epoch: 41
# corrupt_loss 4603.472927715629 180.1545769236982
# true loss 7113.723130796105 69.54673929139972
# Train loss of full data 11717.19597864151 91.59006381034851
# total_corrupt, total_true and total_data respectively are :   10000 40000 50000
# Train accuracy on corrupted train-data 0.835
# Train accuracy on un-corrupted train-data 0.93965
# Train accuracy on full train-data  0.91872
# test accuracy  0.576 207.24337935447693
#
# Epoch: 42
# corrupt_loss 4495.163545936346 175.82745322212577
# true loss 6900.567921437323 67.41833861917257
# Train loss of full data 11395.731497883797 89.07165572047234
# total_corrupt, total_true and total_data respectively are :   10000 40000 50000
# Train accuracy on corrupted train-data 0.8378
# Train accuracy on un-corrupted train-data 0.9418
# Train accuracy on full train-data  0.921
# test accuracy  0.5701 211.77282881736755
#
# Epoch: 43
# corrupt_loss 4631.531768061221 180.5451749637723
# true loss 7040.612135924399 68.8283831179142
# Train loss of full data 11672.143836975098 91.25300881266594
# total_corrupt, total_true and total_data respectively are :   10000 40000 50000
# Train accuracy on corrupted train-data 0.8361
# Train accuracy on un-corrupted train-data 0.940125
# Train accuracy on full train-data  0.91932
# test accuracy  0.5661 212.92610001564026
#
# Epoch: 44
# corrupt_loss 4546.787882171571 177.77594424039125
# true loss 6997.624716624618 68.32897819578648
# Train loss of full data 11544.41263961792 90.2433086335659
# total_corrupt, total_true and total_data respectively are :   10000 40000 50000
# Train accuracy on corrupted train-data 0.8397
# Train accuracy on un-corrupted train-data 0.9406
# Train accuracy on full train-data  0.92042
# test accuracy  0.5722 216.55272209644318
#
# Epoch: 45
# corrupt_loss 4361.521173354238 170.22682101652026
# true loss 6789.40235324949 66.35260471701622
# Train loss of full data 11150.92363023758 87.17483573406935
# total_corrupt, total_true and total_data respectively are :   10000 40000 50000
# Train accuracy on corrupted train-data 0.8484
# Train accuracy on un-corrupted train-data 0.942725
# Train accuracy on full train-data  0.92386
# test accuracy  0.5786 211.98737621307373
#
# Epoch: 46
# corrupt_loss 4389.78028678894 171.91902358084917
# true loss 6621.053763158619 64.68699055537581
# Train loss of full data 11010.834069252014 86.07682874798775
# total_corrupt, total_true and total_data respectively are :   10000 40000 50000
# Train accuracy on corrupted train-data 0.845
# Train accuracy on un-corrupted train-data 0.943325
# Train accuracy on full train-data  0.92366
# test accuracy  0.5696 218.0390260219574
#
# Epoch: 47
# corrupt_loss 4565.212467037141 178.5583587512374
# true loss 6812.4873463362455 66.49885203689337
# Train loss of full data 11377.699826955795 88.93622165173292
# total_corrupt, total_true and total_data respectively are :   10000 40000 50000
# Train accuracy on corrupted train-data 0.8393
# Train accuracy on un-corrupted train-data 0.942375
# Train accuracy on full train-data  0.92176
# test accuracy  0.5645 216.35763132572174
#
# Epoch: 48
# corrupt_loss 4376.572229675949 171.77651781588793
# true loss 6817.616696733981 66.58980855718255
# Train loss of full data 11194.188836753368 87.46895162388682
# total_corrupt, total_true and total_data respectively are :   10000 40000 50000
# Train accuracy on corrupted train-data 0.8446
# Train accuracy on un-corrupted train-data 0.942325
# Train accuracy on full train-data  0.92278
# test accuracy  0.5714 215.1675000190735
#
# Epoch: 49
# corrupt_loss 4169.520420357585 163.99804446473718
# true loss 6530.63011438027 63.844459250569344
# Train loss of full data 10700.150500774384 83.67310329526663
# total_corrupt, total_true and total_data respectively are :   10000 40000 50000
# Train accuracy on corrupted train-data 0.8504
# Train accuracy on un-corrupted train-data 0.94405
# Train accuracy on full train-data  0.92532
# test accuracy  0.5719 213.4796702861786
#
# Epoch: 50
# corrupt_loss 4055.083558782935 158.48822053521872
# true loss 6464.161851096898 63.09440480545163
# Train loss of full data 10519.245447039604 82.21350947022438
# total_corrupt, total_true and total_data respectively are :   10000 40000 50000
# Train accuracy on corrupted train-data 0.857
# Train accuracy on un-corrupted train-data 0.94445
# Train accuracy on full train-data  0.92696
# test accuracy  0.5729 216.44829392433167
#
# Epoch: 51
# corrupt_loss 4010.266018770635 157.0941897071898
# true loss 6423.5356657244265 62.73641647398472
# Train loss of full data 10433.80169403553 81.55321872234344
# total_corrupt, total_true and total_data respectively are :   10000 40000 50000
# Train accuracy on corrupted train-data 0.8584
# Train accuracy on un-corrupted train-data 0.9457
# Train accuracy on full train-data  0.92824
# test accuracy  0.5787 214.71832048892975
#
# Epoch: 52
# corrupt_loss 4150.621907070279 161.58999303728342
# true loss 6597.349781490862 64.47971433773637
# Train loss of full data 10747.97179043293 84.01415161043406
# total_corrupt, total_true and total_data respectively are :   10000 40000 50000
# Train accuracy on corrupted train-data 0.8578
# Train accuracy on un-corrupted train-data 0.9446
# Train accuracy on full train-data  0.92724
# test accuracy  0.5767 212.20715487003326
#
# Epoch: 53
# corrupt_loss 3782.6491566598415 148.2930646687746
# true loss 5878.196269795299 57.475216545164585
# Train loss of full data 9660.845358610153 75.50882148742676
# total_corrupt, total_true and total_data respectively are :   10000 40000 50000
# Train accuracy on corrupted train-data 0.8657
# Train accuracy on un-corrupted train-data 0.950925
# Train accuracy on full train-data  0.93388
# test accuracy  0.5811 213.69872117042542
#
# Epoch: 54
# corrupt_loss 4154.606530897319 161.5600943863392
# true loss 6352.170596666634 62.07227323949337
# Train loss of full data 10506.77708864212 82.13153839111328
# total_corrupt, total_true and total_data respectively are :   10000 40000 50000
# Train accuracy on corrupted train-data 0.8546
# Train accuracy on un-corrupted train-data 0.946675
# Train accuracy on full train-data  0.92826
# test accuracy  0.5707 214.9294466972351
#
# Epoch: 55
# corrupt_loss 4230.622961971909 165.06222330406308
# true loss 6597.446117635816 64.47808761894703
# Train loss of full data 10828.069068431854 84.66182320564985
# total_corrupt, total_true and total_data respectively are :   10000 40000 50000
# Train accuracy on corrupted train-data 0.8516
# Train accuracy on un-corrupted train-data 0.9435
# Train accuracy on full train-data  0.92512
# test accuracy  0.575 214.30604231357574
#
# Epoch: 56
# corrupt_loss 4205.639050252736 164.70196720212698
# true loss 6654.223505411297 65.05525152757764
# Train loss of full data 10859.862491130829 84.8941313996911
# total_corrupt, total_true and total_data respectively are :   10000 40000 50000
# Train accuracy on corrupted train-data 0.8502
# Train accuracy on un-corrupted train-data 0.9438
# Train accuracy on full train-data  0.92508
# test accuracy  0.5668 218.39958333969116
#
# Epoch: 57
# corrupt_loss 4071.1161691769958 158.7709912508726
# true loss 6156.378566544503 60.086800172924995
# Train loss of full data 10227.494719743729 79.94863987714052
# total_corrupt, total_true and total_data respectively are :   10000 40000 50000
# Train accuracy on corrupted train-data 0.8578
# Train accuracy on un-corrupted train-data 0.947475
# Train accuracy on full train-data  0.92954
# test accuracy  0.5809 211.12993776798248
#
# Epoch: 58
# corrupt_loss 3791.642815183848 148.61779407784343
# true loss 5928.17444910109 57.916650872677565
# Train loss of full data 9719.817359924316 75.98444533348083
# total_corrupt, total_true and total_data respectively are :   10000 40000 50000
# Train accuracy on corrupted train-data 0.8669
# Train accuracy on un-corrupted train-data 0.950775
# Train accuracy on full train-data  0.934
# test accuracy  0.581 217.09475576877594
#
# Epoch: 59
# corrupt_loss 3866.9236052259803 151.0985279045999
# true loss 5962.441805586219 58.26078539714217
# Train loss of full data 9829.365438222885 76.82673342525959
# total_corrupt, total_true and total_data respectively are :   10000 40000 50000
# Train accuracy on corrupted train-data 0.8661
# Train accuracy on un-corrupted train-data 0.94895
# Train accuracy on full train-data  0.93238
# test accuracy  0.571 215.67219257354736
#
# Epoch: 60
# corrupt_loss 4205.970406211913 164.2384164109826
# true loss 6190.099189717323 60.477255288511515
# Train loss of full data 10396.069653630257 81.25265923142433
# total_corrupt, total_true and total_data respectively are :   10000 40000 50000
# Train accuracy on corrupted train-data 0.8527
# Train accuracy on un-corrupted train-data 0.9475
# Train accuracy on full train-data  0.92854
# test accuracy  0.5705 212.39484798908234
#
# Epoch: 61
# corrupt_loss 3992.4922778084874 156.5567909553647
# true loss 6465.20689157024 63.13498780503869
# Train loss of full data 10457.699218511581 81.75175367295742
# total_corrupt, total_true and total_data respectively are :   10000 40000 50000
# Train accuracy on corrupted train-data 0.8596
# Train accuracy on un-corrupted train-data 0.944175
# Train accuracy on full train-data  0.92726
# test accuracy  0.5712 215.69384920597076
#
# Epoch: 62
# corrupt_loss 3405.525684837252 133.03626580908895
# true loss 5547.044393938035 54.23267710953951
# Train loss of full data 8952.570157527924 69.99381047487259
# total_corrupt, total_true and total_data respectively are :   10000 40000 50000
# Train accuracy on corrupted train-data 0.8844
# Train accuracy on un-corrupted train-data 0.953925
# Train accuracy on full train-data  0.94002
# test accuracy  0.5652 225.3176783323288
#
# Epoch: 63
# corrupt_loss 3801.6541413739324 148.07528026401997
# true loss 5920.886723700911 57.90014337748289
# Train loss of full data 9722.540826320648 76.0380090251565
# total_corrupt, total_true and total_data respectively are :   10000 40000 50000
# Train accuracy on corrupted train-data 0.8672
# Train accuracy on un-corrupted train-data 0.950625
# Train accuracy on full train-data  0.93394
# test accuracy  0.5682 219.67301905155182
#
# Epoch: 64
# corrupt_loss 3878.4540715143085 151.68274750560522
# true loss 5894.069647606462 57.55294086411595
# Train loss of full data 9772.523796319962 76.4126125946641
# total_corrupt, total_true and total_data respectively are :   10000 40000 50000
# Train accuracy on corrupted train-data 0.8652
# Train accuracy on un-corrupted train-data 0.949425
# Train accuracy on full train-data  0.93258
# test accuracy  0.57 217.4249815940857
#
# Epoch: 65
# corrupt_loss 3874.4197445586324 152.3586842417717
# true loss 6229.869513884187 60.832242257893085
# Train loss of full data 10104.289335846901 78.96595511585474
# total_corrupt, total_true and total_data respectively are :   10000 40000 50000
# Train accuracy on corrupted train-data 0.8641
# Train accuracy on un-corrupted train-data 0.947475
# Train accuracy on full train-data  0.9308
# test accuracy  0.5704 216.2968566417694
#
# Epoch: 66
# corrupt_loss 3764.664017368108 147.3976781219244
# true loss 5925.616035886109 57.96725372970104
# Train loss of full data 9690.280081748962 75.77449219301343
# total_corrupt, total_true and total_data respectively are :   10000 40000 50000
# Train accuracy on corrupted train-data 0.8665
# Train accuracy on un-corrupted train-data 0.949875
# Train accuracy on full train-data  0.9332
# test accuracy  0.5757 215.42368972301483
#
# Epoch: 67
# corrupt_loss 3519.2163491770625 137.45827839523554
# true loss 5622.093807280064 54.877059902995825
# Train loss of full data 9141.310100793839 71.46330431103706
# total_corrupt, total_true and total_data respectively are :   10000 40000 50000
# Train accuracy on corrupted train-data 0.877
# Train accuracy on un-corrupted train-data 0.9519
# Train accuracy on full train-data  0.93692
# test accuracy  0.5723 220.19463443756104
#
# Epoch: 68
# corrupt_loss 3997.497412674129 156.72034426406026
# true loss 6170.661319147795 60.29847535863519
# Train loss of full data 10168.158677816391 79.49077496677637
# total_corrupt, total_true and total_data respectively are :   10000 40000 50000
# Train accuracy on corrupted train-data 0.8595
# Train accuracy on un-corrupted train-data 0.9468
# Train accuracy on full train-data  0.92934
# test accuracy  0.564 223.13764894008636
#
# Epoch: 69
# corrupt_loss 3505.598928295076 136.32870253175497
# true loss 5607.8799326606095 54.799427170306444
# Train loss of full data 9113.478875756264 71.22645592689514
# total_corrupt, total_true and total_data respectively are :   10000 40000 50000
# Train accuracy on corrupted train-data 0.8768
# Train accuracy on un-corrupted train-data 0.952825
# Train accuracy on full train-data  0.93762
# test accuracy  0.5769 214.6207593679428
#
# Epoch: 70
# corrupt_loss 3340.2081310264766 131.07667869701982
# true loss 5371.21287887916 52.45652688294649
# Train loss of full data 8711.42103767395 68.08569969981909
# total_corrupt, total_true and total_data respectively are :   10000 40000 50000
# Train accuracy on corrupted train-data 0.882
# Train accuracy on un-corrupted train-data 0.955075
# Train accuracy on full train-data  0.94046
# test accuracy  0.5785 218.18050742149353
#
# Epoch: 71
# corrupt_loss 3705.5113950408995 145.88792924955487
# true loss 5805.47033213079 56.83341684564948
# Train loss of full data 9510.981744766235 74.42077874392271
# total_corrupt, total_true and total_data respectively are :   10000 40000 50000
# Train accuracy on corrupted train-data 0.8736
# Train accuracy on un-corrupted train-data 0.951325
# Train accuracy on full train-data  0.93578
# test accuracy  0.5827 215.53009021282196
#
# Epoch: 72
# corrupt_loss 4204.577043566853 163.97958502545953
# true loss 6336.377337262034 61.843311447650194
# Train loss of full data 10540.954355955124 82.39314606040716
# total_corrupt, total_true and total_data respectively are :   10000 40000 50000
# Train accuracy on corrupted train-data 0.8509
# Train accuracy on un-corrupted train-data 0.94625
# Train accuracy on full train-data  0.92718
# test accuracy  0.5786 212.20187366008759
#
# Epoch: 73
# corrupt_loss 3796.0317941382527 148.85054702684283
# true loss 6004.318105474114 58.66466945782304
# Train loss of full data 9800.349844932556 76.60419560223818
# total_corrupt, total_true and total_data respectively are :   10000 40000 50000
# Train accuracy on corrupted train-data 0.869
# Train accuracy on un-corrupted train-data 0.9491
# Train accuracy on full train-data  0.93308
# test accuracy  0.5795 211.99881541728973
#
# Epoch: 74
# corrupt_loss 3563.9280871637166 139.47406535223126
# true loss 5605.2329294495285 54.75580324605107
# Train loss of full data 9169.160963892937 71.66031029075384
# total_corrupt, total_true and total_data respectively are :   10000 40000 50000
# Train accuracy on corrupted train-data 0.8723
# Train accuracy on un-corrupted train-data 0.9546
# Train accuracy on full train-data  0.93814
# test accuracy  0.5836 212.07653868198395
#
# Epoch: 75
# corrupt_loss 3914.163544692099 153.18344849720597
# true loss 6137.713440757245 59.896608397364616
# Train loss of full data 10051.876949071884 78.56502764672041
# total_corrupt, total_true and total_data respectively are :   10000 40000 50000
# Train accuracy on corrupted train-data 0.8595
# Train accuracy on un-corrupted train-data 0.947875
# Train accuracy on full train-data  0.9302
# test accuracy  0.5793 211.184743642807
#
# Epoch: 76
# corrupt_loss 3623.208236064762 142.00082275643945
# true loss 5561.527890283614 54.28897224739194
# Train loss of full data 9184.736102819443 71.78514897078276
# total_corrupt, total_true and total_data respectively are :   10000 40000 50000
# Train accuracy on corrupted train-data 0.8733
# Train accuracy on un-corrupted train-data 0.9549
# Train accuracy on full train-data  0.93858
# test accuracy  0.5757 219.92033660411835
#
# Epoch: 77
# corrupt_loss 2791.6098891030997 109.54735664092004
# true loss 4687.602742327377 45.762551138177514
# Train loss of full data 7479.2126551270485 58.45230983570218
# total_corrupt, total_true and total_data respectively are :   10000 40000 50000
# Train accuracy on corrupted train-data 0.9043
# Train accuracy on un-corrupted train-data 0.96225
# Train accuracy on full train-data  0.95066
# test accuracy  0.5782 219.6374716758728
#
# Epoch: 78
# corrupt_loss 3005.6795781962574 118.38813547044992
# true loss 4974.620763169602 48.60588779486716
# Train loss of full data 7980.300424814224 62.382396068423986
# total_corrupt, total_true and total_data respectively are :   10000 40000 50000
# Train accuracy on corrupted train-data 0.8906
# Train accuracy on un-corrupted train-data 0.958825
# Train accuracy on full train-data  0.94518
# test accuracy  0.5702 226.176509141922
#
# Epoch: 79
# corrupt_loss 4927.553303897381 191.96495566517115
# true loss 7302.200319129974 71.33943497762084
# Train loss of full data 12229.753722667694 95.59876645356417
# total_corrupt, total_true and total_data respectively are :   10000 40000 50000
# Train accuracy on corrupted train-data 0.8301
# Train accuracy on un-corrupted train-data 0.938
# Train accuracy on full train-data  0.91642
# test accuracy  0.5709 209.71465146541595
#
# Epoch: 80
# corrupt_loss 3930.0609216839075 154.26206828653812
# true loss 6003.284036960453 58.67660151049495
# Train loss of full data 9933.344925880432 77.64582338184118
# total_corrupt, total_true and total_data respectively are :   10000 40000 50000
# Train accuracy on corrupted train-data 0.8625
# Train accuracy on un-corrupted train-data 0.949775
# Train accuracy on full train-data  0.93232
# test accuracy  0.5828 206.50403332710266
#
# Epoch: 81
# corrupt_loss 2800.2477175556123 110.17415508069098
# true loss 4458.137369982898 43.5594435390085
# Train loss of full data 7258.385075807571 56.74939405545592
# total_corrupt, total_true and total_data respectively are :   10000 40000 50000
# Train accuracy on corrupted train-data 0.9009
# Train accuracy on un-corrupted train-data 0.9627
# Train accuracy on full train-data  0.95034
# test accuracy  0.5877 216.3749953508377
#
# Epoch: 82
# corrupt_loss 3267.2156728301197 127.38047237507999
# true loss 5226.016300637275 51.09804521128535
# Train loss of full data 8493.232033252716 66.40871107578278
# total_corrupt, total_true and total_data respectively are :   10000 40000 50000
# Train accuracy on corrupted train-data 0.8866
# Train accuracy on un-corrupted train-data 0.956425
# Train accuracy on full train-data  0.94246
# test accuracy  0.5705 225.381733417511
#
# Epoch: 83
# corrupt_loss 4235.586309969425 165.1569483950734
# true loss 6732.1611775532365 65.75692163035274
# Train loss of full data 10967.747527599335 85.72055219113827
# total_corrupt, total_true and total_data respectively are :   10000 40000 50000
# Train accuracy on corrupted train-data 0.8547
# Train accuracy on un-corrupted train-data 0.94305
# Train accuracy on full train-data  0.92538
# test accuracy  0.5746 209.22654819488525
#
# Epoch: 84
# corrupt_loss 4302.775644108653 167.732315428555
# true loss 6671.94965711236 65.18081576749682
# Train loss of full data 10974.725308418274 85.79547370225191
# total_corrupt, total_true and total_data respectively are :   10000 40000 50000
# Train accuracy on corrupted train-data 0.8517
# Train accuracy on un-corrupted train-data 0.943625
# Train accuracy on full train-data  0.92524
# test accuracy  0.5968 197.1874840259552
#
# Epoch: 85
# corrupt_loss 2805.05782937631 109.09060062840581
# true loss 4612.341147053987 45.035142911598086
# Train loss of full data 7417.399050712585 57.97073922306299
# total_corrupt, total_true and total_data respectively are :   10000 40000 50000
# Train accuracy on corrupted train-data 0.9041
# Train accuracy on un-corrupted train-data 0.9618
# Train accuracy on full train-data  0.95026
# test accuracy  0.5919 212.20902860164642
#
# Epoch: 86
# corrupt_loss 2951.1405289508402 114.96046075224876
# true loss 4582.395584033802 44.72441465035081
# Train loss of full data 7533.536145210266 58.90928974747658
# total_corrupt, total_true and total_data respectively are :   10000 40000 50000
# Train accuracy on corrupted train-data 0.8983
# Train accuracy on un-corrupted train-data 0.961275
# Train accuracy on full train-data  0.94868
# test accuracy  0.5778 219.14226508140564
#
# Epoch: 87
# corrupt_loss 4183.1432484686375 163.93614617735147
# true loss 6432.930449336767 62.81412814557552
# Train loss of full data 10616.073799610138 82.99916629493237
# total_corrupt, total_true and total_data respectively are :   10000 40000 50000
# Train accuracy on corrupted train-data 0.855
# Train accuracy on un-corrupted train-data 0.945575
# Train accuracy on full train-data  0.92746
# test accuracy  0.5717 214.52591228485107
#
# Epoch: 88
# corrupt_loss 4485.6903182938695 174.76548019051552
# true loss 6664.58678009361 65.04111444205046
# Train loss of full data 11150.277127742767 87.19836615025997
# total_corrupt, total_true and total_data respectively are :   10000 40000 50000
# Train accuracy on corrupted train-data 0.8461
# Train accuracy on un-corrupted train-data 0.942675
# Train accuracy on full train-data  0.92336
# test accuracy  0.5697 208.6152547597885
#
# Epoch: 89
# corrupt_loss 3181.731845723465 124.36080772988498
# true loss 5077.011209182441 49.618335988372564
# Train loss of full data 8258.743103384972 64.55327092856169
# total_corrupt, total_true and total_data respectively are :   10000 40000 50000
# Train accuracy on corrupted train-data 0.8862
# Train accuracy on un-corrupted train-data 0.957675
# Train accuracy on full train-data  0.94338
# test accuracy  0.5788 210.7351667881012
#
# Epoch: 90
# corrupt_loss 2491.8457509242 97.52109643630683
# true loss 3911.149727165699 38.233965618535876
# Train loss of full data 6402.995403826237 50.040761683136225
# total_corrupt, total_true and total_data respectively are :   10000 40000 50000
# Train accuracy on corrupted train-data 0.9158
# Train accuracy on un-corrupted train-data 0.9684
# Train accuracy on full train-data  0.95788
# test accuracy  0.5785 217.36172020435333
#
# Epoch: 91
# corrupt_loss 3149.365685718134 123.08232327736914
# true loss 5003.134191896766 48.912715550512075
# Train loss of full data 8152.499854803085 63.71748016029596
# total_corrupt, total_true and total_data respectively are :   10000 40000 50000
# Train accuracy on corrupted train-data 0.8906
# Train accuracy on un-corrupted train-data 0.957775
# Train accuracy on full train-data  0.94434
# test accuracy  0.5699 222.23478841781616
#
# Epoch: 92
# corrupt_loss 4982.254642143846 193.82727555185556
# true loss 7565.925183836371 73.94254902377725
# Train loss of full data 12548.179708480835 98.12773517519236
# total_corrupt, total_true and total_data respectively are :   10000 40000 50000
# Train accuracy on corrupted train-data 0.8317
# Train accuracy on un-corrupted train-data 0.935
# Train accuracy on full train-data  0.91434
# test accuracy  0.5729 207.25770819187164
#
# Epoch: 93
# corrupt_loss 3938.3812782019377 153.42844118364155
# true loss 5964.718417670578 58.29267616197467
# Train loss of full data 9903.099602222443 77.42256510257721
# total_corrupt, total_true and total_data respectively are :   10000 40000 50000
# Train accuracy on corrupted train-data 0.8637
# Train accuracy on un-corrupted train-data 0.950025
# Train accuracy on full train-data  0.93276
# test accuracy  0.5926 200.04440081119537
#
# Epoch: 94
# corrupt_loss 2611.980772446841 102.96216424368322
# true loss 4221.89666148182 41.22471822146326
# Train loss of full data 6833.877449989319 53.40058681741357
# total_corrupt, total_true and total_data respectively are :   10000 40000 50000
# Train accuracy on corrupted train-data 0.9079
# Train accuracy on un-corrupted train-data 0.965875
# Train accuracy on full train-data  0.95428
# test accuracy  0.5875 216.09357404708862
#
# Epoch: 95
# corrupt_loss 2434.221506977454 95.06960543431342
# true loss 4119.390167878941 40.23657373338938
# Train loss of full data 6553.61165702343 51.21930409967899
# total_corrupt, total_true and total_data respectively are :   10000 40000 50000
# Train accuracy on corrupted train-data 0.9145
# Train accuracy on un-corrupted train-data 0.96545
# Train accuracy on full train-data  0.95526
# test accuracy  0.5826 218.1851270198822
#
# Epoch: 96
# corrupt_loss 4486.157723657787 176.6064680069685
# true loss 6497.440291497856 63.41723823733628
# Train loss of full data 10983.597951054573 85.8516658693552
# total_corrupt, total_true and total_data respectively are :   10000 40000 50000
# Train accuracy on corrupted train-data 0.8447
# Train accuracy on un-corrupted train-data 0.944525
# Train accuracy on full train-data  0.92456
# test accuracy  0.5819 209.33436512947083
#
# Epoch: 97
# corrupt_loss 4445.645052917302 173.5432620793581
# true loss 6738.9016985967755 65.82592745125294
# Train loss of full data 11184.546742916107 87.44900035858154
# total_corrupt, total_true and total_data respectively are :   10000 40000 50000
# Train accuracy on corrupted train-data 0.8466
# Train accuracy on un-corrupted train-data 0.9426
# Train accuracy on full train-data  0.9234
# test accuracy  0.5793 204.01897776126862
#
# Epoch: 98
# corrupt_loss 3293.0211261585355 129.1805876120925
# true loss 5150.78850563243 50.283168490976095
# Train loss of full data 8443.80962896347 66.01462149620056
# total_corrupt, total_true and total_data respectively are :   10000 40000 50000
# Train accuracy on corrupted train-data 0.8853
# Train accuracy on un-corrupted train-data 0.957025
# Train accuracy on full train-data  0.94268
# test accuracy  0.5833 212.25228261947632
#
# Epoch: 99
# corrupt_loss 3005.93365162611 116.85833244398236
# true loss 4953.469723103568 48.36203690804541
# Train loss of full data 7959.403457641602 62.22979434207082
# total_corrupt, total_true and total_data respectively are :   10000 40000 50000
# Train accuracy on corrupted train-data 0.8937
# Train accuracy on un-corrupted train-data 0.958325
# Train accuracy on full train-data  0.9454
# test accuracy  0.5833 217.19775426387787
#
# Epoch: 100
# corrupt_loss 3700.922480247915 144.79832806438208
# true loss 5685.097323659807 55.57860531657934
# Train loss of full data 9386.019805908203 73.3634912148118
# total_corrupt, total_true and total_data respectively are :   10000 40000 50000
# Train accuracy on corrupted train-data 0.8702
# Train accuracy on un-corrupted train-data 0.95155
# Train accuracy on full train-data  0.93528
# test accuracy  0.5699 214.63413166999817
#
# Epoch: 101
# corrupt_loss 4037.3268151953816 157.88531691022217
# true loss 5897.494181666523 57.64339656382799
# Train loss of full data 9934.821063518524 77.68100920319557
# total_corrupt, total_true and total_data respectively are :   10000 40000 50000
# Train accuracy on corrupted train-data 0.8616
# Train accuracy on un-corrupted train-data 0.95075
# Train accuracy on full train-data  0.93292
# test accuracy  0.5698 212.71638870239258
#
# Epoch: 102
# corrupt_loss 3495.9006971418858 135.66513501480222
# true loss 5364.9083710722625 52.39688904583454
# Train loss of full data 8860.809136986732 69.2401564642787
# total_corrupt, total_true and total_data respectively are :   10000 40000 50000
# Train accuracy on corrupted train-data 0.8786
# Train accuracy on un-corrupted train-data 0.956575
# Train accuracy on full train-data  0.94098
# test accuracy  0.5938 205.4945912361145
#
# Epoch: 103
# corrupt_loss 2563.032619986683 99.9014586424455
# true loss 4285.382437070832 41.81394970975816
# Train loss of full data 6848.415035009384 53.54088420793414
# total_corrupt, total_true and total_data respectively are :   10000 40000 50000
# Train accuracy on corrupted train-data 0.9096
# Train accuracy on un-corrupted train-data 0.96505
# Train accuracy on full train-data  0.95396
# test accuracy  0.5843 217.79252922534943
#
# Epoch: 104
# corrupt_loss 3032.3734849356115 118.80120282061398
# true loss 4960.3951763138175 48.42279511317611
# Train loss of full data 7992.7686059474945 62.47297829389572
# total_corrupt, total_true and total_data respectively are :   10000 40000 50000
# Train accuracy on corrupted train-data 0.8959
# Train accuracy on un-corrupted train-data 0.957325
# Train accuracy on full train-data  0.94504
# test accuracy  0.5787 218.80769777297974
#
# Epoch: 105
# corrupt_loss 4413.618848748505 173.80451536923647
# true loss 6708.92348055914 65.52461101859808
# Train loss of full data 11122.542353630066 86.92004343122244
# total_corrupt, total_true and total_data respectively are :   10000 40000 50000
# Train accuracy on corrupted train-data 0.8509
# Train accuracy on un-corrupted train-data 0.942875
# Train accuracy on full train-data  0.92448
# test accuracy  0.5814 205.62948155403137
#
# Epoch: 106
# corrupt_loss 3391.4018083512783 131.45948095992208
# true loss 5475.810891918838 53.50253718532622
# Train loss of full data 8867.212715864182 69.3100276440382
# total_corrupt, total_true and total_data respectively are :   10000 40000 50000
# Train accuracy on corrupted train-data 0.8819
# Train accuracy on un-corrupted train-data 0.954925
# Train accuracy on full train-data  0.94032
# test accuracy  0.5813 214.92818534374237
#
# Epoch: 107
# corrupt_loss 3045.2109712027013 118.9439093619585
# true loss 4782.903156932443 46.76120348274708
# Train loss of full data 7828.114161968231 61.208312682807446
# total_corrupt, total_true and total_data respectively are :   10000 40000 50000
# Train accuracy on corrupted train-data 0.8927
# Train accuracy on un-corrupted train-data 0.959725
# Train accuracy on full train-data  0.94632
# test accuracy  0.5823 213.36175155639648
#
# Epoch: 108
# corrupt_loss 3211.568848967552 125.92990446090698
# true loss 4910.074863549322 47.93596990779042
# Train loss of full data 8121.643671989441 63.551425609737635
# total_corrupt, total_true and total_data respectively are :   10000 40000 50000
# Train accuracy on corrupted train-data 0.8877
# Train accuracy on un-corrupted train-data 0.958375
# Train accuracy on full train-data  0.94424
# test accuracy  0.5824 213.24109411239624
#
# Epoch: 109
# corrupt_loss 3586.188151754439 139.75757710263133
# true loss 5713.710906241089 55.819095976650715
# Train loss of full data 9299.899166345596 72.70612335950136
# total_corrupt, total_true and total_data respectively are :   10000 40000 50000
# Train accuracy on corrupted train-data 0.8736
# Train accuracy on un-corrupted train-data 0.9517
# Train accuracy on full train-data  0.93608
# test accuracy  0.5743 217.03360247612
#
# Epoch: 110
# corrupt_loss 4382.650330752134 171.9917850419879
# true loss 6553.964927915484 63.98022095486522
# Train loss of full data 10936.615358352661 85.51396471261978
# total_corrupt, total_true and total_data respectively are :   10000 40000 50000
# Train accuracy on corrupted train-data 0.8512
# Train accuracy on un-corrupted train-data 0.94465
# Train accuracy on full train-data  0.92596
# test accuracy  0.5942 197.35666620731354
#
# Epoch: 111
# corrupt_loss 3150.490448527038 122.91852881759405
# true loss 4935.904302455485 48.19517423771322
# Train loss of full data 8086.394774675369 63.204487320035696
# total_corrupt, total_true and total_data respectively are :   10000 40000 50000
# Train accuracy on corrupted train-data 0.8904
# Train accuracy on un-corrupted train-data 0.9593
# Train accuracy on full train-data  0.94552
# test accuracy  0.5888 208.2707954645157
#
# Epoch: 112
# ...
# Train loss of full data 2943.8763716369867 23.00319083314389
# total_corrupt, total_true and total_data respectively are :   10000 40000 50000
# Train accuracy on corrupted train-data 0.9651
# Train accuracy on un-corrupted train-data 0.98585
# Train accuracy on full train-data  0.9817
# test accuracy  0.6073 206.04008281230927
#
# Epoch: 153
# corrupt_loss 681.3882430600934 26.791964774252847
# true loss 1237.9521415410563 12.08673716103658
# Train loss of full data 1919.3403949439526 14.998698299750686
# total_corrupt, total_true and total_data respectively are :   10000 40000 50000
# Train accuracy on corrupted train-data 0.9802
# Train accuracy on un-corrupted train-data 0.99165
# Train accuracy on full train-data  0.98936
# test accuracy  0.6058 220.24699413776398
#
# Epoch: 154
# corrupt_loss 752.7533020600677 28.97724077058956
# true loss 1241.3883353406563 12.076689227949828
# Train loss of full data 1994.141650468111 15.583174299448729
# total_corrupt, total_true and total_data respectively are :   10000 40000 50000
# Train accuracy on corrupted train-data 0.9785
# Train accuracy on un-corrupted train-data 0.99135
# Train accuracy on full train-data  0.98878
# test accuracy  0.5998 226.25296926498413
#
# Epoch: 155
# corrupt_loss 3243.1629275698215 126.89670938346535
# true loss 5243.012563846074 51.16380127239972
# Train loss of full data 8486.17559337616 66.41774406284094
# total_corrupt, total_true and total_data respectively are :   10000 40000 50000
# Train accuracy on corrupted train-data 0.894
# Train accuracy on un-corrupted train-data 0.956225
# Train accuracy on full train-data  0.94378
# test accuracy  0.5626 230.08301329612732
#
# Epoch: 156
# corrupt_loss 9592.84469653666 376.00207797437906
# true loss 12395.242422163486 121.21003495901823
# Train loss of full data 21988.086869716644 171.8505207002163
# total_corrupt, total_true and total_data respectively are :   10000 40000 50000
# Train accuracy on corrupted train-data 0.701
# Train accuracy on un-corrupted train-data 0.8977
# Train accuracy on full train-data  0.85836
# test accuracy  0.5986 169.99111187458038
#
# Epoch: 157
# corrupt_loss 2152.1525495536625 84.07271471060812
# true loss 3691.6108314748853 36.09188307262957
# Train loss of full data 5843.763327360153 45.679333217442036
# total_corrupt, total_true and total_data respectively are :   10000 40000 50000
# Train accuracy on corrupted train-data 0.9245
# Train accuracy on un-corrupted train-data 0.9726
# Train accuracy on full train-data  0.96298
# test accuracy  0.6132 186.1870390176773
#
# Epoch: 158
# corrupt_loss 915.9174701026641 36.36540537280962
# true loss 1609.392758877948 15.703923149034381
# Train loss of full data 2525.310228332877 19.73297722544521
# total_corrupt, total_true and total_data respectively are :   10000 40000 50000
# Train accuracy on corrupted train-data 0.9714
# Train accuracy on un-corrupted train-data 0.989175
# Train accuracy on full train-data  0.98562
# test accuracy  0.6128 201.13878309726715
#
# Epoch: 159
# corrupt_loss 482.80389448290225 18.953701995196752
# true loss 908.0304718967527 8.86325312545523
# Train loss of full data 1390.8343605995178 10.869834557175636
# total_corrupt, total_true and total_data respectively are :   10000 40000 50000
# Train accuracy on corrupted train-data 0.9871
# Train accuracy on un-corrupted train-data 0.994325
# Train accuracy on full train-data  0.99288
# test accuracy  0.6121 212.54824268817902
#
# Epoch: 160
# corrupt_loss 329.7012558885617 12.882394957938232
# true loss 582.2796722531784 5.6974567247089
# Train loss of full data 911.9809274598956 7.1268897405825555
# total_corrupt, total_true and total_data respectively are :   10000 40000 50000
# Train accuracy on corrupted train-data 0.9924
# Train accuracy on un-corrupted train-data 0.9971
# Train accuracy on full train-data  0.99616
# test accuracy  0.6227 209.52370059490204
#
# Epoch: 161
# corrupt_loss 329.1715657511959 13.256069679220673
# true loss 419.51438322942704 4.107959021930583
# Train loss of full data 748.685943134129 5.850280343089253
# total_corrupt, total_true and total_data respectively are :   10000 40000 50000
# Train accuracy on corrupted train-data 0.9952
# Train accuracy on un-corrupted train-data 0.998425
# Train accuracy on full train-data  0.99778
# test accuracy  0.6245 207.82262754440308
#
# Epoch: 162
# corrupt_loss 85.91544487942883 3.350232652024715
# true loss 155.93471023876918 1.5094075489323586
# Train loss of full data 241.85015582852066 1.889797130948864
# total_corrupt, total_true and total_data respectively are :   10000 40000 50000
# Train accuracy on corrupted train-data 0.9993
# Train accuracy on un-corrupted train-data 0.9998
# Train accuracy on full train-data  0.9997
# test accuracy  0.6355 201.96287167072296
#
# Epoch: 163
# corrupt_loss 40.80932278354885 1.4757479867548682
# true loss 106.39020160888322 1.039132407400757
# Train loss of full data 147.19952917285264 1.150252950959839
# total_corrupt, total_true and total_data respectively are :   10000 40000 50000
# Train accuracy on corrupted train-data 0.9998
# Train accuracy on un-corrupted train-data 0.999925
# Train accuracy on full train-data  0.9999
# test accuracy  0.6396 195.11169803142548
#
# Epoch: 164
# corrupt_loss 12.845366480061784 0.49855163213214837
# true loss 36.63959983334644 0.3581491679069586
# Train loss of full data 49.484966279007494 0.3868304424104281
# total_corrupt, total_true and total_data respectively are :   10000 40000 50000
# Train accuracy on corrupted train-data 1.0
# Train accuracy on un-corrupted train-data 1.0
# Train accuracy on full train-data  1.0
# test accuracy  0.6392 190.98362696170807
#
# Epoch: 165
# corrupt_loss 11.189240937586874 0.4354050814290531
# true loss 32.62553504196694 0.31881720168166794
# Train loss of full data 43.814775944687426 0.34253031463595107
# total_corrupt, total_true and total_data respectively are :   10000 40000 50000
# Train accuracy on corrupted train-data 1.0
# Train accuracy on un-corrupted train-data 1.0
# Train accuracy on full train-data  1.0
# test accuracy  0.6416 187.3966188430786
#
# Epoch: 166
# corrupt_loss 11.156880390655715 0.4343696124269627
# true loss 32.856061930186115 0.32107612857362255
# Train loss of full data 44.012942316010594 0.34408589231316
# total_corrupt, total_true and total_data respectively are :   10000 40000 50000
# Train accuracy on corrupted train-data 1.0
# Train accuracy on un-corrupted train-data 1.0
# Train accuracy on full train-data  1.0
# test accuracy  0.6422 184.09149026870728
#
# Epoch: 167
# corrupt_loss 11.400960454076994 0.44402212649583817
# true loss 33.85480118676787 0.33084418094949797
# Train loss of full data 45.25576162151992 0.353806497878395
# total_corrupt, total_true and total_data respectively are :   10000 40000 50000
# Train accuracy on corrupted train-data 1.0
# Train accuracy on un-corrupted train-data 1.0
# Train accuracy on full train-data  1.0
# test accuracy  0.6424 181.04235291481018
#
# Epoch: 168
# corrupt_loss 11.765900132420938 0.45836900756694376
# true loss 35.16977309866343 0.34370079991640523
# Train loss of full data 46.935673236846924 0.3669421374797821
# total_corrupt, total_true and total_data respectively are :   10000 40000 50000
# Train accuracy on corrupted train-data 1.0
# Train accuracy on un-corrupted train-data 1.0
# Train accuracy on full train-data  1.0
# test accuracy  0.6426 178.25710213184357
#
# Epoch: 169
# corrupt_loss 12.180880545056425 0.47463706776034087
# true loss 36.58641627477482 0.35755199793493375
# Train loss of full data 48.76729679107666 0.3812633194029331
# total_corrupt, total_true and total_data respectively are :   10000 40000 50000
# Train accuracy on corrupted train-data 1.0
# Train accuracy on un-corrupted train-data 1.0
# Train accuracy on full train-data  1.0
# test accuracy  0.6433 175.72742080688477
#
# Epoch: 170
# corrupt_loss 12.598405390686821 0.4909841865883209
# true loss 38.00166366348276 0.3713882099254988
# Train loss of full data 50.60006904695183 0.395593591791112
# total_corrupt, total_true and total_data respectively are :   10000 40000 50000
# Train accuracy on corrupted train-data 1.0
# Train accuracy on un-corrupted train-data 1.0
# Train accuracy on full train-data  1.0
# test accuracy  0.6437 173.46052205562592
#
# Epoch: 171
# corrupt_loss 12.997452268842608 0.5065881250193343
# true loss 39.34142647992121 0.38448664982570335
# Train loss of full data 52.338878630660474 0.4091886162641458
# total_corrupt, total_true and total_data respectively are :   10000 40000 50000
# Train accuracy on corrupted train-data 1.0
# Train accuracy on un-corrupted train-data 1.0
# Train accuracy on full train-data  1.0
# test accuracy  0.6441 171.4115285873413
#
# Epoch: 172
# corrupt_loss 13.36021898459876 0.5207800909411162
# true loss 40.56446889479412 0.3964466351317242
# Train loss of full data 53.924687860533595 0.42158771527465433
# total_corrupt, total_true and total_data respectively are :   10000 40000 50000
# Train accuracy on corrupted train-data 1.0
# Train accuracy on un-corrupted train-data 1.0
# Train accuracy on full train-data  1.0
# test accuracy  0.6434 169.57716715335846
#
# Epoch: 173
# corrupt_loss 13.683634752465878 0.5334421442821622
# true loss 41.66540715197334 0.40721470868447796
# Train loss of full data 55.34904194064438 0.4327239260310307
# total_corrupt, total_true and total_data respectively are :   10000 40000 50000
# Train accuracy on corrupted train-data 1.0
# Train accuracy on un-corrupted train-data 1.0
# Train accuracy on full train-data  1.0
# test accuracy  0.6433 167.92489767074585
#
# Epoch: 174
# corrupt_loss 13.964450835017487 0.5444597022724338
# true loss 42.6284112141002 0.41663489129859954
# Train loss of full data 56.592862129211426 0.4424482583999634
# total_corrupt, total_true and total_data respectively are :   10000 40000 50000
# Train accuracy on corrupted train-data 1.0
# Train accuracy on un-corrupted train-data 1.0
# Train accuracy on full train-data  1.0
# test accuracy  0.6435 166.44330286979675
#
# Epoch: 175
# corrupt_loss 14.19787170185009 0.553613462659996
# true loss 43.44975658500334 0.42466924246400595
# Train loss of full data 57.64762830734253 0.45069438591599464
# total_corrupt, total_true and total_data respectively are :   10000 40000 50000
# Train accuracy on corrupted train-data 1.0
# Train accuracy on un-corrupted train-data 1.0
# Train accuracy on full train-data  1.0
# test accuracy  0.6437 165.11405873298645
#
# Epoch: 176
# corrupt_loss 14.397523403633386 0.5614371797419153
# true loss 44.14491715520853 0.4314693443593569
# Train loss of full data 58.542440416291356 0.4576902441913262
# total_corrupt, total_true and total_data respectively are :   10000 40000 50000
# Train accuracy on corrupted train-data 1.0
# Train accuracy on un-corrupted train-data 1.0
# Train accuracy on full train-data  1.0
# test accuracy  0.643 163.9300216436386
#
# Epoch: 177
# corrupt_loss 14.555396102485247 0.5676302671199664
# true loss 44.725589710636996 0.4371511113131419
# Train loss of full data 59.28098583128303 0.4634646430495195
# total_corrupt, total_true and total_data respectively are :   10000 40000 50000
# Train accuracy on corrupted train-data 1.0
# Train accuracy on un-corrupted train-data 1.0
# Train accuracy on full train-data  1.0
# test accuracy  0.6433 162.827476978302
#
# Epoch: 178
# corrupt_loss 14.681773674441501 0.5725806711125188
# true loss 45.19102566613583 0.4417059359839186
# Train loss of full data 59.87279939465225 0.4680915012722835
# total_corrupt, total_true and total_data respectively are :   10000 40000 50000
# Train accuracy on corrupted train-data 1.0
# Train accuracy on un-corrupted train-data 1.0
# Train accuracy on full train-data  1.0
# test accuracy  0.643 161.8126324415207
#
# Epoch: 179
# corrupt_loss 14.787537605734542 0.5767458128393628
# true loss 45.57308527169516 0.44544599496293813
# Train loss of full data 60.36062288470566 0.47190555708948523
# total_corrupt, total_true and total_data respectively are :   10000 40000 50000
# Train accuracy on corrupted train-data 1.0
# Train accuracy on un-corrupted train-data 1.0
# Train accuracy on full train-data  1.0
# test accuracy  0.6429 160.87395346164703
#
# Epoch: 180
# corrupt_loss 14.866330132936127 0.5798600719426759
# true loss 45.87349081347929 0.4483860117616132
# Train loss of full data 60.739820956252515 0.47487035318044946
# total_corrupt, total_true and total_data respectively are :   10000 40000 50000
# Train accuracy on corrupted train-data 1.0
# Train accuracy on un-corrupted train-data 1.0
# Train accuracy on full train-data  1.0
# test accuracy  0.643 160.0019110441208
#
# Epoch: 181
# corrupt_loss 14.925726394634694 0.5822408298263326
# true loss 46.10432580357883 0.45064468221971765
# Train loss of full data 61.03005218412727 0.4771392710390501
# total_corrupt, total_true and total_data respectively are :   10000 40000 50000
# Train accuracy on corrupted train-data 1.0
# Train accuracy on un-corrupted train-data 1.0
# Train accuracy on full train-data  1.0
# test accuracy  0.6441 159.18662405014038
#
# Epoch: 182
# corrupt_loss 14.972726344363764 0.5841235714615323
# true loss 46.28075076278765 0.4523692217771895
# Train loss of full data 61.25347709469497 0.4788862265413627
# total_corrupt, total_true and total_data respectively are :   10000 40000 50000
# Train accuracy on corrupted train-data 1.0
# Train accuracy on un-corrupted train-data 1.0
# Train accuracy on full train-data  1.0
# test accuracy  0.6438 158.42928814888
#
# Epoch: 183
# corrupt_loss 15.008323171758093 0.5855581290088594
# true loss 46.41589395655319 0.45369076111819595
# Train loss of full data 61.42421722318977 0.48022162466077134
# total_corrupt, total_true and total_data respectively are :   10000 40000 50000
# Train accuracy on corrupted train-data 1.0
# Train accuracy on un-corrupted train-data 1.0
# Train accuracy on full train-data  1.0
# test accuracy  0.6434 157.73095524311066
#
# Epoch: 184
# corrupt_loss 15.034784813411534 0.5866593149257824
# true loss 46.506302341411356 0.4545753989368677
# Train loss of full data 61.54108715150505 0.48113593162270263
# total_corrupt, total_true and total_data respectively are :   10000 40000 50000
# Train accuracy on corrupted train-data 1.0
# Train accuracy on un-corrupted train-data 1.0
# Train accuracy on full train-data  1.0
# test accuracy  0.6431 157.0608879327774
#
# Epoch: 185
# corrupt_loss 15.059555038111284 0.5876697436906397
# true loss 46.57811499229865 0.4552798967342824
# Train loss of full data 61.637670040130615 0.4818921349942684
# total_corrupt, total_true and total_data respectively are :   10000 40000 50000
# Train accuracy on corrupted train-data 1.0
# Train accuracy on un-corrupted train-data 1.0
# Train accuracy on full train-data  1.0
# test accuracy  0.6437 156.42880523204803
#
# Epoch: 186
# corrupt_loss 15.080608358723111 0.5885484761092812
# true loss 46.63762041926384 0.4558643729542382
# Train loss of full data 61.71822881512344 0.48252284375485033
# total_corrupt, total_true and total_data respectively are :   10000 40000 50000
# Train accuracy on corrupted train-data 1.0
# Train accuracy on un-corrupted train-data 1.0
# Train accuracy on full train-data  1.0
# test accuracy  0.6432 155.8250002861023
#
# Epoch: 187
# corrupt_loss 15.101058007217944 0.5893845320679247
# true loss 46.679827274230774 0.45627814845647663
# Train loss of full data 61.780885219573975 0.48301389813423157
# total_corrupt, total_true and total_data respectively are :   10000 40000 50000
# Train accuracy on corrupted train-data 1.0
# Train accuracy on un-corrupted train-data 1.0
# Train accuracy on full train-data  1.0
# test accuracy  0.6428 155.24760389328003
#
# Epoch: 188
# corrupt_loss 15.120632157835644 0.5901961491326801
# true loss 46.71154029952595 0.45658849587198347
# Train loss of full data 61.832172392867506 0.4834157146397047
# total_corrupt, total_true and total_data respectively are :   10000 40000 50000
# Train accuracy on corrupted train-data 1.0
# Train accuracy on un-corrupted train-data 1.0
# Train accuracy on full train-data  1.0
# test accuracy  0.6433 154.6759091615677
#
# Epoch: 189
# corrupt_loss 15.144054419768509 0.5911627837340347
# true loss 46.740270192560274 0.4568690274027176
# Train loss of full data 61.88432454876602 0.4838250264292583
# total_corrupt, total_true and total_data respectively are :   10000 40000 50000
# Train accuracy on corrupted train-data 1.0
# Train accuracy on un-corrupted train-data 1.0
# Train accuracy on full train-data  1.0
# test accuracy  0.6429 154.13044893741608

# %%
testset = torchvision.datasets.CIFAR10(root='./data', train=False, download=True, transform=transform_test)
import random
length = len(testset.targets)
percentage_corruption = 20
n = length*percentage_corruption/100
corrupt_classes = np.random.randint(0,10,int(n))
# print(np.unique(corrupt_idx))
corrupt_idx = random.sample(range(0,length), int(n))
print(len(corrupt_idx) , len(np.unique(corrupt_idx)))
print(corrupt_idx)
print(len(corrupt_classes))

st1 = testset.targets
a = np.array(testset.targets)
a[corrupt_idx] = corrupt_classes
testset.targets = list(a)
st2 = testset.targets

print(st1 == st2)
# Out:
# Files already downloaded and verified
# 2000 2000
# [3191, 4191, 5065, 8693, 8036, 5787, 4411, 536, 315, 9898, 9915, 8431, 7090, 1937, 1684, 4321, 6701, 1130, 6058, 5224, 6908, 1049, 159, 7786, 1652, 9617, 8823, 3399, 2497, 2175, 7233, 5585, 3854, 7442, 1267, 3974, 7320, 8103, 4218, 6423, 104, 1586, 9014, 9980, 1591, 4679, 7060, 5162, 9244, 1501, 109, 538, 5452, 2871, 4498, 4579, 6, 7888, 5560, 2660, 9251, 8491, 9146, 6510, 9234, 9383, 1023, 8931, 6988, 3264, 7039, 5053, 7680, 8830, 8012, 8041, 2756, 8863, 9881, 796, 4268, 788, 4721, 6434, 9305, 4900, 356, 6318, 1047, 3422, 4482, 4184, 7724, 3251, 7970, 1187, 6368, 4652, 9799, 3656, 2758, 8009, 2449, 8948, 9197, 2026, 3785, 5214, 145, 9817, 4766, 8794, 8166, 8207, 862, 6982, 195, 5951, 5279, 1217, 8514, 8162, 2431, 8770, 5155, 9761, 5767, 9393, 2289, 4286, 805, 4666, 3777, 7357, 6491, 3604, 7733, 8233, 8238, 9056, 3696, 1655, 6774, 8270, 2072, 2823, 7524, 8148, 9015, 7728, 9380, 2263, 6010, 2011, 5766, 1604, 5449, 8781, 8989, 8913, 4764, 3266, 6608, 9995, 1194, 9934, 3672, 8738, 6225, 7139, 6809, 4769, 8327, 2358, 5141, 2552, 6808, 5816, 707, 2855, 7889, 7847, 186, 1807, 7437, 6376, 2332, 2298, 4179, 149, 978, 723, 2773, 5580, 6063, 7690, 6584, 8785, 3848, 8352, 3835, 7456, 3544, 4815, 6918, 5989, 1656, 359, 2421, 9502, 2946, 2687, 6118, 733, 3806, 1417, 7017, 8487, 7248, 3621, 4978, 2033, 3096, 934, 3095, 3127, 9918, 8048, 3329, 7238, 1559, 2492, 6473, 959, 2383, 7376, 3651, 7310, 2905, 8375, 5412, 1401, 1725, 1063, 5175, 1290, 5810, 4097, 6578, 5872, 9262, 279, 9951, 1671, 7393, 854, 8418, 5530, 638, 6121, 2852, 9106, 5746, 8392, 6241, 2883, 2586, 9968, 9326, 1798, 5834, 2180, 8591, 309, 2082, 8163, 133, 2294, 2795, 1674, 3634, 8152, 7126, 4055, 7454, 6299, 6325, 8168, 1348, 2913, 9566, 8716, 5239, 9895, 464, 4460, 3381, 7322, 2879, 8053, 8108, 1917, 8560, 9339, 4048, 1825, 8029, 8474, 6486, 1790, 5258, 7385, 6610, 2564, 7349, 9730, 4500, 1865, 7028, 7556, 5373, 7872, 7501, 9533, 3737, 2466, 4572, 3573, 905, 1890, 348, 1965, 1880, 8967, 3003, 1744, 2522, 3270, 5761, 435, 889, 6919, 877, 52, 7467, 797, 1538, 580, 6764, 812, 7431, 7405, 6176, 3898, 4141, 5453, 215, 7696, 492, 9549, 6676, 3106, 7726, 7302, 5758, 4565, 4635, 7626, 2267, 4236, 8667, 5231, 7342, 4613, 7005, 3837, 6819, 2774, 1511, 6661, 9638, 9447, 1420, 9879, 6103, 1155, 3668, 884, 5659, 9020, 4154, 19, 509, 6799, 3581, 1550, 4062, 8417, 3795, 9633, 6071, 4622, 2443, 2630, 2019, 2690, 2283, 8342, 4521, 6878, 2126, 9768, 5244, 8818, 3029, 4671, 8296, 2525, 59, 1251, 2264, 7823, 3212, 9793, 3441, 3272, 4116, 6602, 7663, 1721, 7161, 1408, 3938, 4419, 4476, 8072, 2036, 4026, 286, 6125, 3717, 451, 7389, 996, 9342, 664, 141, 4914, 4475, 1158, 4912, 5903, 7758, 7435, 9979, 6732, 7742, 4309, 9592, 1452, 2199, 9570, 8413, 9787, 5572, 2599, 8983, 9794, 4377, 6483, 1404, 2983, 1767, 1343, 5515, 2708, 9448, 6459, 6942, 4948, 4649, 1709, 7105, 2502, 5372, 6992, 352, 1171, 6722, 28, 1332, 7444, 3164, 7893, 191, 2322, 174, 2530, 3475, 9779, 4839, 5195, 4830, 3541, 8881, 4028, 5057, 1106, 5100, 8834, 7379, 9103, 4578, 7608, 6169, 6172, 1561, 9492, 342, 5336, 4554, 3199, 9603, 8636, 563, 2770, 7106, 442, 3726, 9233, 1286, 3988, 9987, 3141, 9493, 5612, 8061, 151, 1156, 2990, 2964, 2147, 4376, 1840, 345, 3477, 1598, 5301, 3719, 7943, 3819, 6454, 7928, 7774, 5709, 8949, 7748, 9274, 5866, 4149, 3371, 8338, 9005, 8595, 3128, 5561, 2703, 1724, 1031, 3781, 767, 8258, 3240, 8117, 4962, 9719, 5050, 5569, 7299, 457, 9235, 4559, 9866, 8799, 859, 5489, 1827, 7581, 7396, 4463, 3333, 9231, 6597, 1760, 7729, 3735, 1181, 6246, 2295, 1544, 8107, 7184, 9194, 2661, 9223, 976, 7937, 4263, 463, 2811, 6961, 6632, 4883, 2831, 4314, 307, 4922, 9294, 7200, 2367, 3902, 370, 8680, 1817, 1245, 9224, 3794, 4656, 6684, 840, 9654, 3643, 5525, 2731, 9902, 4443, 9537, 8946, 3815, 4464, 9352, 1075, 2106, 96, 7716, 6986, 3918, 9856, 3205, 9892, 5042, 1142, 5670, 6794, 7589, 9989, 5492, 1441, 9489, 6924, 2422, 8320, 504, 1622, 4980, 4682, 369, 8567, 2470, 1082, 8372, 6310, 3537, 3985, 9695, 9731, 5044, 6387, 7671, 1 ...
# 2000
# False

# %%
test_data = CustomizeDataset(testset,corrupt_idx)
testloader = DataLoader( test_data, batch_size= 100,shuffle= False, num_workers=2)

# testloader = torch.utils.data.DataLoader(testset, batch_size=100, shuffle=False, num_workers=2)
global best_acc

test_loss = 0
tl=0
test_corrupt_loss = 0
tcl=0
test_true_loss = 0
ttl=0

correct = 0
true_correct=0
corrupt_correct=0

total = 0
corrupt_total = 0
true_total=0
with torch.no_grad():
    for batch_idx, (inputs, targets, indicator) in enumerate(testloader):
        inputs, targets, indicator = inputs.to(device), targets.to(device), indicator.to(device)
        outputs = net(inputs)
        loss = criterion(outputs, targets)
        batch_total_loss = loss.item()
        tl += batch_total_loss
        test_loss += batch_total_loss*len(indicator)

#         test_loss += loss.item()
        _, predicted = outputs.max(1)
        total += targets.size(0)
        correct += predicted.eq(targets).sum().item()
#         ***************************************************************************
        corrupt_out = (outputs[indicator])
        loss_corrupt = criterion(corrupt_out, targets[indicator])
        batch_corrupt_loss = loss_corrupt.item()
        tcl += loss_corrupt.item()
        test_corrupt_loss += batch_corrupt_loss*(sum(indicator).item())
       
        _, predict_corrupt = corrupt_out.max(1)
        corrupt_total += targets[indicator].size(0)
        corrupt_correct += predict_corrupt.eq(targets[indicator]).sum().item()
        
        true_out = (outputs[~indicator])
        loss_true = criterion(true_out, targets[~indicator])
        batch_true_loss = loss_true.item()
        ttl += loss_true.item()
        test_true_loss += batch_true_loss*(sum(~indicator).item())
        
        _, predict_true = true_out.max(1)
        true_total += targets[~indicator].size(0)
        true_correct += predict_true.eq(targets[~indicator]).sum().item()
#         *****************************************************************************

#             progress_bar(batch_idx, len(testloader), 'Loss: %.3f | Acc: %.3f%% (%d/%d)'
#                 % (test_loss/(batch_idx+1), 100.*correct/total, correct, total))

print("corrupt_loss", test_corrupt_loss, tcl)
print("true loss", test_true_loss, ttl)
print("Test loss of full data", test_loss, tl)
print("total_corrupt, total_true and total_data respectively are :  ",corrupt_total, true_total, total)
print("Test accuracy on corrupted train-data", corrupt_correct/corrupt_total )
print("Test accuracy on un-corrupted train-data", true_correct/true_total)
print("test accuracy on full test-data", correct/total)
print(correct, total)
# Out:
# corrupt_loss 14784.888087272644 740.5011763572693
# true loss 12214.831941246986 152.89497995376587
# Test loss of full data 26999.71981048584 269.9971981048584
# total_corrupt, total_true and total_data respectively are :   2000 8000 10000
# Test accuracy on corrupted train-data 0.106
# Test accuracy on un-corrupted train-data 0.650875
# test accuracy on full test-data 0.5419
# 5419 10000
