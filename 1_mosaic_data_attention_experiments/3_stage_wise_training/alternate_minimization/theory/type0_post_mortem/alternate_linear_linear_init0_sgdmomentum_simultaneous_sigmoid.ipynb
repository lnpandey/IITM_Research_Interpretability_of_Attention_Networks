# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
from tqdm import tqdm
# %matplotlib inline
from torch.utils.data import Dataset, DataLoader
import torch
import torchvision

import torch.nn as nn
import torch.optim as optim
from torch.nn import functional as F
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda

# %% [markdown]
# # Generate dataset

# %%
y = np.random.randint(0,3,500)
idx= []
for i in range(3):
    print(i,sum(y==i))
    idx.append(y==i)
# Out:
# 0 160
# 1 165
# 2 175

# %%
x = np.zeros((500,))

# %%
np.random.seed(12)
x[idx[0]] = np.random.uniform(low =-1,high =0,size= sum(idx[0]))
x[idx[1]] = np.random.uniform(low =0,high =1,size= sum(idx[1]))
x[idx[2]] = np.random.uniform(low =2,high =3,size= sum(idx[2]))

# %%
x[idx[0]][0], x[idx[2]][5]
# Out:
# (-0.8458371576203276, 2.3773011594614126)

# %%
print(x.shape,y.shape)
# Out:
# (500,) (500,)

# %%
idx= []
for i in range(3):
  idx.append(y==i)

# %%
for i in range(3):
    y= np.zeros(x[idx[i]].shape[0])
    plt.scatter(x[idx[i]],y,label="class_"+str(i))
plt.legend()

# %%
bg_idx = [ np.where(idx[2] == True)[0]]

bg_idx = np.concatenate(bg_idx, axis = 0)
bg_idx.shape
# Out:
# (175,)

# %%
np.unique(bg_idx).shape
# Out:
# (175,)

# %%
x = x - np.mean(x[bg_idx], axis = 0, keepdims = True)

# %%
np.mean(x[bg_idx], axis = 0, keepdims = True), np.mean(x, axis = 0, keepdims = True)
# Out:
# (array([-4.82153999e-17]), array([-1.63429327]))

# %%
x = x/np.std(x[bg_idx], axis = 0, keepdims = True)

# %%
np.std(x[bg_idx], axis = 0, keepdims = True), np.std(x, axis = 0, keepdims = True)
# Out:
# (array([1.]), array([4.33146331]))

# %%
for i in range(3):
    y= np.zeros(x[idx[i]].shape[0])
    plt.scatter(x[idx[i]],y,label="class_"+str(i))
plt.legend()

# %%
foreground_classes = {'class_0','class_1' }

background_classes = {'class_2'}

# %%
fg_class  = np.random.randint(0,2)
fg_idx = np.random.randint(0,9)

a = []
for i in range(9):
    if i == fg_idx:
        b = np.random.choice(np.where(idx[fg_class]==True)[0],size=1)
        a.append(x[b])
        print("foreground "+str(fg_class)+" present at " + str(fg_idx))
    else:
        bg_class = np.random.randint(2,3)
        b = np.random.choice(np.where(idx[bg_class]==True)[0],size=1)
        a.append(x[b])
        print("background "+str(bg_class)+" present at " + str(i))
a = np.concatenate(a,axis=0)
print(a.shape)

print(fg_class , fg_idx)
# Out:
# background 2 present at 0
# background 2 present at 1
# background 2 present at 2
# background 2 present at 3
# background 2 present at 4
# background 2 present at 5
# background 2 present at 6
# background 2 present at 7
# foreground 1 present at 8
# (9,)
# 1 8

# %%
a.shape
# Out:
# (9,)

# %%
np.reshape(a,(9,1))
# Out:
# array([[-1.15794364],
#        [ 0.58697946],
#        [-1.69452431],
#        [-1.29318477],
#        [-0.67262115],
#        [ 1.59854334],
#        [-0.38598503],
#        [-0.67262115],
#        [-6.65351041]])

# %%
a=np.reshape(a,(3,3))

# %%
plt.imshow(a)

# %%
desired_num = 2000
mosaic_list_of_images =[]
mosaic_label = []
fore_idx=[]
for j in range(desired_num):
    np.random.seed(j)
    fg_class  = np.random.randint(0,2)
    fg_idx = 0
    a = []
    for i in range(9):
        if i == fg_idx:
            b = np.random.choice(np.where(idx[fg_class]==True)[0],size=1)
            a.append(x[b])
#             print("foreground "+str(fg_class)+" present at " + str(fg_idx))
        else:
            bg_class = np.random.randint(2,3)
            b = np.random.choice(np.where(idx[bg_class]==True)[0],size=1)
            a.append(x[b])
#             print("background "+str(bg_class)+" present at " + str(i))
    a = np.concatenate(a,axis=0)
    mosaic_list_of_images.append(np.reshape(a,(9,1)))
    mosaic_label.append(fg_class)
    fore_idx.append(fg_idx)

# %%
mosaic_list_of_images = np.concatenate(mosaic_list_of_images,axis=1).T

# %%
mosaic_list_of_images.shape, mosaic_list_of_images[0]
# Out:
# ((2000, 9), array([-10.46807047,   1.05650048,   1.27810018,  -0.01725184,
#           1.59854334,  -0.88637981,  -0.4593889 ,  -1.53162822,
#           1.32266184]))

# %%
for j in range(9):
  print(mosaic_list_of_images[0][j])
# Out:
# -10.468070470054734
# 1.0565004769628443
# 1.278100178112481
# -0.017251837431010407
# 1.598543342240201
# -0.8863798117059832
# -0.45938889515789527
# -1.531628222899254
# 1.3226618426278711

# %%
class MosaicDataset(Dataset):
  """MosaicDataset dataset."""

  def __init__(self, mosaic_list_of_images, mosaic_label, fore_idx):
    """
      Args:
        csv_file (string): Path to the csv file with annotations.
        root_dir (string): Directory with all the images.
        transform (callable, optional): Optional transform to be applied
            on a sample.
    """
    self.mosaic = mosaic_list_of_images
    self.label = mosaic_label
    self.fore_idx = fore_idx

  def __len__(self):
    return len(self.label)

  def __getitem__(self, idx):
    return self.mosaic[idx] , self.label[idx], self.fore_idx[idx]

# %%
batch = 250
msd1 = MosaicDataset(mosaic_list_of_images[0:1000], mosaic_label[0:1000] , fore_idx[0:1000])
train_loader = DataLoader( msd1 ,batch_size= batch ,shuffle=True)

# %%
batch = 250
msd2 = MosaicDataset(mosaic_list_of_images[1000:2000], mosaic_label[1000:2000] , fore_idx[1000:2000])
test_loader = DataLoader( msd2 ,batch_size= batch ,shuffle=True)

# %%
class Focus(nn.Module):
  def __init__(self):
    super(Focus, self).__init__()

    self.fc1 = nn.Linear(1, 1)
    # self.fc2 = nn.Linear(2, 1)

  def forward(self,z):  #y is avg image #z batch of list of 9 images
    y = torch.zeros([batch], dtype=torch.float64)
    x = torch.zeros([batch,9],dtype=torch.float64)
    y = y.to("cuda")
    x = x.to("cuda")
    # print(x.shape, z.shape)
    for i in range(9):
      # print(z[:,i].shape)
      # print(self.helper(z[:,i])[:,0].shape)
      x[:,i] = self.helper(z[:,i])[:,0]
    # print(x.shape, z.shape)
    x = F.softmax(x,dim=1)
    # print(x.shape, z.shape)
    # x1 = x[:,0]
    # print(torch.mul(x[:,0],z[:,0]).shape)

    for i in range(9):            
      # x1 = x[:,i]          
      y = y + torch.mul(x[:,i],z[:,i])

    # print(x.shape, y.shape)
    return x, y
    
  def helper(self, x):
    x = x.view(-1, 1)
    # x = F.relu(self.fc1(x))
    x = (self.fc1(x))

    return x

# %%
class Classification(nn.Module):
  def __init__(self):
    super(Classification, self).__init__()
    self.fc1 = nn.Linear(1, 1)


  def forward(self, x):
    x = x.view(-1, 1)
    x = self.fc1(x)
    # print(x.shape)
    return x

# %%
torch.manual_seed(12)
focus_net = Focus().double()
focus_net = focus_net.to("cuda")

# %%
torch.manual_seed(12)
classify = Classification().double()
classify = classify.to("cuda")

# %%
focus_net.fc1.weight, focus_net.fc1.bias
# Out:
# (Parameter containing:
#  tensor([[-0.0686]], device='cuda:0', dtype=torch.float64, requires_grad=True),
#  Parameter containing:
#  tensor([-0.5345], device='cuda:0', dtype=torch.float64, requires_grad=True))

# %%
classify.fc1.weight, classify.fc1.bias
# Out:
# (Parameter containing:
#  tensor([[-0.0686]], device='cuda:0', dtype=torch.float64, requires_grad=True),
#  Parameter containing:
#  tensor([-0.5345], device='cuda:0', dtype=torch.float64, requires_grad=True))

# %%
focus_net.fc1.weight = torch.nn.Parameter(torch.tensor(np.array([[0.0]])))
focus_net.fc1.bias = torch.nn.Parameter(torch.tensor(np.array([0.0])))
focus_net.fc1.weight, focus_net.fc1.bias
# Out:
# (Parameter containing:
#  tensor([[0.]], dtype=torch.float64, requires_grad=True), Parameter containing:
#  tensor([0.], dtype=torch.float64, requires_grad=True))

# %%
classify.fc1.weight = torch.nn.Parameter(torch.tensor(np.array([[0.0]])))
classify.fc1.bias = torch.nn.Parameter(torch.tensor(np.array([0.0])))
classify.fc1.weight, classify.fc1.bias
# Out:
# (Parameter containing:
#  tensor([[0.]], dtype=torch.float64, requires_grad=True), Parameter containing:
#  tensor([0.], dtype=torch.float64, requires_grad=True))

# %%
focus_net = focus_net.to("cuda")
classify = classify.to("cuda")

# %%
focus_net.fc1.weight, focus_net.fc1.bias
# Out:
# (Parameter containing:
#  tensor([[0.]], device='cuda:0', dtype=torch.float64, requires_grad=True),
#  Parameter containing:
#  tensor([0.], device='cuda:0', dtype=torch.float64, requires_grad=True))

# %%
classify.fc1.weight, classify.fc1.bias
# Out:
# (Parameter containing:
#  tensor([[0.]], device='cuda:0', dtype=torch.float64, requires_grad=True),
#  Parameter containing:
#  tensor([0.], device='cuda:0', dtype=torch.float64, requires_grad=True))

# %%
import torch.optim as optim
criterion = nn.BCEWithLogitsLoss()
optimizer_classify = optim.SGD(classify.parameters(), lr=0.01, momentum=0.9)
optimizer_focus = optim.SGD(focus_net.parameters(), lr=0.01, momentum=0.9)

# optimizer_classify = optim.Adam(classify.parameters(), lr=0.01)
# optimizer_focus = optim.Adam(focus_net.parameters(), lr=0.01)

# %%
col1=[]
col2=[]
col3=[]
col4=[]
col5=[]
col6=[]
col7=[]
col8=[]
col9=[]
col10=[]
col11=[]
col12=[]
col13=[]

# %%
correct = 0
total = 0
count = 0
flag = 1
focus_true_pred_true =0
focus_false_pred_true =0
focus_true_pred_false =0
focus_false_pred_false =0

argmax_more_than_half = 0
argmax_less_than_half =0

with torch.no_grad():
  for data in train_loader:
    inputs, labels , fore_idx = data
    inputs = inputs.double()
    inputs, labels , fore_idx = inputs.to("cuda"),labels.to("cuda"), fore_idx.to("cuda")
    alphas, avg_images = focus_net(inputs)
    outputs = classify(avg_images)
    # print(outputs.shape)
    predicted = np.round(torch.sigmoid(outputs.data).cpu().numpy())
    # print(predicted.shape)

    for j in range(labels.size(0)):
      count += 1
      focus = torch.argmax(alphas[j])
      if alphas[j][focus] >= 0.5 :
        argmax_more_than_half += 1
      else:
        argmax_less_than_half += 1

      # print(focus, fore_idx[j], predicted[j])
      if(focus == fore_idx[j] and predicted[j] == labels[j].item()):
          focus_true_pred_true += 1
      elif(focus != fore_idx[j] and predicted[j] == labels[j].item()):
        focus_false_pred_true += 1
      elif(focus == fore_idx[j] and predicted[j] != labels[j].item()):
        focus_true_pred_false += 1
      elif(focus != fore_idx[j] and predicted[j] != labels[j].item()):
        focus_false_pred_false += 1

    total += labels.size(0)
    correct += np.sum( np.concatenate(predicted,axis=0)== labels.cpu().numpy() )

print('Accuracy of the network on the 1000 train images: %d %%' % ( 100 * correct / total))
print("total correct", correct)
print("total train set images", total)

print("focus_true_pred_true %d =============> FTPT : %d %%" % (focus_true_pred_true , (100 * focus_true_pred_true / total) ) )
print("focus_false_pred_true %d =============> FFPT : %d %%" % (focus_false_pred_true, (100 * focus_false_pred_true / total) ) )
print("focus_true_pred_false %d =============> FTPF : %d %%" %( focus_true_pred_false , ( 100 * focus_true_pred_false / total) ) )
print("focus_false_pred_false %d =============> FFPF : %d %%" % (focus_false_pred_false, ( 100 * focus_false_pred_false / total) ) )

print("argmax_more_than_half ==================> ",argmax_more_than_half)
print("argmax_less_than_half ==================> ",argmax_less_than_half)
print(count)

print("="*100)

col1.append(0)
col2.append(argmax_more_than_half)
col3.append(argmax_less_than_half)
col4.append(focus_true_pred_true)
col5.append(focus_false_pred_true)
col6.append(focus_true_pred_false)
col7.append(focus_false_pred_false)
# Out:
# Accuracy of the network on the 1000 train images: 49 %
# total correct 493
# total train set images 1000
# focus_true_pred_true 493 =============> FTPT : 49 %
# focus_false_pred_true 0 =============> FFPT : 0 %
# focus_true_pred_false 507 =============> FTPF : 50 %
# focus_false_pred_false 0 =============> FFPF : 0 %
# argmax_more_than_half ==================>  0
# argmax_less_than_half ==================>  1000
# 1000
# ====================================================================================================

# %%
correct = 0
total = 0
count = 0
flag = 1
focus_true_pred_true =0
focus_false_pred_true =0
focus_true_pred_false =0
focus_false_pred_false =0

argmax_more_than_half = 0
argmax_less_than_half =0

with torch.no_grad():
  for data in test_loader:
    inputs, labels , fore_idx = data
    inputs = inputs.double()
    inputs, labels , fore_idx = inputs.to("cuda"),labels.to("cuda"), fore_idx.to("cuda")
    alphas, avg_images = focus_net(inputs)
    outputs = classify(avg_images)

    predicted = np.round(torch.sigmoid(outputs.data).cpu().numpy())

    for j in range(labels.size(0)):
      focus = torch.argmax(alphas[j])
      if alphas[j][focus] >= 0.5 :
        argmax_more_than_half += 1
      else:
        argmax_less_than_half += 1

      if(focus == fore_idx[j] and predicted[j] == labels[j].item()):
          focus_true_pred_true += 1
      elif(focus != fore_idx[j] and predicted[j] == labels[j].item()):
        focus_false_pred_true += 1
      elif(focus == fore_idx[j] and predicted[j] != labels[j].item()):
        focus_true_pred_false += 1
      elif(focus != fore_idx[j] and predicted[j] != labels[j].item()):
        focus_false_pred_false += 1

    total += labels.size(0)
    correct += np.sum( np.concatenate(predicted,axis=0)== labels.cpu().numpy() )

print('Accuracy of the network on the 1000 test images: %d %%' % (
    100 * correct / total))
print("total correct", correct)
print("total train set images", total)

print("focus_true_pred_true %d =============> FTPT : %d %%" % (focus_true_pred_true , (100 * focus_true_pred_true / total) ) )
print("focus_false_pred_true %d =============> FFPT : %d %%" % (focus_false_pred_true, (100 * focus_false_pred_true / total) ) )
print("focus_true_pred_false %d =============> FTPF : %d %%" %( focus_true_pred_false , ( 100 * focus_true_pred_false / total) ) )
print("focus_false_pred_false %d =============> FFPF : %d %%" % (focus_false_pred_false, ( 100 * focus_false_pred_false / total) ) )

print("argmax_more_than_half ==================> ",argmax_more_than_half)
print("argmax_less_than_half ==================> ",argmax_less_than_half)
col8.append(argmax_more_than_half)
col9.append(argmax_less_than_half)
col10.append(focus_true_pred_true)
col11.append(focus_false_pred_true)
col12.append(focus_true_pred_false)
col13.append(focus_false_pred_false)
# Out:
# Accuracy of the network on the 1000 test images: 51 %
# total correct 519
# total train set images 1000
# focus_true_pred_true 519 =============> FTPT : 51 %
# focus_false_pred_true 0 =============> FFPT : 0 %
# focus_true_pred_false 481 =============> FTPF : 48 %
# focus_false_pred_false 0 =============> FFPF : 0 %
# argmax_more_than_half ==================>  0
# argmax_less_than_half ==================>  1000

# %%
nos_epochs = 1000
focus_true_pred_true =0
focus_false_pred_true =0
focus_true_pred_false =0
focus_false_pred_false =0

argmax_more_than_half = 0
argmax_less_than_half =0

every_what_epoch = 1

for epoch in range(nos_epochs):  # loop over the dataset multiple times

  focus_true_pred_true =0
  focus_false_pred_true =0
  focus_true_pred_false =0
  focus_false_pred_false =0
  
  argmax_more_than_half = 0
  argmax_less_than_half =0
  
  running_loss = 0.0
  epoch_loss = []
  cnt=0

  iteration = desired_num // batch
  
  #training data set
  if ((epoch) % (every_what_epoch*2) ) <= every_what_epoch-1 :
    print(epoch+1,"updating focus_net, classify_net is freezed")
    print("--"*40)
  elif ((epoch) % (every_what_epoch*2)) > every_what_epoch-1 :
    print(epoch+1,"updating classify_net, focus_net is freezed")
    print("--"*40)

  for i, data in  enumerate(train_loader):
    inputs , labels , fore_idx = data
    inputs, labels = inputs.to("cuda"), labels.to("cuda")
    inputs = inputs.double()
    labels = labels.float()
    # zero the parameter gradients
    
    optimizer_focus.zero_grad()
    optimizer_classify.zero_grad()
    
    alphas, avg_images = focus_net(inputs)
    outputs = classify(avg_images)

    predicted = np.round(torch.sigmoid(outputs.data).cpu().numpy())
    # print(predicted.shape)
    # print(outputs.shape,labels.shape)
    # print(outputs)
    # print(labels)
    loss = criterion(outputs[:,0], labels) 
    loss.backward()
    
    if ((epoch) % (every_what_epoch*2) ) <= every_what_epoch-1 :
      optimizer_focus.step()
    elif ( (epoch) % (every_what_epoch*2)) > every_what_epoch-1 :
      optimizer_classify.step()

    # optimizer_focus.step()
    # optimizer_classify.step()

    running_loss += loss.item()
    mini = 3
    if cnt % mini == mini-1:    # print every 40 mini-batches
      print('[%d, %5d] loss: %.3f' %(epoch + 1, cnt + 1, running_loss / mini))
      epoch_loss.append(running_loss/mini)
      running_loss = 0.0
    cnt=cnt+1
    
    if epoch % 5 == 0:
      for j in range (batch):
        focus = torch.argmax(alphas[j])

        if(alphas[j][focus] >= 0.5):
          argmax_more_than_half +=1
        else:
          argmax_less_than_half +=1

        if(focus == fore_idx[j] and predicted[j] == labels[j].item()):
          focus_true_pred_true += 1

        elif(focus != fore_idx[j] and predicted[j] == labels[j].item()):
          focus_false_pred_true +=1

        elif(focus == fore_idx[j] and predicted[j] != labels[j].item()):
          focus_true_pred_false +=1

        elif(focus != fore_idx[j] and predicted[j] != labels[j].item()):
          focus_false_pred_false +=1

  if(np.mean(epoch_loss) <= 0.001):
      break;

  if epoch % 5 == 0:
    col1.append(epoch + 1)
    col2.append(argmax_more_than_half)
    col3.append(argmax_less_than_half)
    col4.append(focus_true_pred_true)
    col5.append(focus_false_pred_true)
    col6.append(focus_true_pred_false)
    col7.append(focus_false_pred_false)
    # print("="*20)
    # print("Train FTPT : ", col4)
    # print("Train FFPT : ", col5)
    #************************************************************************
    #testing data set  
    # focus_net.eval()
    with torch.no_grad():
      focus_true_pred_true =0
      focus_false_pred_true =0
      focus_true_pred_false =0
      focus_false_pred_false =0

      argmax_more_than_half = 0
      argmax_less_than_half =0
      for data in test_loader:
        inputs, labels , fore_idx = data
        inputs = inputs.double()
        inputs, labels = inputs.to("cuda"), labels.to("cuda")
        alphas, avg_images = focus_net(inputs)
        outputs = classify(avg_images)
        predicted = np.round(torch.sigmoid(outputs.data).cpu().numpy())

        for j in range (batch):
          focus = torch.argmax(alphas[j])

          if(alphas[j][focus] >= 0.5):
            argmax_more_than_half +=1
          else:
            argmax_less_than_half +=1

          if(focus == fore_idx[j] and predicted[j] == labels[j].item()):
            focus_true_pred_true += 1

          elif(focus != fore_idx[j] and predicted[j] == labels[j].item()):
            focus_false_pred_true +=1

          elif(focus == fore_idx[j] and predicted[j] != labels[j].item()):
            focus_true_pred_false +=1

          elif(focus != fore_idx[j] and predicted[j] != labels[j].item()):
            focus_false_pred_false +=1
      
    col8.append(argmax_more_than_half)
    col9.append(argmax_less_than_half)
    col10.append(focus_true_pred_true)
    col11.append(focus_false_pred_true)
    col12.append(focus_true_pred_false)
    col13.append(focus_false_pred_false)
    # print("Test FTPT : ", col10)
    # print("Test FFPT : ", col11)
    # print("="*20)
    
print('Finished Training')
# Out:
# 1 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# [1,     3] loss: 0.693
# 2 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# [2,     3] loss: 0.693
# 3 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# [3,     3] loss: 0.693
# 4 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# [4,     3] loss: 0.692
# 5 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# [5,     3] loss: 0.692
# 6 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# [6,     3] loss: 0.691
# 7 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# [7,     3] loss: 0.690
# 8 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# [8,     3] loss: 0.688
# 9 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# [9,     3] loss: 0.687
# 10 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# [10,     3] loss: 0.685
# 11 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# [11,     3] loss: 0.684
# 12 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# [12,     3] loss: 0.678
# 13 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# [13,     3] loss: 0.670
# 14 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# [14,     3] loss: 0.662
# 15 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# [15,     3] loss: 0.661
# 16 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# [16,     3] loss: 0.639
# 17 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# [17,     3] loss: 0.632
# 18 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# [18,     3] loss: 0.628
# 19 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# [19,     3] loss: 0.633
# 20 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# [20,     3] loss: 0.635
# 21 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# [21,     3] loss: 0.610
# 22 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# [22,     3] loss: 0.611
# 23 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# [23,     3] loss: 0.614
# 24 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# [24,     3] loss: 0.607
# 25 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# [25,     3] loss: 0.597
# 26 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# [26,     3] loss: 0.602
# 27 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# [27,     3] loss: 0.597
# 28 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# [28,     3] loss: 0.597
# 29 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# [29,     3] loss: 0.577
# 30 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# [30,     3] loss: 0.577
# 31 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# [31,     3] loss: 0.582
# 32 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# [32,     3] loss: 0.575
# 33 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# [33,     3] loss: 0.567
# 34 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# [34,     3] loss: 0.571
# 35 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# [35,     3] loss: 0.564
# 36 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# [36,     3] loss: 0.559
# 37 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# [37,     3] loss: 0.554
# 38 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# [38,     3] loss: 0.553
# 39 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# [39,     3] loss: 0.534
# 40 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# [40,     3] loss: 0.537
# 41 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# [41,     3] loss: 0.539
# 42 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# [42,     3] loss: 0.532
# 43 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# [43,     3] loss: 0.538
# 44 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# [44,     3] loss: 0.533
# 45 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# [45,     3] loss: 0.525
# 46 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# [46,     3] loss: 0.526
# 47 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# [47,     3] loss: 0.525
# 48 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# [48,     3] loss: 0.511
# 49 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# [49,     3] loss: 0.511
# 50 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# [50,     3] loss: 0.509
# 51 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# [51,     3] loss: 0.495
# 52 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# [52,     3] loss: 0.507
# 53 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# [53,     3] loss: 0.493
# 54 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# [54,     3] loss: 0.497
# 55 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# [55,     3] loss: 0.494
# 56 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# [56,     3] loss: 0.493
# 57 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# [57,     3] loss: 0.487
# 58 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# [58,     3] loss: 0.487
# 59 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# [59,     3] loss: 0.473
# 60 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# [60,     3] loss: 0.486
# 61 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# [61,     3] loss: 0.476
# 62 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# [62,     3] loss: 0.473
# 63 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# [63,     3] loss: 0.469
# 64 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# [64,     3] loss: 0.469
# 65 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# [65,     3] loss: 0.467
# 66 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# [66,     3] loss: 0.458
# 67 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# [67,     3] loss: 0.464
# 68 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# [68,     3] loss: 0.455
# 69 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# [69,     3] loss: 0.456
# 70 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# [70,     3] loss: 0.453
# 71 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# [71,     3] loss: 0.451
# 72 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# [72,     3] loss: 0.444
# 73 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# [73,     3] loss: 0.446
# 74 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# [74,     3] loss: 0.449
# 75 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# [75,     3] loss: 0.440
# 76 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# [76,     3] loss: 0.440
# 77 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# [77,     3] loss: 0.442
# 78 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# [78,     3] loss: 0.435
# 79 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# [79,     3] loss: 0.425
# 80 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# [80,     3] loss: 0.429
# 81 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# [81,     3] loss: 0.426
# 82 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# [82,     3] loss: 0.420
# 83 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# [83,     3] loss: 0.427
# 84 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# [84,     3] loss: 0.418
# 85 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# [85,     3] loss: 0.420
# 86 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# [86,     3] loss: 0.418
# 87 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# [87,     3] loss: 0.413
# 88 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# [88,     3] loss: 0.421
# 89 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# [89,     3] loss: 0.411
# 90 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# [90,     3] loss: 0.407
# 91 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# [91,     3] loss: 0.404
# 92 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# [92,     3] loss: 0.404
# 93 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# [93,     3] loss: 0.404
# 94 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# [94,     3] loss: 0.407
# 95 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# [95,     3] loss: 0.395
# 96 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# [96,     3] loss: 0.400
# 97 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# [97,     3] loss: 0.403
# 98 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# [98,     3] loss: 0.402
# 99 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# [99,     3] loss: 0.394
# 100 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# [100,     3] loss: 0.396
# 101 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# [101,     3] loss: 0.396
# 102 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# [102,     3] loss: 0.389
# 103 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# [103,     3] loss: 0.392
# 104 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# [104,     3] loss: 0.385
# 105 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# [105,     3] loss: 0.386
# 106 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# [106,     3] loss: 0.384
# 107 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# [107,     3] loss: 0.382
# 108 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# [108,     3] loss: 0.371
# 109 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# [109,     3] loss: 0.381
# 110 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# [110,     3] loss: 0.376
# 111 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# [111,     3] loss: 0.369
# 112 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# [112,     3] loss: 0.373
# 113 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# [113,     3] loss: 0.368
# 114 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# [114,     3] loss: 0.374
# 115 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# [115,     3] loss: 0.374
# 116 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# [116,     3] loss: 0.369
# 117 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# [117,     3] loss: 0.367
# 118 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# [118,     3] loss: 0.371
# 119 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# [119,     3] loss: 0.361
# 120 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# [120,     3] loss: 0.359
# 121 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# [121,     3] loss: 0.353
# 122 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# [122,     3] loss: 0.362
# 123 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# [123,     3] loss: 0.358
# 124 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# [124,     3] loss: 0.358
# 125 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# [125,     3] loss: 0.356
# 126 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# [126,     3] loss: 0.356
# 127 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# [127,     3] loss: 0.350
# 128 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# [128,     3] loss: 0.352
# 129 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# [129,     3] loss: 0.354
# 130 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# [130,     3] loss: 0.355
# 131 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# [131,     3] loss: 0.347
# 132 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# [132,     3] loss: 0.344
# 133 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# [133,     3] loss: 0.346
# 134 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# [134,     3] loss: 0.342
# 135 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# [135,     3] loss: 0.345
# 136 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# [136,     3] loss: 0.342
# 137 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# [137,     3] loss: 0.339
# 138 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# [138,     3] loss: 0.335
# 139 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# [139,     3] loss: 0.336
# 140 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# [140,     3] loss: 0.336
# 141 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# [141,     3] loss: 0.330
# 142 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# [142,     3] loss: 0.333
# 143 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# [143,     3] loss: 0.335
# 144 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# [144,     3] loss: 0.339
# 145 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# [145,     3] loss: 0.332
# 146 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# [146,     3] loss: 0.331
# 147 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# [147,     3] loss: 0.333
# 148 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# [148,     3] loss: 0.327
# 149 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# [149,     3] loss: 0.330
# 150 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# [150,     3] loss: 0.329
# 151 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# [151,     3] loss: 0.326
# 152 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# [152,     3] loss: 0.333
# 153 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# [153,     3] loss: 0.323
# 154 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# [154,     3] loss: 0.320
# 155 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# [155,     3] loss: 0.328
# 156 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# [156,     3] loss: 0.324
# 157 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# [157,     3] loss: 0.316
# 158 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# [158,     3] loss: 0.318
# 159 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# [159,     3] loss: 0.314
# 160 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# [160,     3] loss: 0.314
# 161 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# [161,     3] loss: 0.321
# 162 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# [162,     3] loss: 0.315
# 163 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# [163,     3] loss: 0.310
# 164 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# [164,     3] loss: 0.317
# 165 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# [165,     3] loss: 0.313
# 166 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# [166,     3] loss: 0.314
# 167 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# [167,     3] loss: 0.310
# 168 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# [168,     3] loss: 0.306
# 169 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# [169,     3] loss: 0.308
# 170 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# [170,     3] loss: 0.312
# 171 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# [171,     3] loss: 0.306
# 172 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# [172,     3] loss: 0.302
# 173 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# [173,     3] loss: 0.305
# 174 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# [174,     3] loss: 0.303
# 175 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# [175,     3] loss: 0.301
# 176 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# [176,     3] loss: 0.299
# 177 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# [177,     3] loss: 0.308
# 178 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# [178,     3] loss: 0.303
# 179 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# [179,     3] loss: 0.297
# 180 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# [180,     3] loss: 0.297
# 181 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# [181,     3] loss: 0.290
# 182 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# [182,     3] loss: 0.300
# 183 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# [183,     3] loss: 0.298
# 184 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# [184,     3] loss: 0.298
# 185 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# [185,     3] loss: 0.293
# 186 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# [186,     3] loss: 0.299
# 187 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# [187,     3] loss: 0.293
# 188 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# [188,     3] loss: 0.286
# 189 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# [189,     3] loss: 0.291
# 190 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# [190,     3] loss: 0.286
# 191 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# [191,     3] loss: 0.292
# 192 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# [192,     3] loss: 0.289
# 193 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# [193,     3] loss: 0.295
# 194 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# [194,     3] loss: 0.297
# 195 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# [195,     3] loss: 0.295
# 196 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# [196,     3] loss: 0.286
# 197 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# [197,     3] loss: 0.282
# 198 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# [198,     3] loss: 0.292
# 199 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# [199,     3] loss: 0.284
# 200 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# [200,     3] loss: 0.281
# 201 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# [201,     3] loss: 0.280
# 202 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# [202,     3] loss: 0.287
# 203 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# [203,     3] loss: 0.281
# 204 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# [204,     3] loss: 0.278
# 205 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# [205,     3] loss: 0.284
# 206 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# [206,     3] loss: 0.277
# 207 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# [207,     3] loss: 0.291
# 208 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# [208,     3] loss: 0.280
# 209 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# [209,     3] loss: 0.277
# 210 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# [210,     3] loss: 0.275
# 211 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# [211,     3] loss: 0.284
# 212 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# [212,     3] loss: 0.274
# 213 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# [213,     3] loss: 0.274
# 214 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# [214,     3] loss: 0.277
# 215 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# [215,     3] loss: 0.265
# 216 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# [216,     3] loss: 0.267
# 217 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# [217,     3] loss: 0.275
# 218 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# [218,     3] loss: 0.273
# 219 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# [219,     3] loss: 0.270
# 220 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# [220,     3] loss: 0.273
# 221 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# [221,     3] loss: 0.273
# 222 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# [222,     3] loss: 0.266
# 223 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# [223,     3] loss: 0.270
# 224 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# [224,     3] loss: 0.271
# 225 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# [225,     3] loss: 0.270
# 226 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# [226,     3] loss: 0.264
# 227 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# [227,     3] loss: 0.269
# 228 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# [228,     3] loss: 0.266
# 229 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# [229,     3] loss: 0.261
# 230 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# [230,     3] loss: 0.264
# 231 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# [231,     3] loss: 0.257
# 232 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# [232,     3] loss: 0.260
# 233 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# [233,     3] loss: 0.264
# 234 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# [234,     3] loss: 0.263
# 235 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# [235,     3] loss: 0.264
# 236 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# [236,     3] loss: 0.260
# 237 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# [237,     3] loss: 0.260
# 238 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# [238,     3] loss: 0.261
# 239 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# [239,     3] loss: 0.261
# 240 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# [240,     3] loss: 0.265
# 241 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# [241,     3] loss: 0.264
# 242 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# [242,     3] loss: 0.257
# 243 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# [243,     3] loss: 0.255
# 244 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# [244,     3] loss: 0.261
# 245 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# [245,     3] loss: 0.258
# 246 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# [246,     3] loss: 0.257
# 247 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# [247,     3] loss: 0.257
# 248 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# [248,     3] loss: 0.253
# 249 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# [249,     3] loss: 0.258
# 250 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# [250,     3] loss: 0.254
# 251 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# [251,     3] loss: 0.257
# 252 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# [252,     3] loss: 0.252
# 253 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# [253,     3] loss: 0.259
# 254 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# [254,     3] loss: 0.252
# 255 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# [255,     3] loss: 0.257
# 256 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# [256,     3] loss: 0.249
# 257 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# [257,     3] loss: 0.258
# 258 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# [258,     3] loss: 0.257
# 259 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# [259,     3] loss: 0.250
# 260 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# [260,     3] loss: 0.255
# 261 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# [261,     3] loss: 0.252
# 262 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# [262,     3] loss: 0.243
# 263 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# [263,     3] loss: 0.245
# 264 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# [264,     3] loss: 0.249
# 265 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# [265,     3] loss: 0.246
# 266 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# [266,     3] loss: 0.242
# 267 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# [267,     3] loss: 0.243
# 268 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# [268,     3] loss: 0.250
# 269 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# [269,     3] loss: 0.252
# 270 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# [270,     3] loss: 0.248
# 271 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# [271,     3] loss: 0.250
# 272 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# [272,     3] loss: 0.253
# 273 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# [273,     3] loss: 0.241
# 274 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# [274,     3] loss: 0.252
# 275 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# [275,     3] loss: 0.243
# 276 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# [276,     3] loss: 0.243
# 277 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# [277,     3] loss: 0.243
# 278 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# [278,     3] loss: 0.247
# 279 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# [279,     3] loss: 0.242
# 280 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# [280,     3] loss: 0.244
# 281 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# [281,     3] loss: 0.237
# 282 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# [282,     3] loss: 0.234
# 283 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# [283,     3] loss: 0.246
# 284 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# [284,     3] loss: 0.246
# 285 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# [285,     3] loss: 0.240
# 286 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# [286,     3] loss: 0.236
# 287 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# [287,     3] loss: 0.241
# 288 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# [288,     3] loss: 0.242
# 289 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# [289,     3] loss: 0.236
# 290 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# [290,     3] loss: 0.238
# 291 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# [291,     3] loss: 0.239
# 292 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# [292,     3] loss: 0.235
# 293 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# [293,     3] loss: 0.230
# 294 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# [294,     3] loss: 0.229
# 295 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# [295,     3] loss: 0.235
# 296 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# [296,     3] loss: 0.239
# 297 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# [297,     3] loss: 0.239
# 298 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# [298,     3] loss: 0.232
# 299 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# [299,     3] loss: 0.234
# 300 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# [300,     3] loss: 0.234
# 301 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# [301,     3] loss: 0.233
# 302 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# [302,     3] loss: 0.231
# 303 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# [303,     3] loss: 0.237
# 304 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# [304,     3] loss: 0.234
# 305 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# [305,     3] loss: 0.228
# 306 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# [306,     3] loss: 0.230
# 307 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# [307,     3] loss: 0.229
# 308 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# [308,     3] loss: 0.226
# 309 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# [309,     3] loss: 0.222
# 310 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# [310,     3] loss: 0.224
# 311 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# [311,     3] loss: 0.228
# 312 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# [312,     3] loss: 0.230
# 313 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# [313,     3] loss: 0.231
# ...
# --------------------------------------------------------------------------------
# [897,     3] loss: 0.148
# 898 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# [898,     3] loss: 0.140
# 899 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# [899,     3] loss: 0.153
# 900 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# [900,     3] loss: 0.143
# 901 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# [901,     3] loss: 0.147
# 902 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# [902,     3] loss: 0.149
# 903 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# [903,     3] loss: 0.148
# 904 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# [904,     3] loss: 0.146
# 905 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# [905,     3] loss: 0.145
# 906 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# [906,     3] loss: 0.145
# 907 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# [907,     3] loss: 0.155
# 908 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# [908,     3] loss: 0.144
# 909 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# [909,     3] loss: 0.146
# 910 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# [910,     3] loss: 0.142
# 911 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# [911,     3] loss: 0.148
# 912 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# [912,     3] loss: 0.146
# 913 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# [913,     3] loss: 0.151
# 914 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# [914,     3] loss: 0.150
# 915 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# [915,     3] loss: 0.151
# 916 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# [916,     3] loss: 0.148
# 917 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# [917,     3] loss: 0.149
# 918 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# [918,     3] loss: 0.146
# 919 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# [919,     3] loss: 0.151
# 920 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# [920,     3] loss: 0.143
# 921 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# [921,     3] loss: 0.136
# 922 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# [922,     3] loss: 0.137
# 923 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# [923,     3] loss: 0.141
# 924 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# [924,     3] loss: 0.145
# 925 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# [925,     3] loss: 0.143
# 926 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# [926,     3] loss: 0.143
# 927 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# [927,     3] loss: 0.145
# 928 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# [928,     3] loss: 0.142
# 929 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# [929,     3] loss: 0.145
# 930 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# [930,     3] loss: 0.146
# 931 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# [931,     3] loss: 0.140
# 932 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# [932,     3] loss: 0.143
# 933 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# [933,     3] loss: 0.150
# 934 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# [934,     3] loss: 0.141
# 935 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# [935,     3] loss: 0.145
# 936 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# [936,     3] loss: 0.142
# 937 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# [937,     3] loss: 0.148
# 938 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# [938,     3] loss: 0.143
# 939 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# [939,     3] loss: 0.141
# 940 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# [940,     3] loss: 0.143
# 941 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# [941,     3] loss: 0.138
# 942 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# [942,     3] loss: 0.133
# 943 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# [943,     3] loss: 0.138
# 944 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# [944,     3] loss: 0.141
# 945 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# [945,     3] loss: 0.137
# 946 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# [946,     3] loss: 0.142
# 947 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# [947,     3] loss: 0.150
# 948 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# [948,     3] loss: 0.145
# 949 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# [949,     3] loss: 0.143
# 950 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# [950,     3] loss: 0.134
# 951 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# [951,     3] loss: 0.145
# 952 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# [952,     3] loss: 0.139
# 953 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# [953,     3] loss: 0.142
# 954 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# [954,     3] loss: 0.138
# 955 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# [955,     3] loss: 0.136
# 956 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# [956,     3] loss: 0.131
# 957 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# [957,     3] loss: 0.146
# 958 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# [958,     3] loss: 0.141
# 959 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# [959,     3] loss: 0.141
# 960 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# [960,     3] loss: 0.146
# 961 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# [961,     3] loss: 0.145
# 962 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# [962,     3] loss: 0.136
# 963 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# [963,     3] loss: 0.141
# 964 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# [964,     3] loss: 0.136
# 965 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# [965,     3] loss: 0.143
# 966 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# [966,     3] loss: 0.141
# 967 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# [967,     3] loss: 0.135
# 968 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# [968,     3] loss: 0.137
# 969 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# [969,     3] loss: 0.142
# 970 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# [970,     3] loss: 0.135
# 971 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# [971,     3] loss: 0.141
# 972 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# [972,     3] loss: 0.139
# 973 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# [973,     3] loss: 0.141
# 974 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# [974,     3] loss: 0.139
# 975 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# [975,     3] loss: 0.145
# 976 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# [976,     3] loss: 0.143
# 977 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# [977,     3] loss: 0.150
# 978 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# [978,     3] loss: 0.149
# 979 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# [979,     3] loss: 0.141
# 980 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# [980,     3] loss: 0.135
# 981 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# [981,     3] loss: 0.141
# 982 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# [982,     3] loss: 0.141
# 983 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# [983,     3] loss: 0.134
# 984 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# [984,     3] loss: 0.134
# 985 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# [985,     3] loss: 0.139
# 986 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# [986,     3] loss: 0.129
# 987 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# [987,     3] loss: 0.130
# 988 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# [988,     3] loss: 0.134
# 989 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# [989,     3] loss: 0.135
# 990 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# [990,     3] loss: 0.140
# 991 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# [991,     3] loss: 0.144
# 992 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# [992,     3] loss: 0.135
# 993 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# [993,     3] loss: 0.138
# 994 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# [994,     3] loss: 0.134
# 995 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# [995,     3] loss: 0.137
# 996 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# [996,     3] loss: 0.141
# 997 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# [997,     3] loss: 0.134
# 998 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# [998,     3] loss: 0.139
# 999 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# [999,     3] loss: 0.138
# 1000 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# [1000,     3] loss: 0.141
# Finished Training

# %%
df_train = pd.DataFrame()
df_test = pd.DataFrame()

# %%
columns = ["epochs", "argmax > 0.5" ,"argmax < 0.5", "focus_true_pred_true", "focus_false_pred_true", "focus_true_pred_false", "focus_false_pred_false" ]

# %%
df_train[columns[0]] = col1
df_train[columns[1]] = col2
df_train[columns[2]] = col3
df_train[columns[3]] = col4
df_train[columns[4]] = col5
df_train[columns[5]] = col6
df_train[columns[6]] = col7

df_test[columns[0]] = col1
df_test[columns[1]] = col8
df_test[columns[2]] = col9
df_test[columns[3]] = col10
df_test[columns[4]] = col11
df_test[columns[5]] = col12
df_test[columns[6]] = col13

# %%
df_train
# Out:
#      epochs  argmax > 0.5  ...  focus_true_pred_false  focus_false_pred_false
# 0         0             0  ...                    507                       0
# 1         1             0  ...                    507                       0
# 2         6             0  ...                    504                       0
# 3        11             0  ...                    506                       0
# 4        16             4  ...                    507                       0
# ..      ...           ...  ...                    ...                     ...
# 196     976           596  ...                     15                       0
# 197     981           653  ...                     15                       0
# 198     986           654  ...                     12                       0
# 199     991           642  ...                      8                       0
# 200     996           648  ...                      3                       0
#
# [201 rows x 7 columns]

# %%
# plt.figure(12,12)
plt.plot(col1,np.array(col2)/10, label='argmax > 0.5')
plt.plot(col1,np.array(col3)/10, label='argmax < 0.5')

plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.xlabel("epochs")
plt.ylabel("training data")
plt.title("On Training set")
plt.show()

plt.plot(col1,np.array(col4)/10, label ="focus_true_pred_true ")
plt.plot(col1,np.array(col5)/10, label ="focus_false_pred_true ")
plt.plot(col1,np.array(col6)/10, label ="focus_true_pred_false ")
plt.plot(col1,np.array(col7)/10, label ="focus_false_pred_false ")
plt.title("On Training set")
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.xlabel("epochs")
plt.ylabel("training data")
plt.show()

# %%
df_test
# Out:
#      epochs  argmax > 0.5  ...  focus_true_pred_false  focus_false_pred_false
# 0         0             0  ...                    481                       0
# 1         1             0  ...                    481                       0
# 2         6             0  ...                    469                       0
# 3        11             0  ...                    480                       0
# 4        16             3  ...                    481                       0
# ..      ...           ...  ...                    ...                     ...
# 196     976           624  ...                     14                       0
# 197     981           665  ...                      2                       0
# 198     986           672  ...                      8                       0
# 199     991           665  ...                      3                       0
# 200     996           668  ...                      2                       0
#
# [201 rows x 7 columns]

# %%
# plt.figure(12,12)
plt.plot(col1,np.array(col8)/10, label='argmax > 0.5')
plt.plot(col1,np.array(col9)/10, label='argmax < 0.5')

plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.xlabel("epochs")
plt.ylabel("Testing data")
plt.title("On Testing set")
plt.show()

plt.plot(col1,np.array(col10)/10, label ="focus_true_pred_true ")
plt.plot(col1,np.array(col11)/10, label ="focus_false_pred_true ")
plt.plot(col1,np.array(col12)/10, label ="focus_true_pred_false ")
plt.plot(col1,np.array(col13)/10, label ="focus_false_pred_false ")
plt.title("On Testing set")
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.xlabel("epochs")
plt.ylabel("Testing data")
plt.show()

# %%
correct = 0
total = 0
count = 0
flag = 1
focus_true_pred_true =0
focus_false_pred_true =0
focus_true_pred_false =0
focus_false_pred_false =0

argmax_more_than_half = 0
argmax_less_than_half =0

with torch.no_grad():
  for data in train_loader:
    inputs, labels , fore_idx = data
    inputs = inputs.double()
    
    inputs, labels , fore_idx = inputs.to("cuda"),labels.to("cuda"), fore_idx.to("cuda")
    alphas, avg_images = focus_net(inputs)
    outputs = classify(avg_images)

    predicted = np.round(torch.sigmoid(outputs.data).cpu().numpy())

    for j in range(labels.size(0)):
      focus = torch.argmax(alphas[j])
      if alphas[j][focus] >= 0.5 :
        argmax_more_than_half += 1
      else:
        argmax_less_than_half += 1

      if(focus == fore_idx[j] and predicted[j] == labels[j].item()):
          focus_true_pred_true += 1
      elif(focus != fore_idx[j] and predicted[j] == labels[j].item()):
        focus_false_pred_true += 1
      elif(focus == fore_idx[j] and predicted[j] != labels[j].item()):
        focus_true_pred_false += 1
      elif(focus != fore_idx[j] and predicted[j] != labels[j].item()):
        focus_false_pred_false += 1

    total += labels.size(0)
    correct += np.sum( np.concatenate(predicted,axis=0)== labels.cpu().numpy() )

print('Accuracy of the network on the 1000 train images: %d %%' % (
    100 * correct / total))
print("total correct", correct)
print("total train set images", total)

print("focus_true_pred_true %d =============> FTPT : %d %%" % (focus_true_pred_true , (100 * focus_true_pred_true / total) ) )
print("focus_false_pred_true %d =============> FFPT : %d %%" % (focus_false_pred_true, (100 * focus_false_pred_true / total) ) )
print("focus_true_pred_false %d =============> FTPF : %d %%" %( focus_true_pred_false , ( 100 * focus_true_pred_false / total) ) )
print("focus_false_pred_false %d =============> FFPF : %d %%" % (focus_false_pred_false, ( 100 * focus_false_pred_false / total) ) )

print("argmax_more_than_half ==================> ",argmax_more_than_half)
print("argmax_less_than_half ==================> ",argmax_less_than_half)
# Out:
# Accuracy of the network on the 1000 train images: 98 %
# total correct 989
# total train set images 1000
# focus_true_pred_true 989 =============> FTPT : 98 %
# focus_false_pred_true 0 =============> FFPT : 0 %
# focus_true_pred_false 11 =============> FTPF : 1 %
# focus_false_pred_false 0 =============> FFPF : 0 %
# argmax_more_than_half ==================>  654
# argmax_less_than_half ==================>  346

# %%
correct = 0
total = 0
count = 0
flag = 1
focus_true_pred_true =0
focus_false_pred_true =0
focus_true_pred_false =0
focus_false_pred_false =0

argmax_more_than_half = 0
argmax_less_than_half =0

with torch.no_grad():
  for data in test_loader:
    inputs, labels , fore_idx = data
    inputs = inputs.double()
    inputs, labels , fore_idx = inputs.to("cuda"),labels.to("cuda"), fore_idx.to("cuda")
    alphas, avg_images = focus_net(inputs)
    outputs = classify(avg_images)

    predicted = np.round(torch.sigmoid(outputs.data).cpu().numpy())

    for j in range(labels.size(0)):
      focus = torch.argmax(alphas[j])
      if alphas[j][focus] >= 0.5 :
        argmax_more_than_half += 1
      else:
        argmax_less_than_half += 1

      if(focus == fore_idx[j] and predicted[j] == labels[j].item()):
          focus_true_pred_true += 1
      elif(focus != fore_idx[j] and predicted[j] == labels[j].item()):
        focus_false_pred_true += 1
      elif(focus == fore_idx[j] and predicted[j] != labels[j].item()):
        focus_true_pred_false += 1
      elif(focus != fore_idx[j] and predicted[j] != labels[j].item()):
        focus_false_pred_false += 1

    total += labels.size(0)
    correct += np.sum( np.concatenate(predicted,axis=0)== labels.cpu().numpy() )

print('Accuracy of the network on the 1000 test images: %d %%' % (
    100 * correct / total))
print("total correct", correct)
print("total train set images", total)

print("focus_true_pred_true %d =============> FTPT : %d %%" % (focus_true_pred_true , (100 * focus_true_pred_true / total) ) )
print("focus_false_pred_true %d =============> FFPT : %d %%" % (focus_false_pred_true, (100 * focus_false_pred_true / total) ) )
print("focus_true_pred_false %d =============> FTPF : %d %%" %( focus_true_pred_false , ( 100 * focus_true_pred_false / total) ) )
print("focus_false_pred_false %d =============> FFPF : %d %%" % (focus_false_pred_false, ( 100 * focus_false_pred_false / total) ) )

print("argmax_more_than_half ==================> ",argmax_more_than_half)
print("argmax_less_than_half ==================> ",argmax_less_than_half)
# Out:
# Accuracy of the network on the 1000 test images: 99 %
# total correct 993
# total train set images 1000
# focus_true_pred_true 993 =============> FTPT : 99 %
# focus_false_pred_true 0 =============> FFPT : 0 %
# focus_true_pred_false 7 =============> FTPF : 0 %
# focus_false_pred_false 0 =============> FFPF : 0 %
# argmax_more_than_half ==================>  672
# argmax_less_than_half ==================>  328

# %%
correct = 0
total = 0

with torch.no_grad():
  for data in train_loader:
    inputs, labels , fore_idx = data
    inputs = inputs.double()
    inputs, labels = inputs.to("cuda"), labels.to("cuda")
    alphas, avg_images = focus_net(inputs)
    outputs = classify(avg_images)

    predicted = np.round(torch.sigmoid(outputs.data).cpu().numpy())

    total += labels.size(0)
    correct += np.sum( np.concatenate(predicted,axis=0)== labels.cpu().numpy() )

print('Accuracy of the network on the 1000 train images: %d %%' % ( 100 * correct / total))
print("total correct", correct)
print("total train set images", total)
# Out:
# Accuracy of the network on the 1000 train images: 98 %
# total correct 989
# total train set images 1000

# %%
correct = 0
total = 0

with torch.no_grad():
  for data in test_loader:
    inputs, labels , fore_idx = data
    inputs = inputs.double()
    inputs, labels = inputs.to("cuda"), labels.to("cuda")
    alphas, avg_images = focus_net(inputs)
    outputs = classify(avg_images)

    predicted = np.round(torch.sigmoid(outputs.data).cpu().numpy())

    total += labels.size(0)
    correct += np.sum( np.concatenate(predicted,axis=0)== labels.cpu().numpy() )

print('Accuracy of the network on the 1000 test images: %d %%' % ( 100 * correct / total))
print("total correct", correct)
print("total train set images", total)
# Out:
# Accuracy of the network on the 1000 test images: 99 %
# total correct 993
# total train set images 1000

# %%
focus_net.fc1.weight, focus_net.fc1.bias
# Out:
# (Parameter containing:
#  tensor([[-0.2888]], device='cuda:0', dtype=torch.float64, requires_grad=True),
#  Parameter containing:
#  tensor([-2.7847e-17], device='cuda:0', dtype=torch.float64, requires_grad=True))

# %%
classify.fc1.weight, classify.fc1.bias
# Out:
# (Parameter containing:
#  tensor([[1.6446]], device='cuda:0', dtype=torch.float64, requires_grad=True),
#  Parameter containing:
#  tensor([7.9332], device='cuda:0', dtype=torch.float64, requires_grad=True))
