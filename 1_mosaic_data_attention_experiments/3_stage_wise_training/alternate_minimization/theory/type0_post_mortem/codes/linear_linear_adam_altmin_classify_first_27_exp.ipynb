# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
from tqdm import tqdm
# %matplotlib inline
from torch.utils.data import Dataset, DataLoader
import torch
import torchvision

import torch.nn as nn
import torch.optim as optim
from torch.nn import functional as F
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda

# %% [markdown]
# # Generate dataset

# %%
y = np.random.randint(0,3,500)
idx= []
for i in range(3):
    print(i,sum(y==i))
    idx.append(y==i)
# Out:
# 0 167
# 1 172
# 2 161

# %%
x = np.zeros((500,))

# %%
np.random.seed(12)
x[idx[0]] = np.random.uniform(low =-1,high =0,size= sum(idx[0]))
x[idx[1]] = np.random.uniform(low =0,high =1,size= sum(idx[1]))
x[idx[2]] = np.random.uniform(low =2,high =3,size= sum(idx[2]))

# %%
x[idx[0]][0], x[idx[2]][5]
# Out:
# (-0.8458371576203276, 2.3604378901528515)

# %%
print(x.shape,y.shape)
# Out:
# (500,) (500,)

# %%
idx= []
for i in range(3):
  idx.append(y==i)

# %%
for i in range(3):
    y= np.zeros(x[idx[i]].shape[0])
    plt.scatter(x[idx[i]],y,label="class_"+str(i))
plt.legend()

# %%
bg_idx = [ np.where(idx[2] == True)[0]]

bg_idx = np.concatenate(bg_idx, axis = 0)
bg_idx.shape
# Out:
# (161,)

# %%
np.unique(bg_idx).shape
# Out:
# (161,)

# %%
x = x - np.mean(x[bg_idx], axis = 0, keepdims = True)

# %%
np.mean(x[bg_idx], axis = 0, keepdims = True), np.mean(x, axis = 0, keepdims = True)
# Out:
# (array([2.289404e-16]), array([-1.71288963]))

# %%
x = x/np.std(x[bg_idx], axis = 0, keepdims = True)

# %%
np.std(x[bg_idx], axis = 0, keepdims = True), np.std(x, axis = 0, keepdims = True)
# Out:
# (array([1.]), array([4.31941606]))

# %%
for i in range(3):
    y= np.zeros(x[idx[i]].shape[0])
    plt.scatter(x[idx[i]],y,label="class_"+str(i))
plt.legend()

# %%
foreground_classes = {'class_0','class_1' }

background_classes = {'class_2'}

# %%
fg_class  = np.random.randint(0,2)
fg_idx = np.random.randint(0,9)

a = []
for i in range(9):
    if i == fg_idx:
        b = np.random.choice(np.where(idx[fg_class]==True)[0],size=1)
        a.append(x[b])
        print("foreground "+str(fg_class)+" present at " + str(fg_idx))
    else:
        bg_class = np.random.randint(2,3)
        b = np.random.choice(np.where(idx[bg_class]==True)[0],size=1)
        a.append(x[b])
        print("background "+str(bg_class)+" present at " + str(i))
a = np.concatenate(a,axis=0)
print(a.shape)

print(fg_class , fg_idx)
# Out:
# background 2 present at 0
# background 2 present at 1
# background 2 present at 2
# background 2 present at 3
# background 2 present at 4
# background 2 present at 5
# background 2 present at 6
# background 2 present at 7
# foreground 1 present at 8
# (9,)
# 1 8

# %%
a.shape
# Out:
# (9,)

# %%
np.reshape(a,(9,1))
# Out:
# array([[ 1.3858941 ],
#        [ 1.1016801 ],
#        [ 0.79226066],
#        [-0.1621505 ],
#        [ 1.33632494],
#        [-0.37216541],
#        [-0.24852921],
#        [ 1.33632494],
#        [-8.13790893]])

# %%
a=np.reshape(a,(3,3))

# %%
plt.imshow(a)

# %%
desired_num = 2000
mosaic_list_of_images =[]
mosaic_label = []
fore_idx=[]
for j in range(desired_num):
    np.random.seed(j)
    fg_class  = np.random.randint(0,2)
    fg_idx = 0
    a = []
    for i in range(9):
        if i == fg_idx:
            b = np.random.choice(np.where(idx[fg_class]==True)[0],size=1)
            a.append(x[b])
#             print("foreground "+str(fg_class)+" present at " + str(fg_idx))
        else:
            bg_class = np.random.randint(2,3)
            b = np.random.choice(np.where(idx[bg_class]==True)[0],size=1)
            a.append(x[b])
#             print("background "+str(bg_class)+" present at " + str(i))
    a = np.concatenate(a,axis=0)
    mosaic_list_of_images.append(np.reshape(a,(9,1)))
    mosaic_label.append(fg_class)
    fore_idx.append(fg_idx)

# %%
mosaic_list_of_images = np.concatenate(mosaic_list_of_images,axis=1).T

# %%
mosaic_list_of_images.shape, mosaic_list_of_images[0]
# Out:
# ((2000, 9), array([-10.60437572,  -1.28599156,  -1.06485643,   1.03837598,
#          -0.37216541,  -0.04296858,  -0.53615092,   1.20906795,
#          -1.35543395]))

# %%
for j in range(9):
  print(mosaic_list_of_images[0][j])
# Out:
# -10.604375722450587
# -1.2859915592991948
# -1.064856431217093
# 1.0383759812974351
# -0.37216541084987675
# -0.04296857893374387
# -0.5361509239446812
# 1.2090679495264591
# -1.3554339515399818

# %%
class MosaicDataset(Dataset):
  """MosaicDataset dataset."""

  def __init__(self, mosaic_list_of_images, mosaic_label, fore_idx):
    """
      Args:
        csv_file (string): Path to the csv file with annotations.
        root_dir (string): Directory with all the images.
        transform (callable, optional): Optional transform to be applied
            on a sample.
    """
    self.mosaic = mosaic_list_of_images
    self.label = mosaic_label
    self.fore_idx = fore_idx

  def __len__(self):
    return len(self.label)

  def __getitem__(self, idx):
    return self.mosaic[idx] , self.label[idx], self.fore_idx[idx]

# %%
batch = 250
msd1 = MosaicDataset(mosaic_list_of_images[0:1000], mosaic_label[0:1000] , fore_idx[0:1000])
train_loader = DataLoader( msd1 ,batch_size= batch ,shuffle=True)

# %%
batch = 250
msd2 = MosaicDataset(mosaic_list_of_images[1000:2000], mosaic_label[1000:2000] , fore_idx[1000:2000])
test_loader = DataLoader( msd2 ,batch_size= batch ,shuffle=True)

# %%
class Focus(nn.Module):
  def __init__(self):
    super(Focus, self).__init__()

    self.fc1 = nn.Linear(1, 1, bias= False)
    # self.fc2 = nn.Linear(2, 1)

  def forward(self,z):  #y is avg image #z batch of list of 9 images
    y = torch.zeros([batch], dtype=torch.float64)
    x = torch.zeros([batch,9],dtype=torch.float64)
    y = y.to("cuda")
    x = x.to("cuda")
    # print(x.shape, z.shape)
    for i in range(9):
      # print(z[:,i].shape)
      # print(self.helper(z[:,i])[:,0].shape)
      x[:,i] = self.helper(z[:,i])[:,0]
    # print(x.shape, z.shape)
    x = F.softmax(x,dim=1)
    # print(x.shape, z.shape)
    # x1 = x[:,0]
    # print(torch.mul(x[:,0],z[:,0]).shape)

    for i in range(9):            
      # x1 = x[:,i]          
      y = y + torch.mul(x[:,i],z[:,i])

    # print(x.shape, y.shape)
    return x, y
    
  def helper(self, x):
    x = x.view(-1, 1)
    # x = F.relu(self.fc1(x))
    x = (self.fc1(x))

    return x

# %%
class Classification(nn.Module):
  def __init__(self):
    super(Classification, self).__init__()
    self.fc1 = nn.Linear(1, 1)


  def forward(self, x):
    x = x.view(-1, 1)
    x = self.fc1(x)
    # print(x.shape)
    return x

# %%
import torch.optim as optim

def train(train_loader, test_loader, focus_net, classify):    
  criterion = nn.BCEWithLogitsLoss()
  optimizer_classify = optim.Adam(classify.parameters(), lr=0.01 ) #, momentum=0.9)
  optimizer_focus = optim.Adam(focus_net.parameters(), lr=0.01 ) #, momentum=0.9)

  print('-'*50)
  print(focus_net.fc1.weight, classify.fc1.weight, classify.fc1.bias)
  nos_epochs = 1000
  loss_ret=0.0
  every_what_epoch = 1

  for epoch in range(nos_epochs):  # loop over the dataset multiple times
    
    running_loss = 0.0
    epoch_loss = []
    cnt=0

    iteration = desired_num // batch
    
    #training data set
    if ((epoch) % (every_what_epoch*2) ) <= every_what_epoch-1 :
      print(epoch+1,"updating classify_net, focus_net is freezed")
      print("--"*40)
    elif ((epoch) % (every_what_epoch*2)) > every_what_epoch-1 :
      print(epoch+1,"updating focus_net, classify_net is freezed")
      print("--"*40)    
    for i, data in  enumerate(train_loader):
      inputs , labels , fore_idx = data
      inputs, labels = inputs.to("cuda"), labels.to("cuda")
      inputs = inputs.double()
      labels = labels.float()
      # zero the parameter gradients
      
      optimizer_focus.zero_grad()
      optimizer_classify.zero_grad()
      
      alphas, avg_images = focus_net(inputs)
      outputs = classify(avg_images)

      predicted = np.round(torch.sigmoid(outputs.data).cpu().numpy())
      # print(predicted.shape)
      # print(outputs.shape,labels.shape)
      # print(outputs)
      # print(labels)
      loss = criterion(outputs[:,0], labels) 
      loss.backward()
      if ((epoch) % (every_what_epoch*2) ) <= every_what_epoch-1 :
        optimizer_classify.step()
      elif ( (epoch) % (every_what_epoch*2)) > every_what_epoch-1 :
        optimizer_focus.step()

      running_loss += loss.item()
      # mini = 3
      # if cnt % mini == mini-1 :    # print every 40 mini-batches
      epoch_loss.append(running_loss)
      running_loss = 0.0
      cnt=cnt+1
    loss_ret = np.mean(epoch_loss)
    if(epoch%200==0):
      print('[%d, %5d] loss: %.3f' %(epoch + 1, cnt + 1, np.mean(epoch_loss)))
    if(np.mean(epoch_loss) <= 0.001):
        break;

  with torch.no_grad():
    focus_true_pred_true =0
    focus_false_pred_true =0
    focus_true_pred_false =0
    focus_false_pred_false =0

    argmax_more_than_half = 0
    argmax_less_than_half =0
    for data in test_loader:
      inputs, labels , fore_idx = data
      inputs = inputs.double()
      inputs, labels = inputs.to("cuda"), labels.to("cuda")
      alphas, avg_images = focus_net(inputs)
      outputs = classify(avg_images)
      predicted = np.round(torch.sigmoid(outputs.data).cpu().numpy())

      for j in range (batch):
        focus = torch.argmax(alphas[j])

        if(alphas[j][focus] >= 0.5):
          argmax_more_than_half +=1
        else:
          argmax_less_than_half +=1

        if(focus == fore_idx[j] and predicted[j] == labels[j].item()):
          focus_true_pred_true += 1

        elif(focus != fore_idx[j] and predicted[j] == labels[j].item()):
          focus_false_pred_true +=1

        elif(focus == fore_idx[j] and predicted[j] != labels[j].item()):
          focus_true_pred_false +=1

        elif(focus != fore_idx[j] and predicted[j] != labels[j].item()):
          focus_false_pred_false +=1

  print('Finished Training')  
  return loss_ret, argmax_more_than_half/10, focus_true_pred_true/10, focus_false_pred_true/10, focus_true_pred_false/10 , focus_false_pred_false/10, focus_net.fc1.weight.item(), classify.fc1.weight.item(), classify.fc1.bias.item()

# %%
a = [-0.1, 0.0, 0.1]
b = [-0.1, 0.0, 0.1]
c = [-0.1, 0.0, 0.1]

# %%
# torch.manual_seed(12)
# focus_net = Focus().double()
# focus_net.fc1.weight = torch.nn.Parameter(torch.tensor(np.array([[0.0]])))
# torch.manual_seed(12)
# classify = Classification().double()
# classify.fc1.weight = torch.nn.Parameter(torch.tensor(np.array([[0.0]])))
# classify.fc1.bias = torch.nn.Parameter(torch.tensor(np.array([0.0])))
# focus_net = focus_net.to("cuda")
# classify = classify.to("cuda")
# # print("--"*40,"a,b,c = ",a[i],b[j],c[k])
# print(focus_net.fc1.weight, classify.fc1.weight, classify.fc1.bias)

# %%
# np.round(focus_net.fc1.weight.item(),3), np.round(99.3, 3)

# %%
# train(train_loader, test_loader, focus_net, classify)

# %%
all_loss=[]
all_alphas_more_than_half=[]
all_ftpt=[]
all_ffpt=[]
all_ftpf = []
all_ffpf= []
init_a = []
init_b = []
init_c = []
final_a=[]
final_b = []
final_c = []

for i in range(3):
  for j in range(3):
    for k in range(3):
      torch.manual_seed(12)
      focus_net = Focus().double()
      focus_net.fc1.weight = torch.nn.Parameter(torch.tensor(np.array([[a[i]]])))
      torch.manual_seed(12)
      classify = Classification().double()
      classify.fc1.weight = torch.nn.Parameter(torch.tensor(np.array([[b[j]]])))
      classify.fc1.bias = torch.nn.Parameter(torch.tensor(np.array([c[k]])))
      focus_net = focus_net.to("cuda")
      classify = classify.to("cuda")
      print("--"*40,"a,b,c = ",a[i],b[j],c[k])
      cost, alpha_per, ftpt, ffpt, ftpf, ffpf, f_a, f_b, f_c = train(train_loader, test_loader, focus_net, classify)
      print(cost, alpha_per, ftpt, ffpt, ftpf, ffpf)
      init_a.append(a[i])
      init_b.append(b[j])
      init_c.append(c[k])
      final_a.append(np.round(f_a,3))
      final_b.append(np.round(f_b,3))
      final_c.append(np.round(f_c,3))
      all_loss.append(np.round(cost,3))
      all_alphas_more_than_half.append(alpha_per)
      all_ftpt.append(ftpt)
      all_ffpt.append(ffpt)
      all_ftpf.append(ftpf)
      all_ffpf.append(ffpf)
# Out:
# Streaming output truncated to the last 5000 lines.
# 516 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# 517 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# 518 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# 519 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# 520 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# 521 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# 522 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# 523 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# 524 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# 525 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# 526 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# 527 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# 528 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# 529 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# 530 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# 531 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# 532 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# 533 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# 534 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# 535 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# 536 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# 537 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# 538 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# 539 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# 540 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# 541 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# 542 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# 543 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# 544 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# 545 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# 546 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# 547 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# 548 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# 549 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# 550 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# 551 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# 552 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# 553 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# 554 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# 555 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# 556 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# 557 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# 558 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# 559 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# 560 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# 561 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# 562 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# 563 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# 564 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# 565 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# 566 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# 567 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# 568 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# 569 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# 570 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# 571 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# 572 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# 573 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# 574 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# 575 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# 576 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# 577 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# 578 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# 579 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# 580 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# 581 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# 582 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# 583 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# 584 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# 585 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# 586 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# 587 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# 588 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# 589 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# 590 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# 591 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# 592 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# 593 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# 594 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# 595 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# 596 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# 597 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# 598 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# 599 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# 600 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# 601 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# [601,     5] loss: 0.159
# 602 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# 603 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# 604 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# 605 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# 606 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# 607 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# 608 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# 609 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# 610 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# 611 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# 612 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# 613 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# 614 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# 615 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# 616 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# 617 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# 618 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# 619 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# 620 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# 621 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# 622 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# 623 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# 624 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# 625 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# 626 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# 627 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# 628 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# 629 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# 630 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# 631 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# 632 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# 633 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# 634 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# 635 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# 636 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# 637 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# 638 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# 639 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# 640 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# 641 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# 642 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# 643 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# 644 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# 645 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# 646 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# 647 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# 648 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# 649 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# 650 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# 651 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# 652 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# 653 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# 654 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# 655 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# 656 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# 657 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# 658 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# 659 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# 660 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# 661 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# 662 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# 663 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# 664 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# 665 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# 666 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# 667 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# 668 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# 669 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# 670 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# 671 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# 672 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# 673 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# 674 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# 675 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# 676 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# 677 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# 678 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# 679 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# 680 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# 681 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# 682 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# 683 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# 684 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# 685 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# 686 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# 687 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# 688 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# 689 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# 690 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# 691 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# 692 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# 693 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# 694 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# 695 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# 696 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# 697 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# 698 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# 699 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# 700 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# 701 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# 702 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# 703 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# 704 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# 705 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# 706 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# 707 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# 708 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# 709 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# 710 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# 711 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# 712 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# 713 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# 714 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# 715 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# 716 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# 717 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# 718 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# 719 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# 720 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# 721 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# 722 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# 723 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# 724 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# 725 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# 726 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# 727 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# 728 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# 729 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# 730 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# 731 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# 732 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# 733 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# 734 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# 735 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# 736 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# 737 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# 738 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# 739 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# 740 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# 741 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# 742 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# 743 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# 744 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# 745 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# 746 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# 747 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# 748 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# 749 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# 750 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# 751 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# 752 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# 753 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# 754 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# 755 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# 756 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# 757 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# 758 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# 759 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# 760 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# 761 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# 762 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# 763 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# 764 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# 765 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# 766 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# 767 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# 768 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# 769 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# 770 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# 771 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# 772 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# 773 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# 774 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# 775 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# 776 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# 777 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# 778 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# 779 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# 780 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# 781 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# 782 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# 783 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# 784 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# 785 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# 786 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# 787 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# 788 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# 789 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# 790 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# 791 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# 792 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# 793 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# 794 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# 795 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# 796 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# 797 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# 798 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# 799 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# 800 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# 801 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# [801,     5] loss: 0.133
# 802 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# 803 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# 804 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# 805 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# 806 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# 807 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# 808 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# 809 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# 810 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# 811 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# 812 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# 813 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# 814 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# 815 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# 816 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# 817 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# 818 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# 819 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# 820 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# 821 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# 822 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# 823 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# 824 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# 825 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# 826 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# 827 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# 828 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# 829 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# 830 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# 831 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# 832 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# 833 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# 834 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# 835 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# 836 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# 837 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# 838 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# 839 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# 840 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# 841 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# 842 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# 843 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# 844 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# 845 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# 846 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# 847 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# 848 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# 849 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# 850 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# 851 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# 852 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# 853 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# 854 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# 855 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# 856 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# 857 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# 858 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# 859 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# 860 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# 861 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# 862 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# 863 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# 864 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# 865 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# 866 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# 867 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# 868 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# 869 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# 870 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# 871 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# 872 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# 873 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# 874 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# 875 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# 876 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# 877 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# 878 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# 879 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# 880 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# 881 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# 882 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# 883 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# 884 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# 885 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# 886 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# ...
# 878 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# 879 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# 880 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# 881 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# 882 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# 883 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# 884 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# 885 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# 886 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# 887 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# 888 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# 889 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# 890 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# 891 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# 892 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# 893 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# 894 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# 895 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# 896 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# 897 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# 898 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# 899 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# 900 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# 901 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# 902 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# 903 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# 904 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# 905 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# 906 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# 907 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# 908 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# 909 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# 910 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# 911 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# 912 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# 913 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# 914 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# 915 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# 916 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# 917 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# 918 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# 919 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# 920 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# 921 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# 922 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# 923 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# 924 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# 925 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# 926 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# 927 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# 928 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# 929 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# 930 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# 931 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# 932 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# 933 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# 934 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# 935 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# 936 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# 937 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# 938 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# 939 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# 940 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# 941 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# 942 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# 943 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# 944 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# 945 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# 946 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# 947 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# 948 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# 949 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# 950 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# 951 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# 952 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# 953 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# 954 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# 955 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# 956 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# 957 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# 958 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# 959 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# 960 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# 961 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# 962 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# 963 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# 964 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# 965 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# 966 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# 967 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# 968 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# 969 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# 970 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# 971 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# 972 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# 973 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# 974 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# 975 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# 976 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# 977 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# 978 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# 979 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# 980 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# 981 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# 982 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# 983 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# 984 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# 985 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# 986 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# 987 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# 988 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# 989 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# 990 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# 991 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# 992 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# 993 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# 994 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# 995 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# 996 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# 997 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# 998 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# 999 updating classify_net, focus_net is freezed
# --------------------------------------------------------------------------------
# 1000 updating focus_net, classify_net is freezed
# --------------------------------------------------------------------------------
# Finished Training
# 0.11576027236878872 61.1 99.3 0.0 0.7 0.0

# %%
# df_train = pd.DataFrame()
df_test = pd.DataFrame()

# %%
columns = ["init_a", "init_b", "init_c", "final_a", "final_b", "final_c", "train_loss", "argmax > 0.5" , "ftpt", "ffpt", "ftpf", "ffpf" ]

# %%
df_test[columns[0]] = init_a
df_test[columns[1]] = init_b
df_test[columns[2]] = init_c
df_test[columns[3]] = final_a
df_test[columns[4]] = final_b
df_test[columns[5]] = final_c
df_test[columns[6]] = all_loss
df_test[columns[7]] = all_alphas_more_than_half
df_test[columns[8]] = all_ftpt
df_test[columns[9]] = all_ffpt
df_test[columns[10]] = all_ftpf
df_test[columns[11]] = all_ffpf

# %%
df_test
# Out:
#     init_a  init_b  init_c  final_a  ...  ftpt  ffpt  ftpf  ffpf
# 0     -0.1    -0.1    -0.1   -0.269  ...  99.3   0.0   0.7   0.0
# 1     -0.1    -0.1     0.0   -0.269  ...  99.3   0.0   0.7   0.0
# 2     -0.1    -0.1     0.1   -0.269  ...  99.3   0.0   0.7   0.0
# 3     -0.1     0.0    -0.1   -0.269  ...  99.3   0.0   0.7   0.0
# 4     -0.1     0.0     0.0   -0.269  ...  99.3   0.0   0.7   0.0
# 5     -0.1     0.0     0.1   -0.269  ...  99.3   0.0   0.7   0.0
# 6     -0.1     0.1    -0.1   -0.268  ...  99.3   0.0   0.7   0.0
# 7     -0.1     0.1     0.0   -0.269  ...  99.3   0.0   0.7   0.0
# 8     -0.1     0.1     0.1   -0.269  ...  99.3   0.0   0.7   0.0
# 9      0.0    -0.1    -0.1   -0.269  ...  99.3   0.0   0.7   0.0
# 10     0.0    -0.1     0.0   -0.269  ...  99.3   0.0   0.7   0.0
# 11     0.0    -0.1     0.1   -0.269  ...  99.3   0.0   0.7   0.0
# 12     0.0     0.0    -0.1   -0.269  ...  99.3   0.0   0.7   0.0
# 13     0.0     0.0     0.0   -0.269  ...  99.3   0.0   0.7   0.0
# 14     0.0     0.0     0.1   -0.269  ...  99.3   0.0   0.7   0.0
# 15     0.0     0.1    -0.1   -0.268  ...  99.3   0.0   0.7   0.0
# 16     0.0     0.1     0.0   -0.269  ...  99.3   0.0   0.7   0.0
# 17     0.0     0.1     0.1   -0.269  ...  99.3   0.0   0.7   0.0
# 18     0.1    -0.1    -0.1    0.263  ...   0.0  52.6   0.0  47.4
# 19     0.1    -0.1     0.0    0.263  ...   0.0  52.6   0.0  47.4
# 20     0.1    -0.1     0.1    0.263  ...   0.0  52.6   0.0  47.4
# 21     0.1     0.0    -0.1    0.263  ...   0.0  52.6   0.0  47.4
# 22     0.1     0.0     0.0   -0.269  ...  99.3   0.0   0.7   0.0
# 23     0.1     0.0     0.1   -0.269  ...  99.3   0.0   0.7   0.0
# 24     0.1     0.1    -0.1   -0.269  ...  99.3   0.0   0.7   0.0
# 25     0.1     0.1     0.0   -0.269  ...  99.3   0.0   0.7   0.0
# 26     0.1     0.1     0.1   -0.269  ...  99.3   0.0   0.7   0.0
#
# [27 rows x 12 columns]

# %%
df_test.to_csv("linear_linear_altmin_classify_first.csv")
