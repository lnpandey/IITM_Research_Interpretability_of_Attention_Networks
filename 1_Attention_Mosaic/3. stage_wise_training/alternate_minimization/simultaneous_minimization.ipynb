# %%
import numpy as np
import pandas as pd

import torch
import torchvision
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms, utils
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

from matplotlib import pyplot as plt
# %matplotlib inline

# %% [markdown]
# # load mosaic data

# %%
transform = transforms.Compose(
    [transforms.ToTensor(),
     transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))])

trainset = torchvision.datasets.CIFAR10(root='./data', train=True, download=True, transform=transform)


testset = torchvision.datasets.CIFAR10(root='./data', train=False, download=True, transform=transform)
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to ./data/cifar-10-python.tar.gz
# HBox(children=(FloatProgress(value=0.0, max=170498071.0), HTML(value='')))
# Extracting ./data/cifar-10-python.tar.gz to ./data
# Files already downloaded and verified

# %%
trainloader = torch.utils.data.DataLoader(trainset, batch_size=10, shuffle=True)
testloader = torch.utils.data.DataLoader(testset, batch_size=10, shuffle=False)


classes = ('plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck')

foreground_classes = {'plane', 'car', 'bird'}
#foreground_classes = {'bird', 'cat', 'deer'}
background_classes = {'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck'}
#background_classes = {'plane', 'car', 'dog', 'frog', 'horse','ship', 'truck'}

fg1,fg2,fg3 = 0,1,2

# %%
dataiter = iter(trainloader)
background_data=[]
background_label=[]
foreground_data=[]
foreground_label=[]
batch_size=10

for i in range(5000):
  images, labels = dataiter.next()
  for j in range(batch_size):
    if(classes[labels[j]] in background_classes):
      img = images[j].tolist()
      background_data.append(img)
      background_label.append(labels[j])
    else:
      img = images[j].tolist()
      foreground_data.append(img)
      foreground_label.append(labels[j])
            
foreground_data = torch.tensor(foreground_data)
foreground_label = torch.tensor(foreground_label)
background_data = torch.tensor(background_data)
background_label = torch.tensor(background_label)

# %%
def create_mosaic_img(bg_idx,fg_idx,fg): 
  """
  bg_idx : list of indexes of background_data[] to be used as background images in mosaic
  fg_idx : index of image to be used as foreground image from foreground data
  fg : at what position/index foreground image has to be stored out of 0-8
  """
  image_list=[]
  j=0
  for i in range(9):
    if i != fg:
      image_list.append(background_data[bg_idx[j]])#.type("torch.DoubleTensor"))
      j+=1
    else: 
      image_list.append(foreground_data[fg_idx])#.type("torch.DoubleTensor"))
      label = foreground_label[fg_idx]-fg1  # minus 7 because our fore ground classes are 7,8,9 but we have to store it as 0,1,2
  #image_list = np.concatenate(image_list ,axis=0)
  image_list = torch.stack(image_list) 
  return image_list,label

# %%
desired_num = 30000
mosaic_list_of_images =[]      # list of mosaic images, each mosaic image is saved as list of 9 images
fore_idx =[]                   # list of indexes at which foreground image is present in a mosaic image i.e from 0 to 9               
mosaic_label=[]                # label of mosaic image = foreground class present in that mosaic
for i in range(desired_num):
  np.random.seed(i)
  bg_idx = np.random.randint(0,35000,8)
  fg_idx = np.random.randint(0,15000)
  fg = np.random.randint(0,9)
  fore_idx.append(fg)
  image_list,label = create_mosaic_img(bg_idx,fg_idx,fg)
  mosaic_list_of_images.append(image_list)
  mosaic_label.append(label)

# %%
class MosaicDataset(Dataset):
  """MosaicDataset dataset."""

  def __init__(self, mosaic_list_of_images, mosaic_label, fore_idx):
    """
      Args:
        csv_file (string): Path to the csv file with annotations.
        root_dir (string): Directory with all the images.
        transform (callable, optional): Optional transform to be applied
            on a sample.
    """
    self.mosaic = mosaic_list_of_images
    self.label = mosaic_label
    self.fore_idx = fore_idx

  def __len__(self):
    return len(self.label)

  def __getitem__(self, idx):
    return self.mosaic[idx] , self.label[idx], self.fore_idx[idx]

batch = 250
msd = MosaicDataset(mosaic_list_of_images, mosaic_label , fore_idx)
train_loader = DataLoader( msd,batch_size= batch ,shuffle=True)

# %%
test_images =[]        #list of mosaic images, each mosaic image is saved as laist of 9 images
fore_idx_test =[]                   #list of indexes at which foreground image is present in a mosaic image                
test_label=[]                # label of mosaic image = foreground class present in that mosaic
for i in range(10000):
  np.random.seed(i+30000)
  bg_idx = np.random.randint(0,35000,8)
  fg_idx = np.random.randint(0,15000)
  fg = np.random.randint(0,9)
  fore_idx_test.append(fg)
  image_list,label = create_mosaic_img(bg_idx,fg_idx,fg)
  test_images.append(image_list)
  test_label.append(label)

# %%
test_data = MosaicDataset(test_images,test_label,fore_idx_test)
test_loader = DataLoader( test_data,batch_size= batch ,shuffle=False)

# %% [markdown]
# # models

# %%
class Module1(nn.Module):
  def __init__(self):
    super(Module1, self).__init__()
    self.conv1 = nn.Conv2d(3, 6, 5)
    self.pool = nn.MaxPool2d(2, 2)
    self.conv2 = nn.Conv2d(6, 16, 5)
    self.fc1 = nn.Linear(16 * 5 * 5, 120)
    self.fc2 = nn.Linear(120, 84)
    self.fc3 = nn.Linear(84, 10)
    self.fc4 = nn.Linear(10,1)

  def forward(self, z):
    x = torch.zeros([batch,9],dtype=torch.float64)
    y = torch.zeros([batch,3, 32,32], dtype=torch.float64)
    x,y = x.to("cuda"),y.to("cuda")
    for i in range(9):
      x[:,i] = self.helper(z[:,i])[:,0]
    x = F.softmax(x,dim=1)   # alphas
    
    x1 = x[:,0]
    torch.mul(x1[:,None,None,None],z[:,0])

    for i in range(9):            
      x1 = x[:,i]          
      y = y + torch.mul(x1[:,None,None,None],z[:,i])
    return y , x 
  
  def helper(self,x):
    x = self.pool(F.relu(self.conv1(x)))
    x = self.pool(F.relu(self.conv2(x)))
    x = x.view(-1, 16 * 5 * 5)
    x = F.relu(self.fc1(x))
    x = F.relu(self.fc2(x))
    x = F.relu(self.fc3(x))
    x = self.fc4(x)
    return x

# %%
 class Module2(nn.Module):
  def __init__(self):
    super(Module2, self).__init__()
    
    self.conv1 = nn.Conv2d(3, 6, 5)
    self.pool = nn.MaxPool2d(2, 2)
    self.conv2 = nn.Conv2d(6, 16, 5)
    self.fc1 = nn.Linear(16 * 5 * 5, 120)
    self.fc2 = nn.Linear(120, 84)
    self.fc3 = nn.Linear(84, 10)
    self.fc4 = nn.Linear(10,3)

  def forward(self,y):  #z batch of list of 9 images
    y1 = self.pool(F.relu(self.conv1(y)))
    y1 = self.pool(F.relu(self.conv2(y1)))
    y1 = y1.view(-1, 16 * 5 * 5)

    y1 = F.relu(self.fc1(y1))
    y1 = F.relu(self.fc2(y1))
    y1 = F.relu(self.fc3(y1))
    y1 = self.fc4(y1)
    return y1

# %%
torch.manual_seed(1234)
where_net = Module1().double()
where_net = where_net.to("cuda")
# print(net.parameters)
torch.manual_seed(1234)
what_net = Module2().double()
what_net = what_net.to("cuda")

# %%
def calculate_attn_loss(dataloader,what,where,criter):
  what.eval()
  where.eval()
  r_loss = 0
  alphas = []
  lbls = []
  pred = []
  fidices = []
  correct = 0
  tot = 0
  with torch.no_grad():
    for i, data in enumerate(dataloader, 0):
      inputs, labels,fidx = data
      lbls.append(labels)
      fidices.append(fidx)
      inputs = inputs.double()
      inputs, labels = inputs.to("cuda"),labels.to("cuda")
      avg,alpha = where(inputs)
      outputs = what(avg)
      _, predicted = torch.max(outputs.data, 1)
      correct += sum(predicted == labels)
      tot += len(predicted)
      pred.append(predicted.cpu().numpy())
      alphas.append(alpha.cpu().numpy())
      loss = criter(outputs, labels)
      r_loss += loss.item()
  alphas = np.concatenate(alphas,axis=0)
  pred = np.concatenate(pred,axis=0)
  lbls = np.concatenate(lbls,axis=0)
  fidices = np.concatenate(fidices,axis=0)
  #print(alphas.shape,pred.shape,lbls.shape,fidices.shape) 
  analysis = analyse_data(alphas,lbls,pred,fidices)
  return r_loss/i,analysis,correct.item(),tot,correct.item()/tot

# %%
def analyse_data(alphas,lbls,predicted,f_idx):
    '''
       analysis data is created here
    '''
    batch = len(predicted)
    amth,alth,ftpt,ffpt,ftpf,ffpf = 0,0,0,0,0,0
    for j in range (batch):
      focus = np.argmax(alphas[j])
      if(alphas[j][focus] >= 0.5):
        amth +=1
      else:
        alth +=1
      if(focus == f_idx[j] and predicted[j] == lbls[j]):
        ftpt += 1
      elif(focus != f_idx[j] and predicted[j] == lbls[j]):
        ffpt +=1
      elif(focus == f_idx[j] and predicted[j] != lbls[j]):
        ftpf +=1
      elif(focus != f_idx[j] and predicted[j] != lbls[j]):
        ffpf +=1
    #print(sum(predicted==lbls),ftpt+ffpt)
    return [ftpt,ffpt,ftpf,ffpf,amth,alth]

# %% [markdown]
# # training

# %%
# instantiate optimizer
optimizer_where = optim.Adam(where_net.parameters(),lr =0.001)#,momentum=0.9)
optimizer_what = optim.Adam(what_net.parameters(), lr=0.001)#,momentum=0.9)
criterion = nn.CrossEntropyLoss()
acti = []
analysis_data_tr = []
analysis_data_tst = []
loss_curi_tr = []
loss_curi_tst = []
epochs = 200

#every_what_epoch = 20

# calculate zeroth epoch loss and FTPT values
running_loss,anlys_data,correct,total,accuracy = calculate_attn_loss(train_loader,what_net,where_net,criterion)
print('training epoch: [%d ] loss: %.3f correct: %.3f, total: %.3f, accuracy: %.3f' %(0,running_loss,correct,total,accuracy)) 
loss_curi_tr.append(running_loss)
analysis_data_tr.append(anlys_data)

running_loss,anlys_data,correct,total,accuracy = calculate_attn_loss(test_loader,what_net,where_net,criterion)
print('test epoch: [%d ] loss: %.3f correct: %.3f, total: %.3f, accuracy: %.3f' %(0,running_loss,correct,total,accuracy)) 

loss_curi_tst.append(running_loss)
analysis_data_tst.append(anlys_data)



# training starts 
for epoch in range(epochs): # loop over the dataset multiple times
  ep_lossi = []
  running_loss = 0.0
  what_net.train()
  where_net.train()
  # if ((epoch) % (every_what_epoch*2) ) <= every_what_epoch-1 :
  #   print(epoch+1,"updating what_net, where_net is freezed")
  #   print("--"*40)
  # elif ((epoch) % (every_what_epoch*2)) > every_what_epoch-1 :
  #   print(epoch+1,"updating where_net, what_net is freezed")
  #   print("--"*40)
  for i, data in enumerate(train_loader, 0):
    # get the inputs
    inputs, labels,_ = data
    inputs = inputs.double()
    inputs, labels = inputs.to("cuda"),labels.to("cuda")
        
    # zero the parameter gradients
    optimizer_where.zero_grad()
    optimizer_what.zero_grad()
      
    # forward + backward + optimize
    avg, alpha = where_net(inputs)
    outputs = what_net(avg)
    loss = criterion(outputs, labels)

    # print statistics
    running_loss += loss.item()
    loss.backward()
    # if ((epoch) % (every_what_epoch*2) ) <= every_what_epoch-1 :
    #   optimizer_what.step()
    # elif ( (epoch) % (every_what_epoch*2)) > every_what_epoch-1 :
    #   optimizer_where.step()
    optimizer_what.step()
    optimizer_where.step()
  running_loss_tr,anls_data,correct,total,accuracy = calculate_attn_loss(train_loader,what_net,where_net,criterion)
  analysis_data_tr.append(anls_data)
  loss_curi_tr.append(running_loss_tr)   #loss per epoch
  print('training epoch: [%d ] loss: %.3f correct: %.3f, total: %.3f, accuracy: %.3f' %(epoch+1,running_loss_tr,correct,total,accuracy)) 

  running_loss_tst,anls_data,correct,total,accuracy = calculate_attn_loss(test_loader,what_net,where_net,criterion)
  analysis_data_tst.append(anls_data)
  loss_curi_tst.append(running_loss_tst)   #loss per epoch
  print('test epoch: [%d ] loss: %.3f correct: %.3f, total: %.3f, accuracy: %.3f' %(epoch+1,running_loss_tst,correct,total,accuracy)) 
  
  if running_loss_tr<=0.01:
    break
print('Finished Training run ')
analysis_data_tr = np.array(analysis_data_tr)
analysis_data_tst = np.array(analysis_data_tst)
# Out:
# training epoch: [0 ] loss: 1.121 correct: 9933.000, total: 30000.000, accuracy: 0.331
# test epoch: [0 ] loss: 1.141 correct: 3288.000, total: 10000.000, accuracy: 0.329
# training epoch: [1 ] loss: 1.059 correct: 12830.000, total: 30000.000, accuracy: 0.428
# test epoch: [1 ] loss: 1.081 correct: 4254.000, total: 10000.000, accuracy: 0.425
# training epoch: [2 ] loss: 1.017 correct: 14780.000, total: 30000.000, accuracy: 0.493
# test epoch: [2 ] loss: 1.051 correct: 4790.000, total: 10000.000, accuracy: 0.479
# training epoch: [3 ] loss: 0.962 correct: 16182.000, total: 30000.000, accuracy: 0.539
# test epoch: [3 ] loss: 0.999 correct: 5252.000, total: 10000.000, accuracy: 0.525
# training epoch: [4 ] loss: 0.913 correct: 17197.000, total: 30000.000, accuracy: 0.573
# test epoch: [4 ] loss: 0.958 correct: 5576.000, total: 10000.000, accuracy: 0.558
# training epoch: [5 ] loss: 0.886 correct: 17593.000, total: 30000.000, accuracy: 0.586
# test epoch: [5 ] loss: 0.926 correct: 5699.000, total: 10000.000, accuracy: 0.570
# training epoch: [6 ] loss: 0.798 correct: 19259.000, total: 30000.000, accuracy: 0.642
# test epoch: [6 ] loss: 0.852 correct: 6182.000, total: 10000.000, accuracy: 0.618
# training epoch: [7 ] loss: 0.738 correct: 20212.000, total: 30000.000, accuracy: 0.674
# test epoch: [7 ] loss: 0.808 correct: 6456.000, total: 10000.000, accuracy: 0.646
# training epoch: [8 ] loss: 0.713 correct: 20577.000, total: 30000.000, accuracy: 0.686
# test epoch: [8 ] loss: 0.786 correct: 6541.000, total: 10000.000, accuracy: 0.654
# training epoch: [9 ] loss: 0.657 correct: 21462.000, total: 30000.000, accuracy: 0.715
# test epoch: [9 ] loss: 0.745 correct: 6778.000, total: 10000.000, accuracy: 0.678
# training epoch: [10 ] loss: 0.608 correct: 22250.000, total: 30000.000, accuracy: 0.742
# test epoch: [10 ] loss: 0.714 correct: 6950.000, total: 10000.000, accuracy: 0.695
# training epoch: [11 ] loss: 0.553 correct: 23091.000, total: 30000.000, accuracy: 0.770
# test epoch: [11 ] loss: 0.678 correct: 7148.000, total: 10000.000, accuracy: 0.715
# training epoch: [12 ] loss: 0.530 correct: 23428.000, total: 30000.000, accuracy: 0.781
# test epoch: [12 ] loss: 0.658 correct: 7226.000, total: 10000.000, accuracy: 0.723
# training epoch: [13 ] loss: 0.500 correct: 23964.000, total: 30000.000, accuracy: 0.799
# test epoch: [13 ] loss: 0.628 correct: 7385.000, total: 10000.000, accuracy: 0.739
# training epoch: [14 ] loss: 0.451 correct: 24580.000, total: 30000.000, accuracy: 0.819
# test epoch: [14 ] loss: 0.617 correct: 7489.000, total: 10000.000, accuracy: 0.749
# training epoch: [15 ] loss: 0.435 correct: 24780.000, total: 30000.000, accuracy: 0.826
# test epoch: [15 ] loss: 0.622 correct: 7477.000, total: 10000.000, accuracy: 0.748
# training epoch: [16 ] loss: 0.405 correct: 25276.000, total: 30000.000, accuracy: 0.843
# test epoch: [16 ] loss: 0.587 correct: 7706.000, total: 10000.000, accuracy: 0.771
# training epoch: [17 ] loss: 0.387 correct: 25448.000, total: 30000.000, accuracy: 0.848
# test epoch: [17 ] loss: 0.603 correct: 7645.000, total: 10000.000, accuracy: 0.764
# training epoch: [18 ] loss: 0.356 correct: 25879.000, total: 30000.000, accuracy: 0.863
# test epoch: [18 ] loss: 0.573 correct: 7783.000, total: 10000.000, accuracy: 0.778
# training epoch: [19 ] loss: 0.351 correct: 25938.000, total: 30000.000, accuracy: 0.865
# test epoch: [19 ] loss: 0.558 correct: 7848.000, total: 10000.000, accuracy: 0.785
# training epoch: [20 ] loss: 0.334 correct: 26201.000, total: 30000.000, accuracy: 0.873
# test epoch: [20 ] loss: 0.570 correct: 7846.000, total: 10000.000, accuracy: 0.785
# training epoch: [21 ] loss: 0.318 correct: 26319.000, total: 30000.000, accuracy: 0.877
# test epoch: [21 ] loss: 0.573 correct: 7873.000, total: 10000.000, accuracy: 0.787
# training epoch: [22 ] loss: 0.301 correct: 26567.000, total: 30000.000, accuracy: 0.886
# test epoch: [22 ] loss: 0.558 correct: 7946.000, total: 10000.000, accuracy: 0.795
# training epoch: [23 ] loss: 0.289 correct: 26761.000, total: 30000.000, accuracy: 0.892
# test epoch: [23 ] loss: 0.535 correct: 8032.000, total: 10000.000, accuracy: 0.803
# training epoch: [24 ] loss: 0.285 correct: 26803.000, total: 30000.000, accuracy: 0.893
# test epoch: [24 ] loss: 0.546 correct: 8028.000, total: 10000.000, accuracy: 0.803
# training epoch: [25 ] loss: 0.269 correct: 27043.000, total: 30000.000, accuracy: 0.901
# test epoch: [25 ] loss: 0.543 correct: 8027.000, total: 10000.000, accuracy: 0.803
# training epoch: [26 ] loss: 0.255 correct: 27134.000, total: 30000.000, accuracy: 0.904
# test epoch: [26 ] loss: 0.552 correct: 7997.000, total: 10000.000, accuracy: 0.800
# training epoch: [27 ] loss: 0.240 correct: 27355.000, total: 30000.000, accuracy: 0.912
# test epoch: [27 ] loss: 0.553 correct: 8108.000, total: 10000.000, accuracy: 0.811
# training epoch: [28 ] loss: 0.255 correct: 27191.000, total: 30000.000, accuracy: 0.906
# test epoch: [28 ] loss: 0.548 correct: 8049.000, total: 10000.000, accuracy: 0.805
# training epoch: [29 ] loss: 0.247 correct: 27243.000, total: 30000.000, accuracy: 0.908
# test epoch: [29 ] loss: 0.593 correct: 7967.000, total: 10000.000, accuracy: 0.797
# training epoch: [30 ] loss: 0.228 correct: 27479.000, total: 30000.000, accuracy: 0.916
# test epoch: [30 ] loss: 0.553 correct: 8113.000, total: 10000.000, accuracy: 0.811
# training epoch: [31 ] loss: 0.260 correct: 27107.000, total: 30000.000, accuracy: 0.904
# test epoch: [31 ] loss: 0.570 correct: 8060.000, total: 10000.000, accuracy: 0.806
# training epoch: [32 ] loss: 0.214 correct: 27623.000, total: 30000.000, accuracy: 0.921
# test epoch: [32 ] loss: 0.578 correct: 8077.000, total: 10000.000, accuracy: 0.808
# training epoch: [33 ] loss: 0.205 correct: 27745.000, total: 30000.000, accuracy: 0.925
# test epoch: [33 ] loss: 0.571 correct: 8131.000, total: 10000.000, accuracy: 0.813
# training epoch: [34 ] loss: 0.198 correct: 27835.000, total: 30000.000, accuracy: 0.928
# test epoch: [34 ] loss: 0.556 correct: 8150.000, total: 10000.000, accuracy: 0.815
# training epoch: [35 ] loss: 0.196 correct: 27829.000, total: 30000.000, accuracy: 0.928
# test epoch: [35 ] loss: 0.571 correct: 8180.000, total: 10000.000, accuracy: 0.818
# training epoch: [36 ] loss: 0.195 correct: 27900.000, total: 30000.000, accuracy: 0.930
# test epoch: [36 ] loss: 0.620 correct: 8144.000, total: 10000.000, accuracy: 0.814
# training epoch: [37 ] loss: 0.182 correct: 28037.000, total: 30000.000, accuracy: 0.935
# test epoch: [37 ] loss: 0.552 correct: 8237.000, total: 10000.000, accuracy: 0.824
# training epoch: [38 ] loss: 0.196 correct: 27832.000, total: 30000.000, accuracy: 0.928
# test epoch: [38 ] loss: 0.576 correct: 8072.000, total: 10000.000, accuracy: 0.807
# training epoch: [39 ] loss: 0.166 correct: 28217.000, total: 30000.000, accuracy: 0.941
# test epoch: [39 ] loss: 0.569 correct: 8201.000, total: 10000.000, accuracy: 0.820
# training epoch: [40 ] loss: 0.190 correct: 27954.000, total: 30000.000, accuracy: 0.932
# test epoch: [40 ] loss: 0.625 correct: 8067.000, total: 10000.000, accuracy: 0.807
# training epoch: [41 ] loss: 0.166 correct: 28240.000, total: 30000.000, accuracy: 0.941
# test epoch: [41 ] loss: 0.579 correct: 8201.000, total: 10000.000, accuracy: 0.820
# training epoch: [42 ] loss: 0.158 correct: 28309.000, total: 30000.000, accuracy: 0.944
# test epoch: [42 ] loss: 0.612 correct: 8158.000, total: 10000.000, accuracy: 0.816
# training epoch: [43 ] loss: 0.157 correct: 28302.000, total: 30000.000, accuracy: 0.943
# test epoch: [43 ] loss: 0.625 correct: 8182.000, total: 10000.000, accuracy: 0.818
# training epoch: [44 ] loss: 0.169 correct: 28181.000, total: 30000.000, accuracy: 0.939
# test epoch: [44 ] loss: 0.611 correct: 8142.000, total: 10000.000, accuracy: 0.814
# training epoch: [45 ] loss: 0.142 correct: 28467.000, total: 30000.000, accuracy: 0.949
# test epoch: [45 ] loss: 0.636 correct: 8259.000, total: 10000.000, accuracy: 0.826
# training epoch: [46 ] loss: 0.136 correct: 28578.000, total: 30000.000, accuracy: 0.953
# test epoch: [46 ] loss: 0.657 correct: 8168.000, total: 10000.000, accuracy: 0.817
# training epoch: [47 ] loss: 0.141 correct: 28490.000, total: 30000.000, accuracy: 0.950
# test epoch: [47 ] loss: 0.641 correct: 8202.000, total: 10000.000, accuracy: 0.820
# training epoch: [48 ] loss: 0.135 correct: 28542.000, total: 30000.000, accuracy: 0.951
# test epoch: [48 ] loss: 0.666 correct: 8237.000, total: 10000.000, accuracy: 0.824
# training epoch: [49 ] loss: 0.108 correct: 28886.000, total: 30000.000, accuracy: 0.963
# test epoch: [49 ] loss: 0.643 correct: 8223.000, total: 10000.000, accuracy: 0.822
# training epoch: [50 ] loss: 0.109 correct: 28863.000, total: 30000.000, accuracy: 0.962
# test epoch: [50 ] loss: 0.666 correct: 8203.000, total: 10000.000, accuracy: 0.820
# training epoch: [51 ] loss: 0.138 correct: 28528.000, total: 30000.000, accuracy: 0.951
# test epoch: [51 ] loss: 0.701 correct: 8075.000, total: 10000.000, accuracy: 0.807
# training epoch: [52 ] loss: 0.133 correct: 28564.000, total: 30000.000, accuracy: 0.952
# test epoch: [52 ] loss: 0.659 correct: 8241.000, total: 10000.000, accuracy: 0.824
# training epoch: [53 ] loss: 0.123 correct: 28724.000, total: 30000.000, accuracy: 0.957
# test epoch: [53 ] loss: 0.655 correct: 8185.000, total: 10000.000, accuracy: 0.819
# training epoch: [54 ] loss: 0.107 correct: 28921.000, total: 30000.000, accuracy: 0.964
# test epoch: [54 ] loss: 0.692 correct: 8144.000, total: 10000.000, accuracy: 0.814
# training epoch: [55 ] loss: 0.099 correct: 28957.000, total: 30000.000, accuracy: 0.965
# test epoch: [55 ] loss: 0.698 correct: 8226.000, total: 10000.000, accuracy: 0.823
# training epoch: [56 ] loss: 0.113 correct: 28792.000, total: 30000.000, accuracy: 0.960
# test epoch: [56 ] loss: 0.692 correct: 8129.000, total: 10000.000, accuracy: 0.813
# training epoch: [57 ] loss: 0.109 correct: 28867.000, total: 30000.000, accuracy: 0.962
# test epoch: [57 ] loss: 0.705 correct: 8183.000, total: 10000.000, accuracy: 0.818
# training epoch: [58 ] loss: 0.113 correct: 28779.000, total: 30000.000, accuracy: 0.959
# test epoch: [58 ] loss: 0.731 correct: 8219.000, total: 10000.000, accuracy: 0.822
# training epoch: [59 ] loss: 0.095 correct: 29003.000, total: 30000.000, accuracy: 0.967
# test epoch: [59 ] loss: 0.738 correct: 8187.000, total: 10000.000, accuracy: 0.819
# training epoch: [60 ] loss: 0.104 correct: 28952.000, total: 30000.000, accuracy: 0.965
# test epoch: [60 ] loss: 0.760 correct: 8219.000, total: 10000.000, accuracy: 0.822
# training epoch: [61 ] loss: 0.075 correct: 29248.000, total: 30000.000, accuracy: 0.975
# test epoch: [61 ] loss: 0.760 correct: 8247.000, total: 10000.000, accuracy: 0.825
# training epoch: [62 ] loss: 0.099 correct: 28980.000, total: 30000.000, accuracy: 0.966
# test epoch: [62 ] loss: 0.706 correct: 8144.000, total: 10000.000, accuracy: 0.814
# training epoch: [63 ] loss: 0.104 correct: 28936.000, total: 30000.000, accuracy: 0.965
# test epoch: [63 ] loss: 0.837 correct: 8094.000, total: 10000.000, accuracy: 0.809
# training epoch: [64 ] loss: 0.083 correct: 29164.000, total: 30000.000, accuracy: 0.972
# test epoch: [64 ] loss: 0.751 correct: 8191.000, total: 10000.000, accuracy: 0.819
# training epoch: [65 ] loss: 0.071 correct: 29283.000, total: 30000.000, accuracy: 0.976
# test epoch: [65 ] loss: 0.765 correct: 8215.000, total: 10000.000, accuracy: 0.822
# training epoch: [66 ] loss: 0.066 correct: 29335.000, total: 30000.000, accuracy: 0.978
# test epoch: [66 ] loss: 0.813 correct: 8258.000, total: 10000.000, accuracy: 0.826
# training epoch: [67 ] loss: 0.062 correct: 29404.000, total: 30000.000, accuracy: 0.980
# test epoch: [67 ] loss: 0.833 correct: 8214.000, total: 10000.000, accuracy: 0.821
# training epoch: [68 ] loss: 0.073 correct: 29244.000, total: 30000.000, accuracy: 0.975
# test epoch: [68 ] loss: 0.860 correct: 8129.000, total: 10000.000, accuracy: 0.813
# training epoch: [69 ] loss: 0.070 correct: 29279.000, total: 30000.000, accuracy: 0.976
# test epoch: [69 ] loss: 0.864 correct: 8151.000, total: 10000.000, accuracy: 0.815
# training epoch: [70 ] loss: 0.059 correct: 29382.000, total: 30000.000, accuracy: 0.979
# test epoch: [70 ] loss: 0.858 correct: 8269.000, total: 10000.000, accuracy: 0.827
# training epoch: [71 ] loss: 0.054 correct: 29452.000, total: 30000.000, accuracy: 0.982
# test epoch: [71 ] loss: 0.901 correct: 8252.000, total: 10000.000, accuracy: 0.825
# training epoch: [72 ] loss: 0.095 correct: 29068.000, total: 30000.000, accuracy: 0.969
# test epoch: [72 ] loss: 0.915 correct: 8107.000, total: 10000.000, accuracy: 0.811
# training epoch: [73 ] loss: 0.065 correct: 29366.000, total: 30000.000, accuracy: 0.979
# test epoch: [73 ] loss: 0.853 correct: 8181.000, total: 10000.000, accuracy: 0.818
# training epoch: [74 ] loss: 0.057 correct: 29443.000, total: 30000.000, accuracy: 0.981
# test epoch: [74 ] loss: 0.858 correct: 8210.000, total: 10000.000, accuracy: 0.821
# training epoch: [75 ] loss: 0.078 correct: 29228.000, total: 30000.000, accuracy: 0.974
# test epoch: [75 ] loss: 0.908 correct: 8183.000, total: 10000.000, accuracy: 0.818
# training epoch: [76 ] loss: 0.048 correct: 29498.000, total: 30000.000, accuracy: 0.983
# test epoch: [76 ] loss: 0.918 correct: 8299.000, total: 10000.000, accuracy: 0.830
# training epoch: [77 ] loss: 0.114 correct: 28880.000, total: 30000.000, accuracy: 0.963
# test epoch: [77 ] loss: 0.859 correct: 8070.000, total: 10000.000, accuracy: 0.807
# training epoch: [78 ] loss: 0.067 correct: 29363.000, total: 30000.000, accuracy: 0.979
# test epoch: [78 ] loss: 0.868 correct: 8138.000, total: 10000.000, accuracy: 0.814
# training epoch: [79 ] loss: 0.056 correct: 29412.000, total: 30000.000, accuracy: 0.980
# test epoch: [79 ] loss: 0.960 correct: 8194.000, total: 10000.000, accuracy: 0.819
# training epoch: [80 ] loss: 0.035 correct: 29683.000, total: 30000.000, accuracy: 0.989
# test epoch: [80 ] loss: 0.928 correct: 8207.000, total: 10000.000, accuracy: 0.821
# training epoch: [81 ] loss: 0.039 correct: 29652.000, total: 30000.000, accuracy: 0.988
# test epoch: [81 ] loss: 0.936 correct: 8234.000, total: 10000.000, accuracy: 0.823
# training epoch: [82 ] loss: 0.046 correct: 29571.000, total: 30000.000, accuracy: 0.986
# test epoch: [82 ] loss: 0.952 correct: 8139.000, total: 10000.000, accuracy: 0.814
# training epoch: [83 ] loss: 0.094 correct: 29086.000, total: 30000.000, accuracy: 0.970
# test epoch: [83 ] loss: 0.926 correct: 8108.000, total: 10000.000, accuracy: 0.811
# training epoch: [84 ] loss: 0.044 correct: 29587.000, total: 30000.000, accuracy: 0.986
# test epoch: [84 ] loss: 0.950 correct: 8229.000, total: 10000.000, accuracy: 0.823
# training epoch: [85 ] loss: 0.101 correct: 29079.000, total: 30000.000, accuracy: 0.969
# test epoch: [85 ] loss: 1.039 correct: 8129.000, total: 10000.000, accuracy: 0.813
# training epoch: [86 ] loss: 0.052 correct: 29513.000, total: 30000.000, accuracy: 0.984
# test epoch: [86 ] loss: 0.943 correct: 8172.000, total: 10000.000, accuracy: 0.817
# training epoch: [87 ] loss: 0.047 correct: 29546.000, total: 30000.000, accuracy: 0.985
# test epoch: [87 ] loss: 0.973 correct: 8224.000, total: 10000.000, accuracy: 0.822
# training epoch: [88 ] loss: 0.050 correct: 29536.000, total: 30000.000, accuracy: 0.985
# test epoch: [88 ] loss: 0.917 correct: 8165.000, total: 10000.000, accuracy: 0.817
# training epoch: [89 ] loss: 0.030 correct: 29718.000, total: 30000.000, accuracy: 0.991
# test epoch: [89 ] loss: 0.938 correct: 8281.000, total: 10000.000, accuracy: 0.828
# training epoch: [90 ] loss: 0.023 correct: 29790.000, total: 30000.000, accuracy: 0.993
# test epoch: [90 ] loss: 1.052 correct: 8237.000, total: 10000.000, accuracy: 0.824
# training epoch: [91 ] loss: 0.032 correct: 29691.000, total: 30000.000, accuracy: 0.990
# test epoch: [91 ] loss: 1.050 correct: 8216.000, total: 10000.000, accuracy: 0.822
# training epoch: [92 ] loss: 0.039 correct: 29604.000, total: 30000.000, accuracy: 0.987
# test epoch: [92 ] loss: 0.993 correct: 8154.000, total: 10000.000, accuracy: 0.815
# training epoch: [93 ] loss: 0.042 correct: 29623.000, total: 30000.000, accuracy: 0.987
# test epoch: [93 ] loss: 0.953 correct: 8172.000, total: 10000.000, accuracy: 0.817
# training epoch: [94 ] loss: 0.060 correct: 29427.000, total: 30000.000, accuracy: 0.981
# test epoch: [94 ] loss: 0.861 correct: 8084.000, total: 10000.000, accuracy: 0.808
# training epoch: [95 ] loss: 0.035 correct: 29660.000, total: 30000.000, accuracy: 0.989
# test epoch: [95 ] loss: 1.011 correct: 8176.000, total: 10000.000, accuracy: 0.818
# training epoch: [96 ] loss: 0.027 correct: 29748.000, total: 30000.000, accuracy: 0.992
# test epoch: [96 ] loss: 1.013 correct: 8265.000, total: 10000.000, accuracy: 0.827
# training epoch: [97 ] loss: 0.030 correct: 29694.000, total: 30000.000, accuracy: 0.990
# test epoch: [97 ] loss: 1.069 correct: 8293.000, total: 10000.000, accuracy: 0.829
# training epoch: [98 ] loss: 0.037 correct: 29649.000, total: 30000.000, accuracy: 0.988
# test epoch: [98 ] loss: 1.171 correct: 8261.000, total: 10000.000, accuracy: 0.826
# training epoch: [99 ] loss: 0.106 correct: 28965.000, total: 30000.000, accuracy: 0.966
# test epoch: [99 ] loss: 0.918 correct: 8001.000, total: 10000.000, accuracy: 0.800
# training epoch: [100 ] loss: 0.042 correct: 29595.000, total: 30000.000, accuracy: 0.987
# test epoch: [100 ] loss: 0.960 correct: 8142.000, total: 10000.000, accuracy: 0.814
# training epoch: [101 ] loss: 0.041 correct: 29577.000, total: 30000.000, accuracy: 0.986
# test epoch: [101 ] loss: 1.087 correct: 8144.000, total: 10000.000, accuracy: 0.814
# training epoch: [102 ] loss: 0.049 correct: 29533.000, total: 30000.000, accuracy: 0.984
# test epoch: [102 ] loss: 1.058 correct: 8165.000, total: 10000.000, accuracy: 0.817
# training epoch: [103 ] loss: 0.034 correct: 29673.000, total: 30000.000, accuracy: 0.989
# test epoch: [103 ] loss: 0.949 correct: 8256.000, total: 10000.000, accuracy: 0.826
# training epoch: [104 ] loss: 0.074 correct: 29271.000, total: 30000.000, accuracy: 0.976
# test epoch: [104 ] loss: 1.064 correct: 8146.000, total: 10000.000, accuracy: 0.815
# training epoch: [105 ] loss: 0.024 correct: 29784.000, total: 30000.000, accuracy: 0.993
# test epoch: [105 ] loss: 1.010 correct: 8178.000, total: 10000.000, accuracy: 0.818
# training epoch: [106 ] loss: 0.022 correct: 29794.000, total: 30000.000, accuracy: 0.993
# test epoch: [106 ] loss: 1.060 correct: 8222.000, total: 10000.000, accuracy: 0.822
# training epoch: [107 ] loss: 0.037 correct: 29639.000, total: 30000.000, accuracy: 0.988
# test epoch: [107 ] loss: 1.094 correct: 8242.000, total: 10000.000, accuracy: 0.824
# training epoch: [108 ] loss: 0.043 correct: 29572.000, total: 30000.000, accuracy: 0.986
# test epoch: [108 ] loss: 1.071 correct: 8224.000, total: 10000.000, accuracy: 0.822
# training epoch: [109 ] loss: 0.020 correct: 29825.000, total: 30000.000, accuracy: 0.994
# test epoch: [109 ] loss: 0.979 correct: 8231.000, total: 10000.000, accuracy: 0.823
# training epoch: [110 ] loss: 0.039 correct: 29610.000, total: 30000.000, accuracy: 0.987
# test epoch: [110 ] loss: 1.030 correct: 8227.000, total: 10000.000, accuracy: 0.823
# training epoch: [111 ] loss: 0.039 correct: 29645.000, total: 30000.000, accuracy: 0.988
# test epoch: [111 ] loss: 1.083 correct: 8149.000, total: 10000.000, accuracy: 0.815
# training epoch: [112 ] loss: 0.032 correct: 29675.000, total: 30000.000, accuracy: 0.989
# test epoch: [112 ] loss: 1.048 correct: 8189.000, total: 10000.000, accuracy: 0.819
# training epoch: [113 ] loss: 0.030 correct: 29729.000, total: 30000.000, accuracy: 0.991
# test epoch: [113 ] loss: 1.091 correct: 8184.000, total: 10000.000, accuracy: 0.818
# training epoch: [114 ] loss: 0.028 correct: 29736.000, total: 30000.000, accuracy: 0.991
# test epoch: [114 ] loss: 1.119 correct: 8121.000, total: 10000.000, accuracy: 0.812
# training epoch: [115 ] loss: 0.044 correct: 29584.000, total: 30000.000, accuracy: 0.986
# test epoch: [115 ] loss: 0.983 correct: 8199.000, total: 10000.000, accuracy: 0.820
# training epoch: [116 ] loss: 0.032 correct: 29708.000, total: 30000.000, accuracy: 0.990
# test epoch: [116 ] loss: 0.986 correct: 8210.000, total: 10000.000, accuracy: 0.821
# training epoch: [117 ] loss: 0.030 correct: 29706.000, total: 30000.000, accuracy: 0.990
# test epoch: [117 ] loss: 1.049 correct: 8216.000, total: 10000.000, accuracy: 0.822
# training epoch: [118 ] loss: 0.018 correct: 29853.000, total: 30000.000, accuracy: 0.995
# test epoch: [118 ] loss: 1.017 correct: 8224.000, total: 10000.000, accuracy: 0.822
# training epoch: [119 ] loss: 0.044 correct: 29592.000, total: 30000.000, accuracy: 0.986
# test epoch: [119 ] loss: 1.076 correct: 8169.000, total: 10000.000, accuracy: 0.817
# training epoch: [120 ] loss: 0.023 correct: 29794.000, total: 30000.000, accuracy: 0.993
# test epoch: [120 ] loss: 1.081 correct: 8208.000, total: 10000.000, accuracy: 0.821
# training epoch: [121 ] loss: 0.032 correct: 29697.000, total: 30000.000, accuracy: 0.990
# test epoch: [121 ] loss: 1.068 correct: 8258.000, total: 10000.000, accuracy: 0.826
# training epoch: [122 ] loss: 0.026 correct: 29770.000, total: 30000.000, accuracy: 0.992
# test epoch: [122 ] loss: 1.036 correct: 8210.000, total: 10000.000, accuracy: 0.821
# training epoch: [123 ] loss: 0.022 correct: 29787.000, total: 30000.000, accuracy: 0.993
# test epoch: [123 ] loss: 1.016 correct: 8213.000, total: 10000.000, accuracy: 0.821
# training epoch: [124 ] loss: 0.044 correct: 29604.000, total: 30000.000, accuracy: 0.987
# test epoch: [124 ] loss: 1.074 correct: 8211.000, total: 10000.000, accuracy: 0.821
# training epoch: [125 ] loss: 0.023 correct: 29796.000, total: 30000.000, accuracy: 0.993
# test epoch: [125 ] loss: 1.011 correct: 8228.000, total: 10000.000, accuracy: 0.823
# training epoch: [126 ] loss: 0.026 correct: 29747.000, total: 30000.000, accuracy: 0.992
# test epoch: [126 ] loss: 1.053 correct: 8268.000, total: 10000.000, accuracy: 0.827
# training epoch: [127 ] loss: 0.031 correct: 29694.000, total: 30000.000, accuracy: 0.990
# test epoch: [127 ] loss: 1.018 correct: 8179.000, total: 10000.000, accuracy: 0.818
# training epoch: [128 ] loss: 0.014 correct: 29868.000, total: 30000.000, accuracy: 0.996
# test epoch: [128 ] loss: 1.066 correct: 8268.000, total: 10000.000, accuracy: 0.827
# training epoch: [129 ] loss: 0.029 correct: 29745.000, total: 30000.000, accuracy: 0.992
# test epoch: [129 ] loss: 0.950 correct: 8241.000, total: 10000.000, accuracy: 0.824
# training epoch: [130 ] loss: 0.012 correct: 29895.000, total: 30000.000, accuracy: 0.997
# test epoch: [130 ] loss: 1.073 correct: 8326.000, total: 10000.000, accuracy: 0.833
# training epoch: [131 ] loss: 0.037 correct: 29639.000, total: 30000.000, accuracy: 0.988
# test epoch: [131 ] loss: 1.069 correct: 8102.000, total: 10000.000, accuracy: 0.810
# training epoch: [132 ] loss: 0.018 correct: 29856.000, total: 30000.000, accuracy: 0.995
# test epoch: [132 ] loss: 1.016 correct: 8224.000, total: 10000.000, accuracy: 0.822
# training epoch: [133 ] loss: 0.043 correct: 29616.000, total: 30000.000, accuracy: 0.987
# test epoch: [133 ] loss: 1.084 correct: 8110.000, total: 10000.000, accuracy: 0.811
# training epoch: [134 ] loss: 0.018 correct: 29842.000, total: 30000.000, accuracy: 0.995
# test epoch: [134 ] loss: 1.025 correct: 8251.000, total: 10000.000, accuracy: 0.825
# training epoch: [135 ] loss: 0.018 correct: 29843.000, total: 30000.000, accuracy: 0.995
# test epoch: [135 ] loss: 1.142 correct: 8268.000, total: 10000.000, accuracy: 0.827
# training epoch: [136 ] loss: 0.039 correct: 29645.000, total: 30000.000, accuracy: 0.988
# test epoch: [136 ] loss: 1.161 correct: 8090.000, total: 10000.000, accuracy: 0.809
# training epoch: [137 ] loss: 0.019 correct: 29831.000, total: 30000.000, accuracy: 0.994
# test epoch: [137 ] loss: 1.078 correct: 8269.000, total: 10000.000, accuracy: 0.827
# training epoch: [138 ] loss: 0.030 correct: 29719.000, total: 30000.000, accuracy: 0.991
# test epoch: [138 ] loss: 1.116 correct: 8162.000, total: 10000.000, accuracy: 0.816
# training epoch: [139 ] loss: 0.028 correct: 29745.000, total: 30000.000, accuracy: 0.992
# test epoch: [139 ] loss: 1.037 correct: 8156.000, total: 10000.000, accuracy: 0.816
# training epoch: [140 ] loss: 0.023 correct: 29781.000, total: 30000.000, accuracy: 0.993
# test epoch: [140 ] loss: 1.037 correct: 8212.000, total: 10000.000, accuracy: 0.821
# training epoch: [141 ] loss: 0.026 correct: 29757.000, total: 30000.000, accuracy: 0.992
# test epoch: [141 ] loss: 1.077 correct: 8257.000, total: 10000.000, accuracy: 0.826
# training epoch: [142 ] loss: 0.027 correct: 29744.000, total: 30000.000, accuracy: 0.991
# test epoch: [142 ] loss: 1.080 correct: 8229.000, total: 10000.000, accuracy: 0.823
# training epoch: [143 ] loss: 0.019 correct: 29823.000, total: 30000.000, accuracy: 0.994
# test epoch: [143 ] loss: 1.080 correct: 8245.000, total: 10000.000, accuracy: 0.825
# training epoch: [144 ] loss: 0.032 correct: 29746.000, total: 30000.000, accuracy: 0.992
# test epoch: [144 ] loss: 1.200 correct: 8266.000, total: 10000.000, accuracy: 0.827
# training epoch: [145 ] loss: 0.032 correct: 29691.000, total: 30000.000, accuracy: 0.990
# test epoch: [145 ] loss: 1.045 correct: 8166.000, total: 10000.000, accuracy: 0.817
# training epoch: [146 ] loss: 0.040 correct: 29634.000, total: 30000.000, accuracy: 0.988
# test epoch: [146 ] loss: 0.994 correct: 8102.000, total: 10000.000, accuracy: 0.810
# training epoch: [147 ] loss: 0.021 correct: 29810.000, total: 30000.000, accuracy: 0.994
# test epoch: [147 ] loss: 1.054 correct: 8247.000, total: 10000.000, accuracy: 0.825
# training epoch: [148 ] loss: 0.012 correct: 29897.000, total: 30000.000, accuracy: 0.997
# test epoch: [148 ] loss: 1.058 correct: 8241.000, total: 10000.000, accuracy: 0.824
# training epoch: [149 ] loss: 0.025 correct: 29759.000, total: 30000.000, accuracy: 0.992
# test epoch: [149 ] loss: 1.067 correct: 8201.000, total: 10000.000, accuracy: 0.820
# training epoch: [150 ] loss: 0.029 correct: 29736.000, total: 30000.000, accuracy: 0.991
# test epoch: [150 ] loss: 1.086 correct: 8188.000, total: 10000.000, accuracy: 0.819
# training epoch: [151 ] loss: 0.022 correct: 29796.000, total: 30000.000, accuracy: 0.993
# test epoch: [151 ] loss: 1.047 correct: 8152.000, total: 10000.000, accuracy: 0.815
# training epoch: [152 ] loss: 0.015 correct: 29862.000, total: 30000.000, accuracy: 0.995
# test epoch: [152 ] loss: 1.096 correct: 8206.000, total: 10000.000, accuracy: 0.821
# training epoch: [153 ] loss: 0.027 correct: 29719.000, total: 30000.000, accuracy: 0.991
# test epoch: [153 ] loss: 1.117 correct: 8181.000, total: 10000.000, accuracy: 0.818
# training epoch: [154 ] loss: 0.033 correct: 29692.000, total: 30000.000, accuracy: 0.990
# test epoch: [154 ] loss: 1.094 correct: 8110.000, total: 10000.000, accuracy: 0.811
# training epoch: [155 ] loss: 0.016 correct: 29845.000, total: 30000.000, accuracy: 0.995
# test epoch: [155 ] loss: 1.006 correct: 8208.000, total: 10000.000, accuracy: 0.821
# training epoch: [156 ] loss: 0.018 correct: 29822.000, total: 30000.000, accuracy: 0.994
# test epoch: [156 ] loss: 1.172 correct: 8257.000, total: 10000.000, accuracy: 0.826
# training epoch: [157 ] loss: 0.060 correct: 29456.000, total: 30000.000, accuracy: 0.982
# test epoch: [157 ] loss: 1.055 correct: 8175.000, total: 10000.000, accuracy: 0.818
# training epoch: [158 ] loss: 0.029 correct: 29741.000, total: 30000.000, accuracy: 0.991
# test epoch: [158 ] loss: 1.062 correct: 8154.000, total: 10000.000, accuracy: 0.815
# training epoch: [159 ] loss: 0.048 correct: 29552.000, total: 30000.000, accuracy: 0.985
# test epoch: [159 ] loss: 1.045 correct: 8155.000, total: 10000.000, accuracy: 0.816
# training epoch: [160 ] loss: 0.011 correct: 29899.000, total: 30000.000, accuracy: 0.997

# %%
fig = plt.figure(figsize = (12,8) )
vline_list = np.arange(every_what_epoch, epochs + every_what_epoch, every_what_epoch )
# train_loss = np.random.randn(340)
# test_loss = np.random.randn(340)
epoch_list = np.arange(0, epochs+1)
plt.plot(epoch_list,loss_curi_tr, label='train_loss')
plt.plot(epoch_list,loss_curi_tst, label='test_loss')

plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.xlabel("epochs")
plt.ylabel("CE Loss")
plt.vlines(vline_list,min(min(loss_curi_tr),min(loss_curi_tst)), max(max(loss_curi_tst),max(loss_curi_tr)),linestyles='dotted')
plt.title("train loss vs test loss")
plt.show()
fig.savefig("train_test_loss_plot.pdf")

# %%
analysis_data_tr

# %%
columns = ["epochs", "argmax > 0.5" ,"argmax < 0.5", "focus_true_pred_true", "focus_false_pred_true", "focus_true_pred_false", "focus_false_pred_false" ]
df_train = pd.DataFrame()
df_test = pd.DataFrame()
df_train[columns[0]] = np.arange(0,epochs+1)
df_train[columns[1]] = analysis_data_tr[:,-2]
df_train[columns[2]] = analysis_data_tr[:,-1]
df_train[columns[3]] = analysis_data_tr[:,0]
df_train[columns[4]] = analysis_data_tr[:,1]
df_train[columns[5]] = analysis_data_tr[:,2]
df_train[columns[6]] = analysis_data_tr[:,3]

df_test[columns[0]] = np.arange(0,epochs+1)
df_test[columns[1]] = analysis_data_tst[:,-2]
df_test[columns[2]] = analysis_data_tst[:,-1]
df_test[columns[3]] = analysis_data_tst[:,0]
df_test[columns[4]] = analysis_data_tst[:,1]
df_test[columns[5]] = analysis_data_tst[:,2]
df_test[columns[6]] = analysis_data_tst[:,3]

# %%
df_train

# %%
df_test

# %%
plt.figure(figsize=(12,12))
plt.plot(df_train[columns[0]],df_train[columns[1]], label='argmax > 0.5')
plt.plot(df_train[columns[0]],df_train[columns[2]], label='argmax < 0.5')

plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.xlabel("epochs")
plt.ylabel("training data")
plt.title("On Training set")
plt.vlines(vline_list,min(min(df_train[columns[1]]),min(df_train[columns[2]])), max(max(df_train[columns[1]]),max(df_train[columns[2]])),linestyles='dotted')
plt.show()

plt.figure(figsize=(12,12))
plt.plot(df_train[columns[0]],df_train[columns[3]], label ="focus_true_pred_true ")
plt.plot(df_train[columns[0]],df_train[columns[4]], label ="focus_false_pred_true ")
plt.plot(df_train[columns[0]],df_train[columns[5]], label ="focus_true_pred_false ")
plt.plot(df_train[columns[0]],df_train[columns[6]], label ="focus_false_pred_false ")
plt.title("On Training set")
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.xlabel("epochs")
plt.ylabel("training data")
plt.vlines(vline_list,min(min(df_train[columns[3]]),min(df_train[columns[4]]),min(df_train[columns[5]]),min(df_train[columns[6]])), max(max(df_train[columns[3]]),max(df_train[columns[4]]),max(df_train[columns[5]]),max(df_train[columns[6]])),linestyles='dotted')
plt.show()

# %%
plt.figure(figsize=(12,12))
plt.plot(df_test[columns[0]],df_test[columns[1]], label='argmax > 0.5')
plt.plot(df_test[columns[0]],df_test[columns[2]], label='argmax < 0.5')

plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.xlabel("epochs")
plt.ylabel("training data")
plt.title("On Training set")
plt.vlines(vline_list,min(min(df_test[columns[1]]),min(df_test[columns[2]])), max(max(df_test[columns[1]]),max(df_test[columns[2]])),linestyles='dotted')
plt.show()

plt.figure(figsize=(12,12))
plt.plot(df_test[columns[0]],df_test[columns[3]], label ="focus_true_pred_true ")
plt.plot(df_test[columns[0]],df_test[columns[4]], label ="focus_false_pred_true ")
plt.plot(df_test[columns[0]],df_test[columns[5]], label ="focus_true_pred_false ")
plt.plot(df_test[columns[0]],df_test[columns[6]], label ="focus_false_pred_false ")
plt.title("On Training set")
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.xlabel("epochs")
plt.ylabel("training data")
plt.vlines(vline_list,min(min(df_test[columns[3]]),min(df_test[columns[4]]),min(df_test[columns[5]]),min(df_test[columns[6]])), max(max(df_test[columns[3]]),max(df_test[columns[4]]),max(df_test[columns[5]]),max(df_test[columns[6]])),linestyles='dotted')
plt.show()
