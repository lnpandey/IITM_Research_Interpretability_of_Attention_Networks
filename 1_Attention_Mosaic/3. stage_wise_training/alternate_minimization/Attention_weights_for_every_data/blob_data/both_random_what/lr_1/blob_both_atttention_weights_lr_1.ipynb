# %%
import numpy as np
import pandas as pd

import torch
import torchvision
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms, utils
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

from matplotlib import pyplot as plt
# %matplotlib inline
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False

# %%
train_data = np.load("train_blob_data.npy",allow_pickle=True)

test_data = np.load("test_blob_data.npy",allow_pickle=True)

# %%
mosaic_list_of_images = train_data[0]["mosaic_list"]
mosaic_label = train_data[0]["mosaic_label"]
fore_idx = train_data[0]["fore_idx"]


test_mosaic_list_of_images = test_data[0]["mosaic_list"]
test_mosaic_label = test_data[0]["mosaic_label"]
test_fore_idx = test_data[0]["fore_idx"]

# %%
class MosaicDataset1(Dataset):
  """MosaicDataset dataset."""

  def __init__(self, mosaic_list, mosaic_label,fore_idx):
    """
      Args:
        csv_file (string): Path to the csv file with annotations.
        root_dir (string): Directory with all the images.
        transform (callable, optional): Optional transform to be applied
            on a sample.
    """
    self.mosaic = mosaic_list
    self.label = mosaic_label
    self.fore_idx = fore_idx
    
  def __len__(self):
    return len(self.label)

  def __getitem__(self, idx):
    return self.mosaic[idx] , self.label[idx] , self.fore_idx[idx]

# %%
batch = 250
train_dataset = MosaicDataset1(mosaic_list_of_images, mosaic_label, fore_idx)
train_loader = DataLoader( train_dataset,batch_size= batch ,shuffle=False)
test_dataset = MosaicDataset1(test_mosaic_list_of_images, test_mosaic_label, test_fore_idx)
test_loader = DataLoader(test_dataset,batch_size= batch ,shuffle=False)

# %%
bg = []
for i in range(12):
  torch.manual_seed(i)
  betag = torch.randn(250,9)#torch.ones((250,9))/9
  bg.append( betag.requires_grad_() )

# %%
bg
# Out:
# [tensor([[-1.1258, -1.1524, -0.2506,  ..., -0.3160, -2.1152,  0.3223],
#          [-1.2633,  0.3500,  0.3081,  ..., -0.2473, -1.3527, -1.6959],
#          [ 0.5667,  0.7935,  0.5988,  ...,  0.7502, -0.5855, -0.1734],
#          ...,
#          [ 0.8374, -0.7942, -0.3622,  ...,  0.0121,  0.8032, -0.6962],
#          [-1.0645,  0.2384, -0.3385,  ...,  0.9635, -1.0340,  0.1894],
#          [ 0.8253,  1.1038, -1.2491,  ..., -0.5940, -1.7125,  0.3617]],
#         requires_grad=True),
#  tensor([[-1.5256, -0.7502, -0.6540,  ..., -0.9798, -1.6091, -0.7121],
#          [ 0.3037, -0.7773, -0.2515,  ...,  0.4676, -0.6970, -1.1608],
#          [ 0.6995,  0.1991,  0.8657,  ...,  1.1017, -0.1759, -2.2456],
#          ...,
#          [-0.4302,  0.1508,  0.6937,  ...,  0.0314,  2.6645,  0.1189],
#          [ 1.4484, -0.0213, -1.3367,  ...,  0.6279, -1.4719, -1.0291],
#          [ 0.9081, -1.2433,  1.6062,  ..., -0.1177, -0.5548, -0.0595]],
#         requires_grad=True),
#  tensor([[-1.0408,  0.9166, -1.3042,  ..., -1.0574, -0.1188, -0.9078],
#          [ 0.3452, -0.5713, -0.2351,  ..., -0.4327, -1.5071, -0.4586],
#          [-0.8480,  0.5266,  0.0299,  ...,  0.4640, -0.4986,  0.1289],
#          ...,
#          [ 1.5719,  1.0154, -2.1620,  ..., -1.0790,  1.5801, -1.6557],
#          [-1.1613,  0.3672, -0.3078,  ..., -1.2456, -0.1125,  0.6222],
#          [ 0.4521, -0.2505,  2.3728,  ..., -0.1377, -0.8815, -0.1671]],
#         requires_grad=True),
#  tensor([[-0.0766,  0.3599, -0.7820,  ...,  1.6206, -1.5967, -0.0517],
#          [-0.3060,  0.2485, -0.2226,  ...,  0.4163,  0.2615,  0.9311],
#          [-0.5145, -1.6517,  1.0460,  ...,  0.5638,  2.2566,  1.8693],
#          ...,
#          [ 2.1181,  0.1464, -0.0447,  ...,  1.3816,  0.4975,  0.2814],
#          [-0.7639, -1.4938, -1.1430,  ...,  0.6355,  0.6700,  1.5335],
#          [-0.0191, -0.3568,  0.4536,  ..., -0.9493,  2.0439, -0.3827]],
#         requires_grad=True),
#  tensor([[-0.9414,  1.2632, -0.1838,  ..., -2.6021,  0.6245, -0.8684],
#          [-0.2051,  0.3976,  0.6699,  ..., -2.1205,  1.5191, -0.6682],
#          [ 0.0031, -0.1535,  1.1396,  ..., -0.7588, -0.1853, -0.8558],
#          ...,
#          [ 1.6794, -0.5509,  0.4118,  ...,  0.9084, -0.8626, -0.6553],
#          [ 0.6058, -0.5888,  0.9448,  ...,  0.0072, -0.2579,  1.7659],
#          [-1.2965,  0.2970, -0.5833,  ...,  1.7838, -0.4794,  0.5579]],
#         requires_grad=True),
#  tensor([[ 1.8423,  0.5189, -1.7119,  ..., -0.1307, -1.4374,  0.3908],
#          [-0.0190, -1.3527, -0.7308,  ..., -0.7823,  2.7799,  1.2220],
#          [-0.3364, -0.9651, -0.1297,  ..., -0.4374,  0.7792, -0.0583],
#          ...,
#          [ 0.6700, -0.5400,  0.2353,  ..., -1.0840, -0.6141, -0.0155],
#          [ 0.4779, -0.4648, -0.1366,  ...,  0.1162,  3.0351, -0.2885],
#          [-0.6777, -0.1373, -0.7330,  ...,  0.6185, -0.3036, -1.0850]],
#         requires_grad=True),
#  tensor([[-1.2113,  0.6304, -1.4713,  ...,  0.3295,  0.3264, -0.4806],
#          [ 1.1032,  2.5485,  0.3006,  ..., -1.6279, -1.4801, -1.0631],
#          [ 0.3630,  0.3995,  0.1457,  ..., -1.3437,  0.8535,  0.8811],
#          ...,
#          [-0.5519,  0.2253,  0.4891,  ..., -0.0110, -0.6023, -0.7230],
#          [-1.1593, -0.6551,  1.6578,  ...,  0.4795, -1.3562,  0.2920],
#          [ 0.3474, -0.9874, -0.0130,  ...,  0.6061,  0.8639, -0.9552]],
#         requires_grad=True),
#  tensor([[-0.8201,  0.3956,  0.8989,  ..., -0.6411, -0.8937,  0.9265],
#          [-0.5355, -1.1597, -0.4602,  ...,  1.0902, -1.5827, -0.3246],
#          [ 1.9264, -0.3300,  0.1984,  ..., -0.2093, -0.2153, -1.8157],
#          ...,
#          [-0.6910,  0.3328,  2.2102,  ..., -0.0383,  0.4400, -0.8350],
#          [-0.2194, -0.7611, -0.0921,  ..., -0.3143, -0.4196,  1.1570],
#          [-0.8934, -1.7705,  0.3805,  ...,  0.1963, -0.7307,  1.3581]],
#         requires_grad=True),
#  tensor([[-1.1892,  1.3932,  2.1059,  ...,  2.1414,  0.1317, -0.6388],
#          [ 1.3384, -1.1908, -0.7601,  ..., -0.1051,  0.4414,  0.6590],
#          [-0.7585, -0.6001, -0.3948,  ..., -1.7526,  0.3920,  0.8295],
#          ...,
#          [-0.0557, -0.1032, -0.4624,  ..., -0.1339, -1.6662, -0.4955],
#          [ 1.0884, -0.4479, -0.0847,  ...,  1.7487, -1.6152, -1.8258],
#          [ 1.7062,  1.1041, -1.3736,  ..., -1.5244,  0.4869, -1.7420]],
#         requires_grad=True),
#  tensor([[-1.0674, -0.7172,  1.0897,  ..., -0.7737, -2.4656,  0.9968],
#          [ 0.4524, -0.3464, -0.7245,  ...,  0.2331, -1.1433,  0.8289],
#          [ 0.9534,  0.2948,  1.5159,  ...,  0.3971,  0.4058, -0.5274],
#          ...,
#          [-0.3297, -0.3700,  1.9490,  ..., -0.0443,  1.8073, -0.6388],
#          [ 0.0977,  0.1862,  1.4303,  ..., -1.9735, -1.1663,  1.7066],
#          [-0.8396, -2.5271, -1.0791,  ...,  0.1053,  1.2463, -0.7709]],
#         requires_grad=True),
#  tensor([[-0.8173, -0.5556, -0.8267,  ..., -0.5133,  2.6278, -0.7465],
#          [ 1.0051, -0.2568,  0.4765,  ..., -0.2496,  0.8298,  1.1209],
#          [ 0.9999,  1.1167,  1.0763,  ...,  0.0562,  0.2456,  0.9535],
#          ...,
#          [-1.0042, -0.7732,  0.9129,  ..., -0.4342,  1.3256, -0.6357],
#          [-0.5979,  1.2285,  1.0288,  ..., -1.4067,  0.2403,  0.5257],
#          [-1.7332, -0.2443,  0.1425,  ..., -0.9291,  1.4324, -0.2338]],
#         requires_grad=True),
#  tensor([[-0.5108,  1.0283, -0.3532,  ...,  0.1421, -0.5243, -0.2487],
#          [-0.5252,  2.8922, -0.5947,  ..., -0.0080,  0.2479,  1.5727],
#          [-1.6395, -1.5925, -0.1546,  ..., -0.3935,  0.6171,  0.7528],
#          ...,
#          [-0.3538,  0.1294,  1.1873,  ..., -0.2866, -0.3111,  0.2674],
#          [ 1.7757, -0.1730,  0.6679,  ..., -0.2519,  0.8360, -0.4348],
#          [ 0.4242,  0.7649, -0.5807,  ..., -0.7654, -0.1086,  0.4636]],
#         requires_grad=True)]

# %%
class Module2(nn.Module):
  def __init__(self):
    super(Module2, self).__init__()
    self.linear1 = nn.Linear(5,100)
    self.linear2 = nn.Linear(100,3)

  def forward(self,x):
    x = F.relu(self.linear1(x))
    x = self.linear2(x)
    return x

# %%
torch.manual_seed(1234)
what_net = Module2().double()

#what_net.load_state_dict(torch.load("type4_what_net.pt"))
what_net = what_net.to("cuda")

# %%
def attn_avg(x,beta):
  y = torch.zeros([batch,5], dtype=torch.float64)
  y = y.to("cuda")
  alpha = F.softmax(beta,dim=1)   # alphas
  #print(alpha[0],x[0,:])
  for i in range(9):            
    alpha1 = alpha[:,i]      
    y = y + torch.mul(alpha1[:,None],x[:,i])
  return y,alpha

# %%
def calculate_attn_loss(dataloader,what,criter):
  what.eval()
  r_loss = 0
  alphas = []
  lbls = []
  pred = []
  fidices = []
  correct = 0
  tot = 0
  with torch.no_grad():
    for i, data in enumerate(dataloader, 0):
      inputs, labels,fidx= data
      lbls.append(labels)
      fidices.append(fidx)
      inputs = inputs.double()
      beta = bg[i]  # beta for ith batch
      inputs, labels,beta = inputs.to("cuda"),labels.to("cuda"),beta.to("cuda")
      avg,alpha = attn_avg(inputs,beta)
      alpha = alpha.to("cuda")
      outputs = what(avg)
      _, predicted = torch.max(outputs.data, 1)
      correct += sum(predicted == labels)
      tot += len(predicted)
      pred.append(predicted.cpu().numpy())
      alphas.append(alpha.cpu().numpy())
      loss = criter(outputs, labels)
      r_loss += loss.item()
  alphas = np.concatenate(alphas,axis=0)
  pred = np.concatenate(pred,axis=0)
  lbls = np.concatenate(lbls,axis=0)
  fidices = np.concatenate(fidices,axis=0)
  #print(alphas.shape,pred.shape,lbls.shape,fidices.shape) 
  analysis = analyse_data(alphas,lbls,pred,fidices)
  return r_loss/i,analysis,correct.item(),tot,correct.item()/tot

# %%
# for param in what_net.parameters():
#     param.requires_grad = False

# %%
def analyse_data(alphas,lbls,predicted,f_idx):
    '''
       analysis data is created here
    '''
    batch = len(predicted)
    amth,alth,ftpt,ffpt,ftpf,ffpf = 0,0,0,0,0,0
    for j in range (batch):
      focus = np.argmax(alphas[j])
      if(alphas[j][focus] >= 0.5):
        amth +=1
      else:
        alth +=1
      if(focus == f_idx[j] and predicted[j] == lbls[j]):
        ftpt += 1
      elif(focus != f_idx[j] and predicted[j] == lbls[j]):
        ffpt +=1
      elif(focus == f_idx[j] and predicted[j] != lbls[j]):
        ftpf +=1
      elif(focus != f_idx[j] and predicted[j] != lbls[j]):
        ffpf +=1
    #print(sum(predicted==lbls),ftpt+ffpt)
    return [ftpt,ffpt,ftpf,ffpf,amth,alth]

# %%
optim1 = []
for i in range(12):
  optim1.append(optim.RMSprop([bg[i]], lr=1))

# %%
# instantiate optimizer
optimizer_what = optim.RMSprop(what_net.parameters(), lr=0.001)#, momentum=0.9)#,nesterov=True)


 


criterion = nn.CrossEntropyLoss()
acti = []
analysis_data_tr = []
analysis_data_tst = []
loss_curi_tr = []
loss_curi_tst = []
epochs = 200


# calculate zeroth epoch loss and FTPT values
running_loss,anlys_data,correct,total,accuracy = calculate_attn_loss(train_loader,what_net,criterion)
print('training epoch: [%d ] loss: %.3f correct: %.3f, total: %.3f, accuracy: %.3f' %(0,running_loss,correct,total,accuracy)) 
loss_curi_tr.append(running_loss)
analysis_data_tr.append(anlys_data)




# training starts 
for epoch in range(epochs): # loop over the dataset multiple times
  ep_lossi = []
  running_loss = 0.0
  what_net.train()
  for i, data in enumerate(train_loader, 0):
    # get the inputs
    inputs, labels,_  = data
    inputs = inputs.double()
    beta = bg[i] # alpha for ith batch
    #print(labels)
    inputs, labels,beta = inputs.to("cuda"),labels.to("cuda"),beta.to("cuda")
        
    # zero the parameter gradients
    optimizer_what.zero_grad()
    optim1[i].zero_grad()
      
    # forward + backward + optimize
    avg,alpha = attn_avg(inputs,beta)
    outputs = what_net(avg)     
    loss = criterion(outputs, labels)

    # print statistics
    running_loss += loss.item()
    #alpha.retain_grad()
    loss.backward(retain_graph=False)
    optimizer_what.step()
    optim1[i].step()


  running_loss_tr,anls_data,correct,total,accuracy = calculate_attn_loss(train_loader,what_net,criterion)
  analysis_data_tr.append(anls_data)
  loss_curi_tr.append(running_loss_tr)   #loss per epoch
  print('training epoch: [%d ] loss: %.3f correct: %.3f, total: %.3f, accuracy: %.3f' %(epoch+1,running_loss_tr,correct,total,accuracy)) 


  
  if running_loss_tr<=0.08:
    break
print('Finished Training run ')
analysis_data_tr = np.array(analysis_data_tr)
# Out:
# training epoch: [0 ] loss: 1.759 correct: 935.000, total: 3000.000, accuracy: 0.312
# training epoch: [1 ] loss: 1.226 correct: 1266.000, total: 3000.000, accuracy: 0.422
# training epoch: [2 ] loss: 1.069 correct: 1548.000, total: 3000.000, accuracy: 0.516
# training epoch: [3 ] loss: 0.981 correct: 1809.000, total: 3000.000, accuracy: 0.603
# training epoch: [4 ] loss: 1.007 correct: 1704.000, total: 3000.000, accuracy: 0.568
# training epoch: [5 ] loss: 0.965 correct: 1836.000, total: 3000.000, accuracy: 0.612
# training epoch: [6 ] loss: 0.933 correct: 1888.000, total: 3000.000, accuracy: 0.629
# training epoch: [7 ] loss: 0.925 correct: 1888.000, total: 3000.000, accuracy: 0.629
# training epoch: [8 ] loss: 0.911 correct: 1919.000, total: 3000.000, accuracy: 0.640
# training epoch: [9 ] loss: 0.900 correct: 1932.000, total: 3000.000, accuracy: 0.644
# training epoch: [10 ] loss: 0.886 correct: 1960.000, total: 3000.000, accuracy: 0.653
# training epoch: [11 ] loss: 0.878 correct: 1963.000, total: 3000.000, accuracy: 0.654
# training epoch: [12 ] loss: 0.872 correct: 1979.000, total: 3000.000, accuracy: 0.660
# training epoch: [13 ] loss: 0.866 correct: 1995.000, total: 3000.000, accuracy: 0.665
# training epoch: [14 ] loss: 0.862 correct: 2000.000, total: 3000.000, accuracy: 0.667
# training epoch: [15 ] loss: 0.863 correct: 1986.000, total: 3000.000, accuracy: 0.662
# training epoch: [16 ] loss: 0.858 correct: 1988.000, total: 3000.000, accuracy: 0.663
# training epoch: [17 ] loss: 0.848 correct: 2004.000, total: 3000.000, accuracy: 0.668
# training epoch: [18 ] loss: 0.846 correct: 2004.000, total: 3000.000, accuracy: 0.668
# training epoch: [19 ] loss: 0.842 correct: 2010.000, total: 3000.000, accuracy: 0.670
# training epoch: [20 ] loss: 0.839 correct: 2015.000, total: 3000.000, accuracy: 0.672
# training epoch: [21 ] loss: 0.837 correct: 2022.000, total: 3000.000, accuracy: 0.674
# training epoch: [22 ] loss: 0.836 correct: 2023.000, total: 3000.000, accuracy: 0.674
# training epoch: [23 ] loss: 0.834 correct: 2031.000, total: 3000.000, accuracy: 0.677
# training epoch: [24 ] loss: 0.831 correct: 2037.000, total: 3000.000, accuracy: 0.679
# training epoch: [25 ] loss: 0.829 correct: 2036.000, total: 3000.000, accuracy: 0.679
# training epoch: [26 ] loss: 0.828 correct: 2038.000, total: 3000.000, accuracy: 0.679
# training epoch: [27 ] loss: 0.827 correct: 2042.000, total: 3000.000, accuracy: 0.681
# training epoch: [28 ] loss: 0.826 correct: 2041.000, total: 3000.000, accuracy: 0.680
# training epoch: [29 ] loss: 0.826 correct: 2037.000, total: 3000.000, accuracy: 0.679
# training epoch: [30 ] loss: 0.826 correct: 2041.000, total: 3000.000, accuracy: 0.680
# training epoch: [31 ] loss: 0.825 correct: 2040.000, total: 3000.000, accuracy: 0.680
# training epoch: [32 ] loss: 0.824 correct: 2041.000, total: 3000.000, accuracy: 0.680
# training epoch: [33 ] loss: 0.823 correct: 2042.000, total: 3000.000, accuracy: 0.681
# training epoch: [34 ] loss: 0.821 correct: 2040.000, total: 3000.000, accuracy: 0.680
# training epoch: [35 ] loss: 0.818 correct: 2047.000, total: 3000.000, accuracy: 0.682
# training epoch: [36 ] loss: 0.815 correct: 2051.000, total: 3000.000, accuracy: 0.684
# training epoch: [37 ] loss: 0.815 correct: 2055.000, total: 3000.000, accuracy: 0.685
# training epoch: [38 ] loss: 0.816 correct: 2050.000, total: 3000.000, accuracy: 0.683
# training epoch: [39 ] loss: 0.818 correct: 2057.000, total: 3000.000, accuracy: 0.686
# training epoch: [40 ] loss: 0.817 correct: 2055.000, total: 3000.000, accuracy: 0.685
# training epoch: [41 ] loss: 0.818 correct: 2054.000, total: 3000.000, accuracy: 0.685
# training epoch: [42 ] loss: 0.815 correct: 2053.000, total: 3000.000, accuracy: 0.684
# training epoch: [43 ] loss: 0.812 correct: 2062.000, total: 3000.000, accuracy: 0.687
# training epoch: [44 ] loss: 0.814 correct: 2066.000, total: 3000.000, accuracy: 0.689
# training epoch: [45 ] loss: 0.811 correct: 2063.000, total: 3000.000, accuracy: 0.688
# training epoch: [46 ] loss: 0.811 correct: 2064.000, total: 3000.000, accuracy: 0.688
# training epoch: [47 ] loss: 0.811 correct: 2065.000, total: 3000.000, accuracy: 0.688
# training epoch: [48 ] loss: 0.806 correct: 2072.000, total: 3000.000, accuracy: 0.691
# training epoch: [49 ] loss: 0.806 correct: 2069.000, total: 3000.000, accuracy: 0.690
# training epoch: [50 ] loss: 0.806 correct: 2069.000, total: 3000.000, accuracy: 0.690
# training epoch: [51 ] loss: 0.803 correct: 2073.000, total: 3000.000, accuracy: 0.691
# training epoch: [52 ] loss: 0.802 correct: 2070.000, total: 3000.000, accuracy: 0.690
# training epoch: [53 ] loss: 0.801 correct: 2072.000, total: 3000.000, accuracy: 0.691
# training epoch: [54 ] loss: 0.798 correct: 2075.000, total: 3000.000, accuracy: 0.692
# training epoch: [55 ] loss: 0.797 correct: 2077.000, total: 3000.000, accuracy: 0.692
# training epoch: [56 ] loss: 0.799 correct: 2080.000, total: 3000.000, accuracy: 0.693
# training epoch: [57 ] loss: 0.795 correct: 2080.000, total: 3000.000, accuracy: 0.693
# training epoch: [58 ] loss: 0.796 correct: 2090.000, total: 3000.000, accuracy: 0.697
# training epoch: [59 ] loss: 0.795 correct: 2090.000, total: 3000.000, accuracy: 0.697
# training epoch: [60 ] loss: 0.792 correct: 2093.000, total: 3000.000, accuracy: 0.698
# training epoch: [61 ] loss: 0.793 correct: 2091.000, total: 3000.000, accuracy: 0.697
# training epoch: [62 ] loss: 0.793 correct: 2092.000, total: 3000.000, accuracy: 0.697
# training epoch: [63 ] loss: 0.791 correct: 2095.000, total: 3000.000, accuracy: 0.698
# training epoch: [64 ] loss: 0.790 correct: 2100.000, total: 3000.000, accuracy: 0.700
# training epoch: [65 ] loss: 0.789 correct: 2106.000, total: 3000.000, accuracy: 0.702
# training epoch: [66 ] loss: 0.791 correct: 2102.000, total: 3000.000, accuracy: 0.701
# training epoch: [67 ] loss: 0.790 correct: 2101.000, total: 3000.000, accuracy: 0.700
# training epoch: [68 ] loss: 0.789 correct: 2106.000, total: 3000.000, accuracy: 0.702
# training epoch: [69 ] loss: 0.788 correct: 2109.000, total: 3000.000, accuracy: 0.703
# training epoch: [70 ] loss: 0.787 correct: 2110.000, total: 3000.000, accuracy: 0.703
# training epoch: [71 ] loss: 0.784 correct: 2115.000, total: 3000.000, accuracy: 0.705
# training epoch: [72 ] loss: 0.784 correct: 2111.000, total: 3000.000, accuracy: 0.704
# training epoch: [73 ] loss: 0.784 correct: 2108.000, total: 3000.000, accuracy: 0.703
# training epoch: [74 ] loss: 0.784 correct: 2110.000, total: 3000.000, accuracy: 0.703
# training epoch: [75 ] loss: 0.781 correct: 2116.000, total: 3000.000, accuracy: 0.705
# training epoch: [76 ] loss: 0.782 correct: 2121.000, total: 3000.000, accuracy: 0.707
# training epoch: [77 ] loss: 0.778 correct: 2120.000, total: 3000.000, accuracy: 0.707
# training epoch: [78 ] loss: 0.779 correct: 2121.000, total: 3000.000, accuracy: 0.707
# training epoch: [79 ] loss: 0.780 correct: 2118.000, total: 3000.000, accuracy: 0.706
# training epoch: [80 ] loss: 0.778 correct: 2120.000, total: 3000.000, accuracy: 0.707
# training epoch: [81 ] loss: 0.777 correct: 2116.000, total: 3000.000, accuracy: 0.705
# training epoch: [82 ] loss: 0.776 correct: 2124.000, total: 3000.000, accuracy: 0.708
# training epoch: [83 ] loss: 0.775 correct: 2125.000, total: 3000.000, accuracy: 0.708
# training epoch: [84 ] loss: 0.774 correct: 2128.000, total: 3000.000, accuracy: 0.709
# training epoch: [85 ] loss: 0.773 correct: 2126.000, total: 3000.000, accuracy: 0.709
# training epoch: [86 ] loss: 0.773 correct: 2127.000, total: 3000.000, accuracy: 0.709
# training epoch: [87 ] loss: 0.773 correct: 2128.000, total: 3000.000, accuracy: 0.709
# training epoch: [88 ] loss: 0.773 correct: 2127.000, total: 3000.000, accuracy: 0.709
# training epoch: [89 ] loss: 0.772 correct: 2128.000, total: 3000.000, accuracy: 0.709
# training epoch: [90 ] loss: 0.772 correct: 2126.000, total: 3000.000, accuracy: 0.709
# training epoch: [91 ] loss: 0.772 correct: 2127.000, total: 3000.000, accuracy: 0.709
# training epoch: [92 ] loss: 0.771 correct: 2128.000, total: 3000.000, accuracy: 0.709
# training epoch: [93 ] loss: 0.771 correct: 2126.000, total: 3000.000, accuracy: 0.709
# training epoch: [94 ] loss: 0.769 correct: 2133.000, total: 3000.000, accuracy: 0.711
# training epoch: [95 ] loss: 0.768 correct: 2131.000, total: 3000.000, accuracy: 0.710
# training epoch: [96 ] loss: 0.768 correct: 2131.000, total: 3000.000, accuracy: 0.710
# training epoch: [97 ] loss: 0.770 correct: 2130.000, total: 3000.000, accuracy: 0.710
# training epoch: [98 ] loss: 0.769 correct: 2131.000, total: 3000.000, accuracy: 0.710
# training epoch: [99 ] loss: 0.769 correct: 2133.000, total: 3000.000, accuracy: 0.711
# training epoch: [100 ] loss: 0.768 correct: 2130.000, total: 3000.000, accuracy: 0.710
# training epoch: [101 ] loss: 0.767 correct: 2131.000, total: 3000.000, accuracy: 0.710
# training epoch: [102 ] loss: 0.767 correct: 2130.000, total: 3000.000, accuracy: 0.710
# training epoch: [103 ] loss: 0.767 correct: 2130.000, total: 3000.000, accuracy: 0.710
# training epoch: [104 ] loss: 0.766 correct: 2133.000, total: 3000.000, accuracy: 0.711
# training epoch: [105 ] loss: 0.766 correct: 2135.000, total: 3000.000, accuracy: 0.712
# training epoch: [106 ] loss: 0.767 correct: 2138.000, total: 3000.000, accuracy: 0.713
# training epoch: [107 ] loss: 0.765 correct: 2138.000, total: 3000.000, accuracy: 0.713
# training epoch: [108 ] loss: 0.764 correct: 2144.000, total: 3000.000, accuracy: 0.715
# training epoch: [109 ] loss: 0.764 correct: 2145.000, total: 3000.000, accuracy: 0.715
# training epoch: [110 ] loss: 0.764 correct: 2146.000, total: 3000.000, accuracy: 0.715
# training epoch: [111 ] loss: 0.764 correct: 2143.000, total: 3000.000, accuracy: 0.714
# training epoch: [112 ] loss: 0.764 correct: 2141.000, total: 3000.000, accuracy: 0.714
# training epoch: [113 ] loss: 0.762 correct: 2142.000, total: 3000.000, accuracy: 0.714
# training epoch: [114 ] loss: 0.763 correct: 2146.000, total: 3000.000, accuracy: 0.715
# training epoch: [115 ] loss: 0.762 correct: 2145.000, total: 3000.000, accuracy: 0.715
# training epoch: [116 ] loss: 0.762 correct: 2150.000, total: 3000.000, accuracy: 0.717
# training epoch: [117 ] loss: 0.762 correct: 2146.000, total: 3000.000, accuracy: 0.715
# training epoch: [118 ] loss: 0.761 correct: 2146.000, total: 3000.000, accuracy: 0.715
# training epoch: [119 ] loss: 0.761 correct: 2149.000, total: 3000.000, accuracy: 0.716
# training epoch: [120 ] loss: 0.759 correct: 2152.000, total: 3000.000, accuracy: 0.717
# training epoch: [121 ] loss: 0.759 correct: 2150.000, total: 3000.000, accuracy: 0.717
# training epoch: [122 ] loss: 0.759 correct: 2149.000, total: 3000.000, accuracy: 0.716
# training epoch: [123 ] loss: 0.758 correct: 2152.000, total: 3000.000, accuracy: 0.717
# training epoch: [124 ] loss: 0.758 correct: 2155.000, total: 3000.000, accuracy: 0.718
# training epoch: [125 ] loss: 0.757 correct: 2154.000, total: 3000.000, accuracy: 0.718
# training epoch: [126 ] loss: 0.756 correct: 2156.000, total: 3000.000, accuracy: 0.719
# training epoch: [127 ] loss: 0.758 correct: 2152.000, total: 3000.000, accuracy: 0.717
# training epoch: [128 ] loss: 0.756 correct: 2154.000, total: 3000.000, accuracy: 0.718
# training epoch: [129 ] loss: 0.755 correct: 2155.000, total: 3000.000, accuracy: 0.718
# training epoch: [130 ] loss: 0.755 correct: 2156.000, total: 3000.000, accuracy: 0.719
# training epoch: [131 ] loss: 0.755 correct: 2159.000, total: 3000.000, accuracy: 0.720
# training epoch: [132 ] loss: 0.754 correct: 2159.000, total: 3000.000, accuracy: 0.720
# training epoch: [133 ] loss: 0.754 correct: 2160.000, total: 3000.000, accuracy: 0.720
# training epoch: [134 ] loss: 0.753 correct: 2158.000, total: 3000.000, accuracy: 0.719
# training epoch: [135 ] loss: 0.751 correct: 2158.000, total: 3000.000, accuracy: 0.719
# training epoch: [136 ] loss: 0.752 correct: 2155.000, total: 3000.000, accuracy: 0.718
# training epoch: [137 ] loss: 0.751 correct: 2158.000, total: 3000.000, accuracy: 0.719
# training epoch: [138 ] loss: 0.749 correct: 2161.000, total: 3000.000, accuracy: 0.720
# training epoch: [139 ] loss: 0.749 correct: 2158.000, total: 3000.000, accuracy: 0.719
# training epoch: [140 ] loss: 0.749 correct: 2162.000, total: 3000.000, accuracy: 0.721
# training epoch: [141 ] loss: 0.749 correct: 2160.000, total: 3000.000, accuracy: 0.720
# training epoch: [142 ] loss: 0.749 correct: 2167.000, total: 3000.000, accuracy: 0.722
# training epoch: [143 ] loss: 0.753 correct: 2163.000, total: 3000.000, accuracy: 0.721
# training epoch: [144 ] loss: 0.747 correct: 2169.000, total: 3000.000, accuracy: 0.723
# training epoch: [145 ] loss: 0.747 correct: 2172.000, total: 3000.000, accuracy: 0.724
# training epoch: [146 ] loss: 0.747 correct: 2169.000, total: 3000.000, accuracy: 0.723
# training epoch: [147 ] loss: 0.746 correct: 2171.000, total: 3000.000, accuracy: 0.724
# training epoch: [148 ] loss: 0.746 correct: 2170.000, total: 3000.000, accuracy: 0.723
# training epoch: [149 ] loss: 0.745 correct: 2168.000, total: 3000.000, accuracy: 0.723
# training epoch: [150 ] loss: 0.746 correct: 2167.000, total: 3000.000, accuracy: 0.722
# training epoch: [151 ] loss: 0.746 correct: 2167.000, total: 3000.000, accuracy: 0.722
# training epoch: [152 ] loss: 0.746 correct: 2167.000, total: 3000.000, accuracy: 0.722
# training epoch: [153 ] loss: 0.745 correct: 2168.000, total: 3000.000, accuracy: 0.723
# training epoch: [154 ] loss: 0.742 correct: 2169.000, total: 3000.000, accuracy: 0.723
# training epoch: [155 ] loss: 0.741 correct: 2172.000, total: 3000.000, accuracy: 0.724
# training epoch: [156 ] loss: 0.739 correct: 2172.000, total: 3000.000, accuracy: 0.724
# training epoch: [157 ] loss: 0.741 correct: 2173.000, total: 3000.000, accuracy: 0.724
# training epoch: [158 ] loss: 0.739 correct: 2172.000, total: 3000.000, accuracy: 0.724
# training epoch: [159 ] loss: 0.739 correct: 2171.000, total: 3000.000, accuracy: 0.724
# training epoch: [160 ] loss: 0.739 correct: 2174.000, total: 3000.000, accuracy: 0.725
# training epoch: [161 ] loss: 0.741 correct: 2171.000, total: 3000.000, accuracy: 0.724
# training epoch: [162 ] loss: 0.740 correct: 2171.000, total: 3000.000, accuracy: 0.724
# training epoch: [163 ] loss: 0.740 correct: 2169.000, total: 3000.000, accuracy: 0.723
# training epoch: [164 ] loss: 0.740 correct: 2172.000, total: 3000.000, accuracy: 0.724
# training epoch: [165 ] loss: 0.740 correct: 2170.000, total: 3000.000, accuracy: 0.723
# training epoch: [166 ] loss: 0.740 correct: 2169.000, total: 3000.000, accuracy: 0.723
# training epoch: [167 ] loss: 0.739 correct: 2168.000, total: 3000.000, accuracy: 0.723
# training epoch: [168 ] loss: 0.738 correct: 2169.000, total: 3000.000, accuracy: 0.723
# training epoch: [169 ] loss: 0.737 correct: 2172.000, total: 3000.000, accuracy: 0.724
# training epoch: [170 ] loss: 0.738 correct: 2172.000, total: 3000.000, accuracy: 0.724
# training epoch: [171 ] loss: 0.738 correct: 2175.000, total: 3000.000, accuracy: 0.725
# training epoch: [172 ] loss: 0.737 correct: 2173.000, total: 3000.000, accuracy: 0.724
# training epoch: [173 ] loss: 0.738 correct: 2174.000, total: 3000.000, accuracy: 0.725
# training epoch: [174 ] loss: 0.737 correct: 2173.000, total: 3000.000, accuracy: 0.724
# training epoch: [175 ] loss: 0.737 correct: 2172.000, total: 3000.000, accuracy: 0.724
# training epoch: [176 ] loss: 0.737 correct: 2171.000, total: 3000.000, accuracy: 0.724
# training epoch: [177 ] loss: 0.737 correct: 2174.000, total: 3000.000, accuracy: 0.725
# training epoch: [178 ] loss: 0.736 correct: 2174.000, total: 3000.000, accuracy: 0.725
# training epoch: [179 ] loss: 0.735 correct: 2173.000, total: 3000.000, accuracy: 0.724
# training epoch: [180 ] loss: 0.734 correct: 2175.000, total: 3000.000, accuracy: 0.725
# training epoch: [181 ] loss: 0.734 correct: 2174.000, total: 3000.000, accuracy: 0.725
# training epoch: [182 ] loss: 0.732 correct: 2179.000, total: 3000.000, accuracy: 0.726
# training epoch: [183 ] loss: 0.732 correct: 2178.000, total: 3000.000, accuracy: 0.726
# training epoch: [184 ] loss: 0.730 correct: 2184.000, total: 3000.000, accuracy: 0.728
# training epoch: [185 ] loss: 0.732 correct: 2181.000, total: 3000.000, accuracy: 0.727
# training epoch: [186 ] loss: 0.732 correct: 2182.000, total: 3000.000, accuracy: 0.727
# training epoch: [187 ] loss: 0.732 correct: 2182.000, total: 3000.000, accuracy: 0.727
# training epoch: [188 ] loss: 0.731 correct: 2183.000, total: 3000.000, accuracy: 0.728
# training epoch: [189 ] loss: 0.731 correct: 2182.000, total: 3000.000, accuracy: 0.727
# training epoch: [190 ] loss: 0.730 correct: 2185.000, total: 3000.000, accuracy: 0.728
# training epoch: [191 ] loss: 0.729 correct: 2187.000, total: 3000.000, accuracy: 0.729
# training epoch: [192 ] loss: 0.729 correct: 2187.000, total: 3000.000, accuracy: 0.729
# training epoch: [193 ] loss: 0.730 correct: 2186.000, total: 3000.000, accuracy: 0.729
# training epoch: [194 ] loss: 0.730 correct: 2189.000, total: 3000.000, accuracy: 0.730
# training epoch: [195 ] loss: 0.730 correct: 2186.000, total: 3000.000, accuracy: 0.729
# training epoch: [196 ] loss: 0.729 correct: 2188.000, total: 3000.000, accuracy: 0.729
# training epoch: [197 ] loss: 0.728 correct: 2190.000, total: 3000.000, accuracy: 0.730
# training epoch: [198 ] loss: 0.729 correct: 2187.000, total: 3000.000, accuracy: 0.729
# training epoch: [199 ] loss: 0.727 correct: 2188.000, total: 3000.000, accuracy: 0.729
# training epoch: [200 ] loss: 0.728 correct: 2188.000, total: 3000.000, accuracy: 0.729
# Finished Training run

# %%
columns = ["epochs", "argmax > 0.5" ,"argmax < 0.5", "focus_true_pred_true", "focus_false_pred_true", "focus_true_pred_false", "focus_false_pred_false" ]
df_train = pd.DataFrame()
df_test = pd.DataFrame()
df_train[columns[0]] = np.arange(0,epoch+2)
df_train[columns[1]] = analysis_data_tr[:,-2]
df_train[columns[2]] = analysis_data_tr[:,-1]
df_train[columns[3]] = analysis_data_tr[:,0]
df_train[columns[4]] = analysis_data_tr[:,1]
df_train[columns[5]] = analysis_data_tr[:,2]
df_train[columns[6]] = analysis_data_tr[:,3]

# %%
df_train
# Out:
#      epochs  argmax > 0.5  ...  focus_true_pred_false  focus_false_pred_false
# 0         0           302  ...                    235                    1830
# 1         1          1378  ...                    211                    1523
# 2         2          2831  ...                    218                    1234
# 3         3          2982  ...                    165                    1026
# 4         4          2992  ...                    165                    1131
# ..      ...           ...  ...                    ...                     ...
# 196     196          2998  ...                     57                     755
# 197     197          2999  ...                     56                     754
# 198     198          3000  ...                     57                     756
# 199     199          2999  ...                     57                     755
# 200     200          2999  ...                     57                     755
#
# [201 rows x 7 columns]

# %%
fig= plt.figure(figsize=(6,6))
plt.plot(df_train[columns[0]],df_train[columns[3]]/30, label ="focus_true_pred_true ")
plt.plot(df_train[columns[0]],df_train[columns[4]]/30, label ="focus_false_pred_true ")
plt.plot(df_train[columns[0]],df_train[columns[5]]/30, label ="focus_true_pred_false ")
plt.plot(df_train[columns[0]],df_train[columns[6]]/30, label ="focus_false_pred_false ")
plt.title("On Train set")
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.xlabel("epochs")
plt.ylabel("percentage of data")
plt.xticks([0,50,100,150,200])
#plt.vlines(vline_list,min(min(df_train[columns[3]]/300),min(df_train[columns[4]]/300),min(df_train[columns[5]]/300),min(df_train[columns[6]]/300)), max(max(df_train[columns[3]]/300),max(df_train[columns[4]]/300),max(df_train[columns[5]]/300),max(df_train[columns[6]]/300)),linestyles='dotted')
plt.show()
fig.savefig("train_analysis.pdf")
fig.savefig("train_analysis.png")

# %%
aph = []
for i in bg:
  aph.append(F.softmax(i,dim=1).detach().numpy())
  
aph = np.concatenate(aph,axis=0)
torch.save({
            'epoch': 500,
            'model_state_dict': what_net.state_dict(),
            #'optimizer_state_dict': optimizer_what.state_dict(),
            "optimizer_alpha":optim1,
            "FTPT_analysis":analysis_data_tr,
            "alpha":aph

            }, "type4_what_net_500.pt")

# %%
aph[0]
# Out:
# array([4.6763048e-06, 5.6389697e-13, 5.9916886e-07, 1.4777895e-05,
#        9.9995828e-01, 3.5605616e-12, 1.1802985e-05, 9.8657692e-06,
#        2.4604325e-12], dtype=float32)
