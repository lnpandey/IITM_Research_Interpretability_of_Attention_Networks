# %%
 import numpy as np
import pandas as pd

import torch
import torchvision
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms, utils
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

from matplotlib import pyplot as plt
# %matplotlib inline

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
path="/content/drive/MyDrive/Research/alternate_minimisation/type4_data/"

# %% [markdown]
# #data creation

# %%
# y = np.random.randint(0,10,5000)
# idx= []
# for i in range(10):
#     print(i,sum(y==i))
#     idx.append(y==i)

# %%
# x = np.zeros((5000,2))

# x[idx[0],:] = np.random.multivariate_normal(mean = [4,6.5],cov=[[0.01,0],[0,0.01]],size=sum(idx[0]))

# x[idx[1],:] = np.random.multivariate_normal(mean = [5.5,6],cov=[[0.01,0],[0,0.01]],size=sum(idx[1]))

# x[idx[2],:] = np.random.multivariate_normal(mean = [4.5,4.5],cov=[[0.01,0],[0,0.01]],size=sum(idx[2]))

# x[idx[3],:] = np.random.multivariate_normal(mean = [3,3.5],cov=[[0.01,0],[0,0.01]],size=sum(idx[3]))

# x[idx[4],:] = np.random.multivariate_normal(mean = [2.5,5.5],cov=[[0.01,0],[0,0.01]],size=sum(idx[4]))

# x[idx[5],:] = np.random.multivariate_normal(mean = [3.5,8],cov=[[0.01,0],[0,0.01]],size=sum(idx[5]))

# x[idx[6],:] = np.random.multivariate_normal(mean = [5.5,8],cov=[[0.01,0],[0,0.01]],size=sum(idx[6]))

# x[idx[7],:] = np.random.multivariate_normal(mean = [7,6.5],cov=[[0.01,0],[0,0.01]],size=sum(idx[7]))

# x[idx[8],:] = np.random.multivariate_normal(mean = [6.5,4.5],cov=[[0.01,0],[0,0.01]],size=sum(idx[8]))

# x[idx[9],:] = np.random.multivariate_normal(mean = [5,3],cov=[[0.01,0],[0,0.01]],size=sum(idx[9]))

# %%
# plt.figure(figsize=(6,6))
# for i in range(10):
#     plt.scatter(x[idx[i],0],x[idx[i],1],label="class_"+str(i))
# plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))

# %%
# class SyntheticDataset(Dataset):
#   """MosaicDataset dataset."""

#   def __init__(self, x, y):
#     """
#       Args:
#         csv_file (string): Path to the csv file with annotations.
#         root_dir (string): Directory with all the images.
#         transform (callable, optional): Optional transform to be applied
#             on a sample.
#     """
#     self.x = x
#     self.y = y
#     #self.fore_idx = fore_idx
    
#   def __len__(self):
#     return len(self.y)

#   def __getitem__(self, idx):
#     return self.x[idx] , self.y[idx] #, self.fore_idx[idx]

# %%
# trainset = SyntheticDataset(x,y)
# trainloader = torch.utils.data.DataLoader(trainset, batch_size=100, shuffle=True)
# classes = ('zero','one','two','three','four','five','six','seven','eight','nine')

# foreground_classes = {'zero','one','two'}
# fg_used = '012'
# fg1, fg2, fg3 = 0,1,2


# all_classes = {'zero','one','two','three','four','five','six','seven','eight','nine'}
# background_classes = all_classes - foreground_classes
# background_classes

# %%
# dataiter = iter(trainloader)
# background_data=[]
# background_label=[]
# foreground_data=[]
# foreground_label=[]
# batch_size=100

# for i in range(50):
#   images, labels = dataiter.next()
#   for j in range(batch_size):
#     if(classes[labels[j]] in background_classes):
#       img = images[j].tolist()
#       background_data.append(img)
#       background_label.append(labels[j])
#     else:
#       img = images[j].tolist()
#       foreground_data.append(img)
#       foreground_label.append(labels[j])
            
# foreground_data = torch.tensor(foreground_data)
# foreground_label = torch.tensor(foreground_label)
# background_data = torch.tensor(background_data)
# background_label = torch.tensor(background_label)

# %%
# def create_mosaic_img(bg_idx,fg_idx,fg): 
#   """
#   bg_idx : list of indexes of background_data[] to be used as background images in mosaic
#   fg_idx : index of image to be used as foreground image from foreground data
#   fg : at what position/index foreground image has to be stored out of 0-8
#   """
#   image_list=[]
#   j=0
#   for i in range(9):
#     if i != fg:
#       image_list.append(background_data[bg_idx[j]])
#       j+=1
#     else: 
#       image_list.append(foreground_data[fg_idx])
#       label = foreground_label[fg_idx] - fg1  # minus fg1 because our fore ground classes are fg1,fg2,fg3 but we have to store it as 0,1,2
#   #image_list = np.concatenate(image_list ,axis=0)
#   image_list = torch.stack(image_list) 
#   return image_list,label

# %%
# # number of data points in bg class and fg class
# nbg = sum(idx[3]) + sum(idx[4]) + sum(idx[5]) + sum(idx[6]) + sum(idx[7]) + sum(idx[8]) + sum(idx[9])
# nfg   = sum(idx[0]) + sum(idx[1]) + sum(idx[2])

# print(nbg, nfg, nbg+nfg)

# %%
# desired_num = 3000
# mosaic_list_of_images =[]      # list of mosaic images, each mosaic image is saved as list of 9 images
# fore_idx =[]                   # list of indexes at which foreground image is present in a mosaic image i.e from 0 to 9               
# mosaic_label=[]                # label of mosaic image = foreground class present in that mosaic
# list_set_labels = [] 
# for i in range(desired_num):
#   set_idx = set()
#   np.random.seed(i)
#   bg_idx = np.random.randint(0,nbg,8)
#   set_idx = set(background_label[bg_idx].tolist())
#   fg_idx = np.random.randint(0,nfg)
#   set_idx.add(foreground_label[fg_idx].item())
#   fg = np.random.randint(0,9)
#   fore_idx.append(fg)
#   image_list,label = create_mosaic_img(bg_idx,fg_idx,fg)
#   mosaic_list_of_images.append(image_list)
#   mosaic_label.append(label)
#   list_set_labels.append(set_idx)

# %%
# desired_num = 2000
# test_mosaic_list_of_images =[]      # list of mosaic images, each mosaic image is saved as list of 9 images
# test_fore_idx =[]                   # list of indexes at which foreground image is present in a mosaic image i.e from 0 to 9               
# test_mosaic_label=[]                # label of mosaic image = foreground class present in that mosaic
# test_list_set_labels = [] 
# for i in range(desired_num):
#   set_idx = set()
#   np.random.seed(i+3000)
#   bg_idx = np.random.randint(0,nbg,8)
#   set_idx = set(background_label[bg_idx].tolist())
#   fg_idx = np.random.randint(0,nfg)
#   set_idx.add(foreground_label[fg_idx].item())
#   fg = np.random.randint(0,9)
#   test_fore_idx.append(fg)
#   test_image_list,test_label = create_mosaic_img(bg_idx,fg_idx,fg)
#   test_mosaic_list_of_images.append(test_image_list)
#   test_mosaic_label.append(test_label)
#   test_list_set_labels.append(set_idx)

# %%
# data =  [{"mosaic_list":mosaic_list_of_images, "mosaic_label": mosaic_label, "fore_idx":fore_idx}]
# np.save(path+"train_type4_data.npy",data)

# %%
# data =  [{"mosaic_list":test_mosaic_list_of_images, "mosaic_label": test_mosaic_label, "fore_idx":test_fore_idx}]
# np.save(path+"test_type4_data.npy",data)

# %%
# data = [{"X":x,"Y":y}]
# np.save(path+"type_4_data.npy",data)

# %% [markdown]
# # Data loading

# %%
class MosaicDataset1(Dataset):
  """MosaicDataset dataset."""

  def __init__(self, mosaic_list, mosaic_label,fore_idx):
    """
      Args:
        csv_file (string): Path to the csv file with annotations.
        root_dir (string): Directory with all the images.
        transform (callable, optional): Optional transform to be applied
            on a sample.
    """
    self.mosaic = mosaic_list
    self.label = mosaic_label
    self.fore_idx = fore_idx
    
  def __len__(self):
    return len(self.label)

  def __getitem__(self, idx):
    return self.mosaic[idx] , self.label[idx] , self.fore_idx[idx]

# %%
class SyntheticDataset(Dataset):
  """MosaicDataset dataset."""

  def __init__(self, x, y):
    """
      Args:
        csv_file (string): Path to the csv file with annotations.
        root_dir (string): Directory with all the images.
        transform (callable, optional): Optional transform to be applied
            on a sample.
    """
    self.x = x
    self.y = y
    #self.fore_idx = fore_idx
    
  def __len__(self):
    return len(self.y)

  def __getitem__(self, idx):
    return self.x[idx] , self.y[idx] #, self.fore_idx[idx]

# %%
train_data = np.load(path+"train_type4_data.npy",allow_pickle=True)
test_data = np.load(path+"test_type4_data.npy",allow_pickle=True)
data = np.load(path+"type_4_data.npy",allow_pickle=True)

# %%
train_mosaic_list_of_images = train_data[0]["mosaic_list"]
train_mosaic_label = train_data[0]["mosaic_label"]
train_fore_idx = train_data[0]["fore_idx"]


test_mosaic_list_of_images = test_data[0]["mosaic_list"]
test_mosaic_label = test_data[0]["mosaic_label"]
test_fore_idx = test_data[0]["fore_idx"]
X = data[0]["X"]
Y = data[0]["Y"]

# %%
batch = 250
tr_msd = MosaicDataset1(train_mosaic_list_of_images, train_mosaic_label, train_fore_idx)
train_loader = DataLoader( tr_msd,batch_size= batch ,shuffle=True)

# %%
batch = 250
tst_msd = MosaicDataset1(test_mosaic_list_of_images, test_mosaic_label, test_fore_idx)
test_loader = DataLoader( tst_msd,batch_size= batch ,shuffle=True)

# %%
dset = SyntheticDataset(X,Y)
dtloader = DataLoader(dset,batch_size =batch,shuffle=True )

# %%
def calculate_loss(dataloader,model,criter):
  model.eval()
  r_loss = 0
  with torch.no_grad():
    for i, data in enumerate(dataloader, 0):
      inputs, labels = data
      inputs, labels = inputs.to("cuda"),labels.to("cuda")
      outputs = model(inputs)
      loss = criter(outputs, labels)
      r_loss += loss.item()
  return r_loss/i

# %% [markdown]
# **Focus Net**

# %%
class Module1(nn.Module):
  def __init__(self):
    super(Module1, self).__init__()
    self.fc1 = nn.Linear(2, 100)
    self.fc2 = nn.Linear(100, 1)

  def forward(self, z):
    x = torch.zeros([batch,9],dtype=torch.float64)
    y = torch.zeros([batch,2], dtype=torch.float64)
    x,y = x.to("cuda"),y.to("cuda")
    for i in range(9):
      x[:,i] = self.helper(z[:,i])[:,0]
    x = F.softmax(x,dim=1)   # alphas
    

    for i in range(9):            
      x1 = x[:,i]          
      y = y + torch.mul(x1[:,None],z[:,i])
    return y , x 
  
  def helper(self,x):
    x = F.relu(self.fc1(x))
    x = self.fc2(x)
    return x

# %% [markdown]
# **Classification Net**

# %%
 class Module2(nn.Module):
  def __init__(self):
    super(Module2, self).__init__()
    self.fc1 = nn.Linear(2, 100)
    self.fc2 = nn.Linear(100, 3)

  def forward(self,y):  
    y = F.relu(self.fc1(y))
    y = self.fc2(y)
    return y

# %%
def calculate_attn_loss(dataloader,what,where,criter):
  what.eval()
  where.eval()
  r_loss = 0
  alphas = []
  lbls = []
  pred = []
  fidices = []
  with torch.no_grad():
    for i, data in enumerate(dataloader, 0):
      inputs, labels,fidx = data
      lbls.append(labels)
      fidices.append(fidx)
      inputs = inputs.double()
      inputs, labels = inputs.to("cuda"),labels.to("cuda")
      avg,alpha = where(inputs)
      outputs = what(avg)
      _, predicted = torch.max(outputs.data, 1)
      pred.append(predicted.cpu().numpy())
      alphas.append(alpha.cpu().numpy())
      loss = criter(outputs, labels)
      r_loss += loss.item()
  alphas = np.concatenate(alphas,axis=0)
  pred = np.concatenate(pred,axis=0)
  lbls = np.concatenate(lbls,axis=0)
  fidices = np.concatenate(fidices,axis=0)
  #print(alphas.shape,pred.shape,lbls.shape,fidices.shape) 
  analysis = analyse_data(alphas,lbls,pred,fidices)
  return r_loss/i,analysis

# %%
def analyse_data(alphas,lbls,predicted,f_idx):
    '''
       analysis data is created here
    '''
    batch = len(predicted)
    amth,alth,ftpt,ffpt,ftpf,ffpf = 0,0,0,0,0,0
    for j in range (batch):
      focus = np.argmax(alphas[j])
      if(alphas[j][focus] >= 0.5):
        amth +=1
      else:
        alth +=1
      if(focus == f_idx[j] and predicted[j] == lbls[j]):
        ftpt += 1
      elif(focus != f_idx[j] and predicted[j] == lbls[j]):
        ffpt +=1
      elif(focus == f_idx[j] and predicted[j] != lbls[j]):
        ftpf +=1
      elif(focus != f_idx[j] and predicted[j] != lbls[j]):
        ffpf +=1
    #print(sum(predicted==lbls),ftpt+ffpt)
    return [ftpt,ffpt,ftpf,ffpf,amth,alth]

# %%
number_runs = 10
full_analysis =[]
FTPT_analysis = pd.DataFrame(columns = ["FTPT","FFPT", "FTPF","FFPF"])

every_what_epoch = 20 #to change

for n in range(number_runs):
  print("--"*40)
  
  # instantiate focus and classification Model
  torch.manual_seed(n)
  where = Module1().double()
  torch.manual_seed(n)
  what = Module2().double()
  where = where.to("cuda")
  what = what.to("cuda")



  # instantiate optimizer
  optimizer_where = optim.Adam(where.parameters(),lr =0.001)
  optimizer_what = optim.Adam(what.parameters(), lr=0.001)
  criterion = nn.CrossEntropyLoss()
  acti = []
  analysis_data = []
  loss_curi = []
  epochs = 1000


  # calculate zeroth epoch loss and FTPT values
  running_loss,anlys_data = calculate_attn_loss(train_loader,what,where,criterion)
  loss_curi.append(running_loss)
  analysis_data.append(anlys_data)

  print('epoch: [%d ] loss: %.3f' %(0,running_loss)) 

  # training starts 
  for epoch in range(epochs): # loop over the dataset multiple times
    ep_lossi = []
    running_loss = 0.0
    what.train()
    where.train()
    if ((epoch) % (every_what_epoch*2) ) <= every_what_epoch-1 :
      print(epoch+1,"updating what_net, where_net is freezed")
      print("--"*40)
    elif ((epoch) % (every_what_epoch*2)) > every_what_epoch-1 :
      print(epoch+1,"updating where_net, what_net is freezed")
      print("--"*40)
    for i, data in enumerate(train_loader, 0):
      # get the inputs
      inputs, labels,_ = data
      inputs = inputs.double()
      inputs, labels = inputs.to("cuda"),labels.to("cuda")

      # zero the parameter gradients
      optimizer_where.zero_grad()
      optimizer_what.zero_grad()
      
      # forward + backward + optimize
      avg, alpha = where(inputs)
      outputs = what(avg)
      loss = criterion(outputs, labels)

      # print statistics
      running_loss += loss.item()
      loss.backward()

      if ((epoch) % (every_what_epoch*2) ) <= every_what_epoch-1 :
        optimizer_what.step()
      elif ( (epoch) % (every_what_epoch*2)) > every_what_epoch-1 :
        optimizer_where.step()
      # optimizer_where.step()
      # optimizer_what.step()

    running_loss,anls_data = calculate_attn_loss(train_loader,what,where,criterion)
    analysis_data.append(anls_data)
    print('epoch: [%d] loss: %.3f' %(epoch + 1,running_loss)) 
    loss_curi.append(running_loss)   #loss per epoch
    if running_loss<=0.01:
      break
  print('Finished Training run ' +str(n))
  analysis_data = np.array(analysis_data)
  FTPT_analysis.loc[n] = analysis_data[-1,:4]/30
  full_analysis.append((epoch, analysis_data))
  correct = 0
  total = 0
  with torch.no_grad():
    for data in train_loader:
      images, labels,_ = data
      images = images.double()
      images, labels = images.to("cuda"), labels.to("cuda")
      avg, alpha = where(images)
      outputs  = what(avg)
      _, predicted = torch.max(outputs.data, 1)
      total += labels.size(0)
      correct += (predicted == labels).sum().item()

  print('Accuracy of the network on the 3000 train images: %d %%' % (  100 * correct / total))
# Out:
# Streaming output truncated to the last 5000 lines.
# 808 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [808] loss: 0.013
# 809 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [809] loss: 0.013
# 810 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [810] loss: 0.013
# 811 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [811] loss: 0.013
# 812 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [812] loss: 0.013
# 813 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [813] loss: 0.013
# 814 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [814] loss: 0.013
# 815 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [815] loss: 0.013
# 816 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [816] loss: 0.013
# 817 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [817] loss: 0.013
# 818 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [818] loss: 0.013
# 819 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [819] loss: 0.013
# 820 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [820] loss: 0.013
# 821 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [821] loss: 0.013
# 822 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [822] loss: 0.013
# 823 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [823] loss: 0.013
# 824 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [824] loss: 0.013
# 825 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [825] loss: 0.013
# 826 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [826] loss: 0.012
# 827 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [827] loss: 0.012
# 828 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [828] loss: 0.012
# 829 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [829] loss: 0.012
# 830 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [830] loss: 0.012
# 831 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [831] loss: 0.012
# 832 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [832] loss: 0.013
# 833 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [833] loss: 0.013
# 834 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [834] loss: 0.012
# 835 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [835] loss: 0.012
# 836 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [836] loss: 0.012
# 837 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [837] loss: 0.013
# 838 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [838] loss: 0.012
# 839 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [839] loss: 0.012
# 840 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [840] loss: 0.012
# 841 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [841] loss: 0.012
# 842 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [842] loss: 0.012
# 843 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [843] loss: 0.012
# 844 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [844] loss: 0.012
# 845 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [845] loss: 0.012
# 846 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [846] loss: 0.012
# 847 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [847] loss: 0.012
# 848 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [848] loss: 0.012
# 849 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [849] loss: 0.012
# 850 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [850] loss: 0.012
# 851 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [851] loss: 0.012
# 852 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [852] loss: 0.011
# 853 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [853] loss: 0.011
# 854 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [854] loss: 0.011
# 855 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [855] loss: 0.011
# 856 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [856] loss: 0.011
# 857 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [857] loss: 0.011
# 858 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [858] loss: 0.011
# 859 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [859] loss: 0.011
# 860 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [860] loss: 0.011
# 861 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [861] loss: 0.011
# 862 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [862] loss: 0.011
# 863 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [863] loss: 0.011
# 864 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [864] loss: 0.011
# 865 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [865] loss: 0.011
# 866 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [866] loss: 0.011
# 867 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [867] loss: 0.011
# 868 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [868] loss: 0.011
# 869 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [869] loss: 0.011
# 870 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [870] loss: 0.011
# 871 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [871] loss: 0.011
# 872 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [872] loss: 0.011
# 873 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [873] loss: 0.011
# 874 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [874] loss: 0.011
# 875 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [875] loss: 0.011
# 876 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [876] loss: 0.011
# 877 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [877] loss: 0.011
# 878 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [878] loss: 0.011
# 879 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [879] loss: 0.011
# 880 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [880] loss: 0.011
# 881 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [881] loss: 0.011
# 882 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [882] loss: 0.010
# 883 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [883] loss: 0.010
# 884 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [884] loss: 0.010
# 885 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [885] loss: 0.010
# 886 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [886] loss: 0.010
# 887 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [887] loss: 0.010
# 888 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [888] loss: 0.010
# 889 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [889] loss: 0.010
# 890 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [890] loss: 0.010
# 891 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [891] loss: 0.010
# 892 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [892] loss: 0.010
# 893 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [893] loss: 0.010
# 894 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [894] loss: 0.010
# 895 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [895] loss: 0.010
# 896 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [896] loss: 0.010
# Finished Training run 6
# Accuracy of the network on the 3000 train images: 99 %
# --------------------------------------------------------------------------------
# epoch: [0 ] loss: 1.276
# 1 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1] loss: 1.207
# 2 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [2] loss: 1.204
# 3 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [3] loss: 1.199
# 4 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [4] loss: 1.198
# 5 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [5] loss: 1.197
# 6 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [6] loss: 1.196
# 7 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [7] loss: 1.196
# 8 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [8] loss: 1.198
# 9 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [9] loss: 1.196
# 10 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [10] loss: 1.197
# 11 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [11] loss: 1.194
# 12 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [12] loss: 1.194
# 13 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [13] loss: 1.195
# 14 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [14] loss: 1.193
# 15 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [15] loss: 1.194
# 16 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [16] loss: 1.194
# 17 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [17] loss: 1.194
# 18 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [18] loss: 1.194
# 19 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [19] loss: 1.193
# 20 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [20] loss: 1.193
# 21 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [21] loss: 1.189
# 22 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [22] loss: 1.188
# 23 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [23] loss: 1.187
# 24 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [24] loss: 1.186
# 25 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [25] loss: 1.185
# 26 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [26] loss: 1.184
# 27 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [27] loss: 1.183
# 28 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [28] loss: 1.182
# 29 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [29] loss: 1.181
# 30 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [30] loss: 1.179
# 31 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [31] loss: 1.178
# 32 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [32] loss: 1.177
# 33 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [33] loss: 1.176
# 34 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [34] loss: 1.175
# 35 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [35] loss: 1.174
# 36 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [36] loss: 1.173
# 37 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [37] loss: 1.172
# 38 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [38] loss: 1.171
# 39 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [39] loss: 1.170
# 40 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [40] loss: 1.169
# 41 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [41] loss: 1.148
# 42 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [42] loss: 1.134
# 43 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [43] loss: 1.123
# 44 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [44] loss: 1.116
# 45 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [45] loss: 1.111
# 46 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [46] loss: 1.110
# 47 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [47] loss: 1.103
# 48 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [48] loss: 1.102
# 49 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [49] loss: 1.100
# 50 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [50] loss: 1.097
# 51 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [51] loss: 1.097
# 52 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [52] loss: 1.095
# 53 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [53] loss: 1.092
# 54 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [54] loss: 1.092
# 55 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [55] loss: 1.090
# 56 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [56] loss: 1.091
# 57 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [57] loss: 1.091
# 58 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [58] loss: 1.095
# 59 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [59] loss: 1.090
# 60 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [60] loss: 1.086
# 61 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [61] loss: 1.071
# 62 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [62] loss: 1.062
# 63 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [63] loss: 1.040
# 64 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [64] loss: 1.029
# 65 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [65] loss: 1.021
# 66 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [66] loss: 1.014
# 67 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [67] loss: 1.008
# 68 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [68] loss: 1.003
# 69 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [69] loss: 0.999
# 70 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [70] loss: 0.994
# 71 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [71] loss: 0.990
# 72 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [72] loss: 0.986
# 73 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [73] loss: 0.981
# 74 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [74] loss: 0.979
# 75 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [75] loss: 0.974
# 76 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [76] loss: 0.970
# 77 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [77] loss: 0.968
# 78 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [78] loss: 0.964
# 79 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [79] loss: 0.960
# 80 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [80] loss: 0.956
# 81 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [81] loss: 0.950
# 82 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [82] loss: 0.936
# 83 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [83] loss: 0.924
# 84 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [84] loss: 0.914
# 85 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [85] loss: 0.904
# 86 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [86] loss: 0.902
# 87 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [87] loss: 0.889
# 88 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [88] loss: 0.880
# 89 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [89] loss: 0.873
# 90 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [90] loss: 0.868
# 91 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [91] loss: 0.863
# 92 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [92] loss: 0.857
# 93 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [93] loss: 0.850
# 94 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [94] loss: 0.844
# 95 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [95] loss: 0.839
# 96 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [96] loss: 0.837
# 97 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [97] loss: 0.831
# 98 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [98] loss: 0.830
# 99 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [99] loss: 0.824
# 100 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [100] loss: 0.819
# 101 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [101] loss: 0.810
# 102 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [102] loss: 0.799
# 103 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [103] loss: 0.787
# 104 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [104] loss: 0.779
# 105 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [105] loss: 0.772
# 106 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [106] loss: 0.765
# 107 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [107] loss: 0.755
# 108 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [108] loss: 0.748
# 109 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [109] loss: 0.744
# 110 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [110] loss: 0.736
# 111 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [111] loss: 0.729
# 112 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [112] loss: 0.724
# 113 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [113] loss: 0.718
# 114 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [114] loss: 0.713
# 115 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [115] loss: 0.708
# 116 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [116] loss: 0.704
# 117 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [117] loss: 0.699
# 118 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [118] loss: 0.695
# 119 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [119] loss: 0.689
# 120 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [120] loss: 0.685
# 121 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [121] loss: 0.679
# 122 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [122] loss: 0.671
# 123 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [123] loss: 0.664
# 124 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [124] loss: 0.657
# 125 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [125] loss: 0.656
# 126 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [126] loss: 0.647
# 127 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [127] loss: 0.637
# 128 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [128] loss: 0.631
# 129 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [129] loss: 0.626
# 130 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [130] loss: 0.621
# 131 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [131] loss: 0.616
# 132 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [132] loss: 0.612
# 133 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [133] loss: 0.606
# 134 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [134] loss: 0.601
# 135 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [135] loss: 0.597
# 136 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [136] loss: 0.593
# 137 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [137] loss: 0.588
# 138 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [138] loss: 0.585
# 139 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [139] loss: 0.581
# 140 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [140] loss: 0.577
# 141 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [141] loss: 0.570
# 142 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [142] loss: 0.564
# 143 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [143] loss: 0.559
# 144 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [144] loss: 0.553
# 145 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [145] loss: 0.548
# 146 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [146] loss: 0.543
# 147 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [147] loss: 0.542
# 148 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [148] loss: 0.534
# 149 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [149] loss: 0.529
# 150 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [150] loss: 0.525
# 151 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [151] loss: 0.521
# 152 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [152] loss: 0.517
# 153 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [153] loss: 0.514
# 154 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [154] loss: 0.509
# 155 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [155] loss: 0.507
# 156 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [156] loss: 0.503
# 157 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [157] loss: 0.498
# 158 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [158] loss: 0.494
# 159 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [159] loss: 0.490
# 160 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [160] loss: 0.488
# 161 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [161] loss: 0.483
# 162 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [162] loss: 0.480
# 163 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [163] loss: 0.473
# 164 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [164] loss: 0.468
# 165 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [165] loss: 0.467
# 166 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [166] loss: 0.460
# 167 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [167] loss: 0.454
# 168 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [168] loss: 0.451
# 169 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [169] loss: 0.447
# 170 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [170] loss: 0.444
# 171 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [171] loss: 0.438
# 172 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [172] loss: 0.435
# 173 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [173] loss: 0.434
# 174 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [174] loss: 0.429
# 175 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [175] loss: 0.425
# 176 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [176] loss: 0.422
# 177 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [177] loss: 0.419
# 178 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [178] loss: 0.416
# 179 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [179] loss: 0.416
# 180 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [180] loss: 0.412
# 181 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [181] loss: 0.406
# 182 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [182] loss: 0.398
# 183 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [183] loss: 0.387
# 184 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [184] loss: 0.382
# 185 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [185] loss: 0.376
# 186 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [186] loss: 0.369
# 187 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [187] loss: 0.364
# 188 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [188] loss: 0.361
# 189 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [189] loss: 0.355
# 190 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [190] loss: 0.351
# 191 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [191] loss: 0.347
# 192 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [192] loss: 0.344
# 193 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [193] loss: 0.341
# 194 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [194] loss: 0.338
# 195 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [195] loss: 0.334
# 196 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [196] loss: 0.331
# 197 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [197] loss: 0.328
# 198 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [198] loss: 0.326
# 199 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [199] loss: 0.322
# 200 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [200] loss: 0.320
# 201 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [201] loss: 0.309
# 202 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [202] loss: 0.303
# 203 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [203] loss: 0.297
# 204 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [204] loss: 0.291
# 205 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [205] loss: 0.285
# 206 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [206] loss: 0.281
# 207 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [207] loss: 0.276
# 208 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [208] loss: 0.271
# 209 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [209] loss: 0.265
# 210 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [210] loss: 0.260
# 211 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [211] loss: 0.256
# 212 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [212] loss: 0.253
# 213 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [213] loss: 0.250
# 214 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [214] loss: 0.246
# 215 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [215] loss: 0.240
# 216 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [216] loss: 0.237
# 217 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [217] loss: 0.235
# 218 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [218] loss: 0.231
# 219 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [219] loss: 0.227
# 220 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [220] loss: 0.224
# 221 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [221] loss: 0.212
# 222 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [222] loss: 0.208
# 223 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [223] loss: 0.206
# 224 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [224] loss: 0.200
# 225 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [225] loss: 0.198
# 226 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [226] loss: 0.193
# 227 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [227] loss: 0.192
# 228 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [228] loss: 0.188
# 229 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [229] loss: 0.186
# 230 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [230] loss: 0.182
# 231 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# ...
# 452 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [452] loss: 0.020
# 453 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [453] loss: 0.020
# 454 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [454] loss: 0.020
# 455 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [455] loss: 0.020
# 456 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [456] loss: 0.020
# 457 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [457] loss: 0.020
# 458 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [458] loss: 0.019
# 459 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [459] loss: 0.019
# 460 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [460] loss: 0.019
# 461 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [461] loss: 0.019
# 462 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [462] loss: 0.019
# 463 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [463] loss: 0.019
# 464 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [464] loss: 0.019
# 465 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [465] loss: 0.019
# 466 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [466] loss: 0.019
# 467 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [467] loss: 0.018
# 468 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [468] loss: 0.018
# 469 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [469] loss: 0.018
# 470 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [470] loss: 0.018
# 471 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [471] loss: 0.018
# 472 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [472] loss: 0.018
# 473 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [473] loss: 0.018
# 474 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [474] loss: 0.018
# 475 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [475] loss: 0.018
# 476 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [476] loss: 0.017
# 477 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [477] loss: 0.017
# 478 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [478] loss: 0.017
# 479 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [479] loss: 0.017
# 480 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [480] loss: 0.017
# 481 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [481] loss: 0.017
# 482 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [482] loss: 0.017
# 483 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [483] loss: 0.016
# 484 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [484] loss: 0.016
# 485 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [485] loss: 0.016
# 486 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [486] loss: 0.016
# 487 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [487] loss: 0.016
# 488 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [488] loss: 0.016
# 489 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [489] loss: 0.016
# 490 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [490] loss: 0.016
# 491 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [491] loss: 0.015
# 492 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [492] loss: 0.015
# 493 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [493] loss: 0.015
# 494 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [494] loss: 0.015
# 495 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [495] loss: 0.015
# 496 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [496] loss: 0.015
# 497 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [497] loss: 0.015
# 498 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [498] loss: 0.015
# 499 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [499] loss: 0.014
# 500 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [500] loss: 0.014
# 501 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [501] loss: 0.014
# 502 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [502] loss: 0.014
# 503 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [503] loss: 0.014
# 504 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [504] loss: 0.014
# 505 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [505] loss: 0.014
# 506 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [506] loss: 0.014
# 507 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [507] loss: 0.014
# 508 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [508] loss: 0.014
# 509 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [509] loss: 0.014
# 510 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [510] loss: 0.014
# 511 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [511] loss: 0.013
# 512 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [512] loss: 0.013
# 513 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [513] loss: 0.013
# 514 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [514] loss: 0.013
# 515 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [515] loss: 0.013
# 516 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [516] loss: 0.013
# 517 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [517] loss: 0.013
# 518 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [518] loss: 0.013
# 519 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [519] loss: 0.013
# 520 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [520] loss: 0.013
# 521 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [521] loss: 0.013
# 522 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [522] loss: 0.013
# 523 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [523] loss: 0.013
# 524 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [524] loss: 0.012
# 525 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [525] loss: 0.012
# 526 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [526] loss: 0.012
# 527 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [527] loss: 0.012
# 528 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [528] loss: 0.012
# 529 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [529] loss: 0.012
# 530 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [530] loss: 0.012
# 531 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [531] loss: 0.012
# 532 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [532] loss: 0.012
# 533 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [533] loss: 0.012
# 534 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [534] loss: 0.011
# 535 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [535] loss: 0.011
# 536 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [536] loss: 0.011
# 537 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [537] loss: 0.011
# 538 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [538] loss: 0.011
# 539 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [539] loss: 0.011
# 540 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [540] loss: 0.011
# 541 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [541] loss: 0.011
# 542 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [542] loss: 0.011
# 543 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [543] loss: 0.011
# 544 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [544] loss: 0.011
# 545 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [545] loss: 0.011
# 546 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [546] loss: 0.011
# 547 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [547] loss: 0.011
# 548 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [548] loss: 0.010
# 549 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [549] loss: 0.010
# 550 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [550] loss: 0.010
# 551 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [551] loss: 0.010
# 552 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [552] loss: 0.010
# 553 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [553] loss: 0.010
# 554 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [554] loss: 0.010
# 555 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [555] loss: 0.010
# 556 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [556] loss: 0.010
# 557 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [557] loss: 0.010
# Finished Training run 9
# Accuracy of the network on the 3000 train images: 99 %

# %%
a,b= full_analysis[0]
print(a)
# Out:
# 483

# %%
cnt=1
for epoch, analysis_data in full_analysis:
  analysis_data = np.array(analysis_data)
  # print("="*20+"run ",cnt,"="*20)
  
  plt.figure(figsize=(6,6))
  plt.plot(np.arange(0,epoch+2,1),analysis_data[:,0],label="ftpt")
  plt.plot(np.arange(0,epoch+2,1),analysis_data[:,1],label="ffpt")
  plt.plot(np.arange(0,epoch+2,1),analysis_data[:,2],label="ftpf")
  plt.plot(np.arange(0,epoch+2,1),analysis_data[:,3],label="ffpf")

  plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
  plt.title("Training trends for run "+str(cnt))
  plt.savefig(path+"what_where/every20/run"+str(cnt)+".png",bbox_inches="tight")
  plt.savefig(path+"what_where/every20/run"+str(cnt)+".pdf",bbox_inches="tight")
  cnt+=1

# %%
np.mean(np.array(FTPT_analysis),axis=0) #[9.43033333e+01, 5.68000000e+00, 1.66666667e-02, 0.00000000e+00]
# Out:
# array([8.38800000e+01, 1.60866667e+01, 3.00000000e-02, 3.33333333e-03])

# %%
FTPT_analysis.to_csv(path+"what_where/FTPT_analysis_every20"+".csv",index=False)

# %%
FTPT_analysis
# Out:
#         FTPT       FFPT      FTPF      FFPF
# 0  86.633333  13.366667  0.000000  0.000000
# 1  93.333333   6.600000  0.066667  0.000000
# 2  97.933333   2.000000  0.066667  0.000000
# 3  73.000000  27.000000  0.000000  0.000000
# 4  78.966667  20.933333  0.066667  0.033333
# 5  95.200000   4.800000  0.000000  0.000000
# 6  87.633333  12.333333  0.033333  0.000000
# 7  77.366667  22.633333  0.000000  0.000000
# 8  74.366667  25.633333  0.000000  0.000000
# 9  74.366667  25.566667  0.066667  0.000000
