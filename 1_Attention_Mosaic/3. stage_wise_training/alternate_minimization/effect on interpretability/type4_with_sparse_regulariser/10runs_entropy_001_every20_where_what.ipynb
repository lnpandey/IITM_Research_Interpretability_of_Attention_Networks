# %%
 import numpy as np
import pandas as pd

import torch
import torchvision
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms, utils
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

from matplotlib import pyplot as plt
# %matplotlib inline
from scipy.stats import entropy

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
path="/content/drive/MyDrive/Research/alternate_minimisation/type4_data/"

# %%
class MosaicDataset1(Dataset):
  """MosaicDataset dataset."""

  def __init__(self, mosaic_list, mosaic_label,fore_idx):
    """
      Args:
        csv_file (string): Path to the csv file with annotations.
        root_dir (string): Directory with all the images.
        transform (callable, optional): Optional transform to be applied
            on a sample.
    """
    self.mosaic = mosaic_list
    self.label = mosaic_label
    self.fore_idx = fore_idx
    
  def __len__(self):
    return len(self.label)

  def __getitem__(self, idx):
    return self.mosaic[idx] , self.label[idx] , self.fore_idx[idx]

# %%
class SyntheticDataset(Dataset):
  """MosaicDataset dataset."""

  def __init__(self, x, y):
    """
      Args:
        csv_file (string): Path to the csv file with annotations.
        root_dir (string): Directory with all the images.
        transform (callable, optional): Optional transform to be applied
            on a sample.
    """
    self.x = x
    self.y = y
    #self.fore_idx = fore_idx
    
  def __len__(self):
    return len(self.y)

  def __getitem__(self, idx):
    return self.x[idx] , self.y[idx] #, self.fore_idx[idx]

# %%
train_data = np.load(path+"train_type4_data.npy",allow_pickle=True)
test_data = np.load(path+"test_type4_data.npy",allow_pickle=True)
data = np.load(path+"type_4_data.npy",allow_pickle=True)

# %%
train_mosaic_list_of_images = train_data[0]["mosaic_list"]
train_mosaic_label = train_data[0]["mosaic_label"]
train_fore_idx = train_data[0]["fore_idx"]


test_mosaic_list_of_images = test_data[0]["mosaic_list"]
test_mosaic_label = test_data[0]["mosaic_label"]
test_fore_idx = test_data[0]["fore_idx"]
X = data[0]["X"]
Y = data[0]["Y"]

# %%
batch = 250
tr_msd = MosaicDataset1(train_mosaic_list_of_images, train_mosaic_label, train_fore_idx)
train_loader = DataLoader( tr_msd,batch_size= batch ,shuffle=True)

# %%
batch = 250
tst_msd = MosaicDataset1(test_mosaic_list_of_images, test_mosaic_label, test_fore_idx)
test_loader = DataLoader( tst_msd,batch_size= batch ,shuffle=True)

# %%
dset = SyntheticDataset(X,Y)
dtloader = DataLoader(dset,batch_size =batch,shuffle=True )

# %% [markdown]
# **Focus Net**

# %%
class Module1(nn.Module):
  def __init__(self):
    super(Module1, self).__init__()
    self.fc1 = nn.Linear(2, 100)
    self.fc2 = nn.Linear(100, 1)

  def forward(self, z):
    x = torch.zeros([batch,9],dtype=torch.float64)
    y = torch.zeros([batch,2], dtype=torch.float64)
    x,y = x.to("cuda"),y.to("cuda")
    for i in range(9):
      x[:,i] = self.helper(z[:,i])[:,0]
    
    log_x = F.log_softmax(x,dim=1)  
    x = F.softmax(x,dim=1)   # alphas
    

    for i in range(9):            
      x1 = x[:,i]          
      y = y + torch.mul(x1[:,None],z[:,i])
    return y , x , log_x
  
  def helper(self,x):
    x = F.relu(self.fc1(x))
    x = self.fc2(x)
    return x

# %% [markdown]
# **Classification Net**

# %%
 class Module2(nn.Module):
  def __init__(self):
    super(Module2, self).__init__()
    self.fc1 = nn.Linear(2, 100)
    self.fc2 = nn.Linear(100, 3)

  def forward(self,y):  
    y = F.relu(self.fc1(y))
    y = self.fc2(y)
    return y

# %%
criterion = nn.CrossEntropyLoss()
def my_cross_entropy(x, y,alpha,log_alpha,k):
    # log_prob = -1.0 * F.log_softmax(x, 1)
    # loss = log_prob.gather(1, y.unsqueeze(1))
    # loss = loss.mean()
    loss = criterion(x,y)
    
    #alpha = torch.clamp(alpha,min=1e-10)     
    
    b = -1.0* alpha * log_alpha
    b =  torch.mean(torch.sum(b,dim=1))
    closs = loss
    entropy = b 
    loss = (1-k)*loss + ((k)*b)
    return loss,closs,entropy

# %%
def calculate_attn_loss(dataloader,what,where,criter,k):
  what.eval()
  where.eval()
  r_loss = 0
  cc_loss = 0
  cc_entropy = 0
  alphas = []
  lbls = []
  pred = []
  fidices = []
  with torch.no_grad():
    for i, data in enumerate(dataloader, 0):
      inputs, labels,fidx = data
      lbls.append(labels)
      fidices.append(fidx)
      inputs = inputs.double()
      inputs, labels = inputs.to("cuda"),labels.to("cuda")
      avg,alpha,log_alpha = where(inputs)
      outputs = what(avg)
      _, predicted = torch.max(outputs.data, 1)
      pred.append(predicted.cpu().numpy())
      alphas.append(alpha.cpu().numpy())

      #ent = np.sum(entropy(alpha.cpu().detach().numpy(), base=2, axis=1))/batch
      # mx,_ = torch.max(alpha,1)
      # entropy = np.mean(-np.log2(mx.cpu().detach().numpy()))
      # print("entropy of batch", entropy)

      #loss = (1-k)*criter(outputs, labels) + k*ent
      loss,closs,entropy = my_cross_entropy(outputs,labels,alpha,log_alpha,k)
      r_loss += loss.item()
      cc_loss += closs.item()
      cc_entropy += entropy.item()

  alphas = np.concatenate(alphas,axis=0)
  pred = np.concatenate(pred,axis=0)
  lbls = np.concatenate(lbls,axis=0)
  fidices = np.concatenate(fidices,axis=0)
  #print(alphas.shape,pred.shape,lbls.shape,fidices.shape) 
  analysis = analyse_data(alphas,lbls,pred,fidices)
  return r_loss/i,cc_loss/i,cc_entropy/i,analysis

# %%
def analyse_data(alphas,lbls,predicted,f_idx):
    '''
       analysis data is created here
    '''
    batch = len(predicted)
    amth,alth,ftpt,ffpt,ftpf,ffpf = 0,0,0,0,0,0
    for j in range (batch):
      focus = np.argmax(alphas[j])
      if(alphas[j][focus] >= 0.5):
        amth +=1
      else:
        alth +=1
      if(focus == f_idx[j] and predicted[j] == lbls[j]):
        ftpt += 1
      elif(focus != f_idx[j] and predicted[j] == lbls[j]):
        ffpt +=1
      elif(focus == f_idx[j] and predicted[j] != lbls[j]):
        ftpf +=1
      elif(focus != f_idx[j] and predicted[j] != lbls[j]):
        ffpf +=1
    #print(sum(predicted==lbls),ftpt+ffpt)
    return [ftpt,ffpt,ftpf,ffpf,amth,alth]

# %%
number_runs = 10
full_analysis =[]
FTPT_analysis = pd.DataFrame(columns = ["FTPT","FFPT", "FTPF","FFPF"])
k = 0.001

every_what_epoch = 20

for n in range(number_runs):
  print("--"*40)
  
  # instantiate focus and classification Model
  torch.manual_seed(n)
  where = Module1().double()
  torch.manual_seed(n)
  what = Module2().double()

  where = where.to("cuda")
  what = what.to("cuda")



  # instantiate optimizer
  optimizer_where = optim.Adam(where.parameters(),lr =0.001)
  optimizer_what = optim.Adam(what.parameters(), lr=0.001)
  #criterion = nn.CrossEntropyLoss()
  acti = []
  analysis_data = []
  loss_curi = []
  epochs = 1000


  # calculate zeroth epoch loss and FTPT values
  running_loss ,_,_,anlys_data= calculate_attn_loss(train_loader,what,where,criterion,k)
  loss_curi.append(running_loss)
  analysis_data.append(anlys_data)

  print('epoch: [%d ] loss: %.3f' %(0,running_loss)) 

  # training starts 
  for epoch in range(epochs): # loop over the dataset multiple times
    ep_lossi = []
    running_loss = 0.0
    what.train()
    where.train()
    if ((epoch) % (every_what_epoch*2) ) <= every_what_epoch-1 :
      print(epoch+1,"updating where_net, what_net is freezed")
      print("--"*40)
    elif ((epoch) % (every_what_epoch*2)) > every_what_epoch-1 :
      print(epoch+1,"updating what_net, where_net is freezed")
      print("--"*40)
    for i, data in enumerate(train_loader, 0):
      # get the inputs
      inputs, labels,_ = data
      inputs = inputs.double()
      inputs, labels = inputs.to("cuda"),labels.to("cuda")

      # zero the parameter gradients
      optimizer_where.zero_grad()
      optimizer_what.zero_grad()
      
      # forward + backward + optimize
      avg, alpha,log_alpha = where(inputs)
      outputs = what(avg)

      my_loss,_,_ = my_cross_entropy(outputs,labels,alpha,log_alpha,k)

      # print statistics
      running_loss += my_loss.item()
      my_loss.backward()

      if ((epoch) % (every_what_epoch*2) ) <= every_what_epoch-1 :
        optimizer_where.step()
      elif ( (epoch) % (every_what_epoch*2)) > every_what_epoch-1 :
        optimizer_what.step()
        
      # optimizer_where.step()
      # optimizer_what.step()
    #break
    running_loss,ccloss,ccentropy,anls_data = calculate_attn_loss(train_loader,what,where,criterion,k)
    analysis_data.append(anls_data)
    print('epoch: [%d] loss: %.3f celoss: %.3f entropy: %.3f' %(epoch + 1,running_loss,ccloss,ccentropy)) 
    loss_curi.append(running_loss)   #loss per epoch
    if running_loss<=0.005:
      break
  print('Finished Training run ' +str(n))
  #break
  analysis_data = np.array(analysis_data)
  FTPT_analysis.loc[n] = analysis_data[-1,:4]/30
  full_analysis.append((epoch, analysis_data))
  correct = 0
  total = 0
  with torch.no_grad():
    for data in train_loader:
      images, labels,_ = data
      images = images.double()
      images, labels = images.to("cuda"), labels.to("cuda")
      avg, alpha,log_alpha = where(images)
      outputs  = what(avg)
      _, predicted = torch.max(outputs.data, 1)
      total += labels.size(0)
      correct += (predicted == labels).sum().item()

  print('Accuracy of the network on the 3000 train images: %d %%' % (  100 * correct / total))
# Out:
# Streaming output truncated to the last 5000 lines.
# --------------------------------------------------------------------------------
# epoch: [336] loss: 0.993 celoss: 0.994 entropy: 0.568
# 337 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [337] loss: 0.993 celoss: 0.993 entropy: 0.569
# 338 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [338] loss: 0.992 celoss: 0.993 entropy: 0.571
# 339 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [339] loss: 0.992 celoss: 0.993 entropy: 0.573
# 340 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [340] loss: 0.992 celoss: 0.992 entropy: 0.577
# 341 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [341] loss: 0.989 celoss: 0.989 entropy: 0.577
# 342 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [342] loss: 0.988 celoss: 0.989 entropy: 0.577
# 343 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [343] loss: 0.989 celoss: 0.990 entropy: 0.577
# 344 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [344] loss: 0.987 celoss: 0.988 entropy: 0.577
# 345 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [345] loss: 0.986 celoss: 0.987 entropy: 0.577
# 346 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [346] loss: 0.985 celoss: 0.986 entropy: 0.577
# 347 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [347] loss: 0.985 celoss: 0.986 entropy: 0.577
# 348 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [348] loss: 0.985 celoss: 0.985 entropy: 0.577
# 349 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [349] loss: 0.985 celoss: 0.985 entropy: 0.577
# 350 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [350] loss: 0.984 celoss: 0.984 entropy: 0.577
# 351 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [351] loss: 0.985 celoss: 0.985 entropy: 0.577
# 352 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [352] loss: 0.983 celoss: 0.984 entropy: 0.577
# 353 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [353] loss: 0.984 celoss: 0.984 entropy: 0.577
# 354 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [354] loss: 0.982 celoss: 0.982 entropy: 0.577
# 355 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [355] loss: 0.983 celoss: 0.984 entropy: 0.577
# 356 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [356] loss: 0.982 celoss: 0.982 entropy: 0.577
# 357 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [357] loss: 0.982 celoss: 0.982 entropy: 0.577
# 358 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [358] loss: 0.983 celoss: 0.983 entropy: 0.577
# 359 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [359] loss: 0.981 celoss: 0.981 entropy: 0.577
# 360 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [360] loss: 0.981 celoss: 0.981 entropy: 0.577
# 361 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [361] loss: 0.975 celoss: 0.976 entropy: 0.588
# 362 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [362] loss: 0.974 celoss: 0.974 entropy: 0.605
# 363 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [363] loss: 0.972 celoss: 0.973 entropy: 0.607
# 364 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [364] loss: 0.972 celoss: 0.972 entropy: 0.612
# 365 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [365] loss: 0.973 celoss: 0.974 entropy: 0.609
# 366 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [366] loss: 0.973 celoss: 0.974 entropy: 0.617
# 367 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [367] loss: 0.970 celoss: 0.970 entropy: 0.612
# 368 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [368] loss: 0.968 celoss: 0.969 entropy: 0.622
# 369 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [369] loss: 0.968 celoss: 0.969 entropy: 0.623
# 370 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [370] loss: 0.967 celoss: 0.968 entropy: 0.623
# 371 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [371] loss: 0.966 celoss: 0.966 entropy: 0.631
# 372 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [372] loss: 0.966 celoss: 0.966 entropy: 0.631
# 373 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [373] loss: 0.966 celoss: 0.966 entropy: 0.627
# 374 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [374] loss: 0.965 celoss: 0.965 entropy: 0.641
# 375 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [375] loss: 0.963 celoss: 0.963 entropy: 0.636
# 376 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [376] loss: 0.962 celoss: 0.963 entropy: 0.635
# 377 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [377] loss: 0.962 celoss: 0.963 entropy: 0.644
# 378 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [378] loss: 0.961 celoss: 0.961 entropy: 0.642
# 379 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [379] loss: 0.961 celoss: 0.961 entropy: 0.643
# 380 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [380] loss: 0.961 celoss: 0.961 entropy: 0.641
# 381 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [381] loss: 0.953 celoss: 0.953 entropy: 0.641
# 382 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [382] loss: 0.951 celoss: 0.951 entropy: 0.641
# 383 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [383] loss: 0.948 celoss: 0.949 entropy: 0.641
# 384 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [384] loss: 0.949 celoss: 0.949 entropy: 0.641
# 385 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [385] loss: 0.949 celoss: 0.950 entropy: 0.641
# 386 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [386] loss: 0.950 celoss: 0.950 entropy: 0.641
# 387 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [387] loss: 0.944 celoss: 0.944 entropy: 0.641
# 388 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [388] loss: 0.942 celoss: 0.942 entropy: 0.641
# 389 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [389] loss: 0.942 celoss: 0.942 entropy: 0.641
# 390 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [390] loss: 0.941 celoss: 0.942 entropy: 0.641
# 391 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [391] loss: 0.939 celoss: 0.939 entropy: 0.641
# 392 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [392] loss: 0.939 celoss: 0.939 entropy: 0.641
# 393 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [393] loss: 0.938 celoss: 0.938 entropy: 0.641
# 394 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [394] loss: 0.937 celoss: 0.937 entropy: 0.641
# 395 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [395] loss: 0.935 celoss: 0.935 entropy: 0.641
# 396 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [396] loss: 0.934 celoss: 0.934 entropy: 0.641
# 397 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [397] loss: 0.933 celoss: 0.933 entropy: 0.641
# 398 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [398] loss: 0.932 celoss: 0.932 entropy: 0.641
# 399 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [399] loss: 0.932 celoss: 0.932 entropy: 0.641
# 400 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [400] loss: 0.932 celoss: 0.932 entropy: 0.641
# 401 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [401] loss: 0.925 celoss: 0.925 entropy: 0.672
# 402 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [402] loss: 0.926 celoss: 0.926 entropy: 0.674
# 403 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [403] loss: 0.921 celoss: 0.921 entropy: 0.669
# 404 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [404] loss: 0.922 celoss: 0.922 entropy: 0.676
# 405 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [405] loss: 0.921 celoss: 0.921 entropy: 0.676
# 406 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [406] loss: 0.924 celoss: 0.924 entropy: 0.661
# 407 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [407] loss: 0.917 celoss: 0.917 entropy: 0.668
# 408 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [408] loss: 0.917 celoss: 0.917 entropy: 0.666
# 409 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [409] loss: 0.915 celoss: 0.916 entropy: 0.674
# 410 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [410] loss: 0.915 celoss: 0.915 entropy: 0.655
# 411 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [411] loss: 0.912 celoss: 0.912 entropy: 0.674
# 412 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [412] loss: 0.911 celoss: 0.911 entropy: 0.670
# 413 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [413] loss: 0.910 celoss: 0.910 entropy: 0.666
# 414 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [414] loss: 0.909 celoss: 0.910 entropy: 0.676
# 415 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [415] loss: 0.908 celoss: 0.908 entropy: 0.667
# 416 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [416] loss: 0.907 celoss: 0.907 entropy: 0.670
# 417 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [417] loss: 0.906 celoss: 0.906 entropy: 0.664
# 418 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [418] loss: 0.905 celoss: 0.906 entropy: 0.673
# 419 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [419] loss: 0.904 celoss: 0.905 entropy: 0.670
# 420 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [420] loss: 0.904 celoss: 0.905 entropy: 0.660
# 421 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [421] loss: 0.893 celoss: 0.893 entropy: 0.660
# 422 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [422] loss: 0.892 celoss: 0.892 entropy: 0.660
# 423 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [423] loss: 0.888 celoss: 0.888 entropy: 0.660
# 424 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [424] loss: 0.886 celoss: 0.887 entropy: 0.660
# 425 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [425] loss: 0.883 celoss: 0.884 entropy: 0.660
# 426 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [426] loss: 0.883 celoss: 0.883 entropy: 0.660
# 427 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [427] loss: 0.880 celoss: 0.880 entropy: 0.660
# 428 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [428] loss: 0.877 celoss: 0.878 entropy: 0.660
# 429 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [429] loss: 0.875 celoss: 0.875 entropy: 0.660
# 430 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [430] loss: 0.872 celoss: 0.872 entropy: 0.660
# 431 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [431] loss: 0.870 celoss: 0.870 entropy: 0.660
# 432 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [432] loss: 0.869 celoss: 0.869 entropy: 0.660
# 433 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [433] loss: 0.866 celoss: 0.866 entropy: 0.660
# 434 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [434] loss: 0.865 celoss: 0.866 entropy: 0.660
# 435 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [435] loss: 0.869 celoss: 0.870 entropy: 0.660
# 436 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [436] loss: 0.864 celoss: 0.864 entropy: 0.660
# 437 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [437] loss: 0.863 celoss: 0.863 entropy: 0.660
# 438 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [438] loss: 0.864 celoss: 0.865 entropy: 0.660
# 439 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [439] loss: 0.857 celoss: 0.857 entropy: 0.660
# 440 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [440] loss: 0.856 celoss: 0.856 entropy: 0.660
# 441 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [441] loss: 0.845 celoss: 0.845 entropy: 0.695
# 442 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [442] loss: 0.842 celoss: 0.842 entropy: 0.699
# 443 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [443] loss: 0.840 celoss: 0.840 entropy: 0.689
# 444 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [444] loss: 0.838 celoss: 0.838 entropy: 0.699
# 445 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [445] loss: 0.841 celoss: 0.842 entropy: 0.687
# 446 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [446] loss: 0.835 celoss: 0.835 entropy: 0.696
# 447 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [447] loss: 0.833 celoss: 0.833 entropy: 0.693
# 448 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [448] loss: 0.835 celoss: 0.835 entropy: 0.691
# 449 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [449] loss: 0.830 celoss: 0.830 entropy: 0.697
# 450 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [450] loss: 0.833 celoss: 0.833 entropy: 0.698
# 451 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [451] loss: 0.828 celoss: 0.828 entropy: 0.691
# 452 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [452] loss: 0.825 celoss: 0.825 entropy: 0.690
# 453 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [453] loss: 0.824 celoss: 0.824 entropy: 0.695
# 454 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [454] loss: 0.824 celoss: 0.824 entropy: 0.693
# 455 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [455] loss: 0.820 celoss: 0.821 entropy: 0.693
# 456 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [456] loss: 0.825 celoss: 0.825 entropy: 0.684
# 457 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [457] loss: 0.819 celoss: 0.819 entropy: 0.698
# 458 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [458] loss: 0.817 celoss: 0.817 entropy: 0.686
# 459 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [459] loss: 0.816 celoss: 0.816 entropy: 0.689
# 460 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [460] loss: 0.814 celoss: 0.814 entropy: 0.692
# 461 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [461] loss: 0.806 celoss: 0.806 entropy: 0.692
# 462 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [462] loss: 0.805 celoss: 0.805 entropy: 0.692
# 463 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [463] loss: 0.804 celoss: 0.804 entropy: 0.692
# 464 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [464] loss: 0.801 celoss: 0.801 entropy: 0.692
# 465 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [465] loss: 0.803 celoss: 0.803 entropy: 0.692
# 466 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [466] loss: 0.796 celoss: 0.796 entropy: 0.692
# 467 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [467] loss: 0.794 celoss: 0.794 entropy: 0.692
# 468 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [468] loss: 0.797 celoss: 0.797 entropy: 0.692
# 469 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [469] loss: 0.791 celoss: 0.791 entropy: 0.692
# 470 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [470] loss: 0.788 celoss: 0.788 entropy: 0.692
# 471 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [471] loss: 0.786 celoss: 0.786 entropy: 0.692
# 472 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [472] loss: 0.786 celoss: 0.786 entropy: 0.692
# 473 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [473] loss: 0.784 celoss: 0.784 entropy: 0.692
# 474 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [474] loss: 0.781 celoss: 0.781 entropy: 0.692
# 475 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [475] loss: 0.781 celoss: 0.782 entropy: 0.692
# 476 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [476] loss: 0.778 celoss: 0.779 entropy: 0.692
# 477 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [477] loss: 0.777 celoss: 0.777 entropy: 0.692
# 478 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [478] loss: 0.776 celoss: 0.776 entropy: 0.692
# 479 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [479] loss: 0.776 celoss: 0.776 entropy: 0.692
# 480 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [480] loss: 0.773 celoss: 0.773 entropy: 0.692
# 481 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [481] loss: 0.763 celoss: 0.763 entropy: 0.715
# 482 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [482] loss: 0.760 celoss: 0.760 entropy: 0.713
# 483 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [483] loss: 0.760 celoss: 0.760 entropy: 0.721
# 484 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [484] loss: 0.759 celoss: 0.759 entropy: 0.708
# 485 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [485] loss: 0.755 celoss: 0.755 entropy: 0.715
# 486 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [486] loss: 0.753 celoss: 0.753 entropy: 0.715
# 487 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [487] loss: 0.752 celoss: 0.752 entropy: 0.716
# 488 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [488] loss: 0.750 celoss: 0.750 entropy: 0.708
# 489 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [489] loss: 0.750 celoss: 0.750 entropy: 0.711
# 490 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [490] loss: 0.746 celoss: 0.746 entropy: 0.712
# 491 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [491] loss: 0.745 celoss: 0.745 entropy: 0.705
# 492 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [492] loss: 0.745 celoss: 0.745 entropy: 0.702
# 493 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [493] loss: 0.742 celoss: 0.742 entropy: 0.711
# 494 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [494] loss: 0.741 celoss: 0.741 entropy: 0.704
# 495 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [495] loss: 0.739 celoss: 0.739 entropy: 0.710
# 496 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [496] loss: 0.737 celoss: 0.737 entropy: 0.706
# 497 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [497] loss: 0.736 celoss: 0.736 entropy: 0.710
# 498 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [498] loss: 0.734 celoss: 0.734 entropy: 0.701
# 499 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [499] loss: 0.733 celoss: 0.733 entropy: 0.703
# 500 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [500] loss: 0.732 celoss: 0.732 entropy: 0.705
# 501 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [501] loss: 0.730 celoss: 0.730 entropy: 0.705
# 502 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [502] loss: 0.728 celoss: 0.728 entropy: 0.705
# 503 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [503] loss: 0.723 celoss: 0.723 entropy: 0.705
# 504 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [504] loss: 0.722 celoss: 0.722 entropy: 0.705
# 505 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [505] loss: 0.719 celoss: 0.719 entropy: 0.705
# 506 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [506] loss: 0.718 celoss: 0.718 entropy: 0.705
# 507 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [507] loss: 0.717 celoss: 0.717 entropy: 0.705
# 508 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [508] loss: 0.721 celoss: 0.721 entropy: 0.705
# 509 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [509] loss: 0.713 celoss: 0.713 entropy: 0.705
# 510 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [510] loss: 0.710 celoss: 0.710 entropy: 0.705
# 511 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [511] loss: 0.708 celoss: 0.708 entropy: 0.705
# 512 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [512] loss: 0.706 celoss: 0.706 entropy: 0.705
# 513 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [513] loss: 0.705 celoss: 0.705 entropy: 0.705
# 514 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [514] loss: 0.704 celoss: 0.704 entropy: 0.705
# 515 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [515] loss: 0.703 celoss: 0.703 entropy: 0.705
# 516 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [516] loss: 0.701 celoss: 0.701 entropy: 0.705
# 517 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [517] loss: 0.698 celoss: 0.698 entropy: 0.705
# 518 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [518] loss: 0.698 celoss: 0.697 entropy: 0.705
# 519 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [519] loss: 0.697 celoss: 0.697 entropy: 0.705
# 520 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [520] loss: 0.692 celoss: 0.692 entropy: 0.705
# 521 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [521] loss: 0.684 celoss: 0.684 entropy: 0.711
# 522 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [522] loss: 0.682 celoss: 0.682 entropy: 0.712
# 523 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [523] loss: 0.683 celoss: 0.683 entropy: 0.723
# 524 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [524] loss: 0.679 celoss: 0.679 entropy: 0.708
# 525 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [525] loss: 0.677 celoss: 0.677 entropy: 0.716
# 526 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [526] loss: 0.674 celoss: 0.674 entropy: 0.711
# 527 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [527] loss: 0.672 celoss: 0.672 entropy: 0.704
# 528 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [528] loss: 0.670 celoss: 0.670 entropy: 0.705
# 529 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [529] loss: 0.668 celoss: 0.668 entropy: 0.705
# 530 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [530] loss: 0.667 celoss: 0.667 entropy: 0.708
# 531 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [531] loss: 0.665 celoss: 0.665 entropy: 0.707
# 532 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [532] loss: 0.663 celoss: 0.663 entropy: 0.706
# 533 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [533] loss: 0.661 celoss: 0.661 entropy: 0.704
# 534 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [534] loss: 0.660 celoss: 0.660 entropy: 0.697
# 535 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [535] loss: 0.658 celoss: 0.658 entropy: 0.704
# 536 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [536] loss: 0.657 celoss: 0.657 entropy: 0.695
# 537 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [537] loss: 0.655 celoss: 0.655 entropy: 0.696
# 538 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [538] loss: 0.654 celoss: 0.654 entropy: 0.699
# 539 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [539] loss: 0.652 celoss: 0.652 entropy: 0.691
# 540 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [540] loss: 0.650 celoss: 0.650 entropy: 0.696
# 541 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [541] loss: 0.648 celoss: 0.648 entropy: 0.696
# 542 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [542] loss: 0.642 celoss: 0.642 entropy: 0.696
# 543 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [543] loss: 0.638 celoss: 0.638 entropy: 0.696
# 544 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [544] loss: 0.636 celoss: 0.636 entropy: 0.696
# 545 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [545] loss: 0.633 celoss: 0.633 entropy: 0.696
# 546 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [546] loss: 0.632 celoss: 0.632 entropy: 0.696
# 547 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [547] loss: 0.629 celoss: 0.629 entropy: 0.696
# 548 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [548] loss: 0.627 celoss: 0.627 entropy: 0.696
# 549 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [549] loss: 0.625 celoss: 0.625 entropy: 0.696
# 550 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [550] loss: 0.623 celoss: 0.623 entropy: 0.696
# 551 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [551] loss: 0.621 celoss: 0.621 entropy: 0.696
# 552 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [552] loss: 0.621 celoss: 0.620 entropy: 0.696
# 553 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [553] loss: 0.618 celoss: 0.618 entropy: 0.696
# 554 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [554] loss: 0.619 celoss: 0.619 entropy: 0.696
# 555 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [555] loss: 0.614 celoss: 0.614 entropy: 0.696
# 556 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [556] loss: 0.613 celoss: 0.613 entropy: 0.696
# 557 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [557] loss: 0.610 celoss: 0.610 entropy: 0.696
# 558 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [558] loss: 0.608 celoss: 0.608 entropy: 0.696
# 559 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [559] loss: 0.607 celoss: 0.607 entropy: 0.696
# 560 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [560] loss: 0.605 celoss: 0.604 entropy: 0.696
# 561 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [561] loss: 0.598 celoss: 0.598 entropy: 0.700
# 562 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [562] loss: 0.594 celoss: 0.594 entropy: 0.703
# 563 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [563] loss: 0.593 celoss: 0.593 entropy: 0.703
# 564 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [564] loss: 0.592 celoss: 0.592 entropy: 0.700
# 565 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [565] loss: 0.590 celoss: 0.590 entropy: 0.699
# 566 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [566] loss: 0.588 celoss: 0.588 entropy: 0.702
# 567 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [567] loss: 0.587 celoss: 0.587 entropy: 0.694
# 568 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [568] loss: 0.585 celoss: 0.585 entropy: 0.697
# 569 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [569] loss: 0.583 celoss: 0.583 entropy: 0.694
# 570 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [570] loss: 0.582 celoss: 0.582 entropy: 0.695
# 571 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [571] loss: 0.581 celoss: 0.581 entropy: 0.688
# 572 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [572] loss: 0.579 celoss: 0.579 entropy: 0.693
# 573 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [573] loss: 0.578 celoss: 0.578 entropy: 0.692
# 574 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [574] loss: 0.577 celoss: 0.577 entropy: 0.686
# 575 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [575] loss: 0.577 celoss: 0.577 entropy: 0.691
# 576 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [576] loss: 0.574 celoss: 0.574 entropy: 0.680
# 577 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [577] loss: 0.572 celoss: 0.572 entropy: 0.688
# 578 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [578] loss: 0.571 celoss: 0.571 entropy: 0.683
# 579 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [579] loss: 0.569 celoss: 0.569 entropy: 0.681
# 580 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [580] loss: 0.568 celoss: 0.568 entropy: 0.680
# 581 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [581] loss: 0.562 celoss: 0.562 entropy: 0.680
# 582 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [582] loss: 0.562 celoss: 0.562 entropy: 0.680
# 583 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [583] loss: 0.562 celoss: 0.562 entropy: 0.680
# 584 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [584] loss: 0.560 celoss: 0.559 entropy: 0.680
# 585 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [585] loss: 0.558 celoss: 0.558 entropy: 0.680
# 586 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [586] loss: 0.552 celoss: 0.552 entropy: 0.680
# 587 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [587] loss: 0.551 celoss: 0.551 entropy: 0.680
# 588 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [588] loss: 0.548 celoss: 0.548 entropy: 0.680
# 589 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [589] loss: 0.548 celoss: 0.547 entropy: 0.680
# 590 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [590] loss: 0.544 celoss: 0.544 entropy: 0.680
# 591 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [591] loss: 0.542 celoss: 0.542 entropy: 0.680
# 592 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [592] loss: 0.540 celoss: 0.540 entropy: 0.680
# 593 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [593] loss: 0.539 celoss: 0.539 entropy: 0.680
# 594 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [594] loss: 0.538 celoss: 0.538 entropy: 0.680
# 595 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [595] loss: 0.536 celoss: 0.536 entropy: 0.680
# 596 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [596] loss: 0.535 celoss: 0.534 entropy: 0.680
# 597 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [597] loss: 0.534 celoss: 0.534 entropy: 0.680
# 598 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [598] loss: 0.531 celoss: 0.531 entropy: 0.680
# 599 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [599] loss: 0.529 celoss: 0.529 entropy: 0.680
# 600 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [600] loss: 0.527 celoss: 0.527 entropy: 0.680
# 601 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [601] loss: 0.511 celoss: 0.511 entropy: 0.683
# 602 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [602] loss: 0.501 celoss: 0.500 entropy: 0.681
# 603 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [603] loss: 0.494 celoss: 0.493 entropy: 0.670
# ...
# --------------------------------------------------------------------------------
# epoch: [912] loss: 0.119 celoss: 0.118 entropy: 0.576
# 913 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [913] loss: 0.119 celoss: 0.118 entropy: 0.576
# 914 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [914] loss: 0.118 celoss: 0.118 entropy: 0.576
# 915 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [915] loss: 0.119 celoss: 0.119 entropy: 0.576
# 916 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [916] loss: 0.118 celoss: 0.118 entropy: 0.576
# 917 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [917] loss: 0.117 celoss: 0.116 entropy: 0.576
# 918 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [918] loss: 0.116 celoss: 0.116 entropy: 0.576
# 919 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [919] loss: 0.116 celoss: 0.115 entropy: 0.576
# 920 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [920] loss: 0.115 celoss: 0.115 entropy: 0.576
# 921 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [921] loss: 0.115 celoss: 0.114 entropy: 0.576
# 922 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [922] loss: 0.118 celoss: 0.117 entropy: 0.573
# 923 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [923] loss: 0.114 celoss: 0.114 entropy: 0.573
# 924 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [924] loss: 0.114 celoss: 0.114 entropy: 0.575
# 925 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [925] loss: 0.114 celoss: 0.114 entropy: 0.573
# 926 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [926] loss: 0.120 celoss: 0.119 entropy: 0.571
# 927 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [927] loss: 0.121 celoss: 0.120 entropy: 0.574
# 928 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [928] loss: 0.114 celoss: 0.113 entropy: 0.572
# 929 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [929] loss: 0.114 celoss: 0.113 entropy: 0.570
# 930 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [930] loss: 0.113 celoss: 0.113 entropy: 0.572
# 931 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [931] loss: 0.113 celoss: 0.113 entropy: 0.573
# 932 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [932] loss: 0.113 celoss: 0.113 entropy: 0.569
# 933 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [933] loss: 0.113 celoss: 0.113 entropy: 0.573
# 934 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [934] loss: 0.113 celoss: 0.112 entropy: 0.572
# 935 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [935] loss: 0.114 celoss: 0.113 entropy: 0.571
# 936 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [936] loss: 0.113 celoss: 0.113 entropy: 0.571
# 937 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [937] loss: 0.115 celoss: 0.115 entropy: 0.567
# 938 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [938] loss: 0.117 celoss: 0.117 entropy: 0.574
# 939 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [939] loss: 0.113 celoss: 0.112 entropy: 0.567
# 940 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [940] loss: 0.113 celoss: 0.112 entropy: 0.572
# 941 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [941] loss: 0.114 celoss: 0.114 entropy: 0.572
# 942 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [942] loss: 0.113 celoss: 0.113 entropy: 0.572
# 943 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [943] loss: 0.112 celoss: 0.112 entropy: 0.572
# 944 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [944] loss: 0.112 celoss: 0.112 entropy: 0.572
# 945 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [945] loss: 0.111 celoss: 0.110 entropy: 0.572
# 946 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [946] loss: 0.110 celoss: 0.110 entropy: 0.572
# 947 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [947] loss: 0.110 celoss: 0.109 entropy: 0.572
# 948 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [948] loss: 0.110 celoss: 0.110 entropy: 0.572
# 949 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [949] loss: 0.109 celoss: 0.109 entropy: 0.572
# 950 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [950] loss: 0.108 celoss: 0.108 entropy: 0.572
# 951 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [951] loss: 0.108 celoss: 0.107 entropy: 0.572
# 952 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [952] loss: 0.108 celoss: 0.108 entropy: 0.572
# 953 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [953] loss: 0.107 celoss: 0.107 entropy: 0.572
# 954 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [954] loss: 0.107 celoss: 0.106 entropy: 0.572
# 955 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [955] loss: 0.106 celoss: 0.106 entropy: 0.572
# 956 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [956] loss: 0.106 celoss: 0.106 entropy: 0.572
# 957 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [957] loss: 0.107 celoss: 0.107 entropy: 0.572
# 958 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [958] loss: 0.106 celoss: 0.106 entropy: 0.572
# 959 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [959] loss: 0.104 celoss: 0.104 entropy: 0.572
# 960 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [960] loss: 0.104 celoss: 0.104 entropy: 0.572
# 961 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [961] loss: 0.104 celoss: 0.103 entropy: 0.569
# 962 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [962] loss: 0.104 celoss: 0.103 entropy: 0.571
# 963 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [963] loss: 0.104 celoss: 0.103 entropy: 0.568
# 964 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [964] loss: 0.105 celoss: 0.104 entropy: 0.572
# 965 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [965] loss: 0.104 celoss: 0.103 entropy: 0.567
# 966 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [966] loss: 0.103 celoss: 0.103 entropy: 0.568
# 967 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [967] loss: 0.103 celoss: 0.103 entropy: 0.569
# 968 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [968] loss: 0.104 celoss: 0.104 entropy: 0.568
# 969 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [969] loss: 0.103 celoss: 0.103 entropy: 0.568
# 970 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [970] loss: 0.103 celoss: 0.102 entropy: 0.568
# 971 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [971] loss: 0.104 celoss: 0.103 entropy: 0.566
# 972 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [972] loss: 0.105 celoss: 0.104 entropy: 0.568
# 973 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [973] loss: 0.105 celoss: 0.105 entropy: 0.565
# 974 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [974] loss: 0.102 celoss: 0.102 entropy: 0.567
# 975 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [975] loss: 0.103 celoss: 0.103 entropy: 0.564
# 976 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [976] loss: 0.102 celoss: 0.102 entropy: 0.567
# 977 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [977] loss: 0.106 celoss: 0.106 entropy: 0.566
# 978 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [978] loss: 0.103 celoss: 0.102 entropy: 0.565
# 979 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [979] loss: 0.102 celoss: 0.101 entropy: 0.565
# 980 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [980] loss: 0.102 celoss: 0.102 entropy: 0.564
# 981 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [981] loss: 0.103 celoss: 0.102 entropy: 0.564
# 982 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [982] loss: 0.102 celoss: 0.102 entropy: 0.564
# 983 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [983] loss: 0.101 celoss: 0.100 entropy: 0.564
# 984 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [984] loss: 0.100 celoss: 0.100 entropy: 0.564
# 985 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [985] loss: 0.100 celoss: 0.100 entropy: 0.564
# 986 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [986] loss: 0.100 celoss: 0.100 entropy: 0.564
# 987 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [987] loss: 0.100 celoss: 0.099 entropy: 0.564
# 988 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [988] loss: 0.099 celoss: 0.098 entropy: 0.564
# 989 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [989] loss: 0.098 celoss: 0.098 entropy: 0.564
# 990 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [990] loss: 0.098 celoss: 0.097 entropy: 0.564
# 991 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [991] loss: 0.097 celoss: 0.097 entropy: 0.564
# 992 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [992] loss: 0.097 celoss: 0.096 entropy: 0.564
# 993 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [993] loss: 0.097 celoss: 0.096 entropy: 0.564
# 994 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [994] loss: 0.096 celoss: 0.096 entropy: 0.564
# 995 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [995] loss: 0.096 celoss: 0.095 entropy: 0.564
# 996 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [996] loss: 0.095 celoss: 0.095 entropy: 0.564
# 997 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [997] loss: 0.095 celoss: 0.095 entropy: 0.564
# 998 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [998] loss: 0.095 celoss: 0.094 entropy: 0.564
# 999 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [999] loss: 0.095 celoss: 0.094 entropy: 0.564
# 1000 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1000] loss: 0.094 celoss: 0.094 entropy: 0.564
# Finished Training run 9
# Accuracy of the network on the 3000 train images: 98 %

# %%
a,b= full_analysis[0]
print(a)
# Out:
# 999

# %%
cnt=1
for epoch, analysis_data in full_analysis:
  analysis_data = np.array(analysis_data)
  # print("="*20+"run ",cnt,"="*20)
  
  plt.figure(figsize=(6,6))
  plt.plot(np.arange(0,epoch+2,1),analysis_data[:,0],label="ftpt")
  plt.plot(np.arange(0,epoch+2,1),analysis_data[:,1],label="ffpt")
  plt.plot(np.arange(0,epoch+2,1),analysis_data[:,2],label="ftpf")
  plt.plot(np.arange(0,epoch+2,1),analysis_data[:,3],label="ffpf")

  plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
  plt.title("Training trends for run "+str(cnt))
  plt.savefig(path+"where_what/every20/run"+str(cnt)+".png",bbox_inches="tight")
  plt.savefig(path+"where_what/every20/run"+str(cnt)+".pdf",bbox_inches="tight")
  cnt+=1

# %%
np.mean(np.array(FTPT_analysis),axis=0) #array([87.85333333,  5.92      ,  0.        ,  6.22666667])
# Out:
# array([40.28666667, 36.43333333,  0.69666667, 22.58333333])

# %%
FTPT_analysis.to_csv(path+"where_what/FTPT_analysis_every20.csv",index=False)

# %%
FTPT_analysis
# Out:
#         FTPT       FFPT      FTPF       FFPF
# 0  20.566667  31.500000  0.466667  47.466667
# 1  66.733333  32.500000  0.533333   0.233333
# 2  66.600000  32.566667  0.533333   0.300000
# 3   2.700000  34.466667  0.000000  62.833333
# 4  46.066667  45.300000  2.800000   5.833333
# 5  33.266667  39.900000  0.100000  26.733333
# 6  18.900000  33.233333  0.600000  47.266667
# 7  34.066667  32.233333  0.000000  33.700000
# 8  65.433333  33.133333  0.900000   0.533333
# 9  48.533333  49.500000  1.033333   0.933333
