# %%
 import numpy as np
import pandas as pd

import torch
import torchvision
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms, utils
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

from matplotlib import pyplot as plt
# %matplotlib inline
from scipy.stats import entropy

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
path="/content/drive/MyDrive/Research/alternate_minimisation/type4_data/"

# %%
class MosaicDataset1(Dataset):
  """MosaicDataset dataset."""

  def __init__(self, mosaic_list, mosaic_label,fore_idx):
    """
      Args:
        csv_file (string): Path to the csv file with annotations.
        root_dir (string): Directory with all the images.
        transform (callable, optional): Optional transform to be applied
            on a sample.
    """
    self.mosaic = mosaic_list
    self.label = mosaic_label
    self.fore_idx = fore_idx
    
  def __len__(self):
    return len(self.label)

  def __getitem__(self, idx):
    return self.mosaic[idx] , self.label[idx] , self.fore_idx[idx]

# %%
class SyntheticDataset(Dataset):
  """MosaicDataset dataset."""

  def __init__(self, x, y):
    """
      Args:
        csv_file (string): Path to the csv file with annotations.
        root_dir (string): Directory with all the images.
        transform (callable, optional): Optional transform to be applied
            on a sample.
    """
    self.x = x
    self.y = y
    #self.fore_idx = fore_idx
    
  def __len__(self):
    return len(self.y)

  def __getitem__(self, idx):
    return self.x[idx] , self.y[idx] #, self.fore_idx[idx]

# %%
train_data = np.load(path+"train_type4_data.npy",allow_pickle=True)
test_data = np.load(path+"test_type4_data.npy",allow_pickle=True)
data = np.load(path+"type_4_data.npy",allow_pickle=True)

# %%
train_mosaic_list_of_images = train_data[0]["mosaic_list"]
train_mosaic_label = train_data[0]["mosaic_label"]
train_fore_idx = train_data[0]["fore_idx"]


test_mosaic_list_of_images = test_data[0]["mosaic_list"]
test_mosaic_label = test_data[0]["mosaic_label"]
test_fore_idx = test_data[0]["fore_idx"]
X = data[0]["X"]
Y = data[0]["Y"]

# %%
batch = 250
tr_msd = MosaicDataset1(train_mosaic_list_of_images, train_mosaic_label, train_fore_idx)
train_loader = DataLoader( tr_msd,batch_size= batch ,shuffle=True)

# %%
batch = 250
tst_msd = MosaicDataset1(test_mosaic_list_of_images, test_mosaic_label, test_fore_idx)
test_loader = DataLoader( tst_msd,batch_size= batch ,shuffle=True)

# %%
dset = SyntheticDataset(X,Y)
dtloader = DataLoader(dset,batch_size =batch,shuffle=True )

# %% [markdown]
# **Focus Net**

# %%
class Module1(nn.Module):
  def __init__(self):
    super(Module1, self).__init__()
    self.fc1 = nn.Linear(2, 100)
    self.fc2 = nn.Linear(100, 1)

  def forward(self, z):
    x = torch.zeros([batch,9],dtype=torch.float64)
    y = torch.zeros([batch,2], dtype=torch.float64)
    x,y = x.to("cuda"),y.to("cuda")
    for i in range(9):
      x[:,i] = self.helper(z[:,i])[:,0]
    
    log_x = F.log_softmax(x,dim=1)  
    x = F.softmax(x,dim=1)   # alphas
    

    for i in range(9):            
      x1 = x[:,i]          
      y = y + torch.mul(x1[:,None],z[:,i])
    return y , x , log_x
  
  def helper(self,x):
    x = F.relu(self.fc1(x))
    x = self.fc2(x)
    return x

# %% [markdown]
# **Classification Net**

# %%
 class Module2(nn.Module):
  def __init__(self):
    super(Module2, self).__init__()
    self.fc1 = nn.Linear(2, 100)
    self.fc2 = nn.Linear(100, 3)

  def forward(self,y):  
    y = F.relu(self.fc1(y))
    y = self.fc2(y)
    return y

# %%
criterion = nn.CrossEntropyLoss()
def my_cross_entropy(x, y,alpha,log_alpha,k):
    # log_prob = -1.0 * F.log_softmax(x, 1)
    # loss = log_prob.gather(1, y.unsqueeze(1))
    # loss = loss.mean()
    loss = criterion(x,y)
    
    #alpha = torch.clamp(alpha,min=1e-10)     
    
    b = -1.0* alpha * log_alpha
    b =  torch.mean(torch.sum(b,dim=1))
    closs = loss
    entropy = b 
    loss = (1-k)*loss + ((k)*b)
    return loss,closs,entropy

# %%
def calculate_attn_loss(dataloader,what,where,criter,k):
  what.eval()
  where.eval()
  r_loss = 0
  cc_loss = 0
  cc_entropy = 0
  alphas = []
  lbls = []
  pred = []
  fidices = []
  with torch.no_grad():
    for i, data in enumerate(dataloader, 0):
      inputs, labels,fidx = data
      lbls.append(labels)
      fidices.append(fidx)
      inputs = inputs.double()
      inputs, labels = inputs.to("cuda"),labels.to("cuda")
      avg,alpha,log_alpha = where(inputs)
      outputs = what(avg)
      _, predicted = torch.max(outputs.data, 1)
      pred.append(predicted.cpu().numpy())
      alphas.append(alpha.cpu().numpy())

      #ent = np.sum(entropy(alpha.cpu().detach().numpy(), base=2, axis=1))/batch
      # mx,_ = torch.max(alpha,1)
      # entropy = np.mean(-np.log2(mx.cpu().detach().numpy()))
      # print("entropy of batch", entropy)

      #loss = (1-k)*criter(outputs, labels) + k*ent
      loss,closs,entropy = my_cross_entropy(outputs,labels,alpha,log_alpha,k)
      r_loss += loss.item()
      cc_loss += closs.item()
      cc_entropy += entropy.item()

  alphas = np.concatenate(alphas,axis=0)
  pred = np.concatenate(pred,axis=0)
  lbls = np.concatenate(lbls,axis=0)
  fidices = np.concatenate(fidices,axis=0)
  #print(alphas.shape,pred.shape,lbls.shape,fidices.shape) 
  analysis = analyse_data(alphas,lbls,pred,fidices)
  return r_loss/i,cc_loss/i,cc_entropy/i,analysis

# %%
def analyse_data(alphas,lbls,predicted,f_idx):
    '''
       analysis data is created here
    '''
    batch = len(predicted)
    amth,alth,ftpt,ffpt,ftpf,ffpf = 0,0,0,0,0,0
    for j in range (batch):
      focus = np.argmax(alphas[j])
      if(alphas[j][focus] >= 0.5):
        amth +=1
      else:
        alth +=1
      if(focus == f_idx[j] and predicted[j] == lbls[j]):
        ftpt += 1
      elif(focus != f_idx[j] and predicted[j] == lbls[j]):
        ffpt +=1
      elif(focus == f_idx[j] and predicted[j] != lbls[j]):
        ftpf +=1
      elif(focus != f_idx[j] and predicted[j] != lbls[j]):
        ffpf +=1
    #print(sum(predicted==lbls),ftpt+ffpt)
    return [ftpt,ffpt,ftpf,ffpf,amth,alth]

# %%
number_runs = 10
full_analysis =[]
FTPT_analysis = pd.DataFrame(columns = ["FTPT","FFPT", "FTPF","FFPF"])
k = 0.001

every_what_epoch = 1

for n in range(number_runs):
  print("--"*40)
  
  # instantiate focus and classification Model
  torch.manual_seed(n)
  where = Module1().double()
  torch.manual_seed(n)
  what = Module2().double()

  where = where.to("cuda")
  what = what.to("cuda")



  # instantiate optimizer
  optimizer_where = optim.Adam(where.parameters(),lr =0.01)
  optimizer_what = optim.Adam(what.parameters(), lr=0.01)
  #criterion = nn.CrossEntropyLoss()
  acti = []
  analysis_data = []
  loss_curi = []
  epochs = 2000


  # calculate zeroth epoch loss and FTPT values
  running_loss ,_,_,anlys_data= calculate_attn_loss(train_loader,what,where,criterion,k)
  loss_curi.append(running_loss)
  analysis_data.append(anlys_data)

  print('epoch: [%d ] loss: %.3f' %(0,running_loss)) 

  # training starts 
  for epoch in range(epochs): # loop over the dataset multiple times
    ep_lossi = []
    running_loss = 0.0
    what.train()
    where.train()
    if ((epoch) % (every_what_epoch*2) ) <= every_what_epoch-1 :
      print(epoch+1,"updating where_net, what_net is freezed")
      print("--"*40)
    elif ((epoch) % (every_what_epoch*2)) > every_what_epoch-1 :
      print(epoch+1,"updating what_net, where_net is freezed")
      print("--"*40)
    for i, data in enumerate(train_loader, 0):
      # get the inputs
      inputs, labels,_ = data
      inputs = inputs.double()
      inputs, labels = inputs.to("cuda"),labels.to("cuda")

      # zero the parameter gradients
      optimizer_where.zero_grad()
      optimizer_what.zero_grad()
      
      # forward + backward + optimize
      avg, alpha,log_alpha = where(inputs)
      outputs = what(avg)

      my_loss,_,_ = my_cross_entropy(outputs,labels,alpha,log_alpha,k)

      # print statistics
      running_loss += my_loss.item()
      my_loss.backward()

      if ((epoch) % (every_what_epoch*2) ) <= every_what_epoch-1 :
        optimizer_where.step()
      elif ( (epoch) % (every_what_epoch*2)) > every_what_epoch-1 :
        optimizer_what.step()
        
      # optimizer_where.step()
      # optimizer_what.step()
    #break
    running_loss,ccloss,ccentropy,anls_data = calculate_attn_loss(train_loader,what,where,criterion,k)
    analysis_data.append(anls_data)
    print('epoch: [%d] loss: %.3f celoss: %.3f entropy: %.3f' %(epoch + 1,running_loss,ccloss,ccentropy)) 
    loss_curi.append(running_loss)   #loss per epoch
    if running_loss<=0.005:
      break
  print('Finished Training run ' +str(n))
  #break
  analysis_data = np.array(analysis_data)
  FTPT_analysis.loc[n] = analysis_data[-1,:4]/30
  full_analysis.append((epoch, analysis_data))
  correct = 0
  total = 0
  with torch.no_grad():
    for data in train_loader:
      images, labels,_ = data
      images = images.double()
      images, labels = images.to("cuda"), labels.to("cuda")
      avg, alpha,log_alpha = where(images)
      outputs  = what(avg)
      _, predicted = torch.max(outputs.data, 1)
      total += labels.size(0)
      correct += (predicted == labels).sum().item()

  print('Accuracy of the network on the 3000 train images: %d %%' % (  100 * correct / total))
# Out:
# Streaming output truncated to the last 5000 lines.
# epoch: [1109] loss: 0.498 celoss: 0.498 entropy: 0.683
# 1110 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1110] loss: 0.499 celoss: 0.499 entropy: 0.683
# 1111 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1111] loss: 0.499 celoss: 0.499 entropy: 0.684
# 1112 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1112] loss: 0.505 celoss: 0.504 entropy: 0.684
# 1113 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1113] loss: 0.504 celoss: 0.504 entropy: 0.699
# 1114 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1114] loss: 0.500 celoss: 0.500 entropy: 0.699
# 1115 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1115] loss: 0.500 celoss: 0.500 entropy: 0.696
# 1116 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1116] loss: 0.499 celoss: 0.498 entropy: 0.696
# 1117 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1117] loss: 0.499 celoss: 0.498 entropy: 0.688
# 1118 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1118] loss: 0.498 celoss: 0.498 entropy: 0.688
# 1119 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1119] loss: 0.499 celoss: 0.498 entropy: 0.687
# 1120 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1120] loss: 0.498 celoss: 0.498 entropy: 0.687
# 1121 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1121] loss: 0.498 celoss: 0.498 entropy: 0.685
# 1122 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1122] loss: 0.498 celoss: 0.498 entropy: 0.685
# 1123 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1123] loss: 0.498 celoss: 0.498 entropy: 0.685
# 1124 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1124] loss: 0.499 celoss: 0.499 entropy: 0.685
# 1125 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1125] loss: 0.499 celoss: 0.499 entropy: 0.683
# 1126 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1126] loss: 0.499 celoss: 0.499 entropy: 0.683
# 1127 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1127] loss: 0.499 celoss: 0.499 entropy: 0.685
# 1128 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1128] loss: 0.498 celoss: 0.498 entropy: 0.685
# 1129 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1129] loss: 0.498 celoss: 0.498 entropy: 0.687
# 1130 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1130] loss: 0.499 celoss: 0.498 entropy: 0.687
# 1131 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1131] loss: 0.499 celoss: 0.498 entropy: 0.687
# 1132 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1132] loss: 0.498 celoss: 0.498 entropy: 0.687
# 1133 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1133] loss: 0.498 celoss: 0.498 entropy: 0.688
# 1134 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1134] loss: 0.498 celoss: 0.498 entropy: 0.688
# 1135 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1135] loss: 0.498 celoss: 0.498 entropy: 0.688
# 1136 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1136] loss: 0.498 celoss: 0.498 entropy: 0.688
# 1137 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1137] loss: 0.498 celoss: 0.498 entropy: 0.685
# 1138 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1138] loss: 0.498 celoss: 0.498 entropy: 0.685
# 1139 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1139] loss: 0.498 celoss: 0.498 entropy: 0.685
# 1140 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1140] loss: 0.498 celoss: 0.498 entropy: 0.685
# 1141 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1141] loss: 0.498 celoss: 0.498 entropy: 0.683
# 1142 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1142] loss: 0.498 celoss: 0.498 entropy: 0.683
# 1143 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1143] loss: 0.498 celoss: 0.498 entropy: 0.682
# 1144 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1144] loss: 0.499 celoss: 0.498 entropy: 0.682
# 1145 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1145] loss: 0.499 celoss: 0.498 entropy: 0.682
# 1146 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1146] loss: 0.499 celoss: 0.498 entropy: 0.682
# 1147 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1147] loss: 0.499 celoss: 0.498 entropy: 0.681
# 1148 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1148] loss: 0.498 celoss: 0.498 entropy: 0.681
# 1149 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1149] loss: 0.498 celoss: 0.498 entropy: 0.681
# 1150 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1150] loss: 0.499 celoss: 0.499 entropy: 0.681
# 1151 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1151] loss: 0.499 celoss: 0.499 entropy: 0.680
# 1152 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1152] loss: 0.498 celoss: 0.498 entropy: 0.680
# 1153 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1153] loss: 0.498 celoss: 0.498 entropy: 0.680
# 1154 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1154] loss: 0.498 celoss: 0.498 entropy: 0.680
# 1155 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1155] loss: 0.498 celoss: 0.498 entropy: 0.679
# 1156 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1156] loss: 0.498 celoss: 0.498 entropy: 0.679
# 1157 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1157] loss: 0.498 celoss: 0.498 entropy: 0.678
# 1158 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1158] loss: 0.499 celoss: 0.498 entropy: 0.678
# 1159 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1159] loss: 0.499 celoss: 0.498 entropy: 0.677
# 1160 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1160] loss: 0.498 celoss: 0.498 entropy: 0.677
# 1161 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1161] loss: 0.498 celoss: 0.498 entropy: 0.675
# 1162 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1162] loss: 0.498 celoss: 0.498 entropy: 0.675
# 1163 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1163] loss: 0.498 celoss: 0.498 entropy: 0.673
# 1164 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1164] loss: 0.498 celoss: 0.498 entropy: 0.673
# 1165 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1165] loss: 0.498 celoss: 0.498 entropy: 0.672
# 1166 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1166] loss: 0.498 celoss: 0.498 entropy: 0.672
# 1167 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1167] loss: 0.498 celoss: 0.498 entropy: 0.671
# 1168 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1168] loss: 0.498 celoss: 0.498 entropy: 0.671
# 1169 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1169] loss: 0.498 celoss: 0.498 entropy: 0.671
# 1170 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1170] loss: 0.498 celoss: 0.498 entropy: 0.671
# 1171 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1171] loss: 0.498 celoss: 0.498 entropy: 0.671
# 1172 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1172] loss: 0.498 celoss: 0.498 entropy: 0.671
# 1173 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1173] loss: 0.498 celoss: 0.498 entropy: 0.670
# 1174 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1174] loss: 0.498 celoss: 0.498 entropy: 0.670
# 1175 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1175] loss: 0.498 celoss: 0.498 entropy: 0.668
# 1176 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1176] loss: 0.498 celoss: 0.498 entropy: 0.668
# 1177 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1177] loss: 0.498 celoss: 0.498 entropy: 0.667
# 1178 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1178] loss: 0.498 celoss: 0.498 entropy: 0.667
# 1179 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1179] loss: 0.498 celoss: 0.498 entropy: 0.668
# 1180 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1180] loss: 0.498 celoss: 0.498 entropy: 0.668
# 1181 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1181] loss: 0.498 celoss: 0.498 entropy: 0.670
# 1182 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1182] loss: 0.499 celoss: 0.498 entropy: 0.670
# 1183 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1183] loss: 0.499 celoss: 0.498 entropy: 0.673
# 1184 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1184] loss: 0.498 celoss: 0.498 entropy: 0.673
# 1185 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1185] loss: 0.498 celoss: 0.498 entropy: 0.673
# 1186 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1186] loss: 0.498 celoss: 0.498 entropy: 0.673
# 1187 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1187] loss: 0.498 celoss: 0.498 entropy: 0.672
# 1188 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1188] loss: 0.498 celoss: 0.498 entropy: 0.672
# 1189 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1189] loss: 0.498 celoss: 0.498 entropy: 0.671
# 1190 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1190] loss: 0.498 celoss: 0.498 entropy: 0.671
# 1191 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1191] loss: 0.498 celoss: 0.498 entropy: 0.670
# 1192 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1192] loss: 0.499 celoss: 0.498 entropy: 0.670
# 1193 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1193] loss: 0.499 celoss: 0.498 entropy: 0.669
# 1194 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1194] loss: 0.498 celoss: 0.498 entropy: 0.669
# 1195 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1195] loss: 0.498 celoss: 0.498 entropy: 0.669
# 1196 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1196] loss: 0.498 celoss: 0.498 entropy: 0.669
# 1197 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1197] loss: 0.498 celoss: 0.498 entropy: 0.668
# 1198 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1198] loss: 0.498 celoss: 0.498 entropy: 0.668
# 1199 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1199] loss: 0.498 celoss: 0.498 entropy: 0.667
# 1200 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1200] loss: 0.498 celoss: 0.498 entropy: 0.667
# 1201 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1201] loss: 0.498 celoss: 0.498 entropy: 0.668
# 1202 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1202] loss: 0.498 celoss: 0.498 entropy: 0.668
# 1203 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1203] loss: 0.498 celoss: 0.498 entropy: 0.667
# 1204 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1204] loss: 0.498 celoss: 0.498 entropy: 0.667
# 1205 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1205] loss: 0.498 celoss: 0.498 entropy: 0.666
# 1206 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1206] loss: 0.498 celoss: 0.498 entropy: 0.666
# 1207 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1207] loss: 0.498 celoss: 0.498 entropy: 0.664
# 1208 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1208] loss: 0.498 celoss: 0.498 entropy: 0.664
# 1209 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1209] loss: 0.498 celoss: 0.498 entropy: 0.663
# 1210 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1210] loss: 0.498 celoss: 0.498 entropy: 0.663
# 1211 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1211] loss: 0.498 celoss: 0.498 entropy: 0.663
# 1212 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1212] loss: 0.498 celoss: 0.498 entropy: 0.663
# 1213 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1213] loss: 0.498 celoss: 0.498 entropy: 0.662
# 1214 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1214] loss: 0.498 celoss: 0.498 entropy: 0.662
# 1215 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1215] loss: 0.498 celoss: 0.498 entropy: 0.661
# 1216 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1216] loss: 0.498 celoss: 0.498 entropy: 0.661
# 1217 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1217] loss: 0.498 celoss: 0.498 entropy: 0.660
# 1218 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1218] loss: 0.499 celoss: 0.498 entropy: 0.660
# 1219 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1219] loss: 0.499 celoss: 0.498 entropy: 0.660
# 1220 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1220] loss: 0.498 celoss: 0.498 entropy: 0.660
# 1221 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1221] loss: 0.498 celoss: 0.498 entropy: 0.659
# 1222 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1222] loss: 0.499 celoss: 0.498 entropy: 0.659
# 1223 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1223] loss: 0.499 celoss: 0.498 entropy: 0.656
# 1224 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1224] loss: 0.499 celoss: 0.499 entropy: 0.656
# 1225 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1225] loss: 0.499 celoss: 0.499 entropy: 0.665
# 1226 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1226] loss: 0.502 celoss: 0.502 entropy: 0.665
# 1227 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1227] loss: 0.502 celoss: 0.502 entropy: 0.666
# 1228 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1228] loss: 0.499 celoss: 0.499 entropy: 0.666
# 1229 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1229] loss: 0.499 celoss: 0.498 entropy: 0.689
# 1230 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1230] loss: 0.503 celoss: 0.503 entropy: 0.689
# 1231 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1231] loss: 0.503 celoss: 0.502 entropy: 0.695
# 1232 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1232] loss: 0.500 celoss: 0.500 entropy: 0.695
# 1233 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1233] loss: 0.500 celoss: 0.500 entropy: 0.696
# 1234 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1234] loss: 0.499 celoss: 0.499 entropy: 0.696
# 1235 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1235] loss: 0.499 celoss: 0.499 entropy: 0.697
# 1236 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1236] loss: 0.498 celoss: 0.498 entropy: 0.697
# 1237 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1237] loss: 0.498 celoss: 0.498 entropy: 0.697
# 1238 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1238] loss: 0.503 celoss: 0.503 entropy: 0.697
# 1239 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1239] loss: 0.503 celoss: 0.503 entropy: 0.704
# 1240 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1240] loss: 0.499 celoss: 0.499 entropy: 0.704
# 1241 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1241] loss: 0.499 celoss: 0.499 entropy: 0.700
# 1242 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1242] loss: 0.499 celoss: 0.499 entropy: 0.700
# 1243 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1243] loss: 0.499 celoss: 0.499 entropy: 0.698
# 1244 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1244] loss: 0.499 celoss: 0.499 entropy: 0.698
# 1245 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1245] loss: 0.499 celoss: 0.499 entropy: 0.694
# 1246 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1246] loss: 0.499 celoss: 0.498 entropy: 0.694
# 1247 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1247] loss: 0.499 celoss: 0.498 entropy: 0.691
# 1248 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1248] loss: 0.498 celoss: 0.498 entropy: 0.691
# 1249 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1249] loss: 0.498 celoss: 0.498 entropy: 0.689
# 1250 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1250] loss: 0.498 celoss: 0.498 entropy: 0.689
# 1251 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1251] loss: 0.498 celoss: 0.498 entropy: 0.687
# 1252 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1252] loss: 0.498 celoss: 0.498 entropy: 0.687
# 1253 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1253] loss: 0.498 celoss: 0.498 entropy: 0.686
# 1254 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1254] loss: 0.498 celoss: 0.498 entropy: 0.686
# 1255 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1255] loss: 0.498 celoss: 0.498 entropy: 0.685
# 1256 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1256] loss: 0.498 celoss: 0.498 entropy: 0.685
# 1257 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1257] loss: 0.498 celoss: 0.498 entropy: 0.683
# 1258 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1258] loss: 0.498 celoss: 0.498 entropy: 0.683
# 1259 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1259] loss: 0.498 celoss: 0.498 entropy: 0.681
# 1260 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1260] loss: 0.498 celoss: 0.498 entropy: 0.681
# 1261 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1261] loss: 0.498 celoss: 0.498 entropy: 0.680
# 1262 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1262] loss: 0.498 celoss: 0.498 entropy: 0.680
# 1263 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1263] loss: 0.498 celoss: 0.498 entropy: 0.678
# 1264 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1264] loss: 0.499 celoss: 0.498 entropy: 0.678
# 1265 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1265] loss: 0.498 celoss: 0.498 entropy: 0.676
# 1266 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1266] loss: 0.498 celoss: 0.498 entropy: 0.676
# 1267 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1267] loss: 0.498 celoss: 0.498 entropy: 0.676
# 1268 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1268] loss: 0.498 celoss: 0.498 entropy: 0.676
# 1269 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1269] loss: 0.498 celoss: 0.498 entropy: 0.675
# 1270 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1270] loss: 0.498 celoss: 0.498 entropy: 0.675
# 1271 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1271] loss: 0.498 celoss: 0.498 entropy: 0.674
# 1272 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1272] loss: 0.498 celoss: 0.498 entropy: 0.674
# 1273 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1273] loss: 0.498 celoss: 0.498 entropy: 0.674
# 1274 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1274] loss: 0.498 celoss: 0.498 entropy: 0.674
# 1275 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1275] loss: 0.498 celoss: 0.498 entropy: 0.671
# 1276 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1276] loss: 0.499 celoss: 0.499 entropy: 0.671
# 1277 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1277] loss: 0.499 celoss: 0.499 entropy: 0.678
# 1278 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1278] loss: 0.501 celoss: 0.501 entropy: 0.678
# 1279 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1279] loss: 0.501 celoss: 0.501 entropy: 0.695
# 1280 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1280] loss: 0.537 celoss: 0.537 entropy: 0.695
# 1281 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1281] loss: 0.528 celoss: 0.528 entropy: 0.705
# 1282 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1282] loss: 0.499 celoss: 0.499 entropy: 0.705
# 1283 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1283] loss: 0.499 celoss: 0.499 entropy: 0.709
# 1284 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1284] loss: 0.499 celoss: 0.498 entropy: 0.709
# 1285 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1285] loss: 0.499 celoss: 0.499 entropy: 0.692
# 1286 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1286] loss: 0.499 celoss: 0.499 entropy: 0.692
# 1287 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1287] loss: 0.499 celoss: 0.499 entropy: 0.723
# 1288 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1288] loss: 0.499 celoss: 0.498 entropy: 0.723
# 1289 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1289] loss: 0.499 celoss: 0.498 entropy: 0.740
# 1290 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1290] loss: 0.498 celoss: 0.498 entropy: 0.740
# 1291 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1291] loss: 0.498 celoss: 0.498 entropy: 0.741
# 1292 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1292] loss: 0.499 celoss: 0.498 entropy: 0.741
# 1293 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1293] loss: 0.499 celoss: 0.498 entropy: 0.743
# 1294 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1294] loss: 0.498 celoss: 0.498 entropy: 0.743
# 1295 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1295] loss: 0.498 celoss: 0.498 entropy: 0.732
# 1296 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1296] loss: 0.498 celoss: 0.498 entropy: 0.732
# 1297 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1297] loss: 0.498 celoss: 0.498 entropy: 0.725
# 1298 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1298] loss: 0.498 celoss: 0.498 entropy: 0.725
# 1299 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1299] loss: 0.498 celoss: 0.498 entropy: 0.719
# 1300 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1300] loss: 0.498 celoss: 0.498 entropy: 0.719
# 1301 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1301] loss: 0.498 celoss: 0.498 entropy: 0.715
# 1302 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1302] loss: 0.499 celoss: 0.498 entropy: 0.715
# 1303 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1303] loss: 0.499 celoss: 0.498 entropy: 0.711
# 1304 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1304] loss: 0.499 celoss: 0.498 entropy: 0.711
# 1305 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1305] loss: 0.499 celoss: 0.498 entropy: 0.707
# 1306 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1306] loss: 0.499 celoss: 0.498 entropy: 0.707
# 1307 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1307] loss: 0.499 celoss: 0.498 entropy: 0.703
# 1308 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1308] loss: 0.499 celoss: 0.499 entropy: 0.703
# 1309 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1309] loss: 0.499 celoss: 0.499 entropy: 0.700
# 1310 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1310] loss: 0.499 celoss: 0.498 entropy: 0.700
# 1311 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1311] loss: 0.499 celoss: 0.498 entropy: 0.697
# 1312 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1312] loss: 0.499 celoss: 0.499 entropy: 0.697
# 1313 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1313] loss: 0.499 celoss: 0.499 entropy: 0.695
# 1314 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1314] loss: 0.498 celoss: 0.498 entropy: 0.695
# 1315 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1315] loss: 0.498 celoss: 0.498 entropy: 0.693
# 1316 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1316] loss: 0.498 celoss: 0.498 entropy: 0.693
# 1317 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1317] loss: 0.498 celoss: 0.498 entropy: 0.691
# 1318 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1318] loss: 0.498 celoss: 0.498 entropy: 0.691
# 1319 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1319] loss: 0.498 celoss: 0.498 entropy: 0.691
# 1320 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1320] loss: 0.498 celoss: 0.498 entropy: 0.691
# 1321 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1321] loss: 0.498 celoss: 0.498 entropy: 0.689
# 1322 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1322] loss: 0.498 celoss: 0.498 entropy: 0.689
# 1323 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1323] loss: 0.498 celoss: 0.498 entropy: 0.688
# 1324 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1324] loss: 0.499 celoss: 0.498 entropy: 0.688
# 1325 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1325] loss: 0.499 celoss: 0.498 entropy: 0.687
# 1326 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1326] loss: 0.499 celoss: 0.498 entropy: 0.687
# 1327 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1327] loss: 0.499 celoss: 0.498 entropy: 0.686
# 1328 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1328] loss: 0.498 celoss: 0.498 entropy: 0.686
# 1329 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1329] loss: 0.498 celoss: 0.498 entropy: 0.685
# 1330 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1330] loss: 0.498 celoss: 0.498 entropy: 0.685
# 1331 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1331] loss: 0.498 celoss: 0.498 entropy: 0.683
# 1332 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1332] loss: 0.498 celoss: 0.498 entropy: 0.683
# 1333 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1333] loss: 0.498 celoss: 0.498 entropy: 0.682
# 1334 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1334] loss: 0.498 celoss: 0.498 entropy: 0.682
# 1335 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1335] loss: 0.498 celoss: 0.498 entropy: 0.680
# 1336 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1336] loss: 0.498 celoss: 0.498 entropy: 0.680
# 1337 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1337] loss: 0.498 celoss: 0.498 entropy: 0.679
# 1338 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1338] loss: 0.498 celoss: 0.498 entropy: 0.679
# 1339 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1339] loss: 0.498 celoss: 0.498 entropy: 0.679
# 1340 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1340] loss: 0.498 celoss: 0.498 entropy: 0.679
# 1341 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1341] loss: 0.498 celoss: 0.498 entropy: 0.678
# 1342 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1342] loss: 0.498 celoss: 0.498 entropy: 0.678
# 1343 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1343] loss: 0.498 celoss: 0.498 entropy: 0.678
# 1344 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1344] loss: 0.498 celoss: 0.498 entropy: 0.678
# 1345 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1345] loss: 0.498 celoss: 0.498 entropy: 0.679
# 1346 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1346] loss: 0.498 celoss: 0.498 entropy: 0.679
# 1347 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1347] loss: 0.498 celoss: 0.498 entropy: 0.678
# 1348 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1348] loss: 0.498 celoss: 0.498 entropy: 0.678
# 1349 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1349] loss: 0.498 celoss: 0.498 entropy: 0.677
# 1350 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1350] loss: 0.498 celoss: 0.498 entropy: 0.677
# 1351 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1351] loss: 0.498 celoss: 0.498 entropy: 0.676
# 1352 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1352] loss: 0.498 celoss: 0.498 entropy: 0.676
# 1353 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1353] loss: 0.498 celoss: 0.498 entropy: 0.676
# 1354 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1354] loss: 0.499 celoss: 0.499 entropy: 0.676
# 1355 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1355] loss: 0.499 celoss: 0.499 entropy: 0.674
# 1356 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1356] loss: 0.498 celoss: 0.498 entropy: 0.674
# 1357 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1357] loss: 0.498 celoss: 0.498 entropy: 0.674
# 1358 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1358] loss: 0.498 celoss: 0.498 entropy: 0.674
# 1359 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1359] loss: 0.498 celoss: 0.498 entropy: 0.673
# 1360 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1360] loss: 0.498 celoss: 0.498 entropy: 0.673
# 1361 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1361] loss: 0.498 celoss: 0.498 entropy: 0.672
# 1362 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1362] loss: 0.498 celoss: 0.498 entropy: 0.672
# 1363 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1363] loss: 0.498 celoss: 0.498 entropy: 0.671
# 1364 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1364] loss: 0.498 celoss: 0.498 entropy: 0.671
# 1365 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1365] loss: 0.498 celoss: 0.498 entropy: 0.669
# 1366 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1366] loss: 0.499 celoss: 0.498 entropy: 0.669
# 1367 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1367] loss: 0.499 celoss: 0.498 entropy: 0.670
# 1368 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1368] loss: 0.499 celoss: 0.499 entropy: 0.670
# 1369 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1369] loss: 0.499 celoss: 0.499 entropy: 0.668
# 1370 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1370] loss: 0.498 celoss: 0.498 entropy: 0.668
# 1371 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1371] loss: 0.498 celoss: 0.498 entropy: 0.667
# 1372 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1372] loss: 0.498 celoss: 0.498 entropy: 0.667
# 1373 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1373] loss: 0.498 celoss: 0.498 entropy: 0.666
# 1374 updating what_net, where_net is freezed
# ...
# --------------------------------------------------------------------------------
# epoch: [416] loss: 0.012 celoss: 0.012 entropy: 0.181
# 417 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [417] loss: 0.010 celoss: 0.010 entropy: 0.179
# 418 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [418] loss: 0.009 celoss: 0.009 entropy: 0.179
# 419 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [419] loss: 0.034 celoss: 0.034 entropy: 0.187
# 420 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [420] loss: 0.028 celoss: 0.027 entropy: 0.187
# 421 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [421] loss: 0.023 celoss: 0.023 entropy: 0.205
# 422 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [422] loss: 0.021 celoss: 0.020 entropy: 0.205
# 423 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [423] loss: 0.027 celoss: 0.027 entropy: 0.185
# 424 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [424] loss: 0.023 celoss: 0.023 entropy: 0.185
# 425 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [425] loss: 0.023 celoss: 0.023 entropy: 0.199
# 426 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [426] loss: 0.016 celoss: 0.016 entropy: 0.199
# 427 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [427] loss: 0.017 celoss: 0.017 entropy: 0.201
# 428 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [428] loss: 0.015 celoss: 0.015 entropy: 0.201
# 429 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [429] loss: 0.011 celoss: 0.010 entropy: 0.184
# 430 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [430] loss: 0.011 celoss: 0.011 entropy: 0.184
# 431 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [431] loss: 0.029 celoss: 0.029 entropy: 0.182
# 432 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [432] loss: 0.025 celoss: 0.025 entropy: 0.182
# 433 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [433] loss: 0.022 celoss: 0.021 entropy: 0.177
# 434 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [434] loss: 0.016 celoss: 0.016 entropy: 0.177
# 435 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [435] loss: 0.046 celoss: 0.046 entropy: 0.208
# 436 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [436] loss: 0.035 celoss: 0.035 entropy: 0.208
# 437 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [437] loss: 0.013 celoss: 0.013 entropy: 0.188
# 438 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [438] loss: 0.012 celoss: 0.012 entropy: 0.188
# 439 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [439] loss: 0.032 celoss: 0.032 entropy: 0.214
# 440 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [440] loss: 0.029 celoss: 0.029 entropy: 0.214
# 441 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [441] loss: 0.021 celoss: 0.020 entropy: 0.182
# 442 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [442] loss: 0.020 celoss: 0.019 entropy: 0.182
# 443 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [443] loss: 0.018 celoss: 0.017 entropy: 0.197
# 444 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [444] loss: 0.013 celoss: 0.012 entropy: 0.197
# 445 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [445] loss: 0.018 celoss: 0.018 entropy: 0.180
# 446 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [446] loss: 0.016 celoss: 0.016 entropy: 0.180
# 447 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [447] loss: 0.016 celoss: 0.016 entropy: 0.186
# 448 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [448] loss: 0.013 celoss: 0.013 entropy: 0.186
# 449 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [449] loss: 0.018 celoss: 0.018 entropy: 0.198
# 450 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [450] loss: 0.016 celoss: 0.016 entropy: 0.198
# 451 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [451] loss: 0.015 celoss: 0.015 entropy: 0.196
# 452 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [452] loss: 0.012 celoss: 0.012 entropy: 0.196
# 453 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [453] loss: 0.013 celoss: 0.013 entropy: 0.182
# 454 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [454] loss: 0.012 celoss: 0.012 entropy: 0.182
# 455 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [455] loss: 0.015 celoss: 0.015 entropy: 0.187
# 456 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [456] loss: 0.014 celoss: 0.014 entropy: 0.187
# 457 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [457] loss: 0.013 celoss: 0.013 entropy: 0.175
# 458 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [458] loss: 0.008 celoss: 0.008 entropy: 0.175
# 459 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [459] loss: 0.014 celoss: 0.014 entropy: 0.179
# 460 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [460] loss: 0.015 celoss: 0.015 entropy: 0.179
# 461 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [461] loss: 0.013 celoss: 0.013 entropy: 0.184
# 462 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [462] loss: 0.009 celoss: 0.008 entropy: 0.184
# 463 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [463] loss: 0.007 celoss: 0.007 entropy: 0.177
# 464 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [464] loss: 0.008 celoss: 0.008 entropy: 0.177
# 465 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [465] loss: 0.030 celoss: 0.030 entropy: 0.181
# 466 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [466] loss: 0.027 celoss: 0.026 entropy: 0.181
# 467 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [467] loss: 0.020 celoss: 0.020 entropy: 0.181
# 468 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [468] loss: 0.011 celoss: 0.011 entropy: 0.181
# 469 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [469] loss: 0.020 celoss: 0.020 entropy: 0.193
# 470 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [470] loss: 0.026 celoss: 0.026 entropy: 0.193
# 471 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [471] loss: 0.017 celoss: 0.017 entropy: 0.178
# 472 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [472] loss: 0.019 celoss: 0.019 entropy: 0.178
# 473 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [473] loss: 0.016 celoss: 0.016 entropy: 0.187
# 474 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [474] loss: 0.010 celoss: 0.010 entropy: 0.187
# 475 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [475] loss: 0.008 celoss: 0.008 entropy: 0.179
# 476 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [476] loss: 0.008 celoss: 0.008 entropy: 0.179
# 477 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [477] loss: 0.016 celoss: 0.015 entropy: 0.184
# 478 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [478] loss: 0.012 celoss: 0.012 entropy: 0.184
# 479 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [479] loss: 0.012 celoss: 0.012 entropy: 0.176
# 480 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [480] loss: 0.010 celoss: 0.010 entropy: 0.176
# 481 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [481] loss: 0.009 celoss: 0.009 entropy: 0.178
# 482 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [482] loss: 0.009 celoss: 0.009 entropy: 0.178
# 483 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [483] loss: 0.016 celoss: 0.016 entropy: 0.187
# 484 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [484] loss: 0.011 celoss: 0.011 entropy: 0.187
# 485 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [485] loss: 0.012 celoss: 0.012 entropy: 0.180
# 486 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [486] loss: 0.009 celoss: 0.009 entropy: 0.180
# 487 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [487] loss: 0.011 celoss: 0.010 entropy: 0.181
# 488 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [488] loss: 0.011 celoss: 0.010 entropy: 0.181
# 489 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [489] loss: 0.008 celoss: 0.008 entropy: 0.172
# 490 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [490] loss: 0.007 celoss: 0.007 entropy: 0.172
# 491 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [491] loss: 0.006 celoss: 0.006 entropy: 0.174
# 492 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [492] loss: 0.006 celoss: 0.006 entropy: 0.174
# 493 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [493] loss: 0.011 celoss: 0.011 entropy: 0.171
# 494 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [494] loss: 0.010 celoss: 0.010 entropy: 0.171
# 495 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [495] loss: 0.015 celoss: 0.014 entropy: 0.188
# 496 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [496] loss: 0.015 celoss: 0.014 entropy: 0.188
# 497 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [497] loss: 0.012 celoss: 0.011 entropy: 0.184
# 498 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [498] loss: 0.010 celoss: 0.010 entropy: 0.184
# 499 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [499] loss: 0.008 celoss: 0.008 entropy: 0.182
# 500 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [500] loss: 0.009 celoss: 0.008 entropy: 0.182
# 501 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [501] loss: 0.008 celoss: 0.008 entropy: 0.179
# 502 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [502] loss: 0.007 celoss: 0.007 entropy: 0.179
# 503 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [503] loss: 0.006 celoss: 0.005 entropy: 0.174
# 504 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [504] loss: 0.005 celoss: 0.005 entropy: 0.174
# Finished Training run 9
# Accuracy of the network on the 3000 train images: 99 %

# %%
a,b= full_analysis[0]
print(a)
# Out:
# 335

# %%
cnt=1
for epoch, analysis_data in full_analysis:
  analysis_data = np.array(analysis_data)
  # print("="*20+"run ",cnt,"="*20)
  
  plt.figure(figsize=(6,6))
  plt.plot(np.arange(0,epoch+2,1),analysis_data[:,0],label="ftpt")
  plt.plot(np.arange(0,epoch+2,1),analysis_data[:,1],label="ffpt")
  plt.plot(np.arange(0,epoch+2,1),analysis_data[:,2],label="ftpf")
  plt.plot(np.arange(0,epoch+2,1),analysis_data[:,3],label="ffpf")

  plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
  plt.title("Training trends for run "+str(cnt))
  plt.savefig(path+"where_what/every1/run"+str(cnt)+".png",bbox_inches="tight")
  plt.savefig(path+"where_what/every1/run"+str(cnt)+".pdf",bbox_inches="tight")
  cnt+=1

# %%
np.mean(np.array(FTPT_analysis),axis=0) #array([87.85333333,  5.92      ,  0.        ,  6.22666667])
# Out:
# array([6.01066667e+01, 3.32966667e+01, 3.00000000e-02, 6.56666667e+00])

# %%
FTPT_analysis.to_csv(path+"where_what/FTPT_analysis_every1.csv",index=False)

# %%
FTPT_analysis
# Out:
#         FTPT       FFPT      FTPF       FFPF
# 0  65.933333  34.000000  0.066667   0.000000
# 1  69.166667  30.833333  0.000000   0.000000
# 2  65.966667  34.000000  0.033333   0.000000
# 3  66.033333  33.966667  0.000000   0.000000
# 4  66.000000  33.933333  0.033333   0.033333
# 5  34.000000  32.266667  0.100000  33.633333
# 6  67.900000  32.100000  0.000000   0.000000
# 7  34.100000  33.900000  0.000000  32.000000
# 8  66.033333  33.966667  0.000000   0.000000
# 9  65.933333  34.000000  0.066667   0.000000
