# %%
 import numpy as np
import pandas as pd

import torch
import torchvision
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms, utils
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

from matplotlib import pyplot as plt
# %matplotlib inline
from scipy.stats import entropy

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
path="/content/drive/MyDrive/Research/alternate_minimisation/type4_data/"

# %%
class MosaicDataset1(Dataset):
  """MosaicDataset dataset."""

  def __init__(self, mosaic_list, mosaic_label,fore_idx):
    """
      Args:
        csv_file (string): Path to the csv file with annotations.
        root_dir (string): Directory with all the images.
        transform (callable, optional): Optional transform to be applied
            on a sample.
    """
    self.mosaic = mosaic_list
    self.label = mosaic_label
    self.fore_idx = fore_idx
    
  def __len__(self):
    return len(self.label)

  def __getitem__(self, idx):
    return self.mosaic[idx] , self.label[idx] , self.fore_idx[idx]

# %%
class SyntheticDataset(Dataset):
  """MosaicDataset dataset."""

  def __init__(self, x, y):
    """
      Args:
        csv_file (string): Path to the csv file with annotations.
        root_dir (string): Directory with all the images.
        transform (callable, optional): Optional transform to be applied
            on a sample.
    """
    self.x = x
    self.y = y
    #self.fore_idx = fore_idx
    
  def __len__(self):
    return len(self.y)

  def __getitem__(self, idx):
    return self.x[idx] , self.y[idx] #, self.fore_idx[idx]

# %%
train_data = np.load(path+"train_type4_data.npy",allow_pickle=True)
test_data = np.load(path+"test_type4_data.npy",allow_pickle=True)
data = np.load(path+"type_4_data.npy",allow_pickle=True)

# %%
train_mosaic_list_of_images = train_data[0]["mosaic_list"]
train_mosaic_label = train_data[0]["mosaic_label"]
train_fore_idx = train_data[0]["fore_idx"]


test_mosaic_list_of_images = test_data[0]["mosaic_list"]
test_mosaic_label = test_data[0]["mosaic_label"]
test_fore_idx = test_data[0]["fore_idx"]
X = data[0]["X"]
Y = data[0]["Y"]

# %%
batch = 250
tr_msd = MosaicDataset1(train_mosaic_list_of_images, train_mosaic_label, train_fore_idx)
train_loader = DataLoader( tr_msd,batch_size= batch ,shuffle=True)

# %%
batch = 250
tst_msd = MosaicDataset1(test_mosaic_list_of_images, test_mosaic_label, test_fore_idx)
test_loader = DataLoader( tst_msd,batch_size= batch ,shuffle=True)

# %%
dset = SyntheticDataset(X,Y)
dtloader = DataLoader(dset,batch_size =batch,shuffle=True )

# %% [markdown]
# **Focus Net**

# %%
class Module1(nn.Module):
  def __init__(self):
    super(Module1, self).__init__()
    self.fc1 = nn.Linear(2, 100)
    self.fc2 = nn.Linear(100, 1)

  def forward(self, z):
    x = torch.zeros([batch,9],dtype=torch.float64)
    y = torch.zeros([batch,2], dtype=torch.float64)
    x,y = x.to("cuda"),y.to("cuda")
    for i in range(9):
      x[:,i] = self.helper(z[:,i])[:,0]
    
    log_x = F.log_softmax(x,dim=1)  
    x = F.softmax(x,dim=1)   # alphas
    

    for i in range(9):            
      x1 = x[:,i]          
      y = y + torch.mul(x1[:,None],z[:,i])
    return y , x , log_x
  
  def helper(self,x):
    x = F.relu(self.fc1(x))
    x = self.fc2(x)
    return x

# %% [markdown]
# **Classification Net**

# %%
 class Module2(nn.Module):
  def __init__(self):
    super(Module2, self).__init__()
    self.fc1 = nn.Linear(2, 100)
    self.fc2 = nn.Linear(100, 3)

  def forward(self,y):  
    y = F.relu(self.fc1(y))
    y = self.fc2(y)
    return y

# %%
criterion = nn.CrossEntropyLoss()
def my_cross_entropy(x, y,alpha,log_alpha,k):
    # log_prob = -1.0 * F.log_softmax(x, 1)
    # loss = log_prob.gather(1, y.unsqueeze(1))
    # loss = loss.mean()
    loss = criterion(x,y)
    
    #alpha = torch.clamp(alpha,min=1e-10)     
    
    b = -1.0* alpha * log_alpha
    b =  torch.mean(torch.sum(b,dim=1))
    closs = loss
    entropy = b 
    loss = (1-k)*loss + ((k)*b)
    return loss,closs,entropy

# %%
def calculate_attn_loss(dataloader,what,where,criter,k):
  what.eval()
  where.eval()
  r_loss = 0
  cc_loss = 0
  cc_entropy = 0
  alphas = []
  lbls = []
  pred = []
  fidices = []
  with torch.no_grad():
    for i, data in enumerate(dataloader, 0):
      inputs, labels,fidx = data
      lbls.append(labels)
      fidices.append(fidx)
      inputs = inputs.double()
      inputs, labels = inputs.to("cuda"),labels.to("cuda")
      avg,alpha,log_alpha = where(inputs)
      outputs = what(avg)
      _, predicted = torch.max(outputs.data, 1)
      pred.append(predicted.cpu().numpy())
      alphas.append(alpha.cpu().numpy())

      #ent = np.sum(entropy(alpha.cpu().detach().numpy(), base=2, axis=1))/batch
      # mx,_ = torch.max(alpha,1)
      # entropy = np.mean(-np.log2(mx.cpu().detach().numpy()))
      # print("entropy of batch", entropy)

      #loss = (1-k)*criter(outputs, labels) + k*ent
      loss,closs,entropy = my_cross_entropy(outputs,labels,alpha,log_alpha,k)
      r_loss += loss.item()
      cc_loss += closs.item()
      cc_entropy += entropy.item()

  alphas = np.concatenate(alphas,axis=0)
  pred = np.concatenate(pred,axis=0)
  lbls = np.concatenate(lbls,axis=0)
  fidices = np.concatenate(fidices,axis=0)
  #print(alphas.shape,pred.shape,lbls.shape,fidices.shape) 
  analysis = analyse_data(alphas,lbls,pred,fidices)
  return r_loss/i,cc_loss/i,cc_entropy/i,analysis

# %%
def analyse_data(alphas,lbls,predicted,f_idx):
    '''
       analysis data is created here
    '''
    batch = len(predicted)
    amth,alth,ftpt,ffpt,ftpf,ffpf = 0,0,0,0,0,0
    for j in range (batch):
      focus = np.argmax(alphas[j])
      if(alphas[j][focus] >= 0.5):
        amth +=1
      else:
        alth +=1
      if(focus == f_idx[j] and predicted[j] == lbls[j]):
        ftpt += 1
      elif(focus != f_idx[j] and predicted[j] == lbls[j]):
        ffpt +=1
      elif(focus == f_idx[j] and predicted[j] != lbls[j]):
        ftpf +=1
      elif(focus != f_idx[j] and predicted[j] != lbls[j]):
        ffpf +=1
    #print(sum(predicted==lbls),ftpt+ffpt)
    return [ftpt,ffpt,ftpf,ffpf,amth,alth]

# %%
number_runs = 10
full_analysis =[]
FTPT_analysis = pd.DataFrame(columns = ["FTPT","FFPT", "FTPF","FFPF"])
k = 0.001

every_what_epoch = 1

for n in range(number_runs):
  print("--"*40)
  
  # instantiate focus and classification Model
  torch.manual_seed(n)
  where = Module1().double()
  torch.manual_seed(n)
  what = Module2().double()
  
  where = where.to("cuda")
  what = what.to("cuda")



  # instantiate optimizer
  optimizer_where = optim.Adam(where.parameters(),lr =0.01)
  optimizer_what = optim.Adam(what.parameters(), lr=0.01)
  #criterion = nn.CrossEntropyLoss()
  acti = []
  analysis_data = []
  loss_curi = []
  epochs = 2000


  # calculate zeroth epoch loss and FTPT values
  running_loss ,_,_,anlys_data= calculate_attn_loss(train_loader,what,where,criterion,k)
  loss_curi.append(running_loss)
  analysis_data.append(anlys_data)

  print('epoch: [%d ] loss: %.3f' %(0,running_loss)) 

  # training starts 
  for epoch in range(epochs): # loop over the dataset multiple times
    ep_lossi = []
    running_loss = 0.0
    what.train()
    where.train()
    if ((epoch) % (every_what_epoch*2) ) <= every_what_epoch-1 :
      print(epoch+1,"updating what_net, where_net is freezed")
      print("--"*40)
    elif ((epoch) % (every_what_epoch*2)) > every_what_epoch-1 :
      print(epoch+1,"updating where_net, what_net is freezed")
      print("--"*40)
    for i, data in enumerate(train_loader, 0):
      # get the inputs
      inputs, labels,_ = data
      inputs = inputs.double()
      inputs, labels = inputs.to("cuda"),labels.to("cuda")

      # zero the parameter gradients
      optimizer_where.zero_grad()
      optimizer_what.zero_grad()
      
      # forward + backward + optimize
      avg, alpha,log_alpha = where(inputs)
      outputs = what(avg)

      my_loss,_,_ = my_cross_entropy(outputs,labels,alpha,log_alpha,k)

      # print statistics
      running_loss += my_loss.item()
      my_loss.backward()

      if ((epoch) % (every_what_epoch*2) ) <= every_what_epoch-1 :
        optimizer_what.step()
      elif ( (epoch) % (every_what_epoch*2)) > every_what_epoch-1 :
        optimizer_where.step()
        
      # optimizer_where.step()
      # optimizer_what.step()
    #break
    running_loss,ccloss,ccentropy,anls_data = calculate_attn_loss(train_loader,what,where,criterion,k)
    analysis_data.append(anls_data)
    print('epoch: [%d] loss: %.3f celoss: %.3f entropy: %.3f' %(epoch + 1,running_loss,ccloss,ccentropy)) 
    loss_curi.append(running_loss)   #loss per epoch
    if running_loss<=0.005:
      break
  print('Finished Training run ' +str(n))
  #break
  analysis_data = np.array(analysis_data)
  FTPT_analysis.loc[n] = analysis_data[-1,:4]/30
  full_analysis.append((epoch, analysis_data))
  correct = 0
  total = 0
  with torch.no_grad():
    for data in train_loader:
      images, labels,_ = data
      images = images.double()
      images, labels = images.to("cuda"), labels.to("cuda")
      avg, alpha,log_alpha = where(images)
      outputs  = what(avg)
      _, predicted = torch.max(outputs.data, 1)
      total += labels.size(0)
      correct += (predicted == labels).sum().item()

  print('Accuracy of the network on the 3000 train images: %d %%' % (  100 * correct / total))
# Out:
# Streaming output truncated to the last 5000 lines.
# --------------------------------------------------------------------------------
# epoch: [573] loss: 1.152 celoss: 1.153 entropy: 0.180
# 574 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [574] loss: 1.152 celoss: 1.153 entropy: 0.181
# 575 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [575] loss: 1.153 celoss: 1.154 entropy: 0.181
# 576 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [576] loss: 1.153 celoss: 1.154 entropy: 0.181
# 577 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [577] loss: 1.153 celoss: 1.154 entropy: 0.181
# 578 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [578] loss: 1.153 celoss: 1.154 entropy: 0.182
# 579 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [579] loss: 1.153 celoss: 1.154 entropy: 0.182
# 580 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [580] loss: 1.153 celoss: 1.154 entropy: 0.182
# 581 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [581] loss: 1.153 celoss: 1.154 entropy: 0.182
# 582 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [582] loss: 1.153 celoss: 1.154 entropy: 0.182
# 583 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [583] loss: 1.155 celoss: 1.155 entropy: 0.182
# 584 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [584] loss: 1.155 celoss: 1.155 entropy: 0.182
# 585 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [585] loss: 1.156 celoss: 1.157 entropy: 0.182
# 586 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [586] loss: 1.156 celoss: 1.157 entropy: 0.179
# 587 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [587] loss: 1.154 celoss: 1.155 entropy: 0.179
# 588 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [588] loss: 1.154 celoss: 1.155 entropy: 0.178
# 589 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [589] loss: 1.151 celoss: 1.152 entropy: 0.178
# 590 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [590] loss: 1.151 celoss: 1.152 entropy: 0.177
# 591 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [591] loss: 1.152 celoss: 1.153 entropy: 0.177
# 592 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [592] loss: 1.152 celoss: 1.153 entropy: 0.177
# 593 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [593] loss: 1.154 celoss: 1.155 entropy: 0.177
# 594 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [594] loss: 1.154 celoss: 1.155 entropy: 0.178
# 595 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [595] loss: 1.151 celoss: 1.152 entropy: 0.178
# 596 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [596] loss: 1.151 celoss: 1.152 entropy: 0.180
# 597 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [597] loss: 1.151 celoss: 1.152 entropy: 0.180
# 598 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [598] loss: 1.151 celoss: 1.152 entropy: 0.181
# 599 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [599] loss: 1.153 celoss: 1.154 entropy: 0.181
# 600 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [600] loss: 1.153 celoss: 1.154 entropy: 0.182
# 601 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [601] loss: 1.157 celoss: 1.158 entropy: 0.182
# 602 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [602] loss: 1.157 celoss: 1.158 entropy: 0.184
# 603 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [603] loss: 1.152 celoss: 1.153 entropy: 0.184
# 604 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [604] loss: 1.152 celoss: 1.153 entropy: 0.184
# 605 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [605] loss: 1.152 celoss: 1.153 entropy: 0.184
# 606 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [606] loss: 1.152 celoss: 1.153 entropy: 0.184
# 607 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [607] loss: 1.153 celoss: 1.154 entropy: 0.184
# 608 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [608] loss: 1.153 celoss: 1.154 entropy: 0.184
# 609 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [609] loss: 1.153 celoss: 1.154 entropy: 0.184
# 610 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [610] loss: 1.153 celoss: 1.154 entropy: 0.183
# 611 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [611] loss: 1.159 celoss: 1.160 entropy: 0.183
# 612 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [612] loss: 1.159 celoss: 1.160 entropy: 0.180
# 613 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [613] loss: 1.151 celoss: 1.152 entropy: 0.180
# 614 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [614] loss: 1.151 celoss: 1.152 entropy: 0.178
# 615 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [615] loss: 1.156 celoss: 1.157 entropy: 0.178
# 616 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [616] loss: 1.156 celoss: 1.157 entropy: 0.180
# 617 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [617] loss: 1.151 celoss: 1.152 entropy: 0.180
# 618 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [618] loss: 1.151 celoss: 1.152 entropy: 0.180
# 619 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [619] loss: 1.153 celoss: 1.154 entropy: 0.180
# 620 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [620] loss: 1.153 celoss: 1.154 entropy: 0.181
# 621 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [621] loss: 1.160 celoss: 1.161 entropy: 0.181
# 622 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [622] loss: 1.160 celoss: 1.161 entropy: 0.183
# 623 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [623] loss: 1.152 celoss: 1.153 entropy: 0.183
# 624 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [624] loss: 1.152 celoss: 1.153 entropy: 0.185
# 625 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [625] loss: 1.151 celoss: 1.152 entropy: 0.185
# 626 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [626] loss: 1.151 celoss: 1.152 entropy: 0.184
# 627 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [627] loss: 1.151 celoss: 1.152 entropy: 0.184
# 628 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [628] loss: 1.151 celoss: 1.152 entropy: 0.185
# 629 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [629] loss: 1.152 celoss: 1.153 entropy: 0.185
# 630 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [630] loss: 1.152 celoss: 1.153 entropy: 0.187
# 631 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [631] loss: 1.152 celoss: 1.152 entropy: 0.187
# 632 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [632] loss: 1.152 celoss: 1.152 entropy: 0.187
# 633 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [633] loss: 1.155 celoss: 1.156 entropy: 0.187
# 634 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [634] loss: 1.155 celoss: 1.156 entropy: 0.185
# 635 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [635] loss: 1.154 celoss: 1.155 entropy: 0.185
# 636 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [636] loss: 1.154 celoss: 1.155 entropy: 0.184
# 637 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [637] loss: 1.152 celoss: 1.153 entropy: 0.184
# 638 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [638] loss: 1.152 celoss: 1.153 entropy: 0.184
# 639 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [639] loss: 1.158 celoss: 1.159 entropy: 0.184
# 640 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [640] loss: 1.158 celoss: 1.159 entropy: 0.187
# 641 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [641] loss: 1.155 celoss: 1.156 entropy: 0.187
# 642 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [642] loss: 1.155 celoss: 1.156 entropy: 0.189
# 643 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [643] loss: 1.151 celoss: 1.152 entropy: 0.189
# 644 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [644] loss: 1.151 celoss: 1.152 entropy: 0.191
# 645 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [645] loss: 1.152 celoss: 1.153 entropy: 0.191
# 646 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [646] loss: 1.152 celoss: 1.153 entropy: 0.194
# 647 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [647] loss: 1.151 celoss: 1.152 entropy: 0.194
# 648 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [648] loss: 1.151 celoss: 1.152 entropy: 0.200
# 649 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [649] loss: 1.153 celoss: 1.154 entropy: 0.200
# 650 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [650] loss: 1.153 celoss: 1.154 entropy: 0.194
# 651 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [651] loss: 1.164 celoss: 1.165 entropy: 0.194
# 652 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [652] loss: 1.163 celoss: 1.164 entropy: 0.198
# 653 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [653] loss: 1.153 celoss: 1.154 entropy: 0.198
# 654 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [654] loss: 1.153 celoss: 1.154 entropy: 0.195
# 655 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [655] loss: 1.152 celoss: 1.153 entropy: 0.195
# 656 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [656] loss: 1.152 celoss: 1.153 entropy: 0.192
# 657 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [657] loss: 1.153 celoss: 1.154 entropy: 0.192
# 658 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [658] loss: 1.153 celoss: 1.154 entropy: 0.189
# 659 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [659] loss: 1.151 celoss: 1.152 entropy: 0.189
# 660 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [660] loss: 1.151 celoss: 1.152 entropy: 0.187
# 661 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [661] loss: 1.155 celoss: 1.155 entropy: 0.187
# 662 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [662] loss: 1.154 celoss: 1.155 entropy: 0.184
# 663 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [663] loss: 1.152 celoss: 1.153 entropy: 0.184
# 664 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [664] loss: 1.152 celoss: 1.153 entropy: 0.182
# 665 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [665] loss: 1.152 celoss: 1.153 entropy: 0.182
# 666 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [666] loss: 1.152 celoss: 1.153 entropy: 0.181
# 667 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [667] loss: 1.154 celoss: 1.155 entropy: 0.181
# 668 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [668] loss: 1.154 celoss: 1.155 entropy: 0.182
# 669 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [669] loss: 1.156 celoss: 1.157 entropy: 0.182
# 670 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [670] loss: 1.156 celoss: 1.157 entropy: 0.184
# 671 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [671] loss: 1.152 celoss: 1.153 entropy: 0.184
# 672 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [672] loss: 1.152 celoss: 1.153 entropy: 0.185
# 673 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [673] loss: 1.151 celoss: 1.152 entropy: 0.185
# 674 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [674] loss: 1.151 celoss: 1.152 entropy: 0.185
# 675 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [675] loss: 1.151 celoss: 1.152 entropy: 0.185
# 676 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [676] loss: 1.151 celoss: 1.152 entropy: 0.184
# 677 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [677] loss: 1.151 celoss: 1.152 entropy: 0.184
# 678 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [678] loss: 1.151 celoss: 1.152 entropy: 0.184
# 679 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [679] loss: 1.151 celoss: 1.152 entropy: 0.184
# 680 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [680] loss: 1.151 celoss: 1.152 entropy: 0.183
# 681 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [681] loss: 1.151 celoss: 1.152 entropy: 0.183
# 682 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [682] loss: 1.151 celoss: 1.152 entropy: 0.181
# 683 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [683] loss: 1.151 celoss: 1.152 entropy: 0.181
# 684 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [684] loss: 1.151 celoss: 1.152 entropy: 0.181
# 685 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [685] loss: 1.151 celoss: 1.151 entropy: 0.181
# 686 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [686] loss: 1.151 celoss: 1.151 entropy: 0.181
# 687 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [687] loss: 1.153 celoss: 1.154 entropy: 0.181
# 688 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [688] loss: 1.153 celoss: 1.154 entropy: 0.183
# 689 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [689] loss: 1.155 celoss: 1.156 entropy: 0.183
# 690 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [690] loss: 1.155 celoss: 1.156 entropy: 0.184
# 691 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [691] loss: 1.150 celoss: 1.151 entropy: 0.184
# 692 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [692] loss: 1.150 celoss: 1.151 entropy: 0.185
# 693 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [693] loss: 1.152 celoss: 1.153 entropy: 0.185
# 694 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [694] loss: 1.152 celoss: 1.153 entropy: 0.182
# 695 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [695] loss: 1.156 celoss: 1.157 entropy: 0.182
# 696 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [696] loss: 1.156 celoss: 1.157 entropy: 0.179
# 697 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [697] loss: 1.153 celoss: 1.154 entropy: 0.179
# 698 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [698] loss: 1.153 celoss: 1.154 entropy: 0.178
# 699 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [699] loss: 1.162 celoss: 1.163 entropy: 0.178
# 700 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [700] loss: 1.162 celoss: 1.163 entropy: 0.179
# 701 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [701] loss: 1.151 celoss: 1.152 entropy: 0.179
# 702 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [702] loss: 1.151 celoss: 1.152 entropy: 0.181
# 703 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [703] loss: 1.152 celoss: 1.152 entropy: 0.181
# 704 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [704] loss: 1.151 celoss: 1.152 entropy: 0.180
# 705 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [705] loss: 1.153 celoss: 1.154 entropy: 0.180
# 706 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [706] loss: 1.162 celoss: 1.163 entropy: 0.195
# 707 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [707] loss: 1.158 celoss: 1.159 entropy: 0.195
# 708 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [708] loss: 1.157 celoss: 1.158 entropy: 0.183
# 709 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [709] loss: 1.151 celoss: 1.152 entropy: 0.183
# 710 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [710] loss: 1.154 celoss: 1.155 entropy: 0.172
# 711 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [711] loss: 1.154 celoss: 1.155 entropy: 0.172
# 712 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [712] loss: 1.175 celoss: 1.176 entropy: 0.206
# 713 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [713] loss: 1.174 celoss: 1.175 entropy: 0.206
# 714 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [714] loss: 1.167 celoss: 1.167 entropy: 0.207
# 715 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [715] loss: 1.162 celoss: 1.163 entropy: 0.207
# 716 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [716] loss: 1.163 celoss: 1.164 entropy: 0.144
# 717 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [717] loss: 1.163 celoss: 1.164 entropy: 0.144
# 718 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [718] loss: 1.161 celoss: 1.162 entropy: 0.176
# 719 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [719] loss: 1.162 celoss: 1.163 entropy: 0.176
# 720 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [720] loss: 1.159 celoss: 1.160 entropy: 0.138
# 721 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [721] loss: 1.161 celoss: 1.162 entropy: 0.138
# 722 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [722] loss: 1.160 celoss: 1.161 entropy: 0.136
# 723 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [723] loss: 1.160 celoss: 1.161 entropy: 0.136
# 724 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [724] loss: 1.160 celoss: 1.161 entropy: 0.129
# 725 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [725] loss: 1.157 celoss: 1.158 entropy: 0.129
# 726 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [726] loss: 1.156 celoss: 1.157 entropy: 0.135
# 727 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [727] loss: 1.159 celoss: 1.160 entropy: 0.135
# 728 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [728] loss: 1.160 celoss: 1.161 entropy: 0.167
# 729 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [729] loss: 1.163 celoss: 1.164 entropy: 0.167
# 730 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [730] loss: 1.166 celoss: 1.167 entropy: 0.219
# 731 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [731] loss: 1.169 celoss: 1.170 entropy: 0.219
# 732 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [732] loss: 1.169 celoss: 1.170 entropy: 0.202
# 733 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [733] loss: 1.161 celoss: 1.162 entropy: 0.202
# 734 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [734] loss: 1.158 celoss: 1.159 entropy: 0.139
# 735 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [735] loss: 1.158 celoss: 1.159 entropy: 0.139
# 736 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [736] loss: 1.158 celoss: 1.159 entropy: 0.112
# 737 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [737] loss: 1.155 celoss: 1.156 entropy: 0.112
# 738 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [738] loss: 1.156 celoss: 1.157 entropy: 0.127
# 739 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [739] loss: 1.162 celoss: 1.163 entropy: 0.127
# 740 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [740] loss: 1.160 celoss: 1.161 entropy: 0.174
# 741 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [741] loss: 1.158 celoss: 1.159 entropy: 0.174
# 742 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [742] loss: 1.159 celoss: 1.160 entropy: 0.146
# 743 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [743] loss: 1.157 celoss: 1.158 entropy: 0.146
# 744 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [744] loss: 1.157 celoss: 1.158 entropy: 0.168
# 745 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [745] loss: 1.154 celoss: 1.155 entropy: 0.168
# 746 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [746] loss: 1.157 celoss: 1.158 entropy: 0.172
# 747 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [747] loss: 1.163 celoss: 1.164 entropy: 0.172
# 748 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [748] loss: 1.163 celoss: 1.164 entropy: 0.186
# 749 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [749] loss: 1.156 celoss: 1.157 entropy: 0.186
# 750 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [750] loss: 1.156 celoss: 1.157 entropy: 0.156
# 751 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [751] loss: 1.156 celoss: 1.157 entropy: 0.156
# 752 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [752] loss: 1.154 celoss: 1.155 entropy: 0.136
# 753 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [753] loss: 1.156 celoss: 1.157 entropy: 0.136
# 754 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [754] loss: 1.156 celoss: 1.157 entropy: 0.133
# 755 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [755] loss: 1.154 celoss: 1.155 entropy: 0.133
# 756 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [756] loss: 1.154 celoss: 1.155 entropy: 0.130
# 757 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [757] loss: 1.154 celoss: 1.155 entropy: 0.130
# 758 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [758] loss: 1.154 celoss: 1.155 entropy: 0.130
# 759 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [759] loss: 1.158 celoss: 1.159 entropy: 0.130
# 760 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [760] loss: 1.158 celoss: 1.159 entropy: 0.129
# 761 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [761] loss: 1.153 celoss: 1.154 entropy: 0.129
# 762 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [762] loss: 1.154 celoss: 1.155 entropy: 0.122
# 763 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [763] loss: 1.160 celoss: 1.161 entropy: 0.122
# 764 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [764] loss: 1.161 celoss: 1.162 entropy: 0.119
# 765 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [765] loss: 1.161 celoss: 1.162 entropy: 0.119
# 766 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [766] loss: 1.161 celoss: 1.162 entropy: 0.120
# 767 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [767] loss: 1.158 celoss: 1.159 entropy: 0.120
# 768 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [768] loss: 1.157 celoss: 1.158 entropy: 0.137
# 769 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [769] loss: 1.156 celoss: 1.157 entropy: 0.137
# 770 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [770] loss: 1.156 celoss: 1.157 entropy: 0.144
# 771 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [771] loss: 1.155 celoss: 1.156 entropy: 0.144
# 772 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [772] loss: 1.155 celoss: 1.156 entropy: 0.139
# 773 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [773] loss: 1.157 celoss: 1.158 entropy: 0.139
# 774 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [774] loss: 1.158 celoss: 1.159 entropy: 0.118
# 775 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [775] loss: 1.155 celoss: 1.157 entropy: 0.118
# 776 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [776] loss: 1.154 celoss: 1.155 entropy: 0.126
# 777 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [777] loss: 1.155 celoss: 1.156 entropy: 0.126
# 778 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [778] loss: 1.157 celoss: 1.158 entropy: 0.177
# 779 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [779] loss: 1.158 celoss: 1.159 entropy: 0.177
# 780 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [780] loss: 1.160 celoss: 1.161 entropy: 0.181
# 781 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [781] loss: 1.152 celoss: 1.153 entropy: 0.181
# 782 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [782] loss: 1.153 celoss: 1.154 entropy: 0.182
# 783 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [783] loss: 1.158 celoss: 1.159 entropy: 0.182
# 784 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [784] loss: 1.161 celoss: 1.162 entropy: 0.192
# 785 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [785] loss: 1.157 celoss: 1.158 entropy: 0.192
# 786 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [786] loss: 1.155 celoss: 1.156 entropy: 0.211
# 787 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [787] loss: 1.153 celoss: 1.154 entropy: 0.211
# 788 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [788] loss: 1.153 celoss: 1.154 entropy: 0.229
# 789 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [789] loss: 1.154 celoss: 1.154 entropy: 0.229
# 790 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [790] loss: 1.157 celoss: 1.158 entropy: 0.228
# 791 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [791] loss: 1.163 celoss: 1.164 entropy: 0.228
# 792 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [792] loss: 1.166 celoss: 1.167 entropy: 0.223
# 793 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [793] loss: 1.161 celoss: 1.162 entropy: 0.223
# 794 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [794] loss: 1.161 celoss: 1.162 entropy: 0.194
# 795 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [795] loss: 1.177 celoss: 1.178 entropy: 0.194
# 796 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [796] loss: 1.165 celoss: 1.166 entropy: 0.216
# 797 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [797] loss: 1.157 celoss: 1.158 entropy: 0.216
# 798 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [798] loss: 1.158 celoss: 1.158 entropy: 0.190
# 799 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [799] loss: 1.161 celoss: 1.162 entropy: 0.190
# 800 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [800] loss: 1.160 celoss: 1.161 entropy: 0.172
# 801 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [801] loss: 1.162 celoss: 1.163 entropy: 0.172
# 802 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [802] loss: 1.162 celoss: 1.163 entropy: 0.175
# 803 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [803] loss: 1.152 celoss: 1.153 entropy: 0.175
# 804 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [804] loss: 1.152 celoss: 1.153 entropy: 0.177
# 805 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [805] loss: 1.152 celoss: 1.153 entropy: 0.177
# 806 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [806] loss: 1.152 celoss: 1.153 entropy: 0.172
# 807 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [807] loss: 1.151 celoss: 1.152 entropy: 0.172
# 808 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [808] loss: 1.151 celoss: 1.152 entropy: 0.175
# 809 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [809] loss: 1.150 celoss: 1.151 entropy: 0.175
# 810 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [810] loss: 1.150 celoss: 1.151 entropy: 0.177
# 811 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [811] loss: 1.150 celoss: 1.151 entropy: 0.177
# 812 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [812] loss: 1.150 celoss: 1.151 entropy: 0.164
# 813 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [813] loss: 1.149 celoss: 1.150 entropy: 0.164
# 814 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [814] loss: 1.150 celoss: 1.151 entropy: 0.157
# 815 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [815] loss: 1.151 celoss: 1.152 entropy: 0.157
# 816 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [816] loss: 1.150 celoss: 1.151 entropy: 0.166
# 817 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [817] loss: 1.152 celoss: 1.153 entropy: 0.166
# 818 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [818] loss: 1.152 celoss: 1.153 entropy: 0.163
# 819 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [819] loss: 1.148 celoss: 1.149 entropy: 0.163
# 820 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [820] loss: 1.150 celoss: 1.151 entropy: 0.120
# 821 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [821] loss: 1.153 celoss: 1.154 entropy: 0.120
# 822 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [822] loss: 1.152 celoss: 1.153 entropy: 0.107
# 823 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [823] loss: 1.151 celoss: 1.152 entropy: 0.107
# 824 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [824] loss: 1.152 celoss: 1.153 entropy: 0.104
# 825 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [825] loss: 1.153 celoss: 1.154 entropy: 0.104
# 826 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [826] loss: 1.152 celoss: 1.153 entropy: 0.110
# 827 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [827] loss: 1.150 celoss: 1.151 entropy: 0.110
# 828 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [828] loss: 1.151 celoss: 1.152 entropy: 0.112
# 829 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [829] loss: 1.161 celoss: 1.162 entropy: 0.112
# 830 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [830] loss: 1.161 celoss: 1.162 entropy: 0.106
# 831 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [831] loss: 1.149 celoss: 1.150 entropy: 0.106
# 832 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [832] loss: 1.149 celoss: 1.150 entropy: 0.107
# 833 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [833] loss: 1.151 celoss: 1.152 entropy: 0.107
# 834 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [834] loss: 1.151 celoss: 1.152 entropy: 0.108
# 835 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [835] loss: 1.151 celoss: 1.152 entropy: 0.108
# 836 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [836] loss: 1.151 celoss: 1.152 entropy: 0.108
# 837 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [837] loss: 1.149 celoss: 1.150 entropy: 0.108
# 838 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [838] loss: 1.150 celoss: 1.151 entropy: 0.104
# 839 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [839] loss: 1.156 celoss: 1.157 entropy: 0.104
# 840 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [840] loss: 1.155 celoss: 1.156 entropy: 0.107
# ...
# --------------------------------------------------------------------------------
# epoch: [149] loss: 0.022 celoss: 0.022 entropy: 0.285
# 150 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [150] loss: 0.023 celoss: 0.022 entropy: 0.284
# 151 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [151] loss: 0.017 celoss: 0.017 entropy: 0.284
# 152 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [152] loss: 0.017 celoss: 0.017 entropy: 0.292
# 153 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [153] loss: 0.016 celoss: 0.016 entropy: 0.292
# 154 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [154] loss: 0.016 celoss: 0.016 entropy: 0.287
# 155 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [155] loss: 0.016 celoss: 0.016 entropy: 0.287
# 156 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [156] loss: 0.023 celoss: 0.023 entropy: 0.296
# 157 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [157] loss: 0.022 celoss: 0.022 entropy: 0.296
# 158 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [158] loss: 0.019 celoss: 0.019 entropy: 0.284
# 159 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [159] loss: 0.017 celoss: 0.017 entropy: 0.284
# 160 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [160] loss: 0.024 celoss: 0.024 entropy: 0.298
# 161 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [161] loss: 0.024 celoss: 0.024 entropy: 0.298
# 162 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [162] loss: 0.031 celoss: 0.031 entropy: 0.309
# 163 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [163] loss: 0.030 celoss: 0.030 entropy: 0.309
# 164 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [164] loss: 0.018 celoss: 0.018 entropy: 0.293
# 165 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [165] loss: 0.017 celoss: 0.016 entropy: 0.293
# 166 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [166] loss: 0.018 celoss: 0.018 entropy: 0.287
# 167 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [167] loss: 0.017 celoss: 0.017 entropy: 0.287
# 168 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [168] loss: 0.014 celoss: 0.013 entropy: 0.279
# 169 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [169] loss: 0.013 celoss: 0.012 entropy: 0.279
# 170 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [170] loss: 0.018 celoss: 0.018 entropy: 0.296
# 171 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [171] loss: 0.020 celoss: 0.020 entropy: 0.296
# 172 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [172] loss: 0.020 celoss: 0.020 entropy: 0.276
# 173 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [173] loss: 0.014 celoss: 0.014 entropy: 0.276
# 174 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [174] loss: 0.017 celoss: 0.017 entropy: 0.284
# 175 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [175] loss: 0.014 celoss: 0.013 entropy: 0.284
# 176 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [176] loss: 0.015 celoss: 0.014 entropy: 0.272
# 177 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [177] loss: 0.014 celoss: 0.014 entropy: 0.272
# 178 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [178] loss: 0.013 celoss: 0.012 entropy: 0.261
# 179 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [179] loss: 0.011 celoss: 0.011 entropy: 0.261
# 180 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [180] loss: 0.011 celoss: 0.011 entropy: 0.264
# 181 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [181] loss: 0.010 celoss: 0.010 entropy: 0.264
# 182 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [182] loss: 0.013 celoss: 0.013 entropy: 0.272
# 183 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [183] loss: 0.012 celoss: 0.012 entropy: 0.272
# 184 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [184] loss: 0.010 celoss: 0.010 entropy: 0.257
# 185 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [185] loss: 0.010 celoss: 0.010 entropy: 0.257
# 186 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [186] loss: 0.028 celoss: 0.028 entropy: 0.281
# 187 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [187] loss: 0.025 celoss: 0.025 entropy: 0.281
# 188 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [188] loss: 0.016 celoss: 0.016 entropy: 0.257
# 189 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [189] loss: 0.013 celoss: 0.013 entropy: 0.257
# 190 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [190] loss: 0.023 celoss: 0.023 entropy: 0.253
# 191 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [191] loss: 0.020 celoss: 0.020 entropy: 0.253
# 192 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [192] loss: 0.026 celoss: 0.026 entropy: 0.291
# 193 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [193] loss: 0.038 celoss: 0.038 entropy: 0.291
# 194 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [194] loss: 0.018 celoss: 0.018 entropy: 0.266
# 195 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [195] loss: 0.011 celoss: 0.011 entropy: 0.266
# 196 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [196] loss: 0.014 celoss: 0.014 entropy: 0.244
# 197 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [197] loss: 0.011 celoss: 0.011 entropy: 0.244
# 198 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [198] loss: 0.025 celoss: 0.025 entropy: 0.255
# 199 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [199] loss: 0.024 celoss: 0.024 entropy: 0.255
# 200 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [200] loss: 0.033 celoss: 0.033 entropy: 0.242
# 201 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [201] loss: 0.027 celoss: 0.026 entropy: 0.242
# 202 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [202] loss: 0.012 celoss: 0.011 entropy: 0.259
# 203 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [203] loss: 0.010 celoss: 0.010 entropy: 0.259
# 204 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [204] loss: 0.010 celoss: 0.010 entropy: 0.267
# 205 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [205] loss: 0.008 celoss: 0.008 entropy: 0.267
# 206 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [206] loss: 0.008 celoss: 0.008 entropy: 0.254
# 207 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [207] loss: 0.007 celoss: 0.007 entropy: 0.254
# 208 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [208] loss: 0.008 celoss: 0.008 entropy: 0.245
# 209 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [209] loss: 0.008 celoss: 0.007 entropy: 0.245
# 210 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [210] loss: 0.007 celoss: 0.007 entropy: 0.244
# 211 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [211] loss: 0.007 celoss: 0.006 entropy: 0.244
# 212 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [212] loss: 0.007 celoss: 0.007 entropy: 0.256
# 213 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [213] loss: 0.007 celoss: 0.006 entropy: 0.256
# 214 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [214] loss: 0.008 celoss: 0.008 entropy: 0.255
# 215 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [215] loss: 0.009 celoss: 0.009 entropy: 0.255
# 216 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [216] loss: 0.010 celoss: 0.009 entropy: 0.273
# 217 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [217] loss: 0.008 celoss: 0.008 entropy: 0.273
# 218 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [218] loss: 0.010 celoss: 0.010 entropy: 0.270
# 219 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [219] loss: 0.010 celoss: 0.009 entropy: 0.270
# 220 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [220] loss: 0.011 celoss: 0.011 entropy: 0.257
# 221 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [221] loss: 0.009 celoss: 0.009 entropy: 0.257
# 222 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [222] loss: 0.007 celoss: 0.007 entropy: 0.246
# 223 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [223] loss: 0.007 celoss: 0.007 entropy: 0.246
# 224 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [224] loss: 0.007 celoss: 0.007 entropy: 0.254
# 225 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [225] loss: 0.006 celoss: 0.006 entropy: 0.254
# 226 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [226] loss: 0.007 celoss: 0.007 entropy: 0.251
# 227 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [227] loss: 0.009 celoss: 0.008 entropy: 0.251
# 228 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [228] loss: 0.008 celoss: 0.008 entropy: 0.247
# 229 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [229] loss: 0.006 celoss: 0.006 entropy: 0.247
# 230 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [230] loss: 0.006 celoss: 0.006 entropy: 0.245
# 231 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [231] loss: 0.006 celoss: 0.006 entropy: 0.245
# 232 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [232] loss: 0.006 celoss: 0.006 entropy: 0.246
# 233 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [233] loss: 0.005 celoss: 0.005 entropy: 0.246
# 234 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [234] loss: 0.005 celoss: 0.005 entropy: 0.245
# 235 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [235] loss: 0.005 celoss: 0.005 entropy: 0.245
# 236 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [236] loss: 0.005 celoss: 0.005 entropy: 0.243
# 237 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [237] loss: 0.005 celoss: 0.005 entropy: 0.243
# Finished Training run 9
# Accuracy of the network on the 3000 train images: 100 %

# %%
a,b= full_analysis[0]
print(a)
# Out:
# 132

# %%
cnt=1
for epoch, analysis_data in full_analysis:
  analysis_data = np.array(analysis_data)
  # print("="*20+"run ",cnt,"="*20)
  
  plt.figure(figsize=(6,6))
  plt.plot(np.arange(0,epoch+2,1),analysis_data[:,0],label="ftpt")
  plt.plot(np.arange(0,epoch+2,1),analysis_data[:,1],label="ffpt")
  plt.plot(np.arange(0,epoch+2,1),analysis_data[:,2],label="ftpf")
  plt.plot(np.arange(0,epoch+2,1),analysis_data[:,3],label="ffpf")

  plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
  plt.title("Training trends for run "+str(cnt))
  plt.savefig(path+"what_where/every1/run"+str(cnt)+".png",bbox_inches="tight")
  plt.savefig(path+"what_where/every1/run"+str(cnt)+".pdf",bbox_inches="tight")
  cnt+=1

# %%
np.mean(np.array(FTPT_analysis),axis=0) #array([87.85333333,  5.92      ,  0.        ,  6.22666667])
# Out:
# array([6.93466667e+01, 2.44833333e+01, 6.66666667e-03, 6.16333333e+00])

# %%
FTPT_analysis.to_csv(path+"what_where/FTPT_analysis_every1.csv",index=False)

# %%
FTPT_analysis
# Out:
#          FTPT       FFPT      FTPF       FFPF
# 0  100.000000   0.000000  0.000000   0.000000
# 1   97.966667   2.033333  0.000000   0.000000
# 2   67.900000  32.066667  0.033333   0.000000
# 3   66.000000  33.966667  0.000000   0.033333
# 4   73.633333  26.366667  0.000000   0.000000
# 5   85.333333  14.666667  0.000000   0.000000
# 6   67.900000  32.066667  0.033333   0.000000
# 7   66.000000  34.000000  0.000000   0.000000
# 8    2.733333  35.666667  0.000000  61.600000
# 9   66.000000  34.000000  0.000000   0.000000
