# %%
 import numpy as np
import pandas as pd

import torch
import torchvision
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms, utils
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

from matplotlib import pyplot as plt
# %matplotlib inline
from scipy.stats import entropy

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
path="/content/drive/MyDrive/Research/alternate_minimisation/type4_data/"

# %%
class MosaicDataset1(Dataset):
  """MosaicDataset dataset."""

  def __init__(self, mosaic_list, mosaic_label,fore_idx):
    """
      Args:
        csv_file (string): Path to the csv file with annotations.
        root_dir (string): Directory with all the images.
        transform (callable, optional): Optional transform to be applied
            on a sample.
    """
    self.mosaic = mosaic_list
    self.label = mosaic_label
    self.fore_idx = fore_idx
    
  def __len__(self):
    return len(self.label)

  def __getitem__(self, idx):
    return self.mosaic[idx] , self.label[idx] , self.fore_idx[idx]

# %%
class SyntheticDataset(Dataset):
  """MosaicDataset dataset."""

  def __init__(self, x, y):
    """
      Args:
        csv_file (string): Path to the csv file with annotations.
        root_dir (string): Directory with all the images.
        transform (callable, optional): Optional transform to be applied
            on a sample.
    """
    self.x = x
    self.y = y
    #self.fore_idx = fore_idx
    
  def __len__(self):
    return len(self.y)

  def __getitem__(self, idx):
    return self.x[idx] , self.y[idx] #, self.fore_idx[idx]

# %%
train_data = np.load(path+"train_type4_data.npy",allow_pickle=True)
test_data = np.load(path+"test_type4_data.npy",allow_pickle=True)
data = np.load(path+"type_4_data.npy",allow_pickle=True)

# %%
train_mosaic_list_of_images = train_data[0]["mosaic_list"]
train_mosaic_label = train_data[0]["mosaic_label"]
train_fore_idx = train_data[0]["fore_idx"]


test_mosaic_list_of_images = test_data[0]["mosaic_list"]
test_mosaic_label = test_data[0]["mosaic_label"]
test_fore_idx = test_data[0]["fore_idx"]
X = data[0]["X"]
Y = data[0]["Y"]

# %%
batch = 250
tr_msd = MosaicDataset1(train_mosaic_list_of_images, train_mosaic_label, train_fore_idx)
train_loader = DataLoader( tr_msd,batch_size= batch ,shuffle=True)

# %%
batch = 250
tst_msd = MosaicDataset1(test_mosaic_list_of_images, test_mosaic_label, test_fore_idx)
test_loader = DataLoader( tst_msd,batch_size= batch ,shuffle=True)

# %%
dset = SyntheticDataset(X,Y)
dtloader = DataLoader(dset,batch_size =batch,shuffle=True )

# %% [markdown]
# **Focus Net**

# %%
class Module1(nn.Module):
  def __init__(self):
    super(Module1, self).__init__()
    self.fc1 = nn.Linear(2, 100)
    self.fc2 = nn.Linear(100, 1)

  def forward(self, z):
    x = torch.zeros([batch,9],dtype=torch.float64)
    y = torch.zeros([batch,2], dtype=torch.float64)
    x,y = x.to("cuda"),y.to("cuda")
    for i in range(9):
      x[:,i] = self.helper(z[:,i])[:,0]
    
    log_x = F.log_softmax(x,dim=1)  
    x = F.softmax(x,dim=1)   # alphas
    

    for i in range(9):            
      x1 = x[:,i]          
      y = y + torch.mul(x1[:,None],z[:,i])
    return y , x , log_x
  
  def helper(self,x):
    x = F.relu(self.fc1(x))
    x = self.fc2(x)
    return x

# %% [markdown]
# **Classification Net**

# %%
 class Module2(nn.Module):
  def __init__(self):
    super(Module2, self).__init__()
    self.fc1 = nn.Linear(2, 100)
    self.fc2 = nn.Linear(100, 3)

  def forward(self,y):  
    y = F.relu(self.fc1(y))
    y = self.fc2(y)
    return y

# %%
criterion = nn.CrossEntropyLoss()
def my_cross_entropy(x, y,alpha,log_alpha,k):
    # log_prob = -1.0 * F.log_softmax(x, 1)
    # loss = log_prob.gather(1, y.unsqueeze(1))
    # loss = loss.mean()
    loss = criterion(x,y)
    
    #alpha = torch.clamp(alpha,min=1e-10)     
    
    b = -1.0* alpha * log_alpha
    b =  torch.mean(torch.sum(b,dim=1))
    closs = loss
    entropy = b 
    loss = (1-k)*loss + ((k)*b)
    return loss,closs,entropy

# %%
def calculate_attn_loss(dataloader,what,where,criter,k):
  what.eval()
  where.eval()
  r_loss = 0
  cc_loss = 0
  cc_entropy = 0
  alphas = []
  lbls = []
  pred = []
  fidices = []
  with torch.no_grad():
    for i, data in enumerate(dataloader, 0):
      inputs, labels,fidx = data
      lbls.append(labels)
      fidices.append(fidx)
      inputs = inputs.double()
      inputs, labels = inputs.to("cuda"),labels.to("cuda")
      avg,alpha,log_alpha = where(inputs)
      outputs = what(avg)
      _, predicted = torch.max(outputs.data, 1)
      pred.append(predicted.cpu().numpy())
      alphas.append(alpha.cpu().numpy())

      #ent = np.sum(entropy(alpha.cpu().detach().numpy(), base=2, axis=1))/batch
      # mx,_ = torch.max(alpha,1)
      # entropy = np.mean(-np.log2(mx.cpu().detach().numpy()))
      # print("entropy of batch", entropy)

      #loss = (1-k)*criter(outputs, labels) + k*ent
      loss,closs,entropy = my_cross_entropy(outputs,labels,alpha,log_alpha,k)
      r_loss += loss.item()
      cc_loss += closs.item()
      cc_entropy += entropy.item()

  alphas = np.concatenate(alphas,axis=0)
  pred = np.concatenate(pred,axis=0)
  lbls = np.concatenate(lbls,axis=0)
  fidices = np.concatenate(fidices,axis=0)
  #print(alphas.shape,pred.shape,lbls.shape,fidices.shape) 
  analysis = analyse_data(alphas,lbls,pred,fidices)
  return r_loss/i,cc_loss/i,cc_entropy/i,analysis

# %%
def analyse_data(alphas,lbls,predicted,f_idx):
    '''
       analysis data is created here
    '''
    batch = len(predicted)
    amth,alth,ftpt,ffpt,ftpf,ffpf = 0,0,0,0,0,0
    for j in range (batch):
      focus = np.argmax(alphas[j])
      if(alphas[j][focus] >= 0.5):
        amth +=1
      else:
        alth +=1
      if(focus == f_idx[j] and predicted[j] == lbls[j]):
        ftpt += 1
      elif(focus != f_idx[j] and predicted[j] == lbls[j]):
        ffpt +=1
      elif(focus == f_idx[j] and predicted[j] != lbls[j]):
        ftpf +=1
      elif(focus != f_idx[j] and predicted[j] != lbls[j]):
        ffpf +=1
    #print(sum(predicted==lbls),ftpt+ffpt)
    return [ftpt,ffpt,ftpf,ffpf,amth,alth]

# %%
number_runs = 10
full_analysis =[]
FTPT_analysis = pd.DataFrame(columns = ["FTPT","FFPT", "FTPF","FFPF"])
k = 0.001

every_what_epoch = 100

for n in range(number_runs):
  print("--"*40)
  
  # instantiate focus and classification Model
  torch.manual_seed(n)
  where = Module1().double()
  torch.manual_seed(n)
  what = Module2().double()

  where = where.to("cuda")
  what = what.to("cuda")



  # instantiate optimizer
  optimizer_where = optim.Adam(where.parameters(),lr =0.001)
  optimizer_what = optim.Adam(what.parameters(), lr=0.001)
  #criterion = nn.CrossEntropyLoss()
  acti = []
  analysis_data = []
  loss_curi = []
  epochs = 1000


  # calculate zeroth epoch loss and FTPT values
  running_loss ,_,_,anlys_data= calculate_attn_loss(train_loader,what,where,criterion,k)
  loss_curi.append(running_loss)
  analysis_data.append(anlys_data)

  print('epoch: [%d ] loss: %.3f' %(0,running_loss)) 

  # training starts 
  for epoch in range(epochs): # loop over the dataset multiple times
    ep_lossi = []
    running_loss = 0.0
    what.train()
    where.train()
    if ((epoch) % (every_what_epoch*2) ) <= every_what_epoch-1 :
      print(epoch+1,"updating what_net, where_net is freezed")
      print("--"*40)
    elif ((epoch) % (every_what_epoch*2)) > every_what_epoch-1 :
      print(epoch+1,"updating where_net, what_net is freezed")
      print("--"*40)
    for i, data in enumerate(train_loader, 0):
      # get the inputs
      inputs, labels,_ = data
      inputs = inputs.double()
      inputs, labels = inputs.to("cuda"),labels.to("cuda")

      # zero the parameter gradients
      optimizer_where.zero_grad()
      optimizer_what.zero_grad()
      
      # forward + backward + optimize
      avg, alpha,log_alpha = where(inputs)
      outputs = what(avg)

      my_loss,_,_ = my_cross_entropy(outputs,labels,alpha,log_alpha,k)

      # print statistics
      running_loss += my_loss.item()
      my_loss.backward()

      if ((epoch) % (every_what_epoch*2) ) <= every_what_epoch-1 :
        optimizer_what.step()
      elif ( (epoch) % (every_what_epoch*2)) > every_what_epoch-1 :
        optimizer_where.step()
        
      # optimizer_where.step()
      # optimizer_what.step()
    #break
    running_loss,ccloss,ccentropy,anls_data = calculate_attn_loss(train_loader,what,where,criterion,k)
    analysis_data.append(anls_data)
    print('epoch: [%d] loss: %.3f celoss: %.3f entropy: %.3f' %(epoch + 1,running_loss,ccloss,ccentropy)) 
    loss_curi.append(running_loss)   #loss per epoch
    if running_loss<=0.005:
      break
  print('Finished Training run ' +str(n))
  #break
  analysis_data = np.array(analysis_data)
  FTPT_analysis.loc[n] = analysis_data[-1,:4]/30
  full_analysis.append((epoch, analysis_data))
  correct = 0
  total = 0
  with torch.no_grad():
    for data in train_loader:
      images, labels,_ = data
      images = images.double()
      images, labels = images.to("cuda"), labels.to("cuda")
      avg, alpha,log_alpha = where(images)
      outputs  = what(avg)
      _, predicted = torch.max(outputs.data, 1)
      total += labels.size(0)
      correct += (predicted == labels).sum().item()

  print('Accuracy of the network on the 3000 train images: %d %%' % (  100 * correct / total))
# Out:
# Streaming output truncated to the last 5000 lines.
# --------------------------------------------------------------------------------
# epoch: [2] loss: 1.267 celoss: 1.266 entropy: 2.375
# 3 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [3] loss: 1.206 celoss: 1.205 entropy: 2.375
# 4 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [4] loss: 1.209 celoss: 1.207 entropy: 2.375
# 5 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [5] loss: 1.202 celoss: 1.201 entropy: 2.375
# 6 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [6] loss: 1.200 celoss: 1.199 entropy: 2.375
# 7 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [7] loss: 1.198 celoss: 1.197 entropy: 2.375
# 8 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [8] loss: 1.197 celoss: 1.195 entropy: 2.375
# 9 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [9] loss: 1.194 celoss: 1.193 entropy: 2.375
# 10 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [10] loss: 1.193 celoss: 1.192 entropy: 2.375
# 11 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [11] loss: 1.192 celoss: 1.191 entropy: 2.375
# 12 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [12] loss: 1.191 celoss: 1.190 entropy: 2.375
# 13 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [13] loss: 1.191 celoss: 1.189 entropy: 2.375
# 14 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [14] loss: 1.190 celoss: 1.189 entropy: 2.375
# 15 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [15] loss: 1.190 celoss: 1.189 entropy: 2.375
# 16 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [16] loss: 1.190 celoss: 1.189 entropy: 2.375
# 17 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [17] loss: 1.190 celoss: 1.189 entropy: 2.375
# 18 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [18] loss: 1.190 celoss: 1.189 entropy: 2.375
# 19 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [19] loss: 1.189 celoss: 1.188 entropy: 2.375
# 20 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [20] loss: 1.189 celoss: 1.188 entropy: 2.375
# 21 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [21] loss: 1.189 celoss: 1.188 entropy: 2.375
# 22 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [22] loss: 1.189 celoss: 1.188 entropy: 2.375
# 23 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [23] loss: 1.189 celoss: 1.188 entropy: 2.375
# 24 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [24] loss: 1.189 celoss: 1.188 entropy: 2.375
# 25 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [25] loss: 1.189 celoss: 1.188 entropy: 2.375
# 26 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [26] loss: 1.189 celoss: 1.188 entropy: 2.375
# 27 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [27] loss: 1.189 celoss: 1.188 entropy: 2.375
# 28 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [28] loss: 1.191 celoss: 1.189 entropy: 2.375
# 29 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [29] loss: 1.190 celoss: 1.188 entropy: 2.375
# 30 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [30] loss: 1.191 celoss: 1.190 entropy: 2.375
# 31 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [31] loss: 1.189 celoss: 1.188 entropy: 2.375
# 32 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [32] loss: 1.190 celoss: 1.189 entropy: 2.375
# 33 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [33] loss: 1.189 celoss: 1.188 entropy: 2.375
# 34 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [34] loss: 1.189 celoss: 1.188 entropy: 2.375
# 35 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [35] loss: 1.189 celoss: 1.187 entropy: 2.375
# 36 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [36] loss: 1.190 celoss: 1.189 entropy: 2.375
# 37 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [37] loss: 1.189 celoss: 1.188 entropy: 2.375
# 38 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [38] loss: 1.189 celoss: 1.188 entropy: 2.375
# 39 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [39] loss: 1.190 celoss: 1.189 entropy: 2.375
# 40 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [40] loss: 1.189 celoss: 1.188 entropy: 2.375
# 41 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [41] loss: 1.189 celoss: 1.188 entropy: 2.375
# 42 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [42] loss: 1.188 celoss: 1.187 entropy: 2.375
# 43 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [43] loss: 1.189 celoss: 1.188 entropy: 2.375
# 44 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [44] loss: 1.192 celoss: 1.191 entropy: 2.375
# 45 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [45] loss: 1.190 celoss: 1.189 entropy: 2.375
# 46 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [46] loss: 1.189 celoss: 1.188 entropy: 2.375
# 47 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [47] loss: 1.190 celoss: 1.189 entropy: 2.375
# 48 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [48] loss: 1.188 celoss: 1.187 entropy: 2.375
# 49 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [49] loss: 1.188 celoss: 1.187 entropy: 2.375
# 50 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [50] loss: 1.188 celoss: 1.187 entropy: 2.375
# 51 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [51] loss: 1.190 celoss: 1.188 entropy: 2.375
# 52 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [52] loss: 1.188 celoss: 1.186 entropy: 2.375
# 53 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [53] loss: 1.188 celoss: 1.187 entropy: 2.375
# 54 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [54] loss: 1.187 celoss: 1.186 entropy: 2.375
# 55 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [55] loss: 1.187 celoss: 1.186 entropy: 2.375
# 56 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [56] loss: 1.188 celoss: 1.187 entropy: 2.375
# 57 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [57] loss: 1.188 celoss: 1.187 entropy: 2.375
# 58 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [58] loss: 1.187 celoss: 1.186 entropy: 2.375
# 59 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [59] loss: 1.187 celoss: 1.186 entropy: 2.375
# 60 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [60] loss: 1.187 celoss: 1.186 entropy: 2.375
# 61 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [61] loss: 1.187 celoss: 1.186 entropy: 2.375
# 62 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [62] loss: 1.187 celoss: 1.186 entropy: 2.375
# 63 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [63] loss: 1.187 celoss: 1.186 entropy: 2.375
# 64 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [64] loss: 1.188 celoss: 1.187 entropy: 2.375
# 65 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [65] loss: 1.187 celoss: 1.186 entropy: 2.375
# 66 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [66] loss: 1.187 celoss: 1.186 entropy: 2.375
# 67 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [67] loss: 1.188 celoss: 1.187 entropy: 2.375
# 68 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [68] loss: 1.187 celoss: 1.185 entropy: 2.375
# 69 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [69] loss: 1.187 celoss: 1.186 entropy: 2.375
# 70 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [70] loss: 1.187 celoss: 1.186 entropy: 2.375
# 71 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [71] loss: 1.188 celoss: 1.187 entropy: 2.375
# 72 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [72] loss: 1.190 celoss: 1.189 entropy: 2.375
# 73 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [73] loss: 1.187 celoss: 1.186 entropy: 2.375
# 74 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [74] loss: 1.187 celoss: 1.186 entropy: 2.375
# 75 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [75] loss: 1.189 celoss: 1.188 entropy: 2.375
# 76 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [76] loss: 1.193 celoss: 1.191 entropy: 2.375
# 77 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [77] loss: 1.187 celoss: 1.186 entropy: 2.375
# 78 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [78] loss: 1.188 celoss: 1.186 entropy: 2.375
# 79 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [79] loss: 1.186 celoss: 1.185 entropy: 2.375
# 80 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [80] loss: 1.186 celoss: 1.185 entropy: 2.375
# 81 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [81] loss: 1.187 celoss: 1.186 entropy: 2.375
# 82 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [82] loss: 1.189 celoss: 1.188 entropy: 2.375
# 83 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [83] loss: 1.188 celoss: 1.187 entropy: 2.375
# 84 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [84] loss: 1.186 celoss: 1.185 entropy: 2.375
# 85 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [85] loss: 1.187 celoss: 1.186 entropy: 2.375
# 86 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [86] loss: 1.189 celoss: 1.188 entropy: 2.375
# 87 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [87] loss: 1.187 celoss: 1.186 entropy: 2.375
# 88 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [88] loss: 1.187 celoss: 1.186 entropy: 2.375
# 89 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [89] loss: 1.187 celoss: 1.186 entropy: 2.375
# 90 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [90] loss: 1.186 celoss: 1.185 entropy: 2.375
# 91 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [91] loss: 1.187 celoss: 1.186 entropy: 2.375
# 92 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [92] loss: 1.186 celoss: 1.185 entropy: 2.375
# 93 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [93] loss: 1.186 celoss: 1.185 entropy: 2.375
# 94 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [94] loss: 1.186 celoss: 1.185 entropy: 2.375
# 95 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [95] loss: 1.187 celoss: 1.185 entropy: 2.375
# 96 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [96] loss: 1.188 celoss: 1.187 entropy: 2.375
# 97 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [97] loss: 1.187 celoss: 1.186 entropy: 2.375
# 98 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [98] loss: 1.188 celoss: 1.187 entropy: 2.375
# 99 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [99] loss: 1.185 celoss: 1.184 entropy: 2.375
# 100 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [100] loss: 1.190 celoss: 1.189 entropy: 2.375
# 101 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [101] loss: 1.188 celoss: 1.186 entropy: 2.368
# 102 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [102] loss: 1.186 celoss: 1.185 entropy: 2.361
# 103 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [103] loss: 1.185 celoss: 1.184 entropy: 2.350
# 104 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [104] loss: 1.184 celoss: 1.183 entropy: 2.348
# 105 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [105] loss: 1.183 celoss: 1.182 entropy: 2.344
# 106 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [106] loss: 1.182 celoss: 1.181 entropy: 2.341
# 107 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [107] loss: 1.180 celoss: 1.179 entropy: 2.342
# 108 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [108] loss: 1.179 celoss: 1.178 entropy: 2.325
# 109 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [109] loss: 1.178 celoss: 1.176 entropy: 2.317
# 110 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [110] loss: 1.176 celoss: 1.175 entropy: 2.299
# 111 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [111] loss: 1.175 celoss: 1.174 entropy: 2.307
# 112 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [112] loss: 1.174 celoss: 1.172 entropy: 2.290
# 113 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [113] loss: 1.172 celoss: 1.171 entropy: 2.282
# 114 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [114] loss: 1.171 celoss: 1.170 entropy: 2.263
# 115 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [115] loss: 1.169 celoss: 1.168 entropy: 2.248
# 116 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [116] loss: 1.168 celoss: 1.167 entropy: 2.237
# 117 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [117] loss: 1.166 celoss: 1.165 entropy: 2.220
# 118 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [118] loss: 1.165 celoss: 1.164 entropy: 2.206
# 119 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [119] loss: 1.164 celoss: 1.163 entropy: 2.187
# 120 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [120] loss: 1.162 celoss: 1.161 entropy: 2.166
# 121 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [121] loss: 1.160 celoss: 1.159 entropy: 2.135
# 122 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [122] loss: 1.158 celoss: 1.157 entropy: 2.118
# 123 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [123] loss: 1.156 celoss: 1.155 entropy: 2.098
# 124 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [124] loss: 1.154 celoss: 1.153 entropy: 2.070
# 125 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [125] loss: 1.153 celoss: 1.152 entropy: 2.068
# 126 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [126] loss: 1.151 celoss: 1.150 entropy: 2.022
# 127 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [127] loss: 1.149 celoss: 1.149 entropy: 2.010
# 128 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [128] loss: 1.148 celoss: 1.147 entropy: 1.995
# 129 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [129] loss: 1.146 celoss: 1.146 entropy: 1.981
# 130 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [130] loss: 1.145 celoss: 1.144 entropy: 1.954
# 131 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [131] loss: 1.143 celoss: 1.143 entropy: 1.933
# 132 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [132] loss: 1.142 celoss: 1.141 entropy: 1.917
# 133 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [133] loss: 1.140 celoss: 1.140 entropy: 1.889
# 134 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [134] loss: 1.139 celoss: 1.138 entropy: 1.895
# 135 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [135] loss: 1.137 celoss: 1.137 entropy: 1.873
# 136 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [136] loss: 1.136 celoss: 1.135 entropy: 1.853
# 137 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [137] loss: 1.134 celoss: 1.134 entropy: 1.829
# 138 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [138] loss: 1.133 celoss: 1.132 entropy: 1.821
# 139 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [139] loss: 1.131 celoss: 1.131 entropy: 1.803
# 140 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [140] loss: 1.130 celoss: 1.129 entropy: 1.787
# 141 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [141] loss: 1.129 celoss: 1.128 entropy: 1.781
# 142 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [142] loss: 1.127 celoss: 1.126 entropy: 1.760
# 143 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [143] loss: 1.126 celoss: 1.125 entropy: 1.749
# 144 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [144] loss: 1.124 celoss: 1.123 entropy: 1.737
# 145 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [145] loss: 1.123 celoss: 1.122 entropy: 1.734
# 146 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [146] loss: 1.121 celoss: 1.120 entropy: 1.718
# 147 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [147] loss: 1.120 celoss: 1.119 entropy: 1.702
# 148 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [148] loss: 1.118 celoss: 1.117 entropy: 1.700
# 149 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [149] loss: 1.117 celoss: 1.116 entropy: 1.681
# 150 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [150] loss: 1.115 celoss: 1.114 entropy: 1.662
# 151 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [151] loss: 1.113 celoss: 1.113 entropy: 1.663
# 152 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [152] loss: 1.112 celoss: 1.111 entropy: 1.654
# 153 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [153] loss: 1.110 celoss: 1.110 entropy: 1.635
# 154 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [154] loss: 1.109 celoss: 1.108 entropy: 1.641
# 155 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [155] loss: 1.107 celoss: 1.107 entropy: 1.622
# 156 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [156] loss: 1.105 celoss: 1.105 entropy: 1.619
# 157 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [157] loss: 1.104 celoss: 1.103 entropy: 1.610
# 158 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [158] loss: 1.102 celoss: 1.102 entropy: 1.596
# 159 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [159] loss: 1.101 celoss: 1.100 entropy: 1.598
# 160 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [160] loss: 1.099 celoss: 1.099 entropy: 1.565
# 161 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [161] loss: 1.097 celoss: 1.097 entropy: 1.571
# 162 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [162] loss: 1.096 celoss: 1.095 entropy: 1.570
# 163 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [163] loss: 1.094 celoss: 1.094 entropy: 1.547
# 164 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [164] loss: 1.092 celoss: 1.092 entropy: 1.545
# 165 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [165] loss: 1.091 celoss: 1.090 entropy: 1.531
# 166 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [166] loss: 1.089 celoss: 1.088 entropy: 1.533
# 167 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [167] loss: 1.087 celoss: 1.087 entropy: 1.514
# 168 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [168] loss: 1.086 celoss: 1.085 entropy: 1.516
# 169 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [169] loss: 1.084 celoss: 1.083 entropy: 1.506
# 170 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [170] loss: 1.082 celoss: 1.082 entropy: 1.499
# 171 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [171] loss: 1.080 celoss: 1.080 entropy: 1.489
# 172 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [172] loss: 1.079 celoss: 1.078 entropy: 1.477
# 173 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [173] loss: 1.077 celoss: 1.076 entropy: 1.476
# 174 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [174] loss: 1.075 celoss: 1.075 entropy: 1.469
# 175 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [175] loss: 1.073 celoss: 1.073 entropy: 1.452
# 176 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [176] loss: 1.071 celoss: 1.071 entropy: 1.459
# 177 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [177] loss: 1.069 celoss: 1.069 entropy: 1.442
# 178 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [178] loss: 1.068 celoss: 1.067 entropy: 1.441
# 179 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [179] loss: 1.066 celoss: 1.065 entropy: 1.435
# 180 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [180] loss: 1.064 celoss: 1.063 entropy: 1.439
# 181 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [181] loss: 1.061 celoss: 1.061 entropy: 1.434
# 182 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [182] loss: 1.059 celoss: 1.059 entropy: 1.428
# 183 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [183] loss: 1.057 celoss: 1.057 entropy: 1.423
# 184 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [184] loss: 1.055 celoss: 1.055 entropy: 1.433
# 185 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [185] loss: 1.052 celoss: 1.052 entropy: 1.432
# 186 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [186] loss: 1.050 celoss: 1.050 entropy: 1.436
# 187 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [187] loss: 1.048 celoss: 1.048 entropy: 1.426
# 188 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [188] loss: 1.046 celoss: 1.045 entropy: 1.419
# 189 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [189] loss: 1.043 celoss: 1.043 entropy: 1.401
# 190 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [190] loss: 1.042 celoss: 1.041 entropy: 1.397
# 191 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [191] loss: 1.039 celoss: 1.039 entropy: 1.377
# 192 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [192] loss: 1.037 celoss: 1.037 entropy: 1.369
# 193 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [193] loss: 1.035 celoss: 1.035 entropy: 1.359
# 194 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [194] loss: 1.033 celoss: 1.033 entropy: 1.346
# 195 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [195] loss: 1.031 celoss: 1.031 entropy: 1.340
# 196 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [196] loss: 1.029 celoss: 1.029 entropy: 1.330
# 197 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [197] loss: 1.027 celoss: 1.027 entropy: 1.314
# 198 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [198] loss: 1.025 celoss: 1.025 entropy: 1.308
# 199 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [199] loss: 1.023 celoss: 1.023 entropy: 1.296
# 200 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [200] loss: 1.021 celoss: 1.021 entropy: 1.287
# 201 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [201] loss: 0.902 celoss: 0.902 entropy: 1.287
# 202 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [202] loss: 0.818 celoss: 0.817 entropy: 1.287
# 203 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [203] loss: 0.743 celoss: 0.743 entropy: 1.287
# 204 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [204] loss: 0.695 celoss: 0.694 entropy: 1.287
# 205 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [205] loss: 0.656 celoss: 0.655 entropy: 1.287
# 206 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [206] loss: 0.626 celoss: 0.626 entropy: 1.287
# 207 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [207] loss: 0.601 celoss: 0.601 entropy: 1.287
# 208 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [208] loss: 0.581 celoss: 0.580 entropy: 1.287
# 209 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [209] loss: 0.565 celoss: 0.564 entropy: 1.287
# 210 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [210] loss: 0.549 celoss: 0.549 entropy: 1.287
# 211 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [211] loss: 0.537 celoss: 0.536 entropy: 1.287
# 212 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [212] loss: 0.523 celoss: 0.523 entropy: 1.287
# 213 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [213] loss: 0.508 celoss: 0.507 entropy: 1.287
# 214 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [214] loss: 0.499 celoss: 0.498 entropy: 1.287
# 215 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [215] loss: 0.488 celoss: 0.488 entropy: 1.287
# 216 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [216] loss: 0.477 celoss: 0.477 entropy: 1.287
# 217 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [217] loss: 0.469 celoss: 0.468 entropy: 1.287
# 218 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [218] loss: 0.460 celoss: 0.459 entropy: 1.287
# 219 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [219] loss: 0.452 celoss: 0.451 entropy: 1.287
# 220 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [220] loss: 0.446 celoss: 0.445 entropy: 1.287
# 221 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [221] loss: 0.436 celoss: 0.436 entropy: 1.287
# 222 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [222] loss: 0.431 celoss: 0.430 entropy: 1.287
# 223 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [223] loss: 0.423 celoss: 0.422 entropy: 1.287
# 224 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [224] loss: 0.415 celoss: 0.414 entropy: 1.287
# 225 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [225] loss: 0.409 celoss: 0.409 entropy: 1.287
# 226 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [226] loss: 0.403 celoss: 0.402 entropy: 1.287
# 227 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [227] loss: 0.396 celoss: 0.396 entropy: 1.287
# 228 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [228] loss: 0.393 celoss: 0.392 entropy: 1.287
# 229 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [229] loss: 0.385 celoss: 0.384 entropy: 1.287
# 230 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [230] loss: 0.379 celoss: 0.378 entropy: 1.287
# 231 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [231] loss: 0.376 celoss: 0.375 entropy: 1.287
# 232 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [232] loss: 0.369 celoss: 0.368 entropy: 1.287
# 233 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [233] loss: 0.365 celoss: 0.364 entropy: 1.287
# 234 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [234] loss: 0.359 celoss: 0.358 entropy: 1.287
# 235 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [235] loss: 0.355 celoss: 0.354 entropy: 1.287
# 236 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [236] loss: 0.352 celoss: 0.351 entropy: 1.287
# 237 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [237] loss: 0.346 celoss: 0.345 entropy: 1.287
# 238 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [238] loss: 0.342 celoss: 0.341 entropy: 1.287
# 239 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [239] loss: 0.337 celoss: 0.336 entropy: 1.287
# 240 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [240] loss: 0.333 celoss: 0.332 entropy: 1.287
# 241 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [241] loss: 0.329 celoss: 0.328 entropy: 1.287
# 242 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [242] loss: 0.326 celoss: 0.325 entropy: 1.287
# 243 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [243] loss: 0.321 celoss: 0.320 entropy: 1.287
# 244 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [244] loss: 0.318 celoss: 0.317 entropy: 1.287
# 245 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [245] loss: 0.314 celoss: 0.313 entropy: 1.287
# 246 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [246] loss: 0.310 celoss: 0.309 entropy: 1.287
# 247 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [247] loss: 0.307 celoss: 0.306 entropy: 1.287
# 248 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [248] loss: 0.306 celoss: 0.305 entropy: 1.287
# 249 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [249] loss: 0.300 celoss: 0.299 entropy: 1.287
# 250 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [250] loss: 0.297 celoss: 0.296 entropy: 1.287
# 251 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [251] loss: 0.299 celoss: 0.298 entropy: 1.287
# 252 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [252] loss: 0.291 celoss: 0.290 entropy: 1.287
# 253 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [253] loss: 0.293 celoss: 0.292 entropy: 1.287
# 254 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [254] loss: 0.286 celoss: 0.285 entropy: 1.287
# 255 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [255] loss: 0.284 celoss: 0.283 entropy: 1.287
# 256 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [256] loss: 0.280 celoss: 0.279 entropy: 1.287
# 257 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [257] loss: 0.277 celoss: 0.276 entropy: 1.287
# 258 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [258] loss: 0.274 celoss: 0.273 entropy: 1.287
# 259 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [259] loss: 0.273 celoss: 0.272 entropy: 1.287
# 260 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [260] loss: 0.269 celoss: 0.268 entropy: 1.287
# 261 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [261] loss: 0.266 celoss: 0.265 entropy: 1.287
# 262 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [262] loss: 0.265 celoss: 0.264 entropy: 1.287
# 263 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [263] loss: 0.261 celoss: 0.260 entropy: 1.287
# 264 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [264] loss: 0.259 celoss: 0.258 entropy: 1.287
# 265 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [265] loss: 0.258 celoss: 0.257 entropy: 1.287
# 266 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [266] loss: 0.255 celoss: 0.254 entropy: 1.287
# 267 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [267] loss: 0.253 celoss: 0.252 entropy: 1.287
# 268 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [268] loss: 0.250 celoss: 0.249 entropy: 1.287
# 269 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [269] loss: 0.250 celoss: 0.249 entropy: 1.287
# 270 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [270] loss: 0.246 celoss: 0.245 entropy: 1.287
# 271 updating what_net, where_net is freezed
# ...
# --------------------------------------------------------------------------------
# epoch: [912] loss: 0.037 celoss: 0.035 entropy: 1.149
# 913 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [913] loss: 0.038 celoss: 0.037 entropy: 1.142
# 914 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [914] loss: 0.036 celoss: 0.035 entropy: 1.135
# 915 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [915] loss: 0.036 celoss: 0.035 entropy: 1.140
# 916 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [916] loss: 0.036 celoss: 0.035 entropy: 1.141
# 917 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [917] loss: 0.036 celoss: 0.035 entropy: 1.137
# 918 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [918] loss: 0.036 celoss: 0.035 entropy: 1.134
# 919 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [919] loss: 0.036 celoss: 0.034 entropy: 1.146
# 920 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [920] loss: 0.035 celoss: 0.034 entropy: 1.134
# 921 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [921] loss: 0.035 celoss: 0.034 entropy: 1.137
# 922 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [922] loss: 0.035 celoss: 0.034 entropy: 1.137
# 923 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [923] loss: 0.035 celoss: 0.034 entropy: 1.136
# 924 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [924] loss: 0.035 celoss: 0.034 entropy: 1.133
# 925 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [925] loss: 0.035 celoss: 0.034 entropy: 1.134
# 926 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [926] loss: 0.036 celoss: 0.035 entropy: 1.133
# 927 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [927] loss: 0.035 celoss: 0.034 entropy: 1.134
# 928 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [928] loss: 0.034 celoss: 0.033 entropy: 1.133
# 929 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [929] loss: 0.034 celoss: 0.033 entropy: 1.130
# 930 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [930] loss: 0.035 celoss: 0.034 entropy: 1.126
# 931 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [931] loss: 0.035 celoss: 0.034 entropy: 1.132
# 932 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [932] loss: 0.035 celoss: 0.034 entropy: 1.129
# 933 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [933] loss: 0.034 celoss: 0.033 entropy: 1.128
# 934 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [934] loss: 0.034 celoss: 0.033 entropy: 1.132
# 935 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [935] loss: 0.035 celoss: 0.034 entropy: 1.132
# 936 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [936] loss: 0.036 celoss: 0.035 entropy: 1.126
# 937 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [937] loss: 0.034 celoss: 0.033 entropy: 1.125
# 938 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [938] loss: 0.034 celoss: 0.033 entropy: 1.127
# 939 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [939] loss: 0.034 celoss: 0.033 entropy: 1.124
# 940 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [940] loss: 0.034 celoss: 0.033 entropy: 1.125
# 941 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [941] loss: 0.034 celoss: 0.032 entropy: 1.125
# 942 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [942] loss: 0.033 celoss: 0.032 entropy: 1.124
# 943 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [943] loss: 0.034 celoss: 0.033 entropy: 1.125
# 944 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [944] loss: 0.033 celoss: 0.032 entropy: 1.128
# 945 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [945] loss: 0.033 celoss: 0.032 entropy: 1.121
# 946 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [946] loss: 0.033 celoss: 0.032 entropy: 1.123
# 947 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [947] loss: 0.034 celoss: 0.033 entropy: 1.117
# 948 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [948] loss: 0.033 celoss: 0.032 entropy: 1.119
# 949 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [949] loss: 0.033 celoss: 0.032 entropy: 1.123
# 950 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [950] loss: 0.033 celoss: 0.032 entropy: 1.121
# 951 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [951] loss: 0.033 celoss: 0.032 entropy: 1.122
# 952 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [952] loss: 0.033 celoss: 0.032 entropy: 1.116
# 953 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [953] loss: 0.033 celoss: 0.032 entropy: 1.119
# 954 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [954] loss: 0.033 celoss: 0.032 entropy: 1.114
# 955 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [955] loss: 0.033 celoss: 0.032 entropy: 1.118
# 956 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [956] loss: 0.033 celoss: 0.031 entropy: 1.119
# 957 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [957] loss: 0.032 celoss: 0.031 entropy: 1.113
# 958 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [958] loss: 0.034 celoss: 0.033 entropy: 1.112
# 959 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [959] loss: 0.032 celoss: 0.031 entropy: 1.113
# 960 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [960] loss: 0.032 celoss: 0.031 entropy: 1.122
# 961 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [961] loss: 0.032 celoss: 0.031 entropy: 1.116
# 962 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [962] loss: 0.032 celoss: 0.031 entropy: 1.113
# 963 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [963] loss: 0.032 celoss: 0.031 entropy: 1.113
# 964 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [964] loss: 0.032 celoss: 0.031 entropy: 1.118
# 965 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [965] loss: 0.033 celoss: 0.032 entropy: 1.116
# 966 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [966] loss: 0.032 celoss: 0.031 entropy: 1.112
# 967 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [967] loss: 0.032 celoss: 0.031 entropy: 1.117
# 968 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [968] loss: 0.032 celoss: 0.031 entropy: 1.118
# 969 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [969] loss: 0.032 celoss: 0.031 entropy: 1.107
# 970 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [970] loss: 0.032 celoss: 0.031 entropy: 1.108
# 971 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [971] loss: 0.032 celoss: 0.031 entropy: 1.113
# 972 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [972] loss: 0.032 celoss: 0.031 entropy: 1.105
# 973 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [973] loss: 0.032 celoss: 0.031 entropy: 1.111
# 974 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [974] loss: 0.033 celoss: 0.032 entropy: 1.110
# 975 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [975] loss: 0.034 celoss: 0.033 entropy: 1.107
# 976 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [976] loss: 0.032 celoss: 0.031 entropy: 1.109
# 977 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [977] loss: 0.032 celoss: 0.031 entropy: 1.107
# 978 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [978] loss: 0.034 celoss: 0.033 entropy: 1.106
# 979 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [979] loss: 0.032 celoss: 0.031 entropy: 1.110
# 980 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [980] loss: 0.032 celoss: 0.031 entropy: 1.109
# 981 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [981] loss: 0.032 celoss: 0.031 entropy: 1.114
# 982 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [982] loss: 0.032 celoss: 0.031 entropy: 1.101
# 983 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [983] loss: 0.032 celoss: 0.031 entropy: 1.111
# 984 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [984] loss: 0.032 celoss: 0.031 entropy: 1.101
# 985 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [985] loss: 0.032 celoss: 0.031 entropy: 1.104
# 986 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [986] loss: 0.032 celoss: 0.031 entropy: 1.110
# 987 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [987] loss: 0.032 celoss: 0.030 entropy: 1.104
# 988 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [988] loss: 0.033 celoss: 0.032 entropy: 1.105
# 989 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [989] loss: 0.032 celoss: 0.031 entropy: 1.104
# 990 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [990] loss: 0.031 celoss: 0.030 entropy: 1.103
# 991 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [991] loss: 0.032 celoss: 0.031 entropy: 1.104
# 992 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [992] loss: 0.033 celoss: 0.032 entropy: 1.100
# 993 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [993] loss: 0.033 celoss: 0.032 entropy: 1.104
# 994 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [994] loss: 0.031 celoss: 0.030 entropy: 1.107
# 995 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [995] loss: 0.031 celoss: 0.030 entropy: 1.106
# 996 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [996] loss: 0.031 celoss: 0.030 entropy: 1.100
# 997 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [997] loss: 0.031 celoss: 0.030 entropy: 1.103
# 998 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [998] loss: 0.033 celoss: 0.032 entropy: 1.097
# 999 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [999] loss: 0.031 celoss: 0.030 entropy: 1.100
# 1000 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1000] loss: 0.032 celoss: 0.031 entropy: 1.100
# Finished Training run 9
# Accuracy of the network on the 3000 train images: 99 %

# %%
a,b= full_analysis[0]
print(a)
# Out:
# 715

# %%
cnt=1
for epoch, analysis_data in full_analysis:
  analysis_data = np.array(analysis_data)
  # print("="*20+"run ",cnt,"="*20)
  
  plt.figure(figsize=(6,6))
  plt.plot(np.arange(0,epoch+2,1),analysis_data[:,0],label="ftpt")
  plt.plot(np.arange(0,epoch+2,1),analysis_data[:,1],label="ffpt")
  plt.plot(np.arange(0,epoch+2,1),analysis_data[:,2],label="ftpf")
  plt.plot(np.arange(0,epoch+2,1),analysis_data[:,3],label="ffpf")

  plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
  plt.title("Training trends for run "+str(cnt))
  plt.savefig(path+"what_where/every100/run"+str(cnt)+".png",bbox_inches="tight")
  plt.savefig(path+"what_where/every100/run"+str(cnt)+".pdf",bbox_inches="tight")
  cnt+=1

# %%
np.mean(np.array(FTPT_analysis),axis=0) #array([87.85333333,  5.92      ,  0.        ,  6.22666667])
# Out:
# array([9.02533333e+01, 9.71000000e+00, 3.33333333e-03, 3.33333333e-02])

# %%
FTPT_analysis.to_csv(path+"what_where/FTPT_analysis_every100.csv",index=False)

# %%
FTPT_analysis
# Out:
#          FTPT       FFPT      FTPF      FFPF
# 0   78.133333  21.866667  0.000000  0.000000
# 1   99.966667   0.033333  0.000000  0.000000
# 2   98.200000   1.800000  0.000000  0.000000
# 3   78.533333  21.466667  0.000000  0.000000
# 4   98.733333   1.266667  0.000000  0.000000
# 5  100.000000   0.000000  0.000000  0.000000
# 6   99.100000   0.900000  0.000000  0.000000
# 7   99.666667   0.333333  0.000000  0.000000
# 8   97.000000   3.000000  0.000000  0.000000
# 9   53.200000  46.433333  0.033333  0.333333
