# %%
 import numpy as np
import pandas as pd

import torch
import torchvision
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms, utils
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

from matplotlib import pyplot as plt
# %matplotlib inline
from scipy.stats import entropy

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
path="/content/drive/MyDrive/Research/alternate_minimisation/type4_data/"

# %%
class MosaicDataset1(Dataset):
  """MosaicDataset dataset."""

  def __init__(self, mosaic_list, mosaic_label,fore_idx):
    """
      Args:
        csv_file (string): Path to the csv file with annotations.
        root_dir (string): Directory with all the images.
        transform (callable, optional): Optional transform to be applied
            on a sample.
    """
    self.mosaic = mosaic_list
    self.label = mosaic_label
    self.fore_idx = fore_idx
    
  def __len__(self):
    return len(self.label)

  def __getitem__(self, idx):
    return self.mosaic[idx] , self.label[idx] , self.fore_idx[idx]

# %%
class SyntheticDataset(Dataset):
  """MosaicDataset dataset."""

  def __init__(self, x, y):
    """
      Args:
        csv_file (string): Path to the csv file with annotations.
        root_dir (string): Directory with all the images.
        transform (callable, optional): Optional transform to be applied
            on a sample.
    """
    self.x = x
    self.y = y
    #self.fore_idx = fore_idx
    
  def __len__(self):
    return len(self.y)

  def __getitem__(self, idx):
    return self.x[idx] , self.y[idx] #, self.fore_idx[idx]

# %%
train_data = np.load(path+"train_type4_data.npy",allow_pickle=True)
test_data = np.load(path+"test_type4_data.npy",allow_pickle=True)
data = np.load(path+"type_4_data.npy",allow_pickle=True)

# %%
train_mosaic_list_of_images = train_data[0]["mosaic_list"]
train_mosaic_label = train_data[0]["mosaic_label"]
train_fore_idx = train_data[0]["fore_idx"]


test_mosaic_list_of_images = test_data[0]["mosaic_list"]
test_mosaic_label = test_data[0]["mosaic_label"]
test_fore_idx = test_data[0]["fore_idx"]
X = data[0]["X"]
Y = data[0]["Y"]

# %%
batch = 250
tr_msd = MosaicDataset1(train_mosaic_list_of_images, train_mosaic_label, train_fore_idx)
train_loader = DataLoader( tr_msd,batch_size= batch ,shuffle=True)

# %%
batch = 250
tst_msd = MosaicDataset1(test_mosaic_list_of_images, test_mosaic_label, test_fore_idx)
test_loader = DataLoader( tst_msd,batch_size= batch ,shuffle=True)

# %%
dset = SyntheticDataset(X,Y)
dtloader = DataLoader(dset,batch_size =batch,shuffle=True )

# %% [markdown]
# **Focus Net**

# %%
class Module1(nn.Module):
  def __init__(self):
    super(Module1, self).__init__()
    self.fc1 = nn.Linear(2, 100)
    self.fc2 = nn.Linear(100, 1)

  def forward(self, z):
    x = torch.zeros([batch,9],dtype=torch.float64)
    y = torch.zeros([batch,2], dtype=torch.float64)
    x,y = x.to("cuda"),y.to("cuda")
    for i in range(9):
      x[:,i] = self.helper(z[:,i])[:,0]
    
    log_x = F.log_softmax(x,dim=1)  
    x = F.softmax(x,dim=1)   # alphas
    

    for i in range(9):            
      x1 = x[:,i]          
      y = y + torch.mul(x1[:,None],z[:,i])
    return y , x , log_x
  
  def helper(self,x):
    x = F.relu(self.fc1(x))
    x = self.fc2(x)
    return x

# %% [markdown]
# **Classification Net**

# %%
 class Module2(nn.Module):
  def __init__(self):
    super(Module2, self).__init__()
    self.fc1 = nn.Linear(2, 100)
    self.fc2 = nn.Linear(100, 3)

  def forward(self,y):  
    y = F.relu(self.fc1(y))
    y = self.fc2(y)
    return y

# %%
criterion = nn.CrossEntropyLoss()
def my_cross_entropy(x, y,alpha,log_alpha,k):
    # log_prob = -1.0 * F.log_softmax(x, 1)
    # loss = log_prob.gather(1, y.unsqueeze(1))
    # loss = loss.mean()
    loss = criterion(x,y)
    
    #alpha = torch.clamp(alpha,min=1e-10)     
    
    b = -1.0* alpha * log_alpha
    b =  torch.mean(torch.sum(b,dim=1))
    closs = loss
    entropy = b 
    loss = (1-k)*loss + ((k)*b)
    return loss,closs,entropy

# %%
def calculate_attn_loss(dataloader,what,where,criter,k):
  what.eval()
  where.eval()
  r_loss = 0
  cc_loss = 0
  cc_entropy = 0
  alphas = []
  lbls = []
  pred = []
  fidices = []
  with torch.no_grad():
    for i, data in enumerate(dataloader, 0):
      inputs, labels,fidx = data
      lbls.append(labels)
      fidices.append(fidx)
      inputs = inputs.double()
      inputs, labels = inputs.to("cuda"),labels.to("cuda")
      avg,alpha,log_alpha = where(inputs)
      outputs = what(avg)
      _, predicted = torch.max(outputs.data, 1)
      pred.append(predicted.cpu().numpy())
      alphas.append(alpha.cpu().numpy())

      #ent = np.sum(entropy(alpha.cpu().detach().numpy(), base=2, axis=1))/batch
      # mx,_ = torch.max(alpha,1)
      # entropy = np.mean(-np.log2(mx.cpu().detach().numpy()))
      # print("entropy of batch", entropy)

      #loss = (1-k)*criter(outputs, labels) + k*ent
      loss,closs,entropy = my_cross_entropy(outputs,labels,alpha,log_alpha,k)
      r_loss += loss.item()
      cc_loss += closs.item()
      cc_entropy += entropy.item()

  alphas = np.concatenate(alphas,axis=0)
  pred = np.concatenate(pred,axis=0)
  lbls = np.concatenate(lbls,axis=0)
  fidices = np.concatenate(fidices,axis=0)
  #print(alphas.shape,pred.shape,lbls.shape,fidices.shape) 
  analysis = analyse_data(alphas,lbls,pred,fidices)
  return r_loss/i,cc_loss/i,cc_entropy/i,analysis

# %%
def analyse_data(alphas,lbls,predicted,f_idx):
    '''
       analysis data is created here
    '''
    batch = len(predicted)
    amth,alth,ftpt,ffpt,ftpf,ffpf = 0,0,0,0,0,0
    for j in range (batch):
      focus = np.argmax(alphas[j])
      if(alphas[j][focus] >= 0.5):
        amth +=1
      else:
        alth +=1
      if(focus == f_idx[j] and predicted[j] == lbls[j]):
        ftpt += 1
      elif(focus != f_idx[j] and predicted[j] == lbls[j]):
        ffpt +=1
      elif(focus == f_idx[j] and predicted[j] != lbls[j]):
        ftpf +=1
      elif(focus != f_idx[j] and predicted[j] != lbls[j]):
        ffpf +=1
    #print(sum(predicted==lbls),ftpt+ffpt)
    return [ftpt,ffpt,ftpf,ffpf,amth,alth]

# %%
number_runs = 10
full_analysis =[]
FTPT_analysis = pd.DataFrame(columns = ["FTPT","FFPT", "FTPF","FFPF"])
k = 0.001

every_what_epoch = 5

for n in range(number_runs):
  print("--"*40)
  
  # instantiate focus and classification Model
  torch.manual_seed(n)
  where = Module1().double()
  torch.manual_seed(n)
  what = Module2().double()
  
  where = where.to("cuda")
  what = what.to("cuda")



  # instantiate optimizer
  optimizer_where = optim.Adam(where.parameters(),lr =0.01)
  optimizer_what = optim.Adam(what.parameters(), lr=0.01)
  #criterion = nn.CrossEntropyLoss()
  acti = []
  analysis_data = []
  loss_curi = []
  epochs = 2000


  # calculate zeroth epoch loss and FTPT values
  running_loss ,_,_,anlys_data= calculate_attn_loss(train_loader,what,where,criterion,k)
  loss_curi.append(running_loss)
  analysis_data.append(anlys_data)

  print('epoch: [%d ] loss: %.3f' %(0,running_loss)) 

  # training starts 
  for epoch in range(epochs): # loop over the dataset multiple times
    ep_lossi = []
    running_loss = 0.0
    what.train()
    where.train()
    if ((epoch) % (every_what_epoch*2) ) <= every_what_epoch-1 :
      print(epoch+1,"updating what_net, where_net is freezed")
      print("--"*40)
    elif ((epoch) % (every_what_epoch*2)) > every_what_epoch-1 :
      print(epoch+1,"updating where_net, what_net is freezed")
      print("--"*40)
    for i, data in enumerate(train_loader, 0):
      # get the inputs
      inputs, labels,_ = data
      inputs = inputs.double()
      inputs, labels = inputs.to("cuda"),labels.to("cuda")

      # zero the parameter gradients
      optimizer_where.zero_grad()
      optimizer_what.zero_grad()
      
      # forward + backward + optimize
      avg, alpha,log_alpha = where(inputs)
      outputs = what(avg)

      my_loss,_,_ = my_cross_entropy(outputs,labels,alpha,log_alpha,k)

      # print statistics
      running_loss += my_loss.item()
      my_loss.backward()

      if ((epoch) % (every_what_epoch*2) ) <= every_what_epoch-1 :
        optimizer_what.step()
      elif ( (epoch) % (every_what_epoch*2)) > every_what_epoch-1 :
        optimizer_where.step()
        
      # optimizer_where.step()
      # optimizer_what.step()
    #break
    running_loss,ccloss,ccentropy,anls_data = calculate_attn_loss(train_loader,what,where,criterion,k)
    analysis_data.append(anls_data)
    print('epoch: [%d] loss: %.3f celoss: %.3f entropy: %.3f' %(epoch + 1,running_loss,ccloss,ccentropy)) 
    loss_curi.append(running_loss)   #loss per epoch
    if running_loss<=0.005:
      break
  print('Finished Training run ' +str(n))
  #break
  analysis_data = np.array(analysis_data)
  FTPT_analysis.loc[n] = analysis_data[-1,:4]/30
  full_analysis.append((epoch, analysis_data))
  correct = 0
  total = 0
  with torch.no_grad():
    for data in train_loader:
      images, labels,_ = data
      images = images.double()
      images, labels = images.to("cuda"), labels.to("cuda")
      avg, alpha,log_alpha = where(images)
      outputs  = what(avg)
      _, predicted = torch.max(outputs.data, 1)
      total += labels.size(0)
      correct += (predicted == labels).sum().item()

  print('Accuracy of the network on the 3000 train images: %d %%' % (  100 * correct / total))
# Out:
# Streaming output truncated to the last 5000 lines.
# 48 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [48] loss: 0.225 celoss: 0.224 entropy: 1.008
# 49 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [49] loss: 0.205 celoss: 0.204 entropy: 0.943
# 50 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [50] loss: 0.187 celoss: 0.186 entropy: 0.914
# 51 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [51] loss: 0.160 celoss: 0.159 entropy: 0.914
# 52 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [52] loss: 0.137 celoss: 0.137 entropy: 0.914
# 53 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [53] loss: 0.120 celoss: 0.119 entropy: 0.914
# 54 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [54] loss: 0.117 celoss: 0.116 entropy: 0.914
# 55 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [55] loss: 0.095 celoss: 0.094 entropy: 0.914
# 56 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [56] loss: 0.084 celoss: 0.083 entropy: 0.876
# 57 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [57] loss: 0.080 celoss: 0.079 entropy: 0.842
# 58 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [58] loss: 0.073 celoss: 0.072 entropy: 0.825
# 59 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [59] loss: 0.069 celoss: 0.068 entropy: 0.815
# 60 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [60] loss: 0.067 celoss: 0.066 entropy: 0.801
# 61 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [61] loss: 0.059 celoss: 0.059 entropy: 0.801
# 62 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [62] loss: 0.053 celoss: 0.052 entropy: 0.801
# 63 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [63] loss: 0.050 celoss: 0.049 entropy: 0.801
# 64 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [64] loss: 0.045 celoss: 0.044 entropy: 0.801
# 65 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [65] loss: 0.042 celoss: 0.041 entropy: 0.801
# 66 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [66] loss: 0.039 celoss: 0.038 entropy: 0.797
# 67 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [67] loss: 0.038 celoss: 0.037 entropy: 0.791
# 68 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [68] loss: 0.035 celoss: 0.034 entropy: 0.771
# 69 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [69] loss: 0.036 celoss: 0.035 entropy: 0.770
# 70 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [70] loss: 0.033 celoss: 0.032 entropy: 0.749
# 71 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [71] loss: 0.031 celoss: 0.031 entropy: 0.749
# 72 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [72] loss: 0.028 celoss: 0.028 entropy: 0.749
# 73 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [73] loss: 0.027 celoss: 0.027 entropy: 0.749
# 74 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [74] loss: 0.025 celoss: 0.024 entropy: 0.749
# 75 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [75] loss: 0.024 celoss: 0.023 entropy: 0.749
# 76 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [76] loss: 0.023 celoss: 0.022 entropy: 0.742
# 77 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [77] loss: 0.023 celoss: 0.022 entropy: 0.739
# 78 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [78] loss: 0.022 celoss: 0.021 entropy: 0.726
# 79 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [79] loss: 0.022 celoss: 0.021 entropy: 0.716
# 80 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [80] loss: 0.021 celoss: 0.020 entropy: 0.710
# 81 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [81] loss: 0.020 celoss: 0.019 entropy: 0.710
# 82 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [82] loss: 0.019 celoss: 0.018 entropy: 0.710
# 83 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [83] loss: 0.018 celoss: 0.017 entropy: 0.710
# 84 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [84] loss: 0.017 celoss: 0.016 entropy: 0.710
# 85 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [85] loss: 0.017 celoss: 0.017 entropy: 0.710
# 86 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [86] loss: 0.017 celoss: 0.016 entropy: 0.705
# 87 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [87] loss: 0.017 celoss: 0.016 entropy: 0.698
# 88 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [88] loss: 0.017 celoss: 0.016 entropy: 0.695
# 89 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [89] loss: 0.016 celoss: 0.016 entropy: 0.689
# 90 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [90] loss: 0.016 celoss: 0.016 entropy: 0.686
# 91 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [91] loss: 0.015 celoss: 0.014 entropy: 0.686
# 92 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [92] loss: 0.014 celoss: 0.014 entropy: 0.686
# 93 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [93] loss: 0.014 celoss: 0.013 entropy: 0.686
# 94 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [94] loss: 0.015 celoss: 0.014 entropy: 0.686
# 95 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [95] loss: 0.013 celoss: 0.013 entropy: 0.686
# 96 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [96] loss: 0.012 celoss: 0.011 entropy: 0.687
# 97 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [97] loss: 0.011 celoss: 0.011 entropy: 0.688
# 98 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [98] loss: 0.011 celoss: 0.010 entropy: 0.683
# 99 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [99] loss: 0.011 celoss: 0.010 entropy: 0.678
# 100 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [100] loss: 0.011 celoss: 0.010 entropy: 0.674
# 101 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [101] loss: 0.011 celoss: 0.010 entropy: 0.674
# 102 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [102] loss: 0.010 celoss: 0.009 entropy: 0.674
# 103 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [103] loss: 0.010 celoss: 0.009 entropy: 0.674
# 104 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [104] loss: 0.009 celoss: 0.009 entropy: 0.674
# 105 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [105] loss: 0.009 celoss: 0.008 entropy: 0.674
# 106 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [106] loss: 0.009 celoss: 0.008 entropy: 0.670
# 107 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [107] loss: 0.009 celoss: 0.008 entropy: 0.667
# 108 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [108] loss: 0.009 celoss: 0.008 entropy: 0.665
# 109 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [109] loss: 0.009 celoss: 0.008 entropy: 0.661
# 110 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [110] loss: 0.008 celoss: 0.008 entropy: 0.659
# 111 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [111] loss: 0.009 celoss: 0.008 entropy: 0.659
# 112 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [112] loss: 0.008 celoss: 0.007 entropy: 0.659
# 113 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [113] loss: 0.008 celoss: 0.007 entropy: 0.659
# 114 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [114] loss: 0.007 celoss: 0.007 entropy: 0.659
# 115 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [115] loss: 0.007 celoss: 0.007 entropy: 0.659
# 116 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [116] loss: 0.007 celoss: 0.006 entropy: 0.656
# 117 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [117] loss: 0.007 celoss: 0.006 entropy: 0.654
# 118 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [118] loss: 0.007 celoss: 0.006 entropy: 0.651
# 119 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [119] loss: 0.007 celoss: 0.006 entropy: 0.650
# 120 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [120] loss: 0.007 celoss: 0.006 entropy: 0.646
# 121 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [121] loss: 0.007 celoss: 0.006 entropy: 0.646
# 122 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [122] loss: 0.006 celoss: 0.006 entropy: 0.646
# 123 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [123] loss: 0.006 celoss: 0.006 entropy: 0.646
# 124 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [124] loss: 0.006 celoss: 0.005 entropy: 0.646
# 125 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [125] loss: 0.006 celoss: 0.005 entropy: 0.646
# 126 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [126] loss: 0.006 celoss: 0.005 entropy: 0.644
# 127 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [127] loss: 0.006 celoss: 0.005 entropy: 0.641
# 128 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [128] loss: 0.006 celoss: 0.005 entropy: 0.640
# 129 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [129] loss: 0.006 celoss: 0.005 entropy: 0.637
# 130 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [130] loss: 0.006 celoss: 0.005 entropy: 0.636
# 131 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [131] loss: 0.005 celoss: 0.005 entropy: 0.636
# 132 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [132] loss: 0.005 celoss: 0.005 entropy: 0.636
# 133 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [133] loss: 0.005 celoss: 0.005 entropy: 0.636
# 134 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [134] loss: 0.005 celoss: 0.004 entropy: 0.636
# 135 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [135] loss: 0.005 celoss: 0.004 entropy: 0.636
# Finished Training run 0
# Accuracy of the network on the 3000 train images: 100 %
# --------------------------------------------------------------------------------
# epoch: [0 ] loss: 1.822
# 1 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [1] loss: 1.247 celoss: 1.246 entropy: 2.377
# 2 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [2] loss: 1.192 celoss: 1.191 entropy: 2.377
# 3 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [3] loss: 1.194 celoss: 1.192 entropy: 2.377
# 4 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [4] loss: 1.192 celoss: 1.191 entropy: 2.377
# 5 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [5] loss: 1.195 celoss: 1.194 entropy: 2.377
# 6 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [6] loss: 1.192 celoss: 1.191 entropy: 2.168
# 7 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [7] loss: 1.183 celoss: 1.182 entropy: 2.306
# 8 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [8] loss: 1.178 celoss: 1.177 entropy: 2.199
# 9 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [9] loss: 1.172 celoss: 1.171 entropy: 2.054
# 10 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [10] loss: 1.164 celoss: 1.164 entropy: 1.967
# 11 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [11] loss: 1.091 celoss: 1.090 entropy: 1.967
# 12 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [12] loss: 1.015 celoss: 1.014 entropy: 1.967
# 13 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [13] loss: 0.995 celoss: 0.994 entropy: 1.967
# 14 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [14] loss: 1.021 celoss: 1.020 entropy: 1.967
# 15 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [15] loss: 1.001 celoss: 1.000 entropy: 1.967
# 16 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [16] loss: 0.918 celoss: 0.917 entropy: 1.678
# 17 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [17] loss: 0.858 celoss: 0.857 entropy: 1.633
# 18 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [18] loss: 0.809 celoss: 0.808 entropy: 1.563
# 19 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [19] loss: 0.790 celoss: 0.790 entropy: 1.513
# 20 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [20] loss: 0.760 celoss: 0.759 entropy: 1.480
# 21 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [21] loss: 0.721 celoss: 0.720 entropy: 1.480
# 22 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [22] loss: 0.637 celoss: 0.637 entropy: 1.480
# 23 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [23] loss: 0.586 celoss: 0.585 entropy: 1.480
# 24 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [24] loss: 0.611 celoss: 0.610 entropy: 1.480
# 25 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [25] loss: 0.537 celoss: 0.536 entropy: 1.480
# 26 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [26] loss: 0.496 celoss: 0.495 entropy: 1.399
# 27 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [27] loss: 0.464 celoss: 0.463 entropy: 1.371
# 28 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [28] loss: 0.444 celoss: 0.443 entropy: 1.367
# 29 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [29] loss: 0.419 celoss: 0.418 entropy: 1.346
# 30 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [30] loss: 0.412 celoss: 0.411 entropy: 1.296
# 31 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [31] loss: 0.369 celoss: 0.368 entropy: 1.296
# 32 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [32] loss: 0.347 celoss: 0.346 entropy: 1.296
# 33 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [33] loss: 0.324 celoss: 0.323 entropy: 1.296
# 34 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [34] loss: 0.305 celoss: 0.304 entropy: 1.296
# 35 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [35] loss: 0.282 celoss: 0.281 entropy: 1.296
# 36 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [36] loss: 0.264 celoss: 0.263 entropy: 1.268
# 37 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [37] loss: 0.286 celoss: 0.285 entropy: 1.277
# 38 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [38] loss: 0.236 celoss: 0.234 entropy: 1.258
# 39 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [39] loss: 0.271 celoss: 0.270 entropy: 1.201
# 40 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [40] loss: 0.244 celoss: 0.243 entropy: 1.176
# 41 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [41] loss: 0.211 celoss: 0.210 entropy: 1.176
# 42 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [42] loss: 0.198 celoss: 0.197 entropy: 1.176
# 43 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [43] loss: 0.181 celoss: 0.180 entropy: 1.176
# 44 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [44] loss: 0.173 celoss: 0.172 entropy: 1.176
# 45 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [45] loss: 0.172 celoss: 0.171 entropy: 1.176
# 46 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [46] loss: 0.153 celoss: 0.152 entropy: 1.203
# 47 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [47] loss: 0.144 celoss: 0.142 entropy: 1.215
# 48 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [48] loss: 0.136 celoss: 0.135 entropy: 1.160
# 49 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [49] loss: 0.136 celoss: 0.135 entropy: 1.166
# 50 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [50] loss: 0.127 celoss: 0.126 entropy: 1.178
# 51 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [51] loss: 0.116 celoss: 0.115 entropy: 1.178
# 52 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [52] loss: 0.109 celoss: 0.108 entropy: 1.178
# 53 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [53] loss: 0.101 celoss: 0.100 entropy: 1.178
# 54 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [54] loss: 0.098 celoss: 0.097 entropy: 1.178
# 55 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [55] loss: 0.092 celoss: 0.090 entropy: 1.178
# 56 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [56] loss: 0.090 celoss: 0.089 entropy: 1.113
# 57 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [57] loss: 0.087 celoss: 0.086 entropy: 1.128
# 58 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [58] loss: 0.084 celoss: 0.083 entropy: 1.118
# 59 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [59] loss: 0.078 celoss: 0.077 entropy: 1.120
# 60 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [60] loss: 0.075 celoss: 0.074 entropy: 1.111
# 61 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [61] loss: 0.070 celoss: 0.069 entropy: 1.111
# 62 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [62] loss: 0.066 celoss: 0.065 entropy: 1.111
# 63 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [63] loss: 0.067 celoss: 0.066 entropy: 1.111
# 64 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [64] loss: 0.062 celoss: 0.061 entropy: 1.111
# 65 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [65] loss: 0.063 celoss: 0.062 entropy: 1.111
# 66 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [66] loss: 0.063 celoss: 0.062 entropy: 1.060
# 67 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [67] loss: 0.062 celoss: 0.061 entropy: 1.059
# 68 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [68] loss: 0.055 celoss: 0.054 entropy: 1.059
# 69 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [69] loss: 0.074 celoss: 0.073 entropy: 1.032
# 70 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [70] loss: 0.057 celoss: 0.056 entropy: 1.026
# 71 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [71] loss: 0.053 celoss: 0.052 entropy: 1.026
# 72 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [72] loss: 0.051 celoss: 0.050 entropy: 1.026
# 73 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [73] loss: 0.049 celoss: 0.048 entropy: 1.026
# 74 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [74] loss: 0.047 celoss: 0.046 entropy: 1.026
# 75 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [75] loss: 0.046 celoss: 0.045 entropy: 1.026
# 76 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [76] loss: 0.040 celoss: 0.039 entropy: 1.036
# 77 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [77] loss: 0.040 celoss: 0.039 entropy: 1.063
# 78 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [78] loss: 0.039 celoss: 0.038 entropy: 1.047
# 79 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [79] loss: 0.038 celoss: 0.037 entropy: 1.051
# 80 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [80] loss: 0.040 celoss: 0.039 entropy: 1.037
# 81 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [81] loss: 0.040 celoss: 0.039 entropy: 1.037
# 82 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [82] loss: 0.035 celoss: 0.034 entropy: 1.037
# 83 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [83] loss: 0.033 celoss: 0.032 entropy: 1.037
# 84 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [84] loss: 0.033 celoss: 0.032 entropy: 1.037
# 85 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [85] loss: 0.032 celoss: 0.031 entropy: 1.037
# 86 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [86] loss: 0.030 celoss: 0.029 entropy: 1.011
# 87 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [87] loss: 0.030 celoss: 0.029 entropy: 1.039
# 88 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [88] loss: 0.032 celoss: 0.031 entropy: 1.037
# 89 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [89] loss: 0.032 celoss: 0.031 entropy: 1.013
# 90 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [90] loss: 0.031 celoss: 0.030 entropy: 0.997
# 91 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [91] loss: 0.031 celoss: 0.030 entropy: 0.997
# 92 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [92] loss: 0.029 celoss: 0.028 entropy: 0.997
# 93 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [93] loss: 0.028 celoss: 0.027 entropy: 0.997
# 94 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [94] loss: 0.028 celoss: 0.027 entropy: 0.997
# 95 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [95] loss: 0.025 celoss: 0.024 entropy: 0.997
# 96 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [96] loss: 0.025 celoss: 0.024 entropy: 0.991
# 97 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [97] loss: 0.024 celoss: 0.023 entropy: 1.010
# 98 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [98] loss: 0.025 celoss: 0.025 entropy: 0.976
# 99 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [99] loss: 0.024 celoss: 0.023 entropy: 0.993
# 100 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [100] loss: 0.024 celoss: 0.023 entropy: 0.990
# 101 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [101] loss: 0.025 celoss: 0.025 entropy: 0.990
# 102 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [102] loss: 0.022 celoss: 0.021 entropy: 0.990
# 103 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [103] loss: 0.022 celoss: 0.021 entropy: 0.990
# 104 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [104] loss: 0.021 celoss: 0.020 entropy: 0.990
# 105 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [105] loss: 0.020 celoss: 0.019 entropy: 0.990
# 106 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [106] loss: 0.019 celoss: 0.018 entropy: 1.001
# 107 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [107] loss: 0.020 celoss: 0.019 entropy: 0.981
# 108 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [108] loss: 0.024 celoss: 0.023 entropy: 0.956
# 109 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [109] loss: 0.020 celoss: 0.019 entropy: 0.983
# 110 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [110] loss: 0.019 celoss: 0.018 entropy: 1.007
# 111 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [111] loss: 0.018 celoss: 0.017 entropy: 1.007
# 112 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [112] loss: 0.018 celoss: 0.017 entropy: 1.007
# 113 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [113] loss: 0.017 celoss: 0.016 entropy: 1.007
# 114 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [114] loss: 0.017 celoss: 0.016 entropy: 1.007
# 115 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [115] loss: 0.018 celoss: 0.017 entropy: 1.007
# 116 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [116] loss: 0.018 celoss: 0.017 entropy: 0.978
# 117 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [117] loss: 0.017 celoss: 0.016 entropy: 0.940
# 118 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [118] loss: 0.017 celoss: 0.016 entropy: 0.968
# 119 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [119] loss: 0.017 celoss: 0.016 entropy: 0.954
# 120 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [120] loss: 0.016 celoss: 0.015 entropy: 0.964
# 121 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [121] loss: 0.017 celoss: 0.016 entropy: 0.964
# 122 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [122] loss: 0.015 celoss: 0.014 entropy: 0.964
# 123 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [123] loss: 0.017 celoss: 0.016 entropy: 0.964
# 124 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [124] loss: 0.014 celoss: 0.013 entropy: 0.964
# 125 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [125] loss: 0.014 celoss: 0.013 entropy: 0.964
# 126 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [126] loss: 0.014 celoss: 0.013 entropy: 0.953
# 127 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [127] loss: 0.014 celoss: 0.013 entropy: 0.948
# 128 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [128] loss: 0.014 celoss: 0.013 entropy: 0.963
# 129 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [129] loss: 0.014 celoss: 0.013 entropy: 0.951
# 130 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [130] loss: 0.014 celoss: 0.013 entropy: 0.960
# 131 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [131] loss: 0.013 celoss: 0.012 entropy: 0.960
# 132 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [132] loss: 0.013 celoss: 0.012 entropy: 0.960
# 133 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [133] loss: 0.012 celoss: 0.011 entropy: 0.960
# 134 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [134] loss: 0.013 celoss: 0.012 entropy: 0.960
# 135 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [135] loss: 0.012 celoss: 0.011 entropy: 0.960
# 136 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [136] loss: 0.013 celoss: 0.012 entropy: 0.944
# 137 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [137] loss: 0.011 celoss: 0.010 entropy: 0.955
# 138 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [138] loss: 0.012 celoss: 0.011 entropy: 0.942
# 139 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [139] loss: 0.011 celoss: 0.010 entropy: 0.950
# 140 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [140] loss: 0.011 celoss: 0.010 entropy: 0.945
# 141 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [141] loss: 0.013 celoss: 0.012 entropy: 0.945
# 142 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [142] loss: 0.015 celoss: 0.014 entropy: 0.945
# 143 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [143] loss: 0.011 celoss: 0.010 entropy: 0.945
# 144 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [144] loss: 0.014 celoss: 0.014 entropy: 0.945
# 145 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [145] loss: 0.013 celoss: 0.012 entropy: 0.945
# 146 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [146] loss: 0.012 celoss: 0.011 entropy: 0.982
# 147 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [147] loss: 0.011 celoss: 0.010 entropy: 0.979
# 148 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [148] loss: 0.013 celoss: 0.012 entropy: 0.991
# 149 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [149] loss: 0.014 celoss: 0.013 entropy: 0.967
# 150 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [150] loss: 0.013 celoss: 0.012 entropy: 0.953
# 151 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [151] loss: 0.011 celoss: 0.010 entropy: 0.953
# 152 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [152] loss: 0.014 celoss: 0.013 entropy: 0.953
# 153 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [153] loss: 0.010 celoss: 0.009 entropy: 0.953
# 154 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [154] loss: 0.011 celoss: 0.010 entropy: 0.953
# 155 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [155] loss: 0.012 celoss: 0.011 entropy: 0.953
# 156 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [156] loss: 0.011 celoss: 0.010 entropy: 0.918
# 157 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [157] loss: 0.011 celoss: 0.010 entropy: 0.913
# 158 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [158] loss: 0.011 celoss: 0.010 entropy: 0.911
# 159 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [159] loss: 0.010 celoss: 0.010 entropy: 0.908
# 160 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [160] loss: 0.010 celoss: 0.009 entropy: 0.912
# 161 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [161] loss: 0.009 celoss: 0.009 entropy: 0.912
# 162 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [162] loss: 0.014 celoss: 0.013 entropy: 0.912
# 163 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [163] loss: 0.011 celoss: 0.010 entropy: 0.912
# 164 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [164] loss: 0.009 celoss: 0.008 entropy: 0.912
# 165 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [165] loss: 0.009 celoss: 0.008 entropy: 0.912
# 166 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [166] loss: 0.009 celoss: 0.008 entropy: 0.925
# 167 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [167] loss: 0.009 celoss: 0.008 entropy: 0.935
# 168 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [168] loss: 0.011 celoss: 0.011 entropy: 0.903
# 169 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [169] loss: 0.008 celoss: 0.007 entropy: 0.928
# 170 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [170] loss: 0.008 celoss: 0.007 entropy: 0.944
# 171 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [171] loss: 0.008 celoss: 0.007 entropy: 0.944
# 172 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [172] loss: 0.008 celoss: 0.007 entropy: 0.944
# 173 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [173] loss: 0.009 celoss: 0.008 entropy: 0.944
# 174 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [174] loss: 0.008 celoss: 0.007 entropy: 0.944
# 175 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [175] loss: 0.015 celoss: 0.014 entropy: 0.944
# 176 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [176] loss: 0.016 celoss: 0.015 entropy: 1.019
# 177 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [177] loss: 0.017 celoss: 0.016 entropy: 0.966
# 178 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [178] loss: 0.013 celoss: 0.012 entropy: 0.993
# 179 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [179] loss: 0.013 celoss: 0.012 entropy: 1.017
# 180 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [180] loss: 0.015 celoss: 0.014 entropy: 0.963
# 181 updating what_net, where_net is freezed
# ...
# --------------------------------------------------------------------------------
# epoch: [159] loss: 0.011 celoss: 0.010 entropy: 0.958
# 160 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [160] loss: 0.011 celoss: 0.010 entropy: 0.960
# 161 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [161] loss: 0.010 celoss: 0.009 entropy: 0.960
# 162 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [162] loss: 0.010 celoss: 0.009 entropy: 0.960
# 163 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [163] loss: 0.010 celoss: 0.009 entropy: 0.960
# 164 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [164] loss: 0.010 celoss: 0.009 entropy: 0.960
# 165 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [165] loss: 0.011 celoss: 0.010 entropy: 0.960
# 166 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [166] loss: 0.012 celoss: 0.011 entropy: 0.976
# 167 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [167] loss: 0.012 celoss: 0.012 entropy: 0.956
# 168 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [168] loss: 0.011 celoss: 0.010 entropy: 0.957
# 169 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [169] loss: 0.010 celoss: 0.009 entropy: 0.967
# 170 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [170] loss: 0.015 celoss: 0.014 entropy: 0.956
# 171 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [171] loss: 0.014 celoss: 0.013 entropy: 0.956
# 172 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [172] loss: 0.013 celoss: 0.012 entropy: 0.956
# 173 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [173] loss: 0.013 celoss: 0.012 entropy: 0.956
# 174 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [174] loss: 0.013 celoss: 0.012 entropy: 0.956
# 175 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [175] loss: 0.014 celoss: 0.013 entropy: 0.956
# 176 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [176] loss: 0.009 celoss: 0.008 entropy: 0.955
# 177 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [177] loss: 0.011 celoss: 0.010 entropy: 0.946
# 178 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [178] loss: 0.012 celoss: 0.011 entropy: 0.982
# 179 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [179] loss: 0.018 celoss: 0.017 entropy: 0.901
# 180 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [180] loss: 0.016 celoss: 0.015 entropy: 0.928
# 181 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [181] loss: 0.011 celoss: 0.010 entropy: 0.928
# 182 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [182] loss: 0.012 celoss: 0.011 entropy: 0.928
# 183 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [183] loss: 0.011 celoss: 0.011 entropy: 0.928
# 184 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [184] loss: 0.010 celoss: 0.009 entropy: 0.928
# 185 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [185] loss: 0.011 celoss: 0.010 entropy: 0.928
# 186 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [186] loss: 0.011 celoss: 0.010 entropy: 0.965
# 187 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [187] loss: 0.008 celoss: 0.007 entropy: 0.920
# 188 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [188] loss: 0.009 celoss: 0.008 entropy: 0.942
# 189 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [189] loss: 0.009 celoss: 0.009 entropy: 0.969
# 190 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [190] loss: 0.012 celoss: 0.011 entropy: 0.963
# 191 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [191] loss: 0.010 celoss: 0.009 entropy: 0.963
# 192 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [192] loss: 0.008 celoss: 0.007 entropy: 0.963
# 193 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [193] loss: 0.008 celoss: 0.007 entropy: 0.963
# 194 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [194] loss: 0.008 celoss: 0.007 entropy: 0.963
# 195 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [195] loss: 0.008 celoss: 0.007 entropy: 0.963
# 196 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [196] loss: 0.008 celoss: 0.007 entropy: 0.967
# 197 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [197] loss: 0.008 celoss: 0.007 entropy: 0.940
# 198 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [198] loss: 0.007 celoss: 0.006 entropy: 0.933
# 199 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [199] loss: 0.008 celoss: 0.007 entropy: 0.939
# 200 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [200] loss: 0.007 celoss: 0.006 entropy: 0.940
# 201 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [201] loss: 0.007 celoss: 0.006 entropy: 0.940
# 202 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [202] loss: 0.007 celoss: 0.006 entropy: 0.940
# 203 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [203] loss: 0.006 celoss: 0.006 entropy: 0.940
# 204 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [204] loss: 0.007 celoss: 0.006 entropy: 0.940
# 205 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [205] loss: 0.006 celoss: 0.006 entropy: 0.940
# 206 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [206] loss: 0.008 celoss: 0.007 entropy: 0.938
# 207 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [207] loss: 0.007 celoss: 0.006 entropy: 0.928
# 208 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [208] loss: 0.008 celoss: 0.007 entropy: 0.918
# 209 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [209] loss: 0.006 celoss: 0.005 entropy: 0.915
# 210 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [210] loss: 0.007 celoss: 0.007 entropy: 0.909
# 211 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [211] loss: 0.007 celoss: 0.006 entropy: 0.909
# 212 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [212] loss: 0.007 celoss: 0.006 entropy: 0.909
# 213 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [213] loss: 0.006 celoss: 0.006 entropy: 0.909
# 214 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [214] loss: 0.008 celoss: 0.007 entropy: 0.909
# 215 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [215] loss: 0.007 celoss: 0.006 entropy: 0.909
# 216 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [216] loss: 0.007 celoss: 0.006 entropy: 0.884
# 217 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [217] loss: 0.007 celoss: 0.006 entropy: 0.883
# 218 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [218] loss: 0.007 celoss: 0.006 entropy: 0.877
# 219 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [219] loss: 0.007 celoss: 0.006 entropy: 0.865
# 220 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [220] loss: 0.007 celoss: 0.006 entropy: 0.866
# 221 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [221] loss: 0.009 celoss: 0.008 entropy: 0.866
# 222 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [222] loss: 0.007 celoss: 0.006 entropy: 0.866
# 223 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [223] loss: 0.006 celoss: 0.006 entropy: 0.866
# 224 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [224] loss: 0.006 celoss: 0.005 entropy: 0.866
# 225 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [225] loss: 0.006 celoss: 0.005 entropy: 0.866
# 226 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [226] loss: 0.006 celoss: 0.005 entropy: 0.886
# 227 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [227] loss: 0.006 celoss: 0.005 entropy: 0.879
# 228 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [228] loss: 0.006 celoss: 0.005 entropy: 0.884
# 229 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [229] loss: 0.006 celoss: 0.005 entropy: 0.890
# 230 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [230] loss: 0.006 celoss: 0.005 entropy: 0.877
# 231 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [231] loss: 0.006 celoss: 0.005 entropy: 0.877
# 232 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [232] loss: 0.006 celoss: 0.005 entropy: 0.877
# 233 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [233] loss: 0.006 celoss: 0.005 entropy: 0.877
# 234 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [234] loss: 0.006 celoss: 0.005 entropy: 0.877
# 235 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [235] loss: 0.006 celoss: 0.005 entropy: 0.877
# 236 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [236] loss: 0.006 celoss: 0.005 entropy: 0.877
# 237 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [237] loss: 0.005 celoss: 0.004 entropy: 0.890
# 238 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [238] loss: 0.007 celoss: 0.006 entropy: 0.890
# 239 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [239] loss: 0.005 celoss: 0.004 entropy: 0.883
# 240 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [240] loss: 0.006 celoss: 0.005 entropy: 0.878
# 241 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [241] loss: 0.005 celoss: 0.004 entropy: 0.878
# 242 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [242] loss: 0.006 celoss: 0.005 entropy: 0.878
# 243 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [243] loss: 0.006 celoss: 0.005 entropy: 0.878
# 244 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [244] loss: 0.005 celoss: 0.004 entropy: 0.878
# 245 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# epoch: [245] loss: 0.005 celoss: 0.004 entropy: 0.878
# 246 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [246] loss: 0.005 celoss: 0.004 entropy: 0.873
# 247 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# epoch: [247] loss: 0.005 celoss: 0.004 entropy: 0.877
# Finished Training run 9
# Accuracy of the network on the 3000 train images: 100 %

# %%
a,b= full_analysis[0]
print(a)
# Out:
# 134

# %%
cnt=1
for epoch, analysis_data in full_analysis:
  analysis_data = np.array(analysis_data)
  # print("="*20+"run ",cnt,"="*20)
  
  plt.figure(figsize=(6,6))
  plt.plot(np.arange(0,epoch+2,1),analysis_data[:,0],label="ftpt")
  plt.plot(np.arange(0,epoch+2,1),analysis_data[:,1],label="ffpt")
  plt.plot(np.arange(0,epoch+2,1),analysis_data[:,2],label="ftpf")
  plt.plot(np.arange(0,epoch+2,1),analysis_data[:,3],label="ffpf")

  plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
  plt.title("Training trends for run "+str(cnt))
  plt.savefig(path+"what_where/every5/run"+str(cnt)+".png",bbox_inches="tight")
  plt.savefig(path+"what_where/every5/run"+str(cnt)+".pdf",bbox_inches="tight")
  cnt+=1

# %%
np.mean(np.array(FTPT_analysis),axis=0) #array([87.85333333,  5.92      ,  0.        ,  6.22666667])
# Out:
# array([9.58633333e+01, 4.13333333e+00, 3.33333333e-03, 0.00000000e+00])

# %%
FTPT_analysis.to_csv(path+"what_where/FTPT_analysis_every5.csv",index=False)

# %%
FTPT_analysis
# Out:
#         FTPT       FFPT      FTPF  FFPF
# 0  96.266667   3.733333  0.000000   0.0
# 1  99.833333   0.166667  0.000000   0.0
# 2  99.833333   0.166667  0.000000   0.0
# 3  93.100000   6.900000  0.000000   0.0
# 4  99.666667   0.300000  0.033333   0.0
# 5  98.833333   1.166667  0.000000   0.0
# 6  93.033333   6.966667  0.000000   0.0
# 7  88.566667  11.433333  0.000000   0.0
# 8  99.966667   0.033333  0.000000   0.0
# 9  89.533333  10.466667  0.000000   0.0
