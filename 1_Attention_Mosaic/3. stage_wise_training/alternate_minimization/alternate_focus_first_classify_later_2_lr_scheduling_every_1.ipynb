# %%
import numpy as np
import pandas as pd

import torch
import torchvision
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms, utils
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

from matplotlib import pyplot as plt
# %matplotlib inline

# %% [markdown]
# # load mosaic data

# %%
transform = transforms.Compose(
    [transforms.ToTensor(),
     transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))])

trainset = torchvision.datasets.CIFAR10(root='./data', train=True, download=True, transform=transform)


testset = torchvision.datasets.CIFAR10(root='./data', train=False, download=True, transform=transform)
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to ./data/cifar-10-python.tar.gz
# HBox(children=(FloatProgress(value=0.0, max=170498071.0), HTML(value='')))
# Extracting ./data/cifar-10-python.tar.gz to ./data
# Files already downloaded and verified

# %%
trainloader = torch.utils.data.DataLoader(trainset, batch_size=10, shuffle=True)
testloader = torch.utils.data.DataLoader(testset, batch_size=10, shuffle=False)


classes = ('plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck')

foreground_classes = {'plane', 'car', 'bird'}
#foreground_classes = {'bird', 'cat', 'deer'}
background_classes = {'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck'}
#background_classes = {'plane', 'car', 'dog', 'frog', 'horse','ship', 'truck'}

fg1,fg2,fg3 = 0,1,2

# %%
dataiter = iter(trainloader)
background_data=[]
background_label=[]
foreground_data=[]
foreground_label=[]
batch_size=10

for i in range(5000):
  images, labels = dataiter.next()
  for j in range(batch_size):
    if(classes[labels[j]] in background_classes):
      img = images[j].tolist()
      background_data.append(img)
      background_label.append(labels[j])
    else:
      img = images[j].tolist()
      foreground_data.append(img)
      foreground_label.append(labels[j])
            
foreground_data = torch.tensor(foreground_data)
foreground_label = torch.tensor(foreground_label)
background_data = torch.tensor(background_data)
background_label = torch.tensor(background_label)

# %%
def create_mosaic_img(bg_idx,fg_idx,fg): 
  """
  bg_idx : list of indexes of background_data[] to be used as background images in mosaic
  fg_idx : index of image to be used as foreground image from foreground data
  fg : at what position/index foreground image has to be stored out of 0-8
  """
  image_list=[]
  j=0
  for i in range(9):
    if i != fg:
      image_list.append(background_data[bg_idx[j]])#.type("torch.DoubleTensor"))
      j+=1
    else: 
      image_list.append(foreground_data[fg_idx])#.type("torch.DoubleTensor"))
      label = foreground_label[fg_idx]-fg1  # minus 7 because our fore ground classes are 7,8,9 but we have to store it as 0,1,2
  #image_list = np.concatenate(image_list ,axis=0)
  image_list = torch.stack(image_list) 
  return image_list,label

# %%
desired_num = 30000
mosaic_list_of_images =[]      # list of mosaic images, each mosaic image is saved as list of 9 images
fore_idx =[]                   # list of indexes at which foreground image is present in a mosaic image i.e from 0 to 9               
mosaic_label=[]                # label of mosaic image = foreground class present in that mosaic
for i in range(desired_num):
  np.random.seed(i)
  bg_idx = np.random.randint(0,35000,8)
  fg_idx = np.random.randint(0,15000)
  fg = np.random.randint(0,9)
  fore_idx.append(fg)
  image_list,label = create_mosaic_img(bg_idx,fg_idx,fg)
  mosaic_list_of_images.append(image_list)
  mosaic_label.append(label)

# %%
class MosaicDataset(Dataset):
  """MosaicDataset dataset."""

  def __init__(self, mosaic_list_of_images, mosaic_label, fore_idx):
    """
      Args:
        csv_file (string): Path to the csv file with annotations.
        root_dir (string): Directory with all the images.
        transform (callable, optional): Optional transform to be applied
            on a sample.
    """
    self.mosaic = mosaic_list_of_images
    self.label = mosaic_label
    self.fore_idx = fore_idx

  def __len__(self):
    return len(self.label)

  def __getitem__(self, idx):
    return self.mosaic[idx] , self.label[idx], self.fore_idx[idx]

batch = 250
msd = MosaicDataset(mosaic_list_of_images, mosaic_label , fore_idx)
train_loader = DataLoader( msd,batch_size= batch ,shuffle=True)

# %%
test_images =[]        #list of mosaic images, each mosaic image is saved as laist of 9 images
fore_idx_test =[]                   #list of indexes at which foreground image is present in a mosaic image                
test_label=[]                # label of mosaic image = foreground class present in that mosaic
for i in range(10000):
  np.random.seed(i+30000)
  bg_idx = np.random.randint(0,35000,8)
  fg_idx = np.random.randint(0,15000)
  fg = np.random.randint(0,9)
  fore_idx_test.append(fg)
  image_list,label = create_mosaic_img(bg_idx,fg_idx,fg)
  test_images.append(image_list)
  test_label.append(label)

# %%
test_data = MosaicDataset(test_images,test_label,fore_idx_test)
test_loader = DataLoader( test_data,batch_size= batch ,shuffle=False)

# %% [markdown]
# # models

# %%
class Module1(nn.Module):
  def __init__(self):
    super(Module1, self).__init__()
    self.conv1 = nn.Conv2d(3, 6, 5)
    self.pool = nn.MaxPool2d(2, 2)
    self.conv2 = nn.Conv2d(6, 16, 5)
    self.fc1 = nn.Linear(16 * 5 * 5, 120)
    self.fc2 = nn.Linear(120, 84)
    self.fc3 = nn.Linear(84, 10)
    self.fc4 = nn.Linear(10,1)

  def forward(self, z):
    x = torch.zeros([batch,9],dtype=torch.float64)
    y = torch.zeros([batch,3, 32,32], dtype=torch.float64)
    x,y = x.to("cuda"),y.to("cuda")
    for i in range(9):
      x[:,i] = self.helper(z[:,i])[:,0]
    x = F.softmax(x,dim=1)   # alphas
    
    x1 = x[:,0]
    torch.mul(x1[:,None,None,None],z[:,0])

    for i in range(9):            
      x1 = x[:,i]          
      y = y + torch.mul(x1[:,None,None,None],z[:,i])
    return y , x 
  
  def helper(self,x):
    x = self.pool(F.relu(self.conv1(x)))
    x = self.pool(F.relu(self.conv2(x)))
    x = x.view(-1, 16 * 5 * 5)
    x = F.relu(self.fc1(x))
    x = F.relu(self.fc2(x))
    x = F.relu(self.fc3(x))
    x = self.fc4(x)
    return x

# %%
 class Module2(nn.Module):
  def __init__(self):
    super(Module2, self).__init__()
    
    self.conv1 = nn.Conv2d(3, 6, 5)
    self.pool = nn.MaxPool2d(2, 2)
    self.conv2 = nn.Conv2d(6, 16, 5)
    self.fc1 = nn.Linear(16 * 5 * 5, 120)
    self.fc2 = nn.Linear(120, 84)
    self.fc3 = nn.Linear(84, 10)
    self.fc4 = nn.Linear(10,3)

  def forward(self,y):  #z batch of list of 9 images
    y1 = self.pool(F.relu(self.conv1(y)))
    y1 = self.pool(F.relu(self.conv2(y1)))
    y1 = y1.view(-1, 16 * 5 * 5)

    y1 = F.relu(self.fc1(y1))
    y1 = F.relu(self.fc2(y1))
    y1 = F.relu(self.fc3(y1))
    y1 = self.fc4(y1)
    return y1

# %%
def calculate_attn_loss(dataloader,what,where,criter):
  what.eval()
  where.eval()
  r_loss = 0
  alphas = []
  lbls = []
  pred = []
  fidices = []
  correct = 0
  tot = 0
  with torch.no_grad():
    for i, data in enumerate(dataloader, 0):
      inputs, labels,fidx = data
      lbls.append(labels)
      fidices.append(fidx)
      inputs = inputs.double()
      inputs, labels = inputs.to("cuda"),labels.to("cuda")
      avg,alpha = where(inputs)
      outputs = what(avg)
      _, predicted = torch.max(outputs.data, 1)
      correct += sum(predicted == labels)
      tot += len(predicted)
      pred.append(predicted.cpu().numpy())
      alphas.append(alpha.cpu().numpy())
      loss = criter(outputs, labels)
      r_loss += loss.item()
  alphas = np.concatenate(alphas,axis=0)
  pred = np.concatenate(pred,axis=0)
  lbls = np.concatenate(lbls,axis=0)
  fidices = np.concatenate(fidices,axis=0)
  #print(alphas.shape,pred.shape,lbls.shape,fidices.shape) 
  analysis = analyse_data(alphas,lbls,pred,fidices)
  return r_loss/i,analysis,correct.item(),tot,correct.item()/tot

# %%
def analyse_data(alphas,lbls,predicted,f_idx):
    '''
       analysis data is created here
    '''
    batch = len(predicted)
    amth,alth,ftpt,ffpt,ftpf,ffpf = 0,0,0,0,0,0
    for j in range (batch):
      focus = np.argmax(alphas[j])
      if(alphas[j][focus] >= 0.5):
        amth +=1
      else:
        alth +=1
      if(focus == f_idx[j] and predicted[j] == lbls[j]):
        ftpt += 1
      elif(focus != f_idx[j] and predicted[j] == lbls[j]):
        ffpt +=1
      elif(focus == f_idx[j] and predicted[j] != lbls[j]):
        ftpf +=1
      elif(focus != f_idx[j] and predicted[j] != lbls[j]):
        ffpf +=1
    #print(sum(predicted==lbls),ftpt+ffpt)
    return [ftpt,ffpt,ftpf,ffpf,amth,alth]

# %%
torch.manual_seed(1234)
where_net = Module1().double()
where_net = where_net.to("cuda")
# print(net.parameters)
torch.manual_seed(1234)
what_net = Module2().double()
what_net = what_net.to("cuda")

# %% [markdown]
# # training

# %%
# instantiate optimizer
optimizer_where = optim.Adam(where_net.parameters(),lr =0.001)#,momentum=0.9)#,nesterov=True)
optimizer_what = optim.Adam(what_net.parameters(), lr=0.001)#,momentum=0.9)#,nesterov=True)
 

scheduler_where = optim.lr_scheduler.ReduceLROnPlateau(optimizer_where, mode='min', factor=0.5, patience=3,min_lr=5e-6,verbose=True)
scheduler_what = optim.lr_scheduler.ReduceLROnPlateau(optimizer_what, mode='min', factor=0.5, patience=3,min_lr=5e-6, verbose=True)


criterion = nn.CrossEntropyLoss()
acti = []
analysis_data_tr = []
analysis_data_tst = []
loss_curi_tr = []
loss_curi_tst = []
epochs = 500

every_what_epoch = 1

# calculate zeroth epoch loss and FTPT values
running_loss,anlys_data,correct,total,accuracy = calculate_attn_loss(train_loader,what_net,where_net,criterion)
print('training epoch: [%d ] loss: %.3f correct: %.3f, total: %.3f, accuracy: %.3f' %(0,running_loss,correct,total,accuracy)) 
loss_curi_tr.append(running_loss)
analysis_data_tr.append(anlys_data)

running_loss,anlys_data,correct,total,accuracy = calculate_attn_loss(test_loader,what_net,where_net,criterion)
print('test epoch: [%d ] loss: %.3f correct: %.3f, total: %.3f, accuracy: %.3f' %(0,running_loss,correct,total,accuracy)) 

loss_curi_tst.append(running_loss)
analysis_data_tst.append(anlys_data)



# training starts 
for epoch in range(epochs): # loop over the dataset multiple times
  ep_lossi = []
  running_loss = 0.0
  what_net.train()
  where_net.train()
  if ((epoch) % (every_what_epoch*2) ) <= every_what_epoch-1 :
    print(epoch+1,"updating where_net, what_net is freezed")
    print("--"*40)
  elif ((epoch) % (every_what_epoch*2)) > every_what_epoch-1 :
    print(epoch+1,"updating what_net, where_net is freezed")
    print("--"*40)
  for i, data in enumerate(train_loader, 0):
    # get the inputs
    inputs, labels,_ = data
    inputs = inputs.double()
    inputs, labels = inputs.to("cuda"),labels.to("cuda")
        
    # zero the parameter gradients
    optimizer_where.zero_grad()
    optimizer_what.zero_grad()
      
    # forward + backward + optimize
    avg, alpha = where_net(inputs)
    outputs = what_net(avg)
    loss = criterion(outputs, labels)

    # print statistics
    running_loss += loss.item()
    loss.backward()
    if ((epoch) % (every_what_epoch*2) ) <= every_what_epoch-1 :
      optimizer_where.step()
    elif ( (epoch) % (every_what_epoch*2)) > every_what_epoch-1 :
      optimizer_what.step()
  running_loss_tr,anls_data,correct,total,accuracy = calculate_attn_loss(train_loader,what_net,where_net,criterion)
  analysis_data_tr.append(anls_data)
  loss_curi_tr.append(running_loss_tr)   #loss per epoch
  print('training epoch: [%d ] loss: %.3f correct: %.3f, total: %.3f, accuracy: %.3f' %(epoch+1,running_loss_tr,correct,total,accuracy)) 

  running_loss_tst,anls_data,correct,total,accuracy = calculate_attn_loss(test_loader,what_net,where_net,criterion)
  analysis_data_tst.append(anls_data)
  loss_curi_tst.append(running_loss_tst)   #loss per epoch
  print('test epoch: [%d ] loss: %.3f correct: %.3f, total: %.3f, accuracy: %.3f' %(epoch+1,running_loss_tst,correct,total,accuracy)) 
  
  if running_loss_tr<=0.01:
    break
  if ((epoch) % (every_what_epoch*2) ) <= every_what_epoch-1 :
    scheduler_what.step(running_loss_tst)
  elif ( (epoch) % (every_what_epoch*2)) > every_what_epoch-1 :
    scheduler_where.step(running_loss_tst)
print('Finished Training run ')
analysis_data_tr = np.array(analysis_data_tr)
analysis_data_tst = np.array(analysis_data_tst)
# Out:
# training epoch: [0 ] loss: 1.121 correct: 10007.000, total: 30000.000, accuracy: 0.334
# test epoch: [0 ] loss: 1.141 correct: 3313.000, total: 10000.000, accuracy: 0.331
# 1 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# training epoch: [1 ] loss: 1.120 correct: 10007.000, total: 30000.000, accuracy: 0.334
# test epoch: [1 ] loss: 1.141 correct: 3313.000, total: 10000.000, accuracy: 0.331
# 2 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# training epoch: [2 ] loss: 1.084 correct: 11950.000, total: 30000.000, accuracy: 0.398
# test epoch: [2 ] loss: 1.103 correct: 3996.000, total: 10000.000, accuracy: 0.400
# 3 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# training epoch: [3 ] loss: 1.061 correct: 13505.000, total: 30000.000, accuracy: 0.450
# test epoch: [3 ] loss: 1.082 correct: 4481.000, total: 10000.000, accuracy: 0.448
# 4 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# training epoch: [4 ] loss: 1.019 correct: 14631.000, total: 30000.000, accuracy: 0.488
# test epoch: [4 ] loss: 1.043 correct: 4864.000, total: 10000.000, accuracy: 0.486
# 5 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# training epoch: [5 ] loss: 0.983 correct: 15801.000, total: 30000.000, accuracy: 0.527
# test epoch: [5 ] loss: 1.011 correct: 5203.000, total: 10000.000, accuracy: 0.520
# 6 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# training epoch: [6 ] loss: 0.953 correct: 16237.000, total: 30000.000, accuracy: 0.541
# test epoch: [6 ] loss: 0.984 correct: 5354.000, total: 10000.000, accuracy: 0.535
# 7 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# training epoch: [7 ] loss: 0.910 correct: 17328.000, total: 30000.000, accuracy: 0.578
# test epoch: [7 ] loss: 0.947 correct: 5586.000, total: 10000.000, accuracy: 0.559
# 8 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# training epoch: [8 ] loss: 0.884 correct: 17674.000, total: 30000.000, accuracy: 0.589
# test epoch: [8 ] loss: 0.924 correct: 5710.000, total: 10000.000, accuracy: 0.571
# 9 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# training epoch: [9 ] loss: 0.844 correct: 18455.000, total: 30000.000, accuracy: 0.615
# test epoch: [9 ] loss: 0.885 correct: 6030.000, total: 10000.000, accuracy: 0.603
# 10 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# training epoch: [10 ] loss: 0.825 correct: 18716.000, total: 30000.000, accuracy: 0.624
# test epoch: [10 ] loss: 0.872 correct: 6082.000, total: 10000.000, accuracy: 0.608
# 11 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# training epoch: [11 ] loss: 0.803 correct: 19242.000, total: 30000.000, accuracy: 0.641
# test epoch: [11 ] loss: 0.854 correct: 6189.000, total: 10000.000, accuracy: 0.619
# 12 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# training epoch: [12 ] loss: 0.795 correct: 19163.000, total: 30000.000, accuracy: 0.639
# test epoch: [12 ] loss: 0.859 correct: 6158.000, total: 10000.000, accuracy: 0.616
# 13 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# training epoch: [13 ] loss: 0.768 correct: 19767.000, total: 30000.000, accuracy: 0.659
# test epoch: [13 ] loss: 0.831 correct: 6315.000, total: 10000.000, accuracy: 0.631
# 14 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# training epoch: [14 ] loss: 0.741 correct: 20145.000, total: 30000.000, accuracy: 0.671
# test epoch: [14 ] loss: 0.812 correct: 6416.000, total: 10000.000, accuracy: 0.642
# 15 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# training epoch: [15 ] loss: 0.710 correct: 20561.000, total: 30000.000, accuracy: 0.685
# test epoch: [15 ] loss: 0.796 correct: 6509.000, total: 10000.000, accuracy: 0.651
# 16 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# training epoch: [16 ] loss: 0.681 correct: 21078.000, total: 30000.000, accuracy: 0.703
# test epoch: [16 ] loss: 0.780 correct: 6587.000, total: 10000.000, accuracy: 0.659
# 17 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# training epoch: [17 ] loss: 0.685 correct: 20880.000, total: 30000.000, accuracy: 0.696
# test epoch: [17 ] loss: 0.780 correct: 6595.000, total: 10000.000, accuracy: 0.659
# 18 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# training epoch: [18 ] loss: 0.670 correct: 21210.000, total: 30000.000, accuracy: 0.707
# test epoch: [18 ] loss: 0.764 correct: 6657.000, total: 10000.000, accuracy: 0.666
# 19 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# training epoch: [19 ] loss: 0.630 correct: 21914.000, total: 30000.000, accuracy: 0.730
# test epoch: [19 ] loss: 0.734 correct: 6825.000, total: 10000.000, accuracy: 0.682
# 20 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# training epoch: [20 ] loss: 0.613 correct: 22089.000, total: 30000.000, accuracy: 0.736
# test epoch: [20 ] loss: 0.733 correct: 6848.000, total: 10000.000, accuracy: 0.685
# 21 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# training epoch: [21 ] loss: 0.588 correct: 22417.000, total: 30000.000, accuracy: 0.747
# test epoch: [21 ] loss: 0.705 correct: 7002.000, total: 10000.000, accuracy: 0.700
# 22 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# training epoch: [22 ] loss: 0.569 correct: 22746.000, total: 30000.000, accuracy: 0.758
# test epoch: [22 ] loss: 0.701 correct: 7021.000, total: 10000.000, accuracy: 0.702
# 23 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# training epoch: [23 ] loss: 0.570 correct: 22788.000, total: 30000.000, accuracy: 0.760
# test epoch: [23 ] loss: 0.703 correct: 7025.000, total: 10000.000, accuracy: 0.703
# 24 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# training epoch: [24 ] loss: 0.544 correct: 23071.000, total: 30000.000, accuracy: 0.769
# test epoch: [24 ] loss: 0.686 correct: 7099.000, total: 10000.000, accuracy: 0.710
# 25 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# training epoch: [25 ] loss: 0.525 correct: 23329.000, total: 30000.000, accuracy: 0.778
# test epoch: [25 ] loss: 0.675 correct: 7131.000, total: 10000.000, accuracy: 0.713
# 26 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# training epoch: [26 ] loss: 0.501 correct: 23754.000, total: 30000.000, accuracy: 0.792
# test epoch: [26 ] loss: 0.660 correct: 7275.000, total: 10000.000, accuracy: 0.728
# 27 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# training epoch: [27 ] loss: 0.495 correct: 23885.000, total: 30000.000, accuracy: 0.796
# test epoch: [27 ] loss: 0.645 correct: 7319.000, total: 10000.000, accuracy: 0.732
# 28 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# training epoch: [28 ] loss: 0.485 correct: 23928.000, total: 30000.000, accuracy: 0.798
# test epoch: [28 ] loss: 0.667 correct: 7312.000, total: 10000.000, accuracy: 0.731
# 29 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# training epoch: [29 ] loss: 0.483 correct: 23982.000, total: 30000.000, accuracy: 0.799
# test epoch: [29 ] loss: 0.660 correct: 7322.000, total: 10000.000, accuracy: 0.732
# 30 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# training epoch: [30 ] loss: 0.462 correct: 24297.000, total: 30000.000, accuracy: 0.810
# test epoch: [30 ] loss: 0.637 correct: 7337.000, total: 10000.000, accuracy: 0.734
# 31 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# training epoch: [31 ] loss: 0.431 correct: 24744.000, total: 30000.000, accuracy: 0.825
# test epoch: [31 ] loss: 0.615 correct: 7470.000, total: 10000.000, accuracy: 0.747
# 32 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# training epoch: [32 ] loss: 0.409 correct: 25094.000, total: 30000.000, accuracy: 0.836
# test epoch: [32 ] loss: 0.620 correct: 7495.000, total: 10000.000, accuracy: 0.750
# 33 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# training epoch: [33 ] loss: 0.415 correct: 25004.000, total: 30000.000, accuracy: 0.833
# test epoch: [33 ] loss: 0.623 correct: 7507.000, total: 10000.000, accuracy: 0.751
# 34 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# training epoch: [34 ] loss: 0.399 correct: 25254.000, total: 30000.000, accuracy: 0.842
# test epoch: [34 ] loss: 0.625 correct: 7554.000, total: 10000.000, accuracy: 0.755
# 35 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# training epoch: [35 ] loss: 0.392 correct: 25269.000, total: 30000.000, accuracy: 0.842
# test epoch: [35 ] loss: 0.622 correct: 7562.000, total: 10000.000, accuracy: 0.756
# Epoch    18: reducing learning rate of group 0 to 5.0000e-04.
# 36 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# training epoch: [36 ] loss: 0.371 correct: 25581.000, total: 30000.000, accuracy: 0.853
# test epoch: [36 ] loss: 0.623 correct: 7598.000, total: 10000.000, accuracy: 0.760
# Epoch    18: reducing learning rate of group 0 to 5.0000e-04.
# 37 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# training epoch: [37 ] loss: 0.359 correct: 25751.000, total: 30000.000, accuracy: 0.858
# test epoch: [37 ] loss: 0.611 correct: 7623.000, total: 10000.000, accuracy: 0.762
# 38 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# training epoch: [38 ] loss: 0.344 correct: 25948.000, total: 30000.000, accuracy: 0.865
# test epoch: [38 ] loss: 0.610 correct: 7638.000, total: 10000.000, accuracy: 0.764
# 39 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# training epoch: [39 ] loss: 0.332 correct: 26149.000, total: 30000.000, accuracy: 0.872
# test epoch: [39 ] loss: 0.604 correct: 7712.000, total: 10000.000, accuracy: 0.771
# 40 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# training epoch: [40 ] loss: 0.323 correct: 26257.000, total: 30000.000, accuracy: 0.875
# test epoch: [40 ] loss: 0.607 correct: 7690.000, total: 10000.000, accuracy: 0.769
# 41 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# training epoch: [41 ] loss: 0.316 correct: 26408.000, total: 30000.000, accuracy: 0.880
# test epoch: [41 ] loss: 0.600 correct: 7739.000, total: 10000.000, accuracy: 0.774
# 42 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# training epoch: [42 ] loss: 0.306 correct: 26465.000, total: 30000.000, accuracy: 0.882
# test epoch: [42 ] loss: 0.628 correct: 7684.000, total: 10000.000, accuracy: 0.768
# 43 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# training epoch: [43 ] loss: 0.306 correct: 26495.000, total: 30000.000, accuracy: 0.883
# test epoch: [43 ] loss: 0.616 correct: 7728.000, total: 10000.000, accuracy: 0.773
# 44 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# training epoch: [44 ] loss: 0.304 correct: 26538.000, total: 30000.000, accuracy: 0.885
# test epoch: [44 ] loss: 0.626 correct: 7753.000, total: 10000.000, accuracy: 0.775
# Epoch    22: reducing learning rate of group 0 to 2.5000e-04.
# 45 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# training epoch: [45 ] loss: 0.277 correct: 26919.000, total: 30000.000, accuracy: 0.897
# test epoch: [45 ] loss: 0.619 correct: 7767.000, total: 10000.000, accuracy: 0.777
# Epoch    23: reducing learning rate of group 0 to 2.5000e-04.
# 46 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# training epoch: [46 ] loss: 0.261 correct: 27119.000, total: 30000.000, accuracy: 0.904
# test epoch: [46 ] loss: 0.631 correct: 7773.000, total: 10000.000, accuracy: 0.777
# 47 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# training epoch: [47 ] loss: 0.256 correct: 27216.000, total: 30000.000, accuracy: 0.907
# test epoch: [47 ] loss: 0.627 correct: 7744.000, total: 10000.000, accuracy: 0.774
# 48 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# training epoch: [48 ] loss: 0.248 correct: 27323.000, total: 30000.000, accuracy: 0.911
# test epoch: [48 ] loss: 0.640 correct: 7727.000, total: 10000.000, accuracy: 0.773
# Epoch    24: reducing learning rate of group 0 to 1.2500e-04.
# 49 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# training epoch: [49 ] loss: 0.241 correct: 27387.000, total: 30000.000, accuracy: 0.913
# test epoch: [49 ] loss: 0.644 correct: 7734.000, total: 10000.000, accuracy: 0.773
# Epoch    25: reducing learning rate of group 0 to 1.2500e-04.
# 50 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# training epoch: [50 ] loss: 0.236 correct: 27433.000, total: 30000.000, accuracy: 0.914
# test epoch: [50 ] loss: 0.654 correct: 7766.000, total: 10000.000, accuracy: 0.777
# 51 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# training epoch: [51 ] loss: 0.232 correct: 27518.000, total: 30000.000, accuracy: 0.917
# test epoch: [51 ] loss: 0.657 correct: 7765.000, total: 10000.000, accuracy: 0.776
# 52 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# training epoch: [52 ] loss: 0.228 correct: 27562.000, total: 30000.000, accuracy: 0.919
# test epoch: [52 ] loss: 0.661 correct: 7775.000, total: 10000.000, accuracy: 0.777
# Epoch    26: reducing learning rate of group 0 to 6.2500e-05.
# 53 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# training epoch: [53 ] loss: 0.224 correct: 27617.000, total: 30000.000, accuracy: 0.921
# test epoch: [53 ] loss: 0.658 correct: 7779.000, total: 10000.000, accuracy: 0.778
# Epoch    27: reducing learning rate of group 0 to 6.2500e-05.
# 54 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# training epoch: [54 ] loss: 0.221 correct: 27644.000, total: 30000.000, accuracy: 0.921
# test epoch: [54 ] loss: 0.665 correct: 7767.000, total: 10000.000, accuracy: 0.777
# 55 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# training epoch: [55 ] loss: 0.220 correct: 27667.000, total: 30000.000, accuracy: 0.922
# test epoch: [55 ] loss: 0.665 correct: 7783.000, total: 10000.000, accuracy: 0.778
# 56 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# training epoch: [56 ] loss: 0.218 correct: 27696.000, total: 30000.000, accuracy: 0.923
# test epoch: [56 ] loss: 0.666 correct: 7789.000, total: 10000.000, accuracy: 0.779
# Epoch    28: reducing learning rate of group 0 to 3.1250e-05.
# 57 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# training epoch: [57 ] loss: 0.216 correct: 27731.000, total: 30000.000, accuracy: 0.924
# test epoch: [57 ] loss: 0.671 correct: 7786.000, total: 10000.000, accuracy: 0.779
# Epoch    29: reducing learning rate of group 0 to 3.1250e-05.
# 58 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# training epoch: [58 ] loss: 0.215 correct: 27735.000, total: 30000.000, accuracy: 0.924
# test epoch: [58 ] loss: 0.676 correct: 7788.000, total: 10000.000, accuracy: 0.779
# 59 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# training epoch: [59 ] loss: 0.214 correct: 27752.000, total: 30000.000, accuracy: 0.925
# test epoch: [59 ] loss: 0.674 correct: 7786.000, total: 10000.000, accuracy: 0.779
# 60 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# training epoch: [60 ] loss: 0.213 correct: 27779.000, total: 30000.000, accuracy: 0.926
# test epoch: [60 ] loss: 0.676 correct: 7788.000, total: 10000.000, accuracy: 0.779
# Epoch    30: reducing learning rate of group 0 to 1.5625e-05.
# 61 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# training epoch: [61 ] loss: 0.212 correct: 27793.000, total: 30000.000, accuracy: 0.926
# test epoch: [61 ] loss: 0.678 correct: 7805.000, total: 10000.000, accuracy: 0.780
# Epoch    31: reducing learning rate of group 0 to 1.5625e-05.
# 62 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# training epoch: [62 ] loss: 0.211 correct: 27795.000, total: 30000.000, accuracy: 0.926
# test epoch: [62 ] loss: 0.682 correct: 7795.000, total: 10000.000, accuracy: 0.779
# 63 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# training epoch: [63 ] loss: 0.211 correct: 27798.000, total: 30000.000, accuracy: 0.927
# test epoch: [63 ] loss: 0.682 correct: 7798.000, total: 10000.000, accuracy: 0.780
# 64 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# training epoch: [64 ] loss: 0.210 correct: 27805.000, total: 30000.000, accuracy: 0.927
# test epoch: [64 ] loss: 0.682 correct: 7798.000, total: 10000.000, accuracy: 0.780
# Epoch    32: reducing learning rate of group 0 to 7.8125e-06.
# 65 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# training epoch: [65 ] loss: 0.210 correct: 27798.000, total: 30000.000, accuracy: 0.927
# test epoch: [65 ] loss: 0.682 correct: 7794.000, total: 10000.000, accuracy: 0.779
# Epoch    33: reducing learning rate of group 0 to 7.8125e-06.
# 66 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# training epoch: [66 ] loss: 0.210 correct: 27803.000, total: 30000.000, accuracy: 0.927
# test epoch: [66 ] loss: 0.684 correct: 7792.000, total: 10000.000, accuracy: 0.779
# 67 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# training epoch: [67 ] loss: 0.210 correct: 27803.000, total: 30000.000, accuracy: 0.927
# test epoch: [67 ] loss: 0.683 correct: 7792.000, total: 10000.000, accuracy: 0.779
# 68 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# training epoch: [68 ] loss: 0.209 correct: 27813.000, total: 30000.000, accuracy: 0.927
# test epoch: [68 ] loss: 0.683 correct: 7795.000, total: 10000.000, accuracy: 0.779
# Epoch    34: reducing learning rate of group 0 to 3.9063e-06.
# 69 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# training epoch: [69 ] loss: 0.209 correct: 27829.000, total: 30000.000, accuracy: 0.928
# test epoch: [69 ] loss: 0.684 correct: 7791.000, total: 10000.000, accuracy: 0.779
# Epoch    35: reducing learning rate of group 0 to 3.9063e-06.
# 70 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# training epoch: [70 ] loss: 0.209 correct: 27836.000, total: 30000.000, accuracy: 0.928
# test epoch: [70 ] loss: 0.684 correct: 7794.000, total: 10000.000, accuracy: 0.779
# 71 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# training epoch: [71 ] loss: 0.209 correct: 27835.000, total: 30000.000, accuracy: 0.928
# test epoch: [71 ] loss: 0.684 correct: 7794.000, total: 10000.000, accuracy: 0.779
# 72 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# training epoch: [72 ] loss: 0.209 correct: 27837.000, total: 30000.000, accuracy: 0.928
# test epoch: [72 ] loss: 0.684 correct: 7798.000, total: 10000.000, accuracy: 0.780
# Epoch    36: reducing learning rate of group 0 to 2.0000e-06.
# 73 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# training epoch: [73 ] loss: 0.209 correct: 27841.000, total: 30000.000, accuracy: 0.928
# test epoch: [73 ] loss: 0.684 correct: 7796.000, total: 10000.000, accuracy: 0.780
# Epoch    37: reducing learning rate of group 0 to 2.0000e-06.
# 74 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# training epoch: [74 ] loss: 0.209 correct: 27833.000, total: 30000.000, accuracy: 0.928
# test epoch: [74 ] loss: 0.685 correct: 7797.000, total: 10000.000, accuracy: 0.780
# 75 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# training epoch: [75 ] loss: 0.209 correct: 27833.000, total: 30000.000, accuracy: 0.928
# test epoch: [75 ] loss: 0.684 correct: 7794.000, total: 10000.000, accuracy: 0.779
# 76 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# training epoch: [76 ] loss: 0.208 correct: 27837.000, total: 30000.000, accuracy: 0.928
# test epoch: [76 ] loss: 0.685 correct: 7792.000, total: 10000.000, accuracy: 0.779
# 77 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# training epoch: [77 ] loss: 0.208 correct: 27838.000, total: 30000.000, accuracy: 0.928
# test epoch: [77 ] loss: 0.685 correct: 7794.000, total: 10000.000, accuracy: 0.779
# 78 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# training epoch: [78 ] loss: 0.208 correct: 27838.000, total: 30000.000, accuracy: 0.928
# test epoch: [78 ] loss: 0.685 correct: 7796.000, total: 10000.000, accuracy: 0.780
# 79 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# training epoch: [79 ] loss: 0.208 correct: 27840.000, total: 30000.000, accuracy: 0.928
# test epoch: [79 ] loss: 0.685 correct: 7795.000, total: 10000.000, accuracy: 0.779
# 80 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# training epoch: [80 ] loss: 0.208 correct: 27843.000, total: 30000.000, accuracy: 0.928
# test epoch: [80 ] loss: 0.685 correct: 7795.000, total: 10000.000, accuracy: 0.779
# 81 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# training epoch: [81 ] loss: 0.208 correct: 27842.000, total: 30000.000, accuracy: 0.928
# test epoch: [81 ] loss: 0.685 correct: 7789.000, total: 10000.000, accuracy: 0.779
# 82 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# training epoch: [82 ] loss: 0.208 correct: 27842.000, total: 30000.000, accuracy: 0.928
# test epoch: [82 ] loss: 0.685 correct: 7791.000, total: 10000.000, accuracy: 0.779
# 83 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# training epoch: [83 ] loss: 0.208 correct: 27844.000, total: 30000.000, accuracy: 0.928
# test epoch: [83 ] loss: 0.686 correct: 7792.000, total: 10000.000, accuracy: 0.779
# 84 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# training epoch: [84 ] loss: 0.208 correct: 27847.000, total: 30000.000, accuracy: 0.928
# test epoch: [84 ] loss: 0.686 correct: 7794.000, total: 10000.000, accuracy: 0.779
# 85 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# training epoch: [85 ] loss: 0.208 correct: 27848.000, total: 30000.000, accuracy: 0.928
# test epoch: [85 ] loss: 0.685 correct: 7796.000, total: 10000.000, accuracy: 0.780
# 86 updating what_net, where_net is freezed
# --------------------------------------------------------------------------------
# training epoch: [86 ] loss: 0.208 correct: 27848.000, total: 30000.000, accuracy: 0.928
# test epoch: [86 ] loss: 0.686 correct: 7793.000, total: 10000.000, accuracy: 0.779
# 87 updating where_net, what_net is freezed
# --------------------------------------------------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-15-b5955d7a38f2> in <module>()
#      48     inputs, labels,_ = data
#      49     inputs = inputs.double()
# ---> 50     inputs, labels = inputs.to("cuda"),labels.to("cuda")
#      51
#      52     # zero the parameter gradients
#
# KeyboardInterrupt:

# %%
fig = plt.figure(figsize = (12,8) )
vline_list = np.arange(every_what_epoch, epoch + every_what_epoch, every_what_epoch )
# train_loss = np.random.randn(340)
# test_loss = np.random.randn(340)
epoch_list = np.arange(0, epoch+1)
plt.plot(epoch_list,loss_curi_tr, label='train_loss')
plt.plot(epoch_list,loss_curi_tst, label='test_loss')

plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.xlabel("epochs")
plt.ylabel("CE Loss")
plt.vlines(vline_list,min(min(loss_curi_tr),min(loss_curi_tst)), max(max(loss_curi_tst),max(loss_curi_tr)),linestyles='dotted')
plt.title("train loss vs test loss")
plt.show()
fig.savefig("train_test_loss_plot.pdf")

# %%
analysis_data_tr
# Out:
# [[2428, 7579, 3760, 16233, 0, 30000],
#  [1709, 8298, 3915, 16078, 26076, 3924],
#  [3520, 8430, 2104, 15946, 26076, 3924],
#  [6044, 7461, 2926, 13569, 20321, 9679],
#  [6461, 8170, 2509, 12860, 20321, 9679],
#  [7743, 8058, 2896, 11303, 15670, 14330],
#  [8302, 7935, 2337, 11426, 15670, 14330],
#  [9667, 7661, 2734, 9938, 14312, 15688],
#  [9722, 7952, 2679, 9647, 14312, 15688],
#  [10896, 7559, 2958, 8587, 15776, 14224],
#  [11421, 7295, 2433, 8851, 15776, 14224],
#  [11525, 7717, 2802, 7956, 12636, 17364],
#  [12101, 7062, 2226, 8611, 12636, 17364],
#  [12472, 7295, 2655, 7578, 9868, 20132],
#  [12540, 7605, 2587, 7268, 9868, 20132],
#  [13411, 7150, 2231, 7208, 13257, 16743],
#  [13421, 7657, 2221, 6701, 13257, 16743],
#  [13476, 7404, 2135, 6985, 15108, 14892],
#  [13369, 7841, 2242, 6548, 15108, 14892],
#  [14678, 7236, 2097, 5989, 16646, 13354],
#  [14803, 7286, 1972, 5939, 16646, 13354],
#  [15202, 7215, 1911, 5672, 17061, 12939],
#  [15227, 7519, 1886, 5368, 17061, 12939],
#  [15325, 7463, 1663, 5549, 18302, 11698],
#  [15479, 7592, 1509, 5420, 18302, 11698],
#  [16122, 7207, 1637, 5034, 18582, 11418],
#  [16255, 7499, 1504, 4742, 18582, 11418],
#  [16342, 7543, 1787, 4328, 16895, 13105],
#  [16352, 7576, 1777, 4295, 16895, 13105],
#  [16675, 7307, 1734, 4284, 17638, 12362],
#  [16927, 7370, 1482, 4221, 17638, 12362],
#  [17477, 7267, 1316, 3940, 18097, 11903],
#  [17716, 7378, 1077, 3829, 18097, 11903],
#  [17754, 7250, 1198, 3798, 17920, 12080],
#  [17715, 7539, 1237, 3509, 17920, 12080],
#  [17935, 7334, 1162, 3569, 19430, 10570],
#  [18110, 7471, 987, 3432, 19430, 10570],
#  [18342, 7409, 993, 3256, 18540, 11460],
#  [18430, 7518, 905, 3147, 18540, 11460],
#  [18712, 7437, 823, 3028, 19277, 10723],
#  [18745, 7512, 790, 2953, 19277, 10723],
#  [18885, 7523, 795, 2797, 18925, 11075],
#  [19009, 7456, 671, 2864, 18925, 11075],
#  [18997, 7498, 705, 2800, 18334, 11666],
#  [18920, 7618, 782, 2680, 18334, 11666],
#  [19213, 7706, 678, 2403, 19327, 10673],
#  [19321, 7798, 570, 2311, 19327, 10673],
#  [19391, 7825, 547, 2237, 19392, 10608],
#  [19441, 7882, 497, 2180, 19392, 10608],
#  [19459, 7928, 486, 2127, 19746, 10254],
#  [19473, 7960, 472, 2095, 19746, 10254],
#  [19539, 7979, 444, 2038, 19772, 10228],
#  [19549, 8013, 434, 2004, 19772, 10228],
#  [19550, 8067, 439, 1944, 19806, 10194],
#  [19554, 8090, 435, 1921, 19806, 10194],
#  [19616, 8051, 423, 1910, 19812, 10188],
#  [19619, 8077, 420, 1884, 19812, 10188],
#  [19596, 8135, 408, 1861, 19954, 10046],
#  [19596, 8139, 408, 1857, 19954, 10046],
#  [19607, 8145, 403, 1845, 19965, 10035],
#  [19607, 8172, 403, 1818, 19965, 10035],
#  [19612, 8181, 406, 1801, 20042, 9958],
#  [19617, 8178, 401, 1804, 20042, 9958],
#  [19629, 8169, 395, 1807, 20049, 9951],
#  [19632, 8173, 392, 1803, 20049, 9951],
#  [19625, 8173, 388, 1814, 20047, 9953],
#  [19625, 8178, 388, 1809, 20047, 9953],
#  [19627, 8176, 386, 1811, 20013, 9987],
#  [19621, 8192, 392, 1795, 20013, 9987],
#  [19626, 8203, 387, 1784, 20053, 9947],
#  [19626, 8210, 387, 1777, 20053, 9947],
#  [19630, 8205, 385, 1780, 20064, 9936],
#  [19629, 8208, 386, 1777, 20064, 9936],
#  [19632, 8209, 384, 1775, 20057, 9943],
#  [19632, 8201, 384, 1783, 20057, 9943],
#  [19638, 8195, 386, 1781, 20048, 9952],
#  [19640, 8197, 384, 1779, 20048, 9952],
#  [19637, 8201, 383, 1779, 20060, 9940],
#  [19637, 8201, 383, 1779, 20060, 9940],
#  [19640, 8200, 382, 1778, 20053, 9947],
#  [19640, 8203, 382, 1775, 20053, 9947],
#  [19640, 8202, 381, 1777, 20049, 9951],
#  [19641, 8201, 380, 1778, 20049, 9951],
#  [19639, 8205, 381, 1775, 20059, 9941],
#  [19639, 8208, 381, 1772, 20059, 9941],
#  [19640, 8208, 382, 1770, 20053, 9947],
#  [19641, 8207, 381, 1771, 20053, 9947]]

# %%
analysis_data_tr = np.array(analysis_data_tr)
analysis_data_tst = np.array(analysis_data_tst)

# %%
columns = ["epochs", "argmax > 0.5" ,"argmax < 0.5", "focus_true_pred_true", "focus_false_pred_true", "focus_true_pred_false", "focus_false_pred_false" ]
df_train = pd.DataFrame()
df_test = pd.DataFrame()
df_train[columns[0]] = np.arange(0,epoch+1)
df_train[columns[1]] = analysis_data_tr[:,-2]
df_train[columns[2]] = analysis_data_tr[:,-1]
df_train[columns[3]] = analysis_data_tr[:,0]
df_train[columns[4]] = analysis_data_tr[:,1]
df_train[columns[5]] = analysis_data_tr[:,2]
df_train[columns[6]] = analysis_data_tr[:,3]

df_test[columns[0]] = np.arange(0,epoch+1)
df_test[columns[1]] = analysis_data_tst[:,-2]
df_test[columns[2]] = analysis_data_tst[:,-1]
df_test[columns[3]] = analysis_data_tst[:,0]
df_test[columns[4]] = analysis_data_tst[:,1]
df_test[columns[5]] = analysis_data_tst[:,2]
df_test[columns[6]] = analysis_data_tst[:,3]

# %%
df_train
# Out:
#     epochs  argmax > 0.5  ...  focus_true_pred_false  focus_false_pred_false
# 0        0             0  ...                   3760                   16233
# 1        1         26076  ...                   3915                   16078
# 2        2         26076  ...                   2104                   15946
# 3        3         20321  ...                   2926                   13569
# 4        4         20321  ...                   2509                   12860
# ..     ...           ...  ...                    ...                     ...
# 82      82         20049  ...                    380                    1778
# 83      83         20059  ...                    381                    1775
# 84      84         20059  ...                    381                    1772
# 85      85         20053  ...                    382                    1770
# 86      86         20053  ...                    381                    1771
#
# [87 rows x 7 columns]

# %%
df_test
# Out:
#     epochs  argmax > 0.5  ...  focus_true_pred_false  focus_false_pred_false
# 0        0             0  ...                   1187                    5500
# 1        1          8699  ...                   1288                    5399
# 2        2          8699  ...                    714                    5290
# 3        3          6870  ...                    932                    4587
# 4        4          6870  ...                    793                    4343
# ..     ...           ...  ...                    ...                     ...
# 82      82          6516  ...                    511                    1698
# 83      83          6517  ...                    511                    1697
# 84      84          6517  ...                    511                    1695
# 85      85          6510  ...                    511                    1693
# 86      86          6510  ...                    510                    1697
#
# [87 rows x 7 columns]

# %%
plt.figure(figsize=(12,12))
plt.plot(df_train[columns[0]],df_train[columns[1]], label='argmax > 0.5')
plt.plot(df_train[columns[0]],df_train[columns[2]], label='argmax < 0.5')

plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.xlabel("epochs")
plt.ylabel("training data")
plt.title("On Training set")
plt.vlines(vline_list,min(min(df_train[columns[1]]),min(df_train[columns[2]])), max(max(df_train[columns[1]]),max(df_train[columns[2]])),linestyles='dotted')
plt.show()

plt.figure(figsize=(12,12))
plt.plot(df_train[columns[0]],df_train[columns[3]], label ="focus_true_pred_true ")
plt.plot(df_train[columns[0]],df_train[columns[4]], label ="focus_false_pred_true ")
plt.plot(df_train[columns[0]],df_train[columns[5]], label ="focus_true_pred_false ")
plt.plot(df_train[columns[0]],df_train[columns[6]], label ="focus_false_pred_false ")
plt.title("On Training set")
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.xlabel("epochs")
plt.ylabel("training data")
plt.vlines(vline_list,min(min(df_train[columns[3]]),min(df_train[columns[4]]),min(df_train[columns[5]]),min(df_train[columns[6]])), max(max(df_train[columns[3]]),max(df_train[columns[4]]),max(df_train[columns[5]]),max(df_train[columns[6]])),linestyles='dotted')
plt.show()

# %%
plt.figure(figsize=(12,12))
plt.plot(df_test[columns[0]],df_test[columns[1]], label='argmax > 0.5')
plt.plot(df_test[columns[0]],df_test[columns[2]], label='argmax < 0.5')

plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.xlabel("epochs")
plt.ylabel("training data")
plt.title("On Training set")
plt.vlines(vline_list,min(min(df_test[columns[1]]),min(df_test[columns[2]])), max(max(df_test[columns[1]]),max(df_test[columns[2]])),linestyles='dotted')
plt.show()

plt.figure(figsize=(12,12))
plt.plot(df_test[columns[0]],df_test[columns[3]], label ="focus_true_pred_true ")
plt.plot(df_test[columns[0]],df_test[columns[4]], label ="focus_false_pred_true ")
plt.plot(df_test[columns[0]],df_test[columns[5]], label ="focus_true_pred_false ")
plt.plot(df_test[columns[0]],df_test[columns[6]], label ="focus_false_pred_false ")
plt.title("On Training set")
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.xlabel("epochs")
plt.ylabel("training data")
plt.vlines(vline_list,min(min(df_test[columns[3]]),min(df_test[columns[4]]),min(df_test[columns[5]]),min(df_test[columns[6]])), max(max(df_test[columns[3]]),max(df_test[columns[4]]),max(df_test[columns[5]]),max(df_test[columns[6]])),linestyles='dotted')
plt.show()
