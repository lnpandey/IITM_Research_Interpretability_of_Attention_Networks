# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
path = '/content/drive/MyDrive/Research/AAAI/dataset1/zeroth_layer_with_entropy/'

# %%
import numpy as np
import pandas as pd

import torch
import torchvision
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms, utils
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

from matplotlib import pyplot as plt
# %matplotlib inline

torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False

# %% [markdown]
# # Generate dataset

# %%
np.random.seed(12)
y = np.random.randint(0,10,5000)
idx= []
for i in range(10):
    print(i,sum(y==i))
    idx.append(y==i)
x = np.zeros((5000,2))
np.random.seed(12)
x[idx[0],:] = np.random.multivariate_normal(mean = [4,6.5],cov=[[0.01,0],[0,0.01]],size=sum(idx[0]))
x[idx[1],:] = np.random.multivariate_normal(mean = [5.5,6],cov=[[0.01,0],[0,0.01]],size=sum(idx[1]))
x[idx[2],:] = np.random.multivariate_normal(mean = [4.5,4.5],cov=[[0.01,0],[0,0.01]],size=sum(idx[2]))
x[idx[3],:] = np.random.multivariate_normal(mean = [3,3.5],cov=[[0.01,0],[0,0.01]],size=sum(idx[3]))
x[idx[4],:] = np.random.multivariate_normal(mean = [2.5,5.5],cov=[[0.01,0],[0,0.01]],size=sum(idx[4]))
x[idx[5],:] = np.random.multivariate_normal(mean = [3.5,8],cov=[[0.01,0],[0,0.01]],size=sum(idx[5]))
x[idx[6],:] = np.random.multivariate_normal(mean = [5.5,8],cov=[[0.01,0],[0,0.01]],size=sum(idx[6]))
x[idx[7],:] = np.random.multivariate_normal(mean = [7,6.5],cov=[[0.01,0],[0,0.01]],size=sum(idx[7]))
x[idx[8],:] = np.random.multivariate_normal(mean = [6.5,4.5],cov=[[0.01,0],[0,0.01]],size=sum(idx[8]))
x[idx[9],:] = np.random.multivariate_normal(mean = [5,3],cov=[[0.01,0],[0,0.01]],size=sum(idx[9]))
color = ['#1F77B4','orange', 'g','brown']
name = [1,2,3,0]
for i in range(10):
  if i==3:
    plt.scatter(x[idx[i],0],x[idx[i],1],c=color[3],label="D_"+str(name[i]))
  elif i>=4:
    plt.scatter(x[idx[i],0],x[idx[i],1],c=color[3])
  else:
    plt.scatter(x[idx[i],0],x[idx[i],1],c=color[i],label="D_"+str(name[i]))
plt.legend()
# Out:
# 0 530
# 1 463
# 2 494
# 3 517
# 4 488
# 5 497
# 6 493
# 7 507
# 8 492
# 9 519

# %%
x[idx[0]][0], x[idx[5]][5]
# Out:
# (array([4.04729858, 6.43185741]), array([3.4612816 , 8.00144771]))

# %%
desired_num = 6000
mosaic_list_of_images =[]
mosaic_label = []
fore_idx=[]
for j in range(desired_num):
    np.random.seed(j)
    fg_class  = np.random.randint(0,3)
    fg_idx = np.random.randint(0,9)
    a = []
    for i in range(9):
        if i == fg_idx:
            b = np.random.choice(np.where(idx[fg_class]==True)[0],size=1)
            a.append(x[b])
#             print("foreground "+str(fg_class)+" present at " + str(fg_idx))
        else:
            bg_class = np.random.randint(3,10)
            b = np.random.choice(np.where(idx[bg_class]==True)[0],size=1)
            a.append(x[b])
#             print("background "+str(bg_class)+" present at " + str(i))
    a = np.concatenate(a,axis=0)
    mosaic_list_of_images.append(a)
    mosaic_label.append(fg_class)
    fore_idx.append(fg_idx)

# %%
len(mosaic_list_of_images), mosaic_list_of_images[0]
# Out:
# (6000, array([[2.97319488, 3.56326392],
#         [2.59779787, 5.38694546],
#         [6.50095845, 4.49418185],
#         [7.06459245, 6.53896691],
#         [5.0161796 , 2.92679482],
#         [4.1251117 , 6.62627906],
#         [3.43548455, 7.98866194],
#         [5.01328229, 3.05196492],
#         [4.91416206, 3.02422072]]))

# %% [markdown]
# # load mosaic data

# %%
class MosaicDataset(Dataset):
  """MosaicDataset dataset."""

  def __init__(self, mosaic_list, mosaic_label,fore_idx):
    """
      Args:
        csv_file (string): Path to the csv file with annotations.
        root_dir (string): Directory with all the images.
        transform (callable, optional): Optional transform to be applied
            on a sample.
    """
    self.mosaic = mosaic_list
    self.label = mosaic_label
    self.fore_idx = fore_idx
    
  def __len__(self):
    return len(self.label)

  def __getitem__(self, idx):
    return self.mosaic[idx] , self.label[idx] , self.fore_idx[idx]

# %%
batch = 250
msd1 = MosaicDataset(mosaic_list_of_images[0:3000], mosaic_label[0:3000] , fore_idx[0:3000])
train_loader = DataLoader( msd1 ,batch_size= batch ,shuffle=True)

# %%
batch = 250
msd2 = MosaicDataset(mosaic_list_of_images[3000:6000], mosaic_label[3000:6000] , fore_idx[3000:6000])
test_loader = DataLoader( msd2 ,batch_size= batch ,shuffle=True)

# %% [markdown]
# # models

# %%
class Focus_deep(nn.Module):
    '''
       deep focus network averaged at zeroth layer
       input : elemental data
    '''
    def __init__(self,inputs,output,K,d):
        super(Focus_deep,self).__init__()
        self.inputs = inputs
        self.output = output
        self.K = K
        self.d  = d
        self.linear1 = nn.Linear(self.inputs,50, bias=False)  #,self.output)
        self.linear2 = nn.Linear(50,50 , bias=False)
        self.linear3 = nn.Linear(50,self.output, bias=False) 

        torch.nn.init.xavier_normal_(self.linear1.weight)
        torch.nn.init.xavier_normal_(self.linear2.weight)
        torch.nn.init.xavier_normal_(self.linear3.weight)
        
    def forward(self,z):
        batch = z.shape[0]
        x = torch.zeros([batch,self.K],dtype=torch.float64)
        y = torch.zeros([batch,self.d], dtype=torch.float64)
        x,y = x.to("cuda"),y.to("cuda")
        #print(z[:,0].shape,z[:,self.d*0:self.d*0+self.d].shape)
        for i in range(self.K):
            x[:,i] = self.helper(z[:,i] )[:,0]  # self.d*i:self.d*i+self.d
        log_x = F.log_softmax(x,dim=1)
        x = F.softmax(x,dim=1)   # alphas
        x1 = x[:,0]
        for i in range(self.K):
            x1 = x[:,i]          
            y = y+torch.mul(x1[:,None],z[:,i])  # self.d*i:self.d*i+self.d
        return y , x , log_x
    def helper(self,x):
      x = F.relu(self.linear1(x))
      x = F.relu(self.linear2(x))
      x = self.linear3(x)
      return x

# %%
class Classification_deep(nn.Module):
    '''
       input : elemental data
       deep classification module data averaged at zeroth layer
    '''
    def __init__(self,inputs,output):
        super(Classification_deep,self).__init__()
        self.inputs = inputs
        self.output = output
        self.linear1 = nn.Linear(self.inputs,50)
        #self.linear2 = nn.Linear(6,12)
        self.linear2 = nn.Linear(50,self.output)

        torch.nn.init.xavier_normal_(self.linear1.weight)
        torch.nn.init.zeros_(self.linear1.bias)
        torch.nn.init.xavier_normal_(self.linear2.weight)
        torch.nn.init.zeros_(self.linear2.bias)

    def forward(self,x):
      x = F.relu(self.linear1(x))
      #x = F.relu(self.linear2(x))
      x = self.linear2(x)
      return x

# %%
# torch.manual_seed(12)
# focus_net = Focus_deep(2,1,9,2).double()
# focus_net = focus_net.to("cuda")

# %%
# focus_net.linear2.weight.shape,focus_net.linear3.weight.shape

# %%
# focus_net.linear2.weight.data[25:,:] = focus_net.linear2.weight.data[:25,:] #torch.nn.Parameter(torch.tensor([last_layer]) )
# (focus_net.linear2.weight[:25,:]== focus_net.linear2.weight[25:,:] )

# %%
# focus_net.linear3.weight.data[:,25:] = -focus_net.linear3.weight.data[:,:25] #torch.nn.Parameter(torch.tensor([last_layer]) )
# focus_net.linear3.weight

# %%
# focus_net.helper( torch.randn((5,2,2)).double().to("cuda") )

# %%
criterion = nn.CrossEntropyLoss()
def my_cross_entropy(x, y,alpha,log_alpha,k):
    # log_prob = -1.0 * F.log_softmax(x, 1)
    # loss = log_prob.gather(1, y.unsqueeze(1))
    # loss = loss.mean()
    loss = criterion(x,y)
    
    #alpha = torch.clamp(alpha,min=1e-10)     
    
    b = -1.0* alpha * log_alpha
    b =  torch.mean(torch.sum(b,dim=1))
    closs = loss
    entropy = b 
    loss = (1-k)*loss + ((k)*b)
    return loss,closs,entropy

# %%
def calculate_attn_loss(dataloader,what,where,criter,k):
  what.eval()
  where.eval()
  r_loss = 0
  cc_loss = 0
  cc_entropy = 0
  alphas = []
  lbls = []
  pred = []
  fidices = []
  with torch.no_grad():
    for i, data in enumerate(dataloader, 0):
      inputs, labels,fidx = data
      lbls.append(labels)
      fidices.append(fidx)
      inputs = inputs.double()
      inputs, labels = inputs.to("cuda"),labels.to("cuda")
      avg,alpha,log_alpha = where(inputs)
      outputs = what(avg)
      _, predicted = torch.max(outputs.data, 1)
      pred.append(predicted.cpu().numpy())
      alphas.append(alpha.cpu().numpy())

      #ent = np.sum(entropy(alpha.cpu().detach().numpy(), base=2, axis=1))/batch
      # mx,_ = torch.max(alpha,1)
      # entropy = np.mean(-np.log2(mx.cpu().detach().numpy()))
      # print("entropy of batch", entropy)

      #loss = (1-k)*criter(outputs, labels) + k*ent
      loss,closs,entropy = my_cross_entropy(outputs,labels,alpha,log_alpha,k)
      r_loss += loss.item()
      cc_loss += closs.item()
      cc_entropy += entropy.item()

  alphas = np.concatenate(alphas,axis=0)
  pred = np.concatenate(pred,axis=0)
  lbls = np.concatenate(lbls,axis=0)
  fidices = np.concatenate(fidices,axis=0)
  #print(alphas.shape,pred.shape,lbls.shape,fidices.shape) 
  analysis = analyse_data(alphas,lbls,pred,fidices)
  return r_loss/i,cc_loss/i,cc_entropy/i,analysis

# %%
def analyse_data(alphas,lbls,predicted,f_idx):
    '''
       analysis data is created here
    '''
    batch = len(predicted)
    amth,alth,ftpt,ffpt,ftpf,ffpf = 0,0,0,0,0,0
    for j in range (batch):
      focus = np.argmax(alphas[j])
      if(alphas[j][focus] >= 0.5):
        amth +=1
      else:
        alth +=1
      if(focus == f_idx[j] and predicted[j] == lbls[j]):
        ftpt += 1
      elif(focus != f_idx[j] and predicted[j] == lbls[j]):
        ffpt +=1
      elif(focus == f_idx[j] and predicted[j] != lbls[j]):
        ftpf +=1
      elif(focus != f_idx[j] and predicted[j] != lbls[j]):
        ffpf +=1
    #print(sum(predicted==lbls),ftpt+ffpt)
    return [ftpt,ffpt,ftpf,ffpf,amth,alth]

# %% [markdown]
# # training

# %%
number_runs = 10
full_analysis =[]
FTPT_analysis = pd.DataFrame(columns = ["FTPT","FFPT", "FTPF","FFPF"])
k = 0.0005
for n in range(number_runs):
  print("--"*40)
  
  # instantiate focus and classification Model
  torch.manual_seed(n)
  where = Focus_deep(2,1,9,2).double()
  where.linear2.weight.data[25:,:] = where.linear2.weight.data[:25,:]
  where.linear3.weight.data[:,25:] = -where.linear3.weight.data[:,:25]
  where = where.double().to("cuda")

  print(where.helper( torch.randn((5,2,2)).double().to("cuda")))
  what = Classification_deep(2,3).double()
  where = where.to("cuda")
  what = what.to("cuda")

  # instantiate optimizer
  optimizer_where = optim.Adam(where.parameters(),lr =0.001)
  optimizer_what = optim.Adam(what.parameters(), lr=0.001)
  #criterion = nn.CrossEntropyLoss()
  acti = []
  analysis_data = []
  loss_curi = []
  epochs = 4000


  # calculate zeroth epoch loss and FTPT values
  running_loss ,_,_,anlys_data= calculate_attn_loss(train_loader,what,where,criterion,k)
  loss_curi.append(running_loss)
  analysis_data.append(anlys_data)

  print('epoch: [%d ] loss: %.3f' %(0,running_loss)) 

  # training starts 
  for epoch in range(epochs): # loop over the dataset multiple times
    ep_lossi = []
    running_loss = 0.0
    what.train()
    where.train()
    for i, data in enumerate(train_loader, 0):
      # get the inputs
      inputs, labels,_ = data
      inputs = inputs.double()
      inputs, labels = inputs.to("cuda"),labels.to("cuda")

      # zero the parameter gradients
      optimizer_where.zero_grad()
      optimizer_what.zero_grad()
      
      # forward + backward + optimize
      avg, alpha,log_alpha = where(inputs)
      outputs = what(avg)

      my_loss,_,_ = my_cross_entropy(outputs,labels,alpha,log_alpha,k)

      # print statistics
      running_loss += my_loss.item()
      my_loss.backward()
      optimizer_where.step()
      optimizer_what.step()
    #break
    running_loss,ccloss,ccentropy,anls_data = calculate_attn_loss(train_loader,what,where,criterion,k)
    analysis_data.append(anls_data)

    if(epoch % 200==0):
      print('epoch: [%d] loss: %.3f celoss: %.3f entropy: %.3f' %(epoch + 1,running_loss,ccloss,ccentropy)) 
    loss_curi.append(running_loss)   #loss per epoch
    if running_loss<=0.02:
      break
  print('Finished Training run ' +str(n))
  #break
  analysis_data = np.array(analysis_data)
  FTPT_analysis.loc[n] = analysis_data[-1,:4]/30
  full_analysis.append((epoch, analysis_data))
  correct = 0
  total = 0
  with torch.no_grad():
    for data in test_loader:
      images, labels,_ = data
      images = images.double()
      images, labels = images.to("cuda"), labels.to("cuda")
      avg, alpha,log_alpha = where(images)
      outputs  = what(avg)
      _, predicted = torch.max(outputs.data, 1)
      total += labels.size(0)
      correct += (predicted == labels).sum().item()

  print('Accuracy of the network on the 3000 test images: %f %%' % (  100 * correct / total))
# Out:
# --------------------------------------------------------------------------------
# tensor([[[ 8.6736e-19],
#          [-1.0408e-17]],
#
#         [[-8.4568e-18],
#          [ 0.0000e+00]],
#
#         [[-8.6736e-18],
#          [ 6.0173e-18]],
#
#         [[-6.9389e-18],
#          [-6.9389e-18]],
#
#         [[ 8.6736e-19],
#          [-2.0817e-17]]], device='cuda:0', dtype=torch.float64,
#        grad_fn=<UnsafeViewBackward>)
# epoch: [0 ] loss: 1.463
# epoch: [1] loss: 1.230 celoss: 1.229 entropy: 2.333
# epoch: [201] loss: 0.511 celoss: 0.511 entropy: 1.052
# epoch: [401] loss: 0.146 celoss: 0.146 entropy: 0.696
# epoch: [601] loss: 0.091 celoss: 0.091 entropy: 0.545
# epoch: [801] loss: 0.088 celoss: 0.087 entropy: 0.526
# epoch: [1001] loss: 0.082 celoss: 0.081 entropy: 0.511
# epoch: [1201] loss: 0.088 celoss: 0.088 entropy: 0.475
# epoch: [1401] loss: 0.073 celoss: 0.073 entropy: 0.475
# epoch: [1601] loss: 0.068 celoss: 0.068 entropy: 0.474
# epoch: [1801] loss: 0.067 celoss: 0.067 entropy: 0.478
# epoch: [2001] loss: 0.058 celoss: 0.058 entropy: 0.473
# epoch: [2201] loss: 0.053 celoss: 0.052 entropy: 0.465
# epoch: [2401] loss: 0.059 celoss: 0.059 entropy: 0.485
# epoch: [2601] loss: 0.048 celoss: 0.048 entropy: 0.480
# epoch: [2801] loss: 0.056 celoss: 0.055 entropy: 0.490
# epoch: [3001] loss: 0.048 celoss: 0.048 entropy: 0.517
# epoch: [3201] loss: 0.048 celoss: 0.047 entropy: 0.492
# epoch: [3401] loss: 0.040 celoss: 0.040 entropy: 0.512
# epoch: [3601] loss: 0.044 celoss: 0.044 entropy: 0.525
# epoch: [3801] loss: 0.043 celoss: 0.043 entropy: 0.485
# Finished Training run 0
# Accuracy of the network on the 3000 test images: 98.600000 %
# --------------------------------------------------------------------------------
# tensor([[[-6.9389e-18],
#          [ 9.3648e-18]],
#
#         [[-5.2313e-18],
#          [-6.9389e-18]],
#
#         [[ 2.7756e-17],
#          [ 6.9389e-18]],
#
#         [[ 3.4694e-18],
#          [ 7.5894e-19]],
#
#         [[ 0.0000e+00],
#          [-1.7347e-18]]], device='cuda:0', dtype=torch.float64,
#        grad_fn=<UnsafeViewBackward>)
# epoch: [0 ] loss: 1.273
# epoch: [1] loss: 1.197 celoss: 1.196 entropy: 2.377
# epoch: [201] loss: 0.369 celoss: 0.369 entropy: 1.109
# epoch: [401] loss: 0.252 celoss: 0.252 entropy: 1.101
# epoch: [601] loss: 0.108 celoss: 0.107 entropy: 0.963
# epoch: [801] loss: 0.090 celoss: 0.090 entropy: 0.809
# epoch: [1001] loss: 0.048 celoss: 0.048 entropy: 0.720
# epoch: [1201] loss: 0.037 celoss: 0.036 entropy: 0.665
# epoch: [1401] loss: 0.039 celoss: 0.039 entropy: 0.640
# epoch: [1601] loss: 0.025 celoss: 0.025 entropy: 0.604
# epoch: [1801] loss: 0.028 celoss: 0.028 entropy: 0.574
# Finished Training run 1
# Accuracy of the network on the 3000 test images: 99.500000 %
# --------------------------------------------------------------------------------
# tensor([[[-1.7347e-17],
#          [ 0.0000e+00]],
#
#         [[-1.3878e-17],
#          [-3.4694e-18]],
#
#         [[-3.4694e-17],
#          [-8.6736e-18]],
#
#         [[-6.9389e-18],
#          [-6.9389e-18]],
#
#         [[ 6.9389e-18],
#          [ 0.0000e+00]]], device='cuda:0', dtype=torch.float64,
#        grad_fn=<UnsafeViewBackward>)
# epoch: [0 ] loss: 1.956
# epoch: [1] loss: 1.458 celoss: 1.458 entropy: 2.356
# epoch: [201] loss: 0.458 celoss: 0.458 entropy: 0.937
# epoch: [401] loss: 0.155 celoss: 0.155 entropy: 0.444
# epoch: [601] loss: 0.090 celoss: 0.090 entropy: 0.366
# epoch: [801] loss: 0.069 celoss: 0.069 entropy: 0.349
# epoch: [1001] loss: 0.061 celoss: 0.061 entropy: 0.337
# epoch: [1201] loss: 0.057 celoss: 0.057 entropy: 0.338
# epoch: [1401] loss: 0.054 celoss: 0.054 entropy: 0.337
# epoch: [1601] loss: 0.053 celoss: 0.053 entropy: 0.335
# epoch: [1801] loss: 0.051 celoss: 0.051 entropy: 0.336
# epoch: [2001] loss: 0.051 celoss: 0.051 entropy: 0.336
# epoch: [2201] loss: 0.054 celoss: 0.053 entropy: 0.339
# epoch: [2401] loss: 0.050 celoss: 0.050 entropy: 0.341
# epoch: [2601] loss: 0.049 celoss: 0.049 entropy: 0.336
# epoch: [2801] loss: 0.050 celoss: 0.050 entropy: 0.346
# epoch: [3001] loss: 0.058 celoss: 0.058 entropy: 0.363
# epoch: [3201] loss: 0.045 celoss: 0.045 entropy: 0.348
# epoch: [3401] loss: 0.046 celoss: 0.045 entropy: 0.362
# epoch: [3601] loss: 0.043 celoss: 0.043 entropy: 0.365
# epoch: [3801] loss: 0.042 celoss: 0.042 entropy: 0.355
# Finished Training run 2
# Accuracy of the network on the 3000 test images: 98.200000 %
# --------------------------------------------------------------------------------
# tensor([[[ 6.9389e-18],
#          [ 4.3368e-19]],
#
#         [[ 4.3368e-18],
#          [-2.6021e-18]],
#
#         [[ 1.5613e-17],
#          [-3.4694e-18]],
#
#         [[-4.7705e-18],
#          [-3.4694e-17]],
#
#         [[-6.9389e-18],
#          [-1.7347e-18]]], device='cuda:0', dtype=torch.float64,
#        grad_fn=<UnsafeViewBackward>)
# epoch: [0 ] loss: 1.208
# epoch: [1] loss: 1.193 celoss: 1.193 entropy: 2.395
# epoch: [201] loss: 0.233 celoss: 0.233 entropy: 0.758
# epoch: [401] loss: 0.094 celoss: 0.094 entropy: 0.460
# epoch: [601] loss: 0.084 celoss: 0.084 entropy: 0.447
# epoch: [801] loss: 0.086 celoss: 0.085 entropy: 0.415
# epoch: [1001] loss: 0.080 celoss: 0.080 entropy: 0.453
# epoch: [1201] loss: 0.084 celoss: 0.083 entropy: 0.458
# epoch: [1401] loss: 0.071 celoss: 0.071 entropy: 0.426
# epoch: [1601] loss: 0.070 celoss: 0.070 entropy: 0.413
# epoch: [1801] loss: 0.064 celoss: 0.064 entropy: 0.392
# epoch: [2001] loss: 0.052 celoss: 0.052 entropy: 0.364
# epoch: [2201] loss: 0.041 celoss: 0.040 entropy: 0.303
# epoch: [2401] loss: 0.033 celoss: 0.033 entropy: 0.298
# epoch: [2601] loss: 0.030 celoss: 0.030 entropy: 0.286
# epoch: [2801] loss: 0.034 celoss: 0.034 entropy: 0.300
# epoch: [3001] loss: 0.030 celoss: 0.030 entropy: 0.272
# epoch: [3201] loss: 0.021 celoss: 0.021 entropy: 0.260
# Finished Training run 3
# Accuracy of the network on the 3000 test images: 98.633333 %
# --------------------------------------------------------------------------------
# tensor([[[-3.4694e-18],
#          [ 0.0000e+00]],
#
#         [[ 2.6021e-18],
#          [-1.3878e-17]],
#
#         [[ 2.7105e-18],
#          [ 1.3878e-17]],
#
#         [[ 6.5052e-19],
#          [ 2.0817e-17]],
#
#         [[-2.1684e-18],
#          [ 1.0408e-17]]], device='cuda:0', dtype=torch.float64,
#        grad_fn=<UnsafeViewBackward>)
# epoch: [0 ] loss: 2.268
# epoch: [1] loss: 1.702 celoss: 1.702 entropy: 2.350
# epoch: [201] loss: 0.358 celoss: 0.358 entropy: 1.096
# epoch: [401] loss: 0.296 celoss: 0.295 entropy: 1.064
# epoch: [601] loss: 0.253 celoss: 0.253 entropy: 1.073
# epoch: [801] loss: 0.248 celoss: 0.248 entropy: 1.094
# epoch: [1001] loss: 0.175 celoss: 0.174 entropy: 1.079
# epoch: [1201] loss: 0.079 celoss: 0.078 entropy: 0.911
# epoch: [1401] loss: 0.045 celoss: 0.045 entropy: 0.748
# epoch: [1601] loss: 0.036 celoss: 0.036 entropy: 0.642
# epoch: [1801] loss: 0.030 celoss: 0.030 entropy: 0.567
# epoch: [2001] loss: 0.037 celoss: 0.037 entropy: 0.498
# epoch: [2201] loss: 0.025 celoss: 0.025 entropy: 0.504
# epoch: [2401] loss: 0.026 celoss: 0.026 entropy: 0.521
# Finished Training run 4
# Accuracy of the network on the 3000 test images: 99.566667 %
# --------------------------------------------------------------------------------
# tensor([[[ 1.3878e-17],
#          [-1.7347e-18]],
#
#         [[ 0.0000e+00],
#          [ 0.0000e+00]],
#
#         [[ 4.3368e-19],
#          [-1.0408e-17]],
#
#         [[-2.7756e-17],
#          [ 3.4694e-17]],
#
#         [[-1.3878e-17],
#          [ 2.7756e-17]]], device='cuda:0', dtype=torch.float64,
#        grad_fn=<UnsafeViewBackward>)
# epoch: [0 ] loss: 1.373
# epoch: [1] loss: 1.230 celoss: 1.229 entropy: 2.322
# epoch: [201] loss: 0.290 celoss: 0.290 entropy: 0.598
# epoch: [401] loss: 0.246 celoss: 0.246 entropy: 0.569
# epoch: [601] loss: 0.223 celoss: 0.222 entropy: 0.548
# epoch: [801] loss: 0.211 celoss: 0.211 entropy: 0.520
# epoch: [1001] loss: 0.195 celoss: 0.195 entropy: 0.518
# epoch: [1201] loss: 0.180 celoss: 0.180 entropy: 0.503
# epoch: [1401] loss: 0.170 celoss: 0.170 entropy: 0.488
# epoch: [1601] loss: 0.157 celoss: 0.157 entropy: 0.465
# epoch: [1801] loss: 0.151 celoss: 0.151 entropy: 0.445
# epoch: [2001] loss: 0.139 celoss: 0.139 entropy: 0.431
# epoch: [2201] loss: 0.138 celoss: 0.138 entropy: 0.416
# epoch: [2401] loss: 0.138 celoss: 0.138 entropy: 0.401
# epoch: [2601] loss: 0.134 celoss: 0.134 entropy: 0.412
# epoch: [2801] loss: 0.129 celoss: 0.129 entropy: 0.405
# epoch: [3001] loss: 0.134 celoss: 0.134 entropy: 0.400
# epoch: [3201] loss: 0.126 celoss: 0.126 entropy: 0.389
# epoch: [3401] loss: 0.138 celoss: 0.138 entropy: 0.391
# epoch: [3601] loss: 0.127 celoss: 0.127 entropy: 0.407
# epoch: [3801] loss: 0.125 celoss: 0.124 entropy: 0.399
# Finished Training run 5
# Accuracy of the network on the 3000 test images: 94.366667 %
# --------------------------------------------------------------------------------
# tensor([[[-1.0408e-17],
#          [-5.2042e-18]],
#
#         [[-6.0715e-18],
#          [ 6.9389e-18]],
#
#         [[ 0.0000e+00],
#          [-1.3878e-17]],
#
#         [[-1.3878e-17],
#          [ 4.8925e-18]],
#
#         [[ 0.0000e+00],
#          [-3.4694e-18]]], device='cuda:0', dtype=torch.float64,
#        grad_fn=<UnsafeViewBackward>)
# epoch: [0 ] loss: 2.502
# epoch: [1] loss: 1.442 celoss: 1.442 entropy: 2.261
# epoch: [201] loss: 0.207 celoss: 0.207 entropy: 0.994
# epoch: [401] loss: 0.084 celoss: 0.084 entropy: 0.613
# epoch: [601] loss: 0.072 celoss: 0.072 entropy: 0.489
# epoch: [801] loss: 0.052 celoss: 0.052 entropy: 0.451
# epoch: [1001] loss: 0.039 celoss: 0.039 entropy: 0.414
# epoch: [1201] loss: 0.042 celoss: 0.042 entropy: 0.394
# epoch: [1401] loss: 0.043 celoss: 0.043 entropy: 0.393
# epoch: [1601] loss: 0.028 celoss: 0.028 entropy: 0.376
# Finished Training run 6
# Accuracy of the network on the 3000 test images: 99.666667 %
# --------------------------------------------------------------------------------
# tensor([[[-7.6328e-17],
#          [ 0.0000e+00]],
#
#         [[-6.2450e-17],
#          [-1.3010e-18]],
#
#         [[ 9.7145e-17],
#          [ 2.4286e-17]],
#
#         [[ 1.5613e-17],
#          [ 0.0000e+00]],
#
#         [[ 8.6736e-18],
#          [-1.7347e-18]]], device='cuda:0', dtype=torch.float64,
#        grad_fn=<UnsafeViewBackward>)
# epoch: [0 ] loss: 1.318
# epoch: [1] loss: 1.195 celoss: 1.194 entropy: 2.375
# epoch: [201] loss: 0.148 celoss: 0.147 entropy: 0.561
# epoch: [401] loss: 0.078 celoss: 0.078 entropy: 0.429
# epoch: [601] loss: 0.078 celoss: 0.078 entropy: 0.386
# epoch: [801] loss: 0.066 celoss: 0.066 entropy: 0.337
# epoch: [1001] loss: 0.040 celoss: 0.040 entropy: 0.322
# epoch: [1201] loss: 0.035 celoss: 0.035 entropy: 0.287
# epoch: [1401] loss: 0.031 celoss: 0.031 entropy: 0.281
# epoch: [1601] loss: 0.032 celoss: 0.032 entropy: 0.256
# epoch: [1801] loss: 0.031 celoss: 0.031 entropy: 0.234
# epoch: [2001] loss: 0.027 celoss: 0.027 entropy: 0.259
# epoch: [2201] loss: 0.030 celoss: 0.030 entropy: 0.238
# epoch: [2401] loss: 0.027 celoss: 0.027 entropy: 0.248
# epoch: [2601] loss: 0.049 celoss: 0.049 entropy: 0.234
# epoch: [2801] loss: 0.030 celoss: 0.030 entropy: 0.234
# epoch: [3001] loss: 0.034 celoss: 0.033 entropy: 0.190
# epoch: [3201] loss: 0.028 celoss: 0.028 entropy: 0.203
# epoch: [3401] loss: 0.032 celoss: 0.032 entropy: 0.196
# epoch: [3601] loss: 0.024 celoss: 0.024 entropy: 0.194
# epoch: [3801] loss: 0.027 celoss: 0.027 entropy: 0.174
# Finished Training run 7
# Accuracy of the network on the 3000 test images: 98.833333 %
# --------------------------------------------------------------------------------
# tensor([[[ 1.5613e-17],
#          [ 0.0000e+00]],
#
#         [[ 1.6480e-17],
#          [ 1.3878e-17]],
#
#         [[ 0.0000e+00],
#          [ 5.5511e-17]],
#
#         [[ 7.6328e-17],
#          [-5.3776e-17]],
#
#         [[-1.7347e-18],
#          [ 0.0000e+00]]], device='cuda:0', dtype=torch.float64,
#        grad_fn=<UnsafeViewBackward>)
# epoch: [0 ] loss: 3.311
# epoch: [1] loss: 2.351 celoss: 2.351 entropy: 2.338
# epoch: [201] loss: 0.547 celoss: 0.547 entropy: 0.518
# epoch: [401] loss: 0.511 celoss: 0.511 entropy: 0.421
# epoch: [601] loss: 0.504 celoss: 0.504 entropy: 0.381
# epoch: [801] loss: 0.501 celoss: 0.501 entropy: 0.339
# epoch: [1001] loss: 0.499 celoss: 0.499 entropy: 0.326
# epoch: [1201] loss: 0.497 celoss: 0.497 entropy: 0.361
# epoch: [1401] loss: 0.495 celoss: 0.496 entropy: 0.276
# epoch: [1601] loss: 0.492 celoss: 0.493 entropy: 0.309
# epoch: [1801] loss: 0.486 celoss: 0.486 entropy: 0.271
# epoch: [2001] loss: 0.482 celoss: 0.482 entropy: 0.284
# epoch: [2201] loss: 0.479 celoss: 0.479 entropy: 0.267
# epoch: [2401] loss: 0.478 celoss: 0.478 entropy: 0.291
# epoch: [2601] loss: 0.474 celoss: 0.474 entropy: 0.270
# epoch: [2801] loss: 0.474 celoss: 0.474 entropy: 0.251
# epoch: [3001] loss: 0.471 celoss: 0.471 entropy: 0.253
# epoch: [3201] loss: 0.469 celoss: 0.469 entropy: 0.252
# epoch: [3401] loss: 0.469 celoss: 0.470 entropy: 0.250
# epoch: [3601] loss: 0.469 celoss: 0.469 entropy: 0.251
# epoch: [3801] loss: 0.469 celoss: 0.469 entropy: 0.251
# Finished Training run 8
# Accuracy of the network on the 3000 test images: 70.733333 %
# --------------------------------------------------------------------------------
# tensor([[[-8.6736e-19],
#          [-6.9389e-18]],
#
#         [[ 1.2468e-18],
#          [-3.4694e-18]],
#
#         [[ 3.4694e-18],
#          [-2.6970e-18]],
#
#         [[ 6.9389e-18],
#          [ 8.6736e-19]],
#
#         [[-2.7756e-17],
#          [ 2.7756e-17]]], device='cuda:0', dtype=torch.float64,
#        grad_fn=<UnsafeViewBackward>)
# epoch: [0 ] loss: 1.217
# epoch: [1] loss: 1.205 celoss: 1.204 entropy: 2.337
# epoch: [201] loss: 0.289 celoss: 0.289 entropy: 0.588
# epoch: [401] loss: 0.240 celoss: 0.240 entropy: 0.513
# epoch: [601] loss: 0.218 celoss: 0.218 entropy: 0.529
# epoch: [801] loss: 0.203 celoss: 0.203 entropy: 0.533
# epoch: [1001] loss: 0.192 celoss: 0.192 entropy: 0.506
# epoch: [1201] loss: 0.186 celoss: 0.186 entropy: 0.529
# epoch: [1401] loss: 0.178 celoss: 0.178 entropy: 0.562
# epoch: [1601] loss: 0.171 celoss: 0.171 entropy: 0.596
# epoch: [1801] loss: 0.169 celoss: 0.169 entropy: 0.579
# epoch: [2001] loss: 0.173 celoss: 0.173 entropy: 0.567
# epoch: [2201] loss: 0.157 celoss: 0.157 entropy: 0.596
# epoch: [2401] loss: 0.152 celoss: 0.152 entropy: 0.547
# epoch: [2601] loss: 0.140 celoss: 0.140 entropy: 0.437
# epoch: [2801] loss: 0.142 celoss: 0.142 entropy: 0.474
# epoch: [3001] loss: 0.129 celoss: 0.129 entropy: 0.445
# epoch: [3201] loss: 0.137 celoss: 0.137 entropy: 0.449
# epoch: [3401] loss: 0.128 celoss: 0.128 entropy: 0.451
# epoch: [3601] loss: 0.125 celoss: 0.124 entropy: 0.448
# epoch: [3801] loss: 0.131 celoss: 0.130 entropy: 0.435
# Finished Training run 9
# Accuracy of the network on the 3000 test images: 94.566667 %

# %%
print(np.mean(np.array(FTPT_analysis),axis=0)) #[7.42700000e+01 2.44100000e+01 7.33333333e-02 1.24666667e+00]
# Out:
# [70.55666667 25.05        0.08        4.31333333]

# %%
FTPT_analysis
# Out:
#         FTPT       FFPT      FTPF       FFPF
# 0  83.733333  15.366667  0.200000   0.700000
# 1  75.400000  24.066667  0.100000   0.433333
# 2  64.400000  34.133333  0.033333   1.433333
# 3  91.100000   8.466667  0.133333   0.300000
# 4  75.233333  24.200000  0.100000   0.466667
# 5  56.733333  38.966667  0.066667   4.233333
# 6  75.800000  23.600000  0.100000   0.500000
# 7  89.166667  10.200000  0.066667   0.566667
# 8  39.333333  30.566667  0.000000  30.100000
# 9  54.666667  40.933333  0.000000   4.400000

# %%
FTPT_analysis[FTPT_analysis['FTPT']+FTPT_analysis['FFPT'] > 90 ]
# Out:
#         FTPT       FFPT      FTPF      FFPF
# 0  83.733333  15.366667  0.200000  0.700000
# 1  75.400000  24.066667  0.100000  0.433333
# 2  64.400000  34.133333  0.033333  1.433333
# 3  91.100000   8.466667  0.133333  0.300000
# 4  75.233333  24.200000  0.100000  0.466667
# 5  56.733333  38.966667  0.066667  4.233333
# 6  75.800000  23.600000  0.100000  0.500000
# 7  89.166667  10.200000  0.066667  0.566667
# 9  54.666667  40.933333  0.000000  4.400000

# %%
print(np.mean(np.array(FTPT_analysis[FTPT_analysis['FTPT']+FTPT_analysis['FFPT'] > 90 ]),axis=0))
# Out:
# [74.02592593 24.43703704  0.08888889  1.44814815]

# %%
cnt=1
for epoch, analysis_data in full_analysis:
  analysis_data = np.array(analysis_data)
  # print("="*20+"run ",cnt,"="*20)
  
  plt.figure(figsize=(6,5))
  plt.plot(np.arange(0,epoch+2,1),analysis_data[:,0]/30,label="FTPT")
  plt.plot(np.arange(0,epoch+2,1),analysis_data[:,1]/30,label="FFPT")
  plt.plot(np.arange(0,epoch+2,1),analysis_data[:,2]/30,label="FTPF")
  plt.plot(np.arange(0,epoch+2,1),analysis_data[:,3]/30,label="FFPF")

  plt.title("Training trends for run "+str(cnt))
  plt.grid()
  # plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
  plt.legend()
  plt.xlabel("epochs", fontsize=14, fontweight = 'bold')
  plt.ylabel("percentage train data", fontsize=14, fontweight = 'bold')
  plt.savefig(path + "run"+str(cnt)+".png",bbox_inches="tight")
  plt.savefig(path + "run"+str(cnt)+".pdf",bbox_inches="tight")
  cnt+=1

# %%
FTPT_analysis.to_csv(path+"synthetic_zeroth.csv",index=False)
