# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
path = '/content/drive/MyDrive/Research/AAAI/complexity/50_200/'

# %%
import numpy as np
import pandas as pd

import torch
import torchvision
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms, utils
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

from matplotlib import pyplot as plt
# %matplotlib inline

torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False

# %% [markdown]
# # Generate dataset

# %%
np.random.seed(12)
y = np.random.randint(0,10,5000)
idx= []
for i in range(10):
    print(i,sum(y==i))
    idx.append(y==i)
x = np.zeros((5000,2))
np.random.seed(12)
x[idx[0],:] = np.random.multivariate_normal(mean = [4,6.5],cov=[[0.01,0],[0,0.01]],size=sum(idx[0]))
x[idx[1],:] = np.random.multivariate_normal(mean = [5.5,6],cov=[[0.01,0],[0,0.01]],size=sum(idx[1]))
x[idx[2],:] = np.random.multivariate_normal(mean = [4.5,4.5],cov=[[0.01,0],[0,0.01]],size=sum(idx[2]))
x[idx[3],:] = np.random.multivariate_normal(mean = [3,3.5],cov=[[0.01,0],[0,0.01]],size=sum(idx[3]))
x[idx[4],:] = np.random.multivariate_normal(mean = [2.5,5.5],cov=[[0.01,0],[0,0.01]],size=sum(idx[4]))
x[idx[5],:] = np.random.multivariate_normal(mean = [3.5,8],cov=[[0.01,0],[0,0.01]],size=sum(idx[5]))
x[idx[6],:] = np.random.multivariate_normal(mean = [5.5,8],cov=[[0.01,0],[0,0.01]],size=sum(idx[6]))
x[idx[7],:] = np.random.multivariate_normal(mean = [7,6.5],cov=[[0.01,0],[0,0.01]],size=sum(idx[7]))
x[idx[8],:] = np.random.multivariate_normal(mean = [6.5,4.5],cov=[[0.01,0],[0,0.01]],size=sum(idx[8]))
x[idx[9],:] = np.random.multivariate_normal(mean = [5,3],cov=[[0.01,0],[0,0.01]],size=sum(idx[9]))
color = ['#1F77B4','orange', 'g','brown']
name = [1,2,3,0]
for i in range(10):
  if i==3:
    plt.scatter(x[idx[i],0],x[idx[i],1],c=color[3],label="D_"+str(name[i]))
  elif i>=4:
    plt.scatter(x[idx[i],0],x[idx[i],1],c=color[3])
  else:
    plt.scatter(x[idx[i],0],x[idx[i],1],c=color[i],label="D_"+str(name[i]))
plt.legend()
# Out:
# 0 530
# 1 463
# 2 494
# 3 517
# 4 488
# 5 497
# 6 493
# 7 507
# 8 492
# 9 519

# %%
x[idx[0]][0], x[idx[5]][5]
# Out:
# (array([4.04729858, 6.43185741]), array([3.4612816 , 8.00144771]))

# %%
desired_num = 6000
mosaic_list_of_images =[]
mosaic_label = []
fore_idx=[]
for j in range(desired_num):
    np.random.seed(j)
    fg_class  = np.random.randint(0,3)
    fg_idx = np.random.randint(0,9)
    a = []
    for i in range(9):
        if i == fg_idx:
            b = np.random.choice(np.where(idx[fg_class]==True)[0],size=1)
            a.append(x[b])
#             print("foreground "+str(fg_class)+" present at " + str(fg_idx))
        else:
            bg_class = np.random.randint(3,10)
            b = np.random.choice(np.where(idx[bg_class]==True)[0],size=1)
            a.append(x[b])
#             print("background "+str(bg_class)+" present at " + str(i))
    a = np.concatenate(a,axis=0)
    mosaic_list_of_images.append(a)
    mosaic_label.append(fg_class)
    fore_idx.append(fg_idx)

# %%
len(mosaic_list_of_images), mosaic_list_of_images[0]
# Out:
# (6000, array([[2.97319488, 3.56326392],
#         [2.59779787, 5.38694546],
#         [6.50095845, 4.49418185],
#         [7.06459245, 6.53896691],
#         [5.0161796 , 2.92679482],
#         [4.1251117 , 6.62627906],
#         [3.43548455, 7.98866194],
#         [5.01328229, 3.05196492],
#         [4.91416206, 3.02422072]]))

# %% [markdown]
# # load mosaic data

# %%
class MosaicDataset(Dataset):
  """MosaicDataset dataset."""

  def __init__(self, mosaic_list, mosaic_label,fore_idx):
    """
      Args:
        csv_file (string): Path to the csv file with annotations.
        root_dir (string): Directory with all the images.
        transform (callable, optional): Optional transform to be applied
            on a sample.
    """
    self.mosaic = mosaic_list
    self.label = mosaic_label
    self.fore_idx = fore_idx
    
  def __len__(self):
    return len(self.label)

  def __getitem__(self, idx):
    return self.mosaic[idx] , self.label[idx] , self.fore_idx[idx]

# %%
batch = 250
msd1 = MosaicDataset(mosaic_list_of_images[0:3000], mosaic_label[0:3000] , fore_idx[0:3000])
train_loader = DataLoader( msd1 ,batch_size= batch ,shuffle=True)

# %%
batch = 250
msd2 = MosaicDataset(mosaic_list_of_images[3000:6000], mosaic_label[3000:6000] , fore_idx[3000:6000])
test_loader = DataLoader( msd2 ,batch_size= batch ,shuffle=True)

# %% [markdown]
# # models

# %%
class Focus_deep(nn.Module):
    '''
       deep focus network averaged at zeroth layer
       input : elemental data
    '''
    def __init__(self,inputs,output,K,d):
        super(Focus_deep,self).__init__()
        self.inputs = inputs
        self.output = output
        self.K = K
        self.d  = d
        self.linear1 = nn.Linear(self.inputs,50, bias=False)  #,self.output)
        self.linear2 = nn.Linear(50,self.output, bias=False) 

        torch.nn.init.xavier_normal_(self.linear1.weight)
        torch.nn.init.xavier_normal_(self.linear2.weight)
        
    def forward(self,z):
        batch = z.shape[0]
        x = torch.zeros([batch,self.K],dtype=torch.float64)
        y = torch.zeros([batch,50], dtype=torch.float64)   # number of features of output
        features = torch.zeros([batch,self.K,50],dtype=torch.float64)
        x,y = x.to("cuda"),y.to("cuda")
        features = features.to("cuda")
        for i in range(self.K):
            alp,ftrs = self.helper(z[:,i] )  # self.d*i:self.d*i+self.d
            x[:,i] = alp[:,0]
            features[:,i]  = ftrs 
        log_x = F.log_softmax(x,dim=1)  # log_alphas
        x = F.softmax(x,dim=1)   # alphas
        
        for i in range(self.K):
            x1 = x[:,i]          
            y = y+torch.mul(x1[:,None],features[:,i])  # self.d*i:self.d*i+self.d
        return y , x,log_x 
    def helper(self,x):
      x = self.linear1(x)
      x1 = F.tanh(x)
      x = F.relu(x) 

      x = self.linear2(x)

      return x,x1

# %%
class Classification_deep(nn.Module):
    '''
       input : elemental data
       deep classification module data averaged at zeroth layer with input-50-output architecture
    '''
    def __init__(self,inputs,output):
        super(Classification_deep,self).__init__()
        self.inputs = inputs
        self.output = output
        self.linear1 = nn.Linear(self.inputs,200)
        self.linear2 = nn.Linear(200,self.output)
        
        torch.nn.init.xavier_normal_(self.linear1.weight)
        torch.nn.init.zeros_(self.linear1.bias)
        torch.nn.init.xavier_normal_(self.linear2.weight)
        torch.nn.init.zeros_(self.linear2.bias)

    def forward(self,x):
      x = F.relu(self.linear1(x))
      x = self.linear2(x)
      return x

# %%
torch.manual_seed(12)
focus_net = Focus_deep(2,1,9,2).double()
focus_net = focus_net.to("cuda")

# %%
focus_net.linear1.weight.shape,focus_net.linear2.weight.shape
# Out:
# (torch.Size([50, 2]), torch.Size([1, 50]))

# %%
focus_net.linear1.weight.data[25:,:] = focus_net.linear1.weight.data[:25,:] #torch.nn.Parameter(torch.tensor([last_layer]) )
(focus_net.linear1.weight[:25,:]== focus_net.linear1.weight[25:,:] )
# Out:
# tensor([[True, True],
#         [True, True],
#         [True, True],
#         [True, True],
#         [True, True],
#         [True, True],
#         [True, True],
#         [True, True],
#         [True, True],
#         [True, True],
#         [True, True],
#         [True, True],
#         [True, True],
#         [True, True],
#         [True, True],
#         [True, True],
#         [True, True],
#         [True, True],
#         [True, True],
#         [True, True],
#         [True, True],
#         [True, True],
#         [True, True],
#         [True, True],
#         [True, True]], device='cuda:0')

# %%
focus_net.linear2.weight.data[:,25:] = -focus_net.linear2.weight.data[:,:25] #torch.nn.Parameter(torch.tensor([last_layer]) )
focus_net.linear2.weight
# Out:
# Parameter containing:
# tensor([[ 0.2877,  0.2409, -0.1060,  0.0798,  0.0235,  0.5752,  0.2892,  0.3077,
#          -0.0946,  0.0924, -0.1857,  0.1151, -0.0581, -0.1602, -0.0622, -0.3845,
#           0.2236, -0.0697, -0.1184, -0.0754,  0.0007,  0.0488,  0.0265, -0.2130,
#          -0.1718, -0.2877, -0.2409,  0.1060, -0.0798, -0.0235, -0.5752, -0.2892,
#          -0.3077,  0.0946, -0.0924,  0.1857, -0.1151,  0.0581,  0.1602,  0.0622,
#           0.3845, -0.2236,  0.0697,  0.1184,  0.0754, -0.0007, -0.0488, -0.0265,
#           0.2130,  0.1718]], device='cuda:0', dtype=torch.float64,
#        requires_grad=True)

# %%
ex,_ = focus_net.helper( torch.randn((1,2,2)).double().to("cuda") )
print(ex)
# Out:
# tensor([[[-6.9389e-17],
#          [ 8.3267e-17]]], device='cuda:0', dtype=torch.float64,
#        grad_fn=<UnsafeViewBackward>)
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:1794: UserWarning: nn.functional.tanh is deprecated. Use torch.tanh instead.
#   warnings.warn("nn.functional.tanh is deprecated. Use torch.tanh instead.")

# %%
criterion = nn.CrossEntropyLoss()
def my_cross_entropy(x, y,alpha,log_alpha,k):
    # log_prob = -1.0 * F.log_softmax(x, 1)
    # loss = log_prob.gather(1, y.unsqueeze(1))
    # loss = loss.mean()
    loss = criterion(x,y)
    
    #alpha = torch.clamp(alpha,min=1e-10)     
    
    b = -1.0* alpha * log_alpha
    b =  torch.mean(torch.sum(b,dim=1))
    closs = loss
    entropy = b 
    loss = (1-k)*loss + ((k)*b)
    return loss,closs,entropy

# %%
def calculate_attn_loss(dataloader,what,where,criter,k):
  what.eval()
  where.eval()
  r_loss = 0
  cc_loss = 0
  cc_entropy = 0
  alphas = []
  lbls = []
  pred = []
  fidices = []
  with torch.no_grad():
    for i, data in enumerate(dataloader, 0):
      inputs, labels,fidx = data
      lbls.append(labels)
      fidices.append(fidx)
      inputs = inputs.double()
      inputs, labels = inputs.to("cuda"),labels.to("cuda")
      avg,alpha,log_alpha = where(inputs)
      outputs = what(avg)
      _, predicted = torch.max(outputs.data, 1)
      pred.append(predicted.cpu().numpy())
      alphas.append(alpha.cpu().numpy())

      #ent = np.sum(entropy(alpha.cpu().detach().numpy(), base=2, axis=1))/batch
      # mx,_ = torch.max(alpha,1)
      # entropy = np.mean(-np.log2(mx.cpu().detach().numpy()))
      # print("entropy of batch", entropy)

      #loss = (1-k)*criter(outputs, labels) + k*ent
      loss,closs,entropy = my_cross_entropy(outputs,labels,alpha,log_alpha,k)
      r_loss += loss.item()
      cc_loss += closs.item()
      cc_entropy += entropy.item()

  alphas = np.concatenate(alphas,axis=0)
  pred = np.concatenate(pred,axis=0)
  lbls = np.concatenate(lbls,axis=0)
  fidices = np.concatenate(fidices,axis=0)
  #print(alphas.shape,pred.shape,lbls.shape,fidices.shape) 
  analysis = analyse_data(alphas,lbls,pred,fidices)
  return r_loss/i,cc_loss/i,cc_entropy/i,analysis

# %%
def analyse_data(alphas,lbls,predicted,f_idx):
    '''
       analysis data is created here
    '''
    batch = len(predicted)
    amth,alth,ftpt,ffpt,ftpf,ffpf = 0,0,0,0,0,0
    for j in range (batch):
      focus = np.argmax(alphas[j])
      if(alphas[j][focus] >= 0.5):
        amth +=1
      else:
        alth +=1
      if(focus == f_idx[j] and predicted[j] == lbls[j]):
        ftpt += 1
      elif(focus != f_idx[j] and predicted[j] == lbls[j]):
        ffpt +=1
      elif(focus == f_idx[j] and predicted[j] != lbls[j]):
        ftpf +=1
      elif(focus != f_idx[j] and predicted[j] != lbls[j]):
        ffpf +=1
    #print(sum(predicted==lbls),ftpt+ffpt)
    return [ftpt,ffpt,ftpf,ffpf,amth,alth]

# %% [markdown]
# # training

# %%
number_runs = 10
full_analysis =[]
FTPT_analysis = pd.DataFrame(columns = ["FTPT","FFPT", "FTPF","FFPF"])
k = 0
for n in range(number_runs):
  print("--"*40)
  
  # instantiate focus and classification Model
  torch.manual_seed(n)
  where = Focus_deep(2,1,9,2).double()
  where.linear1.weight.data[25:,:] = where.linear1.weight.data[:25,:]
  where.linear2.weight.data[:,25:] = -where.linear2.weight.data[:,:25]
  where = where.double().to("cuda")
  ex, _ = where.helper( torch.randn((1,5,2)).double().to("cuda"))
  print(ex)

  what = Classification_deep(50,3).double()
  where = where.to("cuda")
  what = what.to("cuda")

  # instantiate optimizer
  optimizer_where = optim.Adam(where.parameters(),lr =0.001)
  optimizer_what = optim.Adam(what.parameters(), lr=0.001)
  #criterion = nn.CrossEntropyLoss()
  acti = []
  analysis_data = []
  loss_curi = []
  epochs = 2000


  # calculate zeroth epoch loss and FTPT values
  running_loss ,_,_,anlys_data= calculate_attn_loss(train_loader,what,where,criterion,k)
  loss_curi.append(running_loss)
  analysis_data.append(anlys_data)

  print('epoch: [%d ] loss: %.3f' %(0,running_loss)) 

  # training starts 
  for epoch in range(epochs): # loop over the dataset multiple times
    ep_lossi = []
    running_loss = 0.0
    what.train()
    where.train()
    for i, data in enumerate(train_loader, 0):
      # get the inputs
      inputs, labels,_ = data
      inputs = inputs.double()
      inputs, labels = inputs.to("cuda"),labels.to("cuda")

      # zero the parameter gradients
      optimizer_where.zero_grad()
      optimizer_what.zero_grad()
      
      # forward + backward + optimize
      avg, alpha,log_alpha = where(inputs)
      outputs = what(avg)

      my_loss,_,_ = my_cross_entropy(outputs,labels,alpha,log_alpha,k)

      # print statistics
      running_loss += my_loss.item()
      my_loss.backward()
      optimizer_where.step()
      optimizer_what.step()
    #break
    running_loss,ccloss,ccentropy,anls_data = calculate_attn_loss(train_loader,what,where,criterion,k)
    analysis_data.append(anls_data)

    if(epoch % 200==0):
      print('epoch: [%d] loss: %.3f celoss: %.3f entropy: %.3f' %(epoch + 1,running_loss,ccloss,ccentropy)) 
    loss_curi.append(running_loss)   #loss per epoch
    if running_loss<=0.01:
      print('breaking in epoch: ', epoch)
      break
  print('Finished Training run ' +str(n))
  #break
  analysis_data = np.array(analysis_data)
  FTPT_analysis.loc[n] = analysis_data[-1,:4]/30
  full_analysis.append((epoch, analysis_data))
  correct = 0
  total = 0
  with torch.no_grad():
    for data in test_loader:
      images, labels,_ = data
      images = images.double()
      images, labels = images.to("cuda"), labels.to("cuda")
      avg, alpha,log_alpha = where(images)
      outputs  = what(avg)
      _, predicted = torch.max(outputs.data, 1)
      total += labels.size(0)
      correct += (predicted == labels).sum().item()

  print('Accuracy of the network on the 3000 test images: %f %%' % (  100 * correct / total))
# Out:
# --------------------------------------------------------------------------------
# tensor([[[-3.4694e-18],
#          [ 3.4694e-18],
#          [-1.0408e-17],
#          [ 3.4694e-18],
#          [ 2.0817e-17]]], device='cuda:0', dtype=torch.float64,
#        grad_fn=<UnsafeViewBackward>)
# epoch: [0 ] loss: 1.209
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:1794: UserWarning: nn.functional.tanh is deprecated. Use torch.tanh instead.
#   warnings.warn("nn.functional.tanh is deprecated. Use torch.tanh instead.")
# epoch: [1] loss: 1.194 celoss: 1.194 entropy: 2.397
# epoch: [201] loss: 0.188 celoss: 0.188 entropy: 1.270
# epoch: [401] loss: 0.140 celoss: 0.140 entropy: 1.204
# epoch: [601] loss: 0.128 celoss: 0.128 entropy: 1.179
# epoch: [801] loss: 0.107 celoss: 0.107 entropy: 1.162
# epoch: [1001] loss: 0.091 celoss: 0.091 entropy: 1.156
# epoch: [1201] loss: 0.086 celoss: 0.086 entropy: 1.157
# epoch: [1401] loss: 0.055 celoss: 0.055 entropy: 1.161
# epoch: [1601] loss: 0.035 celoss: 0.035 entropy: 1.157
# epoch: [1801] loss: 0.030 celoss: 0.030 entropy: 1.167
# Finished Training run 0
# Accuracy of the network on the 3000 test images: 99.466667 %
# --------------------------------------------------------------------------------
# tensor([[[4.3368e-19],
#          [8.6736e-19],
#          [2.7756e-17],
#          [8.6736e-19],
#          [8.6736e-19]]], device='cuda:0', dtype=torch.float64,
#        grad_fn=<UnsafeViewBackward>)
# epoch: [0 ] loss: 1.231
# epoch: [1] loss: 1.198 celoss: 1.198 entropy: 2.396
# epoch: [201] loss: 0.218 celoss: 0.218 entropy: 1.299
# epoch: [401] loss: 0.160 celoss: 0.160 entropy: 1.319
# epoch: [601] loss: 0.133 celoss: 0.133 entropy: 1.301
# epoch: [801] loss: 0.106 celoss: 0.106 entropy: 1.284
# epoch: [1001] loss: 0.101 celoss: 0.101 entropy: 1.279
# epoch: [1201] loss: 0.084 celoss: 0.084 entropy: 1.274
# epoch: [1401] loss: 0.076 celoss: 0.076 entropy: 1.286
# epoch: [1601] loss: 0.060 celoss: 0.060 entropy: 1.293
# epoch: [1801] loss: 0.060 celoss: 0.060 entropy: 1.298
# Finished Training run 1
# Accuracy of the network on the 3000 test images: 97.133333 %
# --------------------------------------------------------------------------------
# tensor([[[-1.9516e-18],
#          [ 3.4694e-18],
#          [-6.5052e-18],
#          [-6.9389e-18],
#          [ 0.0000e+00]]], device='cuda:0', dtype=torch.float64,
#        grad_fn=<UnsafeViewBackward>)
# epoch: [0 ] loss: 1.314
# epoch: [1] loss: 1.191 celoss: 1.191 entropy: 2.396
# epoch: [201] loss: 0.192 celoss: 0.192 entropy: 1.280
# epoch: [401] loss: 0.153 celoss: 0.153 entropy: 1.203
# epoch: [601] loss: 0.137 celoss: 0.137 entropy: 1.174
# epoch: [801] loss: 0.141 celoss: 0.141 entropy: 1.146
# epoch: [1001] loss: 0.104 celoss: 0.104 entropy: 1.133
# epoch: [1201] loss: 0.087 celoss: 0.087 entropy: 1.107
# epoch: [1401] loss: 0.070 celoss: 0.070 entropy: 1.090
# epoch: [1601] loss: 0.091 celoss: 0.091 entropy: 1.081
# epoch: [1801] loss: 0.051 celoss: 0.051 entropy: 1.084
# Finished Training run 2
# Accuracy of the network on the 3000 test images: 98.266667 %
# --------------------------------------------------------------------------------
# tensor([[[ 3.4694e-17],
#          [-2.0817e-17],
#          [-3.0358e-18],
#          [ 0.0000e+00],
#          [ 0.0000e+00]]], device='cuda:0', dtype=torch.float64,
#        grad_fn=<UnsafeViewBackward>)
# epoch: [0 ] loss: 1.243
# epoch: [1] loss: 1.195 celoss: 1.195 entropy: 2.394
# epoch: [201] loss: 0.179 celoss: 0.179 entropy: 1.247
# epoch: [401] loss: 0.141 celoss: 0.141 entropy: 1.182
# epoch: [601] loss: 0.130 celoss: 0.130 entropy: 1.156
# epoch: [801] loss: 0.114 celoss: 0.114 entropy: 1.138
# epoch: [1001] loss: 0.098 celoss: 0.098 entropy: 1.107
# epoch: [1201] loss: 0.083 celoss: 0.083 entropy: 1.091
# epoch: [1401] loss: 0.078 celoss: 0.078 entropy: 1.055
# epoch: [1601] loss: 0.065 celoss: 0.065 entropy: 1.050
# epoch: [1801] loss: 0.059 celoss: 0.059 entropy: 1.040
# Finished Training run 3
# Accuracy of the network on the 3000 test images: 97.666667 %
# --------------------------------------------------------------------------------
# tensor([[[ 4.1633e-17],
#          [-1.7347e-17],
#          [ 3.4694e-18],
#          [ 2.4286e-17],
#          [-6.9389e-18]]], device='cuda:0', dtype=torch.float64,
#        grad_fn=<UnsafeViewBackward>)
# epoch: [0 ] loss: 1.212
# epoch: [1] loss: 1.192 celoss: 1.192 entropy: 2.397
# epoch: [201] loss: 0.187 celoss: 0.187 entropy: 1.272
# epoch: [401] loss: 0.149 celoss: 0.149 entropy: 1.194
# epoch: [601] loss: 0.121 celoss: 0.121 entropy: 1.166
# epoch: [801] loss: 0.103 celoss: 0.103 entropy: 1.145
# epoch: [1001] loss: 0.107 celoss: 0.107 entropy: 1.140
# epoch: [1201] loss: 0.086 celoss: 0.086 entropy: 1.135
# epoch: [1401] loss: 0.080 celoss: 0.080 entropy: 1.133
# epoch: [1601] loss: 0.046 celoss: 0.046 entropy: 1.149
# epoch: [1801] loss: 0.033 celoss: 0.033 entropy: 1.159
# Finished Training run 4
# Accuracy of the network on the 3000 test images: 97.800000 %
# --------------------------------------------------------------------------------
# tensor([[[-5.2042e-18],
#          [-5.4210e-18],
#          [ 4.3368e-18],
#          [ 6.9389e-18],
#          [ 5.2042e-18]]], device='cuda:0', dtype=torch.float64,
#        grad_fn=<UnsafeViewBackward>)
# epoch: [0 ] loss: 1.206
# epoch: [1] loss: 1.206 celoss: 1.206 entropy: 2.396
# epoch: [201] loss: 0.253 celoss: 0.253 entropy: 1.345
# epoch: [401] loss: 0.165 celoss: 0.165 entropy: 1.255
# epoch: [601] loss: 0.136 celoss: 0.136 entropy: 1.227
# epoch: [801] loss: 0.112 celoss: 0.112 entropy: 1.191
# epoch: [1001] loss: 0.109 celoss: 0.109 entropy: 1.167
# epoch: [1201] loss: 0.084 celoss: 0.084 entropy: 1.132
# epoch: [1401] loss: 0.080 celoss: 0.080 entropy: 1.113
# epoch: [1601] loss: 0.067 celoss: 0.067 entropy: 1.086
# epoch: [1801] loss: 0.072 celoss: 0.072 entropy: 1.074
# Finished Training run 5
# Accuracy of the network on the 3000 test images: 97.600000 %
# --------------------------------------------------------------------------------
# tensor([[[-8.6736e-19],
#          [ 1.3878e-17],
#          [ 2.7756e-17],
#          [ 2.7756e-17],
#          [ 5.5511e-17]]], device='cuda:0', dtype=torch.float64,
#        grad_fn=<UnsafeViewBackward>)
# epoch: [0 ] loss: 1.499
# epoch: [1] loss: 1.227 celoss: 1.227 entropy: 2.392
# epoch: [201] loss: 0.184 celoss: 0.184 entropy: 1.284
# epoch: [401] loss: 0.128 celoss: 0.128 entropy: 1.196
# epoch: [601] loss: 0.105 celoss: 0.105 entropy: 1.176
# epoch: [801] loss: 0.072 celoss: 0.072 entropy: 1.201
# epoch: [1001] loss: 0.043 celoss: 0.043 entropy: 1.254
# epoch: [1201] loss: 0.025 celoss: 0.025 entropy: 1.304
# epoch: [1401] loss: 0.017 celoss: 0.017 entropy: 1.360
# breaking in epoch:  1560
# Finished Training run 6
# Accuracy of the network on the 3000 test images: 99.733333 %
# --------------------------------------------------------------------------------
# tensor([[[ 3.4694e-18],
#          [-3.4694e-18],
#          [-6.9389e-18],
#          [ 3.4694e-18],
#          [-1.1276e-17]]], device='cuda:0', dtype=torch.float64,
#        grad_fn=<UnsafeViewBackward>)
# epoch: [0 ] loss: 1.237
# epoch: [1] loss: 1.205 celoss: 1.205 entropy: 2.395
# epoch: [201] loss: 0.175 celoss: 0.175 entropy: 1.230
# epoch: [401] loss: 0.139 celoss: 0.139 entropy: 1.179
# epoch: [601] loss: 0.125 celoss: 0.125 entropy: 1.155
# epoch: [801] loss: 0.101 celoss: 0.101 entropy: 1.144
# epoch: [1001] loss: 0.078 celoss: 0.078 entropy: 1.147
# epoch: [1201] loss: 0.064 celoss: 0.064 entropy: 1.147
# epoch: [1401] loss: 0.048 celoss: 0.048 entropy: 1.162
# epoch: [1601] loss: 0.039 celoss: 0.039 entropy: 1.152
# epoch: [1801] loss: 0.031 celoss: 0.031 entropy: 1.159
# Finished Training run 7
# Accuracy of the network on the 3000 test images: 98.566667 %
# --------------------------------------------------------------------------------
# tensor([[[-1.3878e-17],
#          [ 8.6736e-19],
#          [ 0.0000e+00],
#          [ 3.4694e-18],
#          [ 6.9389e-18]]], device='cuda:0', dtype=torch.float64,
#        grad_fn=<UnsafeViewBackward>)
# epoch: [0 ] loss: 1.245
# epoch: [1] loss: 1.196 celoss: 1.196 entropy: 2.394
# epoch: [201] loss: 0.165 celoss: 0.165 entropy: 1.243
# epoch: [401] loss: 0.123 celoss: 0.123 entropy: 1.187
# epoch: [601] loss: 0.084 celoss: 0.084 entropy: 1.166
# epoch: [801] loss: 0.057 celoss: 0.057 entropy: 1.166
# epoch: [1001] loss: 0.034 celoss: 0.034 entropy: 1.161
# epoch: [1201] loss: 0.023 celoss: 0.023 entropy: 1.159
# epoch: [1401] loss: 0.014 celoss: 0.014 entropy: 1.162
# breaking in epoch:  1567
# Finished Training run 8
# Accuracy of the network on the 3000 test images: 99.600000 %
# --------------------------------------------------------------------------------
# tensor([[[-4.1633e-17],
#          [ 6.9389e-18],
#          [-1.7347e-17],
#          [-4.1633e-17],
#          [-1.3878e-17]]], device='cuda:0', dtype=torch.float64,
#        grad_fn=<UnsafeViewBackward>)
# epoch: [0 ] loss: 1.226
# epoch: [1] loss: 1.193 celoss: 1.193 entropy: 2.396
# epoch: [201] loss: 0.234 celoss: 0.234 entropy: 1.349
# epoch: [401] loss: 0.160 celoss: 0.160 entropy: 1.316
# epoch: [601] loss: 0.131 celoss: 0.131 entropy: 1.280
# epoch: [801] loss: 0.128 celoss: 0.128 entropy: 1.267
# epoch: [1001] loss: 0.095 celoss: 0.095 entropy: 1.262
# epoch: [1201] loss: 0.090 celoss: 0.090 entropy: 1.270
# epoch: [1401] loss: 0.069 celoss: 0.069 entropy: 1.264
# epoch: [1601] loss: 0.058 celoss: 0.058 entropy: 1.278
# epoch: [1801] loss: 0.052 celoss: 0.052 entropy: 1.285
# Finished Training run 9
# Accuracy of the network on the 3000 test images: 97.433333 %

# %%
print(np.mean(np.array(FTPT_analysis),axis=0))
# Out:
# [45.9        53.00666667  0.14666667  0.94666667]

# %%
FTPT_analysis
# Out:
#         FTPT       FFPT      FTPF      FFPF
# 0  50.666667  49.033333  0.033333  0.266667
# 1  45.300000  53.333333  0.100000  1.266667
# 2  46.433333  52.000000  0.366667  1.200000
# 3  41.966667  56.300000  0.433333  1.300000
# 4  45.700000  52.866667  0.133333  1.300000
# 5  25.766667  72.300000  0.133333  1.800000
# 6  59.033333  40.733333  0.066667  0.166667
# 7  47.633333  51.500000  0.000000  0.866667
# 8  49.866667  49.900000  0.100000  0.133333
# 9  46.633333  52.100000  0.100000  1.166667

# %%
FTPT_analysis[FTPT_analysis['FTPT']+FTPT_analysis['FFPT'] > 90 ]
# Out:
#         FTPT       FFPT      FTPF      FFPF
# 0  50.666667  49.033333  0.033333  0.266667
# 1  45.300000  53.333333  0.100000  1.266667
# 2  46.433333  52.000000  0.366667  1.200000
# 3  41.966667  56.300000  0.433333  1.300000
# 4  45.700000  52.866667  0.133333  1.300000
# 5  25.766667  72.300000  0.133333  1.800000
# 6  59.033333  40.733333  0.066667  0.166667
# 7  47.633333  51.500000  0.000000  0.866667
# 8  49.866667  49.900000  0.100000  0.133333
# 9  46.633333  52.100000  0.100000  1.166667

# %%
print(np.mean(np.array(FTPT_analysis[FTPT_analysis['FTPT']+FTPT_analysis['FFPT'] > 90 ]),axis=0))
# Out:
# [45.9        53.00666667  0.14666667  0.94666667]

# %%
cnt=1
for epoch, analysis_data in full_analysis:
  analysis_data = np.array(analysis_data)
  # print("="*20+"run ",cnt,"="*20)
  
  plt.figure(figsize=(6,5))
  plt.plot(np.arange(0,epoch+2,1),analysis_data[:,0]/30,label="FTPT")
  plt.plot(np.arange(0,epoch+2,1),analysis_data[:,1]/30,label="FFPT")
  plt.plot(np.arange(0,epoch+2,1),analysis_data[:,2]/30,label="FTPF")
  plt.plot(np.arange(0,epoch+2,1),analysis_data[:,3]/30,label="FFPF")

  plt.title("Training trends for run "+str(cnt))
  plt.grid()
  # plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
  plt.legend()
  plt.xlabel("epochs", fontsize=14, fontweight = 'bold')
  plt.ylabel("percentage train data", fontsize=14, fontweight = 'bold')
  plt.savefig(path + "run"+str(cnt)+".png",bbox_inches="tight")
  plt.savefig(path + "run"+str(cnt)+".pdf",bbox_inches="tight")
  cnt+=1

# %%
FTPT_analysis.to_csv(path+"synthetic_zeroth.csv",index=False)
