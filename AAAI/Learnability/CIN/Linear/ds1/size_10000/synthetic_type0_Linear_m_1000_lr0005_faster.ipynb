# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
from tqdm import tqdm
# %matplotlib inline
from torch.utils.data import Dataset, DataLoader
import torch
import torchvision

import torch.nn as nn
import torch.optim as optim
from torch.nn import functional as F
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda

# %%
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark= False

# %%
m = 1000                            # 5, 50, 100, 500 , 1000 , 2000

# %%
desired_num = 10000

# %%
tr_i = 0
tr_j = desired_num
tr_k = desired_num+1000

tr_i, tr_j, tr_k
# Out:
# (0, 10000, 11000)

# %% [markdown]
# # Generate dataset

# %%
np.random.seed(12)
y = np.random.randint(0,3,500)
idx= []
for i in range(3):
    print(i,sum(y==i))
    idx.append(y==i)
# Out:
# 0 174
# 1 163
# 2 163

# %%
x = np.zeros((500,))

# %%
np.random.seed(12)
x[idx[0]] = np.random.uniform(low =-1,high =0,size= sum(idx[0]))
x[idx[1]] = np.random.uniform(low =0,high =1,size= sum(idx[1]))
x[idx[2]] = np.random.uniform(low =2,high =3,size= sum(idx[2]))

# %%
x[idx[0]][0], x[idx[2]][5]
# Out:
# (-0.8458371576203276, 2.2459800877058114)

# %%
print(x.shape,y.shape)
# Out:
# (500,) (500,)

# %%
idx= []
for i in range(3):
  idx.append(y==i)

# %%
for i in range(3):
    y= np.zeros(x[idx[i]].shape[0])
    plt.scatter(x[idx[i]],y,label="class_"+str(i))
plt.legend()

# %%
bg_idx = [ np.where(idx[2] == True)[0]]

bg_idx = np.concatenate(bg_idx, axis = 0)
bg_idx.shape
# Out:
# (163,)

# %%
np.unique(bg_idx).shape
# Out:
# (163,)

# %%
x = x - np.mean(x[bg_idx], axis = 0, keepdims = True)

# %%
np.mean(x[bg_idx], axis = 0, keepdims = True), np.mean(x, axis = 0, keepdims = True)
# Out:
# (array([-1.00805526e-16]), array([-1.7163962]))

# %%
x = x/np.std(x[bg_idx], axis = 0, keepdims = True)

# %%
np.std(x[bg_idx], axis = 0, keepdims = True), np.std(x, axis = 0, keepdims = True)
# Out:
# (array([1.]), array([4.37808847]))

# %%
for i in range(3):
    y= np.zeros(x[idx[i]].shape[0])
    plt.scatter(x[idx[i]],y,label="class_"+str(i))
plt.legend()

# %%
foreground_classes = {'class_0','class_1' }

background_classes = {'class_2'}

# %%
fg_class  = np.random.randint(0,2)
fg_idx = np.random.randint(0,m)

a = []
for i in range(m):
    if i == fg_idx:
        b = np.random.choice(np.where(idx[fg_class]==True)[0],size=1)
        a.append(x[b])
        print("foreground "+str(fg_class)+" present at " + str(fg_idx))
    else:
        bg_class = np.random.randint(2,3)
        b = np.random.choice(np.where(idx[bg_class]==True)[0],size=1)
        a.append(x[b])
        print("background "+str(bg_class)+" present at " + str(i))
a = np.concatenate(a,axis=0)
print(a.shape)

print(fg_class , fg_idx)
# Out:
# background 2 present at 0
# background 2 present at 1
# background 2 present at 2
# background 2 present at 3
# background 2 present at 4
# background 2 present at 5
# background 2 present at 6
# background 2 present at 7
# background 2 present at 8
# background 2 present at 9
# background 2 present at 10
# background 2 present at 11
# background 2 present at 12
# background 2 present at 13
# background 2 present at 14
# background 2 present at 15
# background 2 present at 16
# background 2 present at 17
# background 2 present at 18
# background 2 present at 19
# background 2 present at 20
# background 2 present at 21
# background 2 present at 22
# background 2 present at 23
# background 2 present at 24
# background 2 present at 25
# background 2 present at 26
# background 2 present at 27
# background 2 present at 28
# background 2 present at 29
# background 2 present at 30
# background 2 present at 31
# background 2 present at 32
# background 2 present at 33
# background 2 present at 34
# background 2 present at 35
# background 2 present at 36
# background 2 present at 37
# background 2 present at 38
# background 2 present at 39
# background 2 present at 40
# background 2 present at 41
# background 2 present at 42
# background 2 present at 43
# background 2 present at 44
# background 2 present at 45
# background 2 present at 46
# background 2 present at 47
# background 2 present at 48
# background 2 present at 49
# background 2 present at 50
# background 2 present at 51
# background 2 present at 52
# background 2 present at 53
# background 2 present at 54
# background 2 present at 55
# background 2 present at 56
# background 2 present at 57
# background 2 present at 58
# background 2 present at 59
# background 2 present at 60
# background 2 present at 61
# background 2 present at 62
# background 2 present at 63
# background 2 present at 64
# background 2 present at 65
# background 2 present at 66
# background 2 present at 67
# background 2 present at 68
# background 2 present at 69
# background 2 present at 70
# background 2 present at 71
# background 2 present at 72
# background 2 present at 73
# background 2 present at 74
# background 2 present at 75
# background 2 present at 76
# background 2 present at 77
# background 2 present at 78
# background 2 present at 79
# background 2 present at 80
# background 2 present at 81
# background 2 present at 82
# background 2 present at 83
# background 2 present at 84
# background 2 present at 85
# background 2 present at 86
# background 2 present at 87
# background 2 present at 88
# background 2 present at 89
# background 2 present at 90
# background 2 present at 91
# background 2 present at 92
# background 2 present at 93
# background 2 present at 94
# background 2 present at 95
# background 2 present at 96
# background 2 present at 97
# background 2 present at 98
# background 2 present at 99
# background 2 present at 100
# background 2 present at 101
# background 2 present at 102
# background 2 present at 103
# background 2 present at 104
# background 2 present at 105
# background 2 present at 106
# background 2 present at 107
# background 2 present at 108
# background 2 present at 109
# background 2 present at 110
# background 2 present at 111
# background 2 present at 112
# background 2 present at 113
# background 2 present at 114
# background 2 present at 115
# background 2 present at 116
# background 2 present at 117
# background 2 present at 118
# background 2 present at 119
# background 2 present at 120
# background 2 present at 121
# background 2 present at 122
# background 2 present at 123
# background 2 present at 124
# background 2 present at 125
# background 2 present at 126
# background 2 present at 127
# background 2 present at 128
# background 2 present at 129
# background 2 present at 130
# background 2 present at 131
# background 2 present at 132
# background 2 present at 133
# background 2 present at 134
# background 2 present at 135
# background 2 present at 136
# background 2 present at 137
# background 2 present at 138
# background 2 present at 139
# background 2 present at 140
# background 2 present at 141
# background 2 present at 142
# background 2 present at 143
# background 2 present at 144
# background 2 present at 145
# background 2 present at 146
# background 2 present at 147
# background 2 present at 148
# background 2 present at 149
# background 2 present at 150
# background 2 present at 151
# background 2 present at 152
# background 2 present at 153
# background 2 present at 154
# background 2 present at 155
# background 2 present at 156
# background 2 present at 157
# background 2 present at 158
# background 2 present at 159
# background 2 present at 160
# background 2 present at 161
# background 2 present at 162
# background 2 present at 163
# background 2 present at 164
# background 2 present at 165
# background 2 present at 166
# background 2 present at 167
# background 2 present at 168
# background 2 present at 169
# background 2 present at 170
# background 2 present at 171
# background 2 present at 172
# background 2 present at 173
# background 2 present at 174
# background 2 present at 175
# background 2 present at 176
# background 2 present at 177
# background 2 present at 178
# background 2 present at 179
# background 2 present at 180
# background 2 present at 181
# background 2 present at 182
# background 2 present at 183
# background 2 present at 184
# background 2 present at 185
# background 2 present at 186
# background 2 present at 187
# background 2 present at 188
# background 2 present at 189
# background 2 present at 190
# background 2 present at 191
# background 2 present at 192
# background 2 present at 193
# background 2 present at 194
# background 2 present at 195
# background 2 present at 196
# background 2 present at 197
# background 2 present at 198
# background 2 present at 199
# background 2 present at 200
# background 2 present at 201
# background 2 present at 202
# background 2 present at 203
# background 2 present at 204
# background 2 present at 205
# background 2 present at 206
# background 2 present at 207
# background 2 present at 208
# background 2 present at 209
# background 2 present at 210
# background 2 present at 211
# background 2 present at 212
# background 2 present at 213
# background 2 present at 214
# background 2 present at 215
# background 2 present at 216
# background 2 present at 217
# background 2 present at 218
# background 2 present at 219
# background 2 present at 220
# background 2 present at 221
# background 2 present at 222
# background 2 present at 223
# background 2 present at 224
# background 2 present at 225
# background 2 present at 226
# background 2 present at 227
# background 2 present at 228
# background 2 present at 229
# background 2 present at 230
# background 2 present at 231
# background 2 present at 232
# background 2 present at 233
# background 2 present at 234
# background 2 present at 235
# background 2 present at 236
# background 2 present at 237
# background 2 present at 238
# background 2 present at 239
# background 2 present at 240
# background 2 present at 241
# background 2 present at 242
# background 2 present at 243
# background 2 present at 244
# background 2 present at 245
# background 2 present at 246
# background 2 present at 247
# background 2 present at 248
# background 2 present at 249
# background 2 present at 250
# background 2 present at 251
# background 2 present at 252
# background 2 present at 253
# background 2 present at 254
# background 2 present at 255
# background 2 present at 256
# background 2 present at 257
# background 2 present at 258
# background 2 present at 259
# background 2 present at 260
# background 2 present at 261
# background 2 present at 262
# background 2 present at 263
# background 2 present at 264
# background 2 present at 265
# background 2 present at 266
# background 2 present at 267
# background 2 present at 268
# background 2 present at 269
# background 2 present at 270
# background 2 present at 271
# background 2 present at 272
# background 2 present at 273
# background 2 present at 274
# background 2 present at 275
# background 2 present at 276
# background 2 present at 277
# background 2 present at 278
# background 2 present at 279
# background 2 present at 280
# background 2 present at 281
# background 2 present at 282
# background 2 present at 283
# background 2 present at 284
# background 2 present at 285
# background 2 present at 286
# background 2 present at 287
# background 2 present at 288
# background 2 present at 289
# background 2 present at 290
# background 2 present at 291
# background 2 present at 292
# background 2 present at 293
# background 2 present at 294
# background 2 present at 295
# background 2 present at 296
# background 2 present at 297
# background 2 present at 298
# background 2 present at 299
# background 2 present at 300
# background 2 present at 301
# background 2 present at 302
# background 2 present at 303
# background 2 present at 304
# background 2 present at 305
# background 2 present at 306
# background 2 present at 307
# background 2 present at 308
# background 2 present at 309
# background 2 present at 310
# background 2 present at 311
# background 2 present at 312
# background 2 present at 313
# background 2 present at 314
# background 2 present at 315
# background 2 present at 316
# background 2 present at 317
# background 2 present at 318
# background 2 present at 319
# background 2 present at 320
# background 2 present at 321
# background 2 present at 322
# background 2 present at 323
# background 2 present at 324
# background 2 present at 325
# background 2 present at 326
# background 2 present at 327
# background 2 present at 328
# background 2 present at 329
# background 2 present at 330
# background 2 present at 331
# background 2 present at 332
# background 2 present at 333
# background 2 present at 334
# background 2 present at 335
# background 2 present at 336
# background 2 present at 337
# background 2 present at 338
# background 2 present at 339
# background 2 present at 340
# background 2 present at 341
# background 2 present at 342
# background 2 present at 343
# background 2 present at 344
# background 2 present at 345
# background 2 present at 346
# background 2 present at 347
# background 2 present at 348
# background 2 present at 349
# background 2 present at 350
# background 2 present at 351
# background 2 present at 352
# background 2 present at 353
# background 2 present at 354
# background 2 present at 355
# background 2 present at 356
# background 2 present at 357
# background 2 present at 358
# background 2 present at 359
# background 2 present at 360
# background 2 present at 361
# background 2 present at 362
# background 2 present at 363
# background 2 present at 364
# background 2 present at 365
# background 2 present at 366
# background 2 present at 367
# background 2 present at 368
# background 2 present at 369
# background 2 present at 370
# background 2 present at 371
# background 2 present at 372
# background 2 present at 373
# background 2 present at 374
# background 2 present at 375
# background 2 present at 376
# background 2 present at 377
# background 2 present at 378
# background 2 present at 379
# background 2 present at 380
# background 2 present at 381
# background 2 present at 382
# background 2 present at 383
# background 2 present at 384
# background 2 present at 385
# background 2 present at 386
# background 2 present at 387
# background 2 present at 388
# background 2 present at 389
# background 2 present at 390
# background 2 present at 391
# background 2 present at 392
# background 2 present at 393
# background 2 present at 394
# background 2 present at 395
# background 2 present at 396
# background 2 present at 397
# background 2 present at 398
# background 2 present at 399
# background 2 present at 400
# background 2 present at 401
# background 2 present at 402
# background 2 present at 403
# background 2 present at 404
# background 2 present at 405
# background 2 present at 406
# background 2 present at 407
# background 2 present at 408
# background 2 present at 409
# background 2 present at 410
# background 2 present at 411
# background 2 present at 412
# background 2 present at 413
# background 2 present at 414
# background 2 present at 415
# background 2 present at 416
# background 2 present at 417
# background 2 present at 418
# background 2 present at 419
# background 2 present at 420
# background 2 present at 421
# background 2 present at 422
# background 2 present at 423
# background 2 present at 424
# background 2 present at 425
# background 2 present at 426
# background 2 present at 427
# background 2 present at 428
# background 2 present at 429
# background 2 present at 430
# background 2 present at 431
# background 2 present at 432
# background 2 present at 433
# background 2 present at 434
# background 2 present at 435
# background 2 present at 436
# background 2 present at 437
# background 2 present at 438
# background 2 present at 439
# background 2 present at 440
# background 2 present at 441
# background 2 present at 442
# background 2 present at 443
# background 2 present at 444
# background 2 present at 445
# background 2 present at 446
# background 2 present at 447
# background 2 present at 448
# background 2 present at 449
# background 2 present at 450
# background 2 present at 451
# background 2 present at 452
# background 2 present at 453
# background 2 present at 454
# background 2 present at 455
# background 2 present at 456
# background 2 present at 457
# background 2 present at 458
# background 2 present at 459
# background 2 present at 460
# background 2 present at 461
# background 2 present at 462
# background 2 present at 463
# background 2 present at 464
# background 2 present at 465
# background 2 present at 466
# background 2 present at 467
# background 2 present at 468
# background 2 present at 469
# background 2 present at 470
# background 2 present at 471
# background 2 present at 472
# background 2 present at 473
# background 2 present at 474
# background 2 present at 475
# background 2 present at 476
# background 2 present at 477
# background 2 present at 478
# background 2 present at 479
# background 2 present at 480
# background 2 present at 481
# background 2 present at 482
# background 2 present at 483
# background 2 present at 484
# background 2 present at 485
# background 2 present at 486
# background 2 present at 487
# background 2 present at 488
# background 2 present at 489
# background 2 present at 490
# background 2 present at 491
# background 2 present at 492
# background 2 present at 493
# background 2 present at 494
# background 2 present at 495
# background 2 present at 496
# background 2 present at 497
# background 2 present at 498
# background 2 present at 499
# background 2 present at 500
# background 2 present at 501
# background 2 present at 502
# background 2 present at 503
# background 2 present at 504
# background 2 present at 505
# background 2 present at 506
# background 2 present at 507
# background 2 present at 508
# background 2 present at 509
# background 2 present at 510
# background 2 present at 511
# background 2 present at 512
# background 2 present at 513
# background 2 present at 514
# background 2 present at 515
# background 2 present at 516
# background 2 present at 517
# background 2 present at 518
# background 2 present at 519
# background 2 present at 520
# background 2 present at 521
# background 2 present at 522
# background 2 present at 523
# background 2 present at 524
# background 2 present at 525
# background 2 present at 526
# background 2 present at 527
# background 2 present at 528
# background 2 present at 529
# background 2 present at 530
# background 2 present at 531
# background 2 present at 532
# background 2 present at 533
# background 2 present at 534
# background 2 present at 535
# background 2 present at 536
# background 2 present at 537
# background 2 present at 538
# background 2 present at 539
# background 2 present at 540
# background 2 present at 541
# background 2 present at 542
# background 2 present at 543
# background 2 present at 544
# background 2 present at 545
# background 2 present at 546
# background 2 present at 547
# background 2 present at 548
# background 2 present at 549
# background 2 present at 550
# background 2 present at 551
# background 2 present at 552
# background 2 present at 553
# background 2 present at 554
# background 2 present at 555
# background 2 present at 556
# background 2 present at 557
# background 2 present at 558
# background 2 present at 559
# background 2 present at 560
# background 2 present at 561
# background 2 present at 562
# background 2 present at 563
# background 2 present at 564
# background 2 present at 565
# background 2 present at 566
# background 2 present at 567
# background 2 present at 568
# background 2 present at 569
# background 2 present at 570
# background 2 present at 571
# background 2 present at 572
# background 2 present at 573
# background 2 present at 574
# background 2 present at 575
# background 2 present at 576
# background 2 present at 577
# background 2 present at 578
# background 2 present at 579
# background 2 present at 580
# background 2 present at 581
# background 2 present at 582
# background 2 present at 583
# background 2 present at 584
# background 2 present at 585
# background 2 present at 586
# background 2 present at 587
# background 2 present at 588
# background 2 present at 589
# background 2 present at 590
# background 2 present at 591
# background 2 present at 592
# background 2 present at 593
# background 2 present at 594
# background 2 present at 595
# background 2 present at 596
# background 2 present at 597
# background 2 present at 598
# background 2 present at 599
# background 2 present at 600
# background 2 present at 601
# background 2 present at 602
# background 2 present at 603
# background 2 present at 604
# background 2 present at 605
# background 2 present at 606
# background 2 present at 607
# background 2 present at 608
# background 2 present at 609
# background 2 present at 610
# background 2 present at 611
# background 2 present at 612
# background 2 present at 613
# background 2 present at 614
# background 2 present at 615
# background 2 present at 616
# background 2 present at 617
# background 2 present at 618
# background 2 present at 619
# background 2 present at 620
# background 2 present at 621
# background 2 present at 622
# background 2 present at 623
# background 2 present at 624
# background 2 present at 625
# background 2 present at 626
# background 2 present at 627
# background 2 present at 628
# background 2 present at 629
# background 2 present at 630
# background 2 present at 631
# background 2 present at 632
# background 2 present at 633
# background 2 present at 634
# background 2 present at 635
# background 2 present at 636
# background 2 present at 637
# background 2 present at 638
# background 2 present at 639
# background 2 present at 640
# background 2 present at 641
# background 2 present at 642
# background 2 present at 643
# background 2 present at 644
# background 2 present at 645
# background 2 present at 646
# background 2 present at 647
# background 2 present at 648
# background 2 present at 649
# background 2 present at 650
# background 2 present at 651
# background 2 present at 652
# background 2 present at 653
# background 2 present at 654
# background 2 present at 655
# background 2 present at 656
# background 2 present at 657
# background 2 present at 658
# background 2 present at 659
# background 2 present at 660
# background 2 present at 661
# background 2 present at 662
# background 2 present at 663
# background 2 present at 664
# background 2 present at 665
# background 2 present at 666
# background 2 present at 667
# background 2 present at 668
# background 2 present at 669
# background 2 present at 670
# background 2 present at 671
# background 2 present at 672
# background 2 present at 673
# background 2 present at 674
# background 2 present at 675
# background 2 present at 676
# background 2 present at 677
# background 2 present at 678
# background 2 present at 679
# background 2 present at 680
# background 2 present at 681
# background 2 present at 682
# background 2 present at 683
# background 2 present at 684
# background 2 present at 685
# background 2 present at 686
# background 2 present at 687
# background 2 present at 688
# background 2 present at 689
# background 2 present at 690
# background 2 present at 691
# background 2 present at 692
# background 2 present at 693
# background 2 present at 694
# background 2 present at 695
# background 2 present at 696
# background 2 present at 697
# background 2 present at 698
# background 2 present at 699
# background 2 present at 700
# background 2 present at 701
# background 2 present at 702
# background 2 present at 703
# background 2 present at 704
# background 2 present at 705
# background 2 present at 706
# background 2 present at 707
# background 2 present at 708
# background 2 present at 709
# background 2 present at 710
# background 2 present at 711
# background 2 present at 712
# background 2 present at 713
# background 2 present at 714
# background 2 present at 715
# background 2 present at 716
# background 2 present at 717
# background 2 present at 718
# background 2 present at 719
# background 2 present at 720
# background 2 present at 721
# background 2 present at 722
# background 2 present at 723
# background 2 present at 724
# background 2 present at 725
# background 2 present at 726
# background 2 present at 727
# background 2 present at 728
# background 2 present at 729
# background 2 present at 730
# background 2 present at 731
# background 2 present at 732
# background 2 present at 733
# background 2 present at 734
# background 2 present at 735
# background 2 present at 736
# background 2 present at 737
# background 2 present at 738
# background 2 present at 739
# background 2 present at 740
# background 2 present at 741
# background 2 present at 742
# background 2 present at 743
# background 2 present at 744
# background 2 present at 745
# background 2 present at 746
# background 2 present at 747
# background 2 present at 748
# background 2 present at 749
# background 2 present at 750
# background 2 present at 751
# background 2 present at 752
# background 2 present at 753
# background 2 present at 754
# background 2 present at 755
# background 2 present at 756
# background 2 present at 757
# background 2 present at 758
# background 2 present at 759
# background 2 present at 760
# background 2 present at 761
# background 2 present at 762
# background 2 present at 763
# foreground 1 present at 764
# background 2 present at 765
# background 2 present at 766
# background 2 present at 767
# background 2 present at 768
# background 2 present at 769
# background 2 present at 770
# background 2 present at 771
# background 2 present at 772
# background 2 present at 773
# background 2 present at 774
# background 2 present at 775
# background 2 present at 776
# background 2 present at 777
# background 2 present at 778
# background 2 present at 779
# background 2 present at 780
# background 2 present at 781
# background 2 present at 782
# background 2 present at 783
# background 2 present at 784
# background 2 present at 785
# background 2 present at 786
# background 2 present at 787
# background 2 present at 788
# background 2 present at 789
# background 2 present at 790
# background 2 present at 791
# background 2 present at 792
# background 2 present at 793
# background 2 present at 794
# background 2 present at 795
# background 2 present at 796
# background 2 present at 797
# background 2 present at 798
# background 2 present at 799
# background 2 present at 800
# background 2 present at 801
# background 2 present at 802
# background 2 present at 803
# background 2 present at 804
# background 2 present at 805
# background 2 present at 806
# background 2 present at 807
# background 2 present at 808
# background 2 present at 809
# background 2 present at 810
# background 2 present at 811
# background 2 present at 812
# background 2 present at 813
# background 2 present at 814
# background 2 present at 815
# background 2 present at 816
# background 2 present at 817
# background 2 present at 818
# background 2 present at 819
# background 2 present at 820
# background 2 present at 821
# background 2 present at 822
# background 2 present at 823
# background 2 present at 824
# background 2 present at 825
# background 2 present at 826
# background 2 present at 827
# background 2 present at 828
# background 2 present at 829
# background 2 present at 830
# background 2 present at 831
# background 2 present at 832
# background 2 present at 833
# background 2 present at 834
# background 2 present at 835
# background 2 present at 836
# background 2 present at 837
# background 2 present at 838
# background 2 present at 839
# background 2 present at 840
# background 2 present at 841
# background 2 present at 842
# background 2 present at 843
# background 2 present at 844
# background 2 present at 845
# background 2 present at 846
# background 2 present at 847
# background 2 present at 848
# background 2 present at 849
# background 2 present at 850
# background 2 present at 851
# background 2 present at 852
# background 2 present at 853
# background 2 present at 854
# background 2 present at 855
# background 2 present at 856
# background 2 present at 857
# background 2 present at 858
# background 2 present at 859
# background 2 present at 860
# background 2 present at 861
# background 2 present at 862
# background 2 present at 863
# background 2 present at 864
# background 2 present at 865
# background 2 present at 866
# background 2 present at 867
# background 2 present at 868
# background 2 present at 869
# background 2 present at 870
# background 2 present at 871
# background 2 present at 872
# background 2 present at 873
# background 2 present at 874
# background 2 present at 875
# background 2 present at 876
# background 2 present at 877
# background 2 present at 878
# background 2 present at 879
# background 2 present at 880
# background 2 present at 881
# background 2 present at 882
# background 2 present at 883
# background 2 present at 884
# background 2 present at 885
# background 2 present at 886
# background 2 present at 887
# background 2 present at 888
# background 2 present at 889
# background 2 present at 890
# background 2 present at 891
# background 2 present at 892
# background 2 present at 893
# background 2 present at 894
# background 2 present at 895
# background 2 present at 896
# background 2 present at 897
# background 2 present at 898
# background 2 present at 899
# background 2 present at 900
# background 2 present at 901
# background 2 present at 902
# background 2 present at 903
# background 2 present at 904
# background 2 present at 905
# background 2 present at 906
# background 2 present at 907
# background 2 present at 908
# background 2 present at 909
# background 2 present at 910
# background 2 present at 911
# background 2 present at 912
# background 2 present at 913
# background 2 present at 914
# background 2 present at 915
# background 2 present at 916
# background 2 present at 917
# background 2 present at 918
# background 2 present at 919
# background 2 present at 920
# background 2 present at 921
# background 2 present at 922
# background 2 present at 923
# background 2 present at 924
# background 2 present at 925
# background 2 present at 926
# background 2 present at 927
# background 2 present at 928
# background 2 present at 929
# background 2 present at 930
# background 2 present at 931
# background 2 present at 932
# background 2 present at 933
# background 2 present at 934
# background 2 present at 935
# background 2 present at 936
# background 2 present at 937
# background 2 present at 938
# background 2 present at 939
# background 2 present at 940
# background 2 present at 941
# background 2 present at 942
# background 2 present at 943
# background 2 present at 944
# background 2 present at 945
# background 2 present at 946
# background 2 present at 947
# background 2 present at 948
# background 2 present at 949
# background 2 present at 950
# background 2 present at 951
# background 2 present at 952
# background 2 present at 953
# background 2 present at 954
# background 2 present at 955
# background 2 present at 956
# background 2 present at 957
# background 2 present at 958
# background 2 present at 959
# background 2 present at 960
# background 2 present at 961
# background 2 present at 962
# background 2 present at 963
# background 2 present at 964
# background 2 present at 965
# background 2 present at 966
# background 2 present at 967
# background 2 present at 968
# background 2 present at 969
# background 2 present at 970
# background 2 present at 971
# background 2 present at 972
# background 2 present at 973
# background 2 present at 974
# background 2 present at 975
# background 2 present at 976
# background 2 present at 977
# background 2 present at 978
# background 2 present at 979
# background 2 present at 980
# background 2 present at 981
# background 2 present at 982
# background 2 present at 983
# background 2 present at 984
# background 2 present at 985
# background 2 present at 986
# background 2 present at 987
# background 2 present at 988
# background 2 present at 989
# background 2 present at 990
# background 2 present at 991
# background 2 present at 992
# background 2 present at 993
# background 2 present at 994
# background 2 present at 995
# background 2 present at 996
# background 2 present at 997
# background 2 present at 998
# background 2 present at 999
# (1000,)
# 1 764

# %%
a.shape
# Out:
# (1000,)

# %%
np.reshape(a,(m,1))
# Out:
# array([[-8.02410432e-01],
#        [ 1.00228507e+00],
#        [-8.11329880e-01],
#        [ 1.27744090e+00],
#        [ 5.73986455e-01],
#        [-9.18503310e-01],
#        [ 6.60064797e-01],
#        [ 5.73986455e-01],
#        [ 1.39799803e+00],
#        [ 1.36953727e-01],
#        [-1.44264034e+00],
#        [ 7.18378258e-01],
#        [ 1.08544127e+00],
#        [ 1.55171236e+00],
#        [ 4.15214402e-01],
#        [-1.15692643e+00],
#        [-1.62776348e+00],
#        [ 6.53394308e-01],
#        [ 4.49983364e-01],
#        [-1.35067387e+00],
#        [-1.54166304e-01],
#        [ 1.27744090e+00],
#        [ 4.49983364e-01],
#        [ 1.20061574e+00],
#        [-8.39523638e-01],
#        [ 4.62796449e-01],
#        [-9.04878365e-01],
#        [ 8.32545402e-01],
#        [-4.11611269e-01],
#        [-9.45249641e-01],
#        [-2.40778404e-01],
#        [ 8.02823556e-01],
#        [ 1.86780224e-01],
#        [ 4.15532911e-01],
#        [ 9.93043577e-01],
#        [-9.45249641e-01],
#        [-1.44264034e+00],
#        [-1.36429042e+00],
#        [-3.64748654e-01],
#        [ 1.39226705e-01],
#        [ 1.42821598e-01],
#        [-1.08085196e+00],
#        [ 6.60064797e-01],
#        [-1.17697967e+00],
#        [-2.99187881e-01],
#        [-1.35067387e+00],
#        [ 3.48205465e-01],
#        [ 1.35486532e+00],
#        [-1.37597620e+00],
#        [ 9.85899779e-01],
#        [-5.95116619e-01],
#        [ 1.41734616e+00],
#        [ 7.18378258e-01],
#        [ 1.00274723e+00],
#        [-9.04878365e-01],
#        [ 3.23092585e-01],
#        [-9.18503310e-01],
#        [-1.54166304e-01],
#        [-9.22694519e-01],
#        [ 1.41734616e+00],
#        [-1.54993781e+00],
#        [-5.95116619e-01],
#        [ 1.03475943e+00],
#        [ 4.67863442e-01],
#        [ 9.76066844e-01],
#        [ 6.60064797e-01],
#        [ 5.17837754e-01],
#        [-4.25227595e-01],
#        [ 1.28615767e+00],
#        [ 9.76066844e-01],
#        [-1.44985264e+00],
#        [-1.54993781e+00],
#        [ 1.40413128e+00],
#        [ 1.04969471e+00],
#        [ 9.42697031e-01],
#        [-1.19359320e+00],
#        [-7.57526877e-03],
#        [ 7.55823134e-01],
#        [ 1.39806093e+00],
#        [-1.46523851e+00],
#        [-1.05676650e+00],
#        [ 9.32430600e-01],
#        [-7.29879997e-01],
#        [ 1.52408356e+00],
#        [ 1.39236683e+00],
#        [ 6.74731264e-02],
#        [-3.85453547e-01],
#        [-1.19359320e+00],
#        [-1.43069628e+00],
#        [ 1.27744090e+00],
#        [ 1.62014849e+00],
#        [-1.27266268e+00],
#        [ 1.40749270e+00],
#        [-1.74493859e+00],
#        [ 1.20061574e+00],
#        [ 4.67863442e-01],
#        [-1.05676650e+00],
#        [ 8.31223753e-01],
#        [ 6.60064797e-01],
#        [ 5.88584223e-01],
#        [ 1.50127618e+00],
#        [ 1.50127618e+00],
#        [-7.58940247e-01],
#        [ 3.45865811e-01],
#        [ 9.07524131e-01],
#        [ 9.71918741e-01],
#        [-1.73154424e+00],
#        [ 1.43580093e+00],
#        [ 1.62014849e+00],
#        [-1.54166304e-01],
#        [ 3.87458426e-01],
#        [ 1.10390156e+00],
#        [-5.97739995e-01],
#        [ 1.55171236e+00],
#        [-2.40778404e-01],
#        [ 7.81700467e-01],
#        [-3.64648966e-01],
#        [ 2.57560056e-02],
#        [ 1.04960385e+00],
#        [-1.15692643e+00],
#        [-1.62776348e+00],
#        [-3.64648966e-01],
#        [-4.25227595e-01],
#        [-2.40778404e-01],
#        [ 2.70346477e-01],
#        [ 4.67863442e-01],
#        [-1.73714097e+00],
#        [ 3.87458426e-01],
#        [ 9.76066844e-01],
#        [ 4.15532911e-01],
#        [-1.62071732e+00],
#        [ 1.10390156e+00],
#        [ 7.18378258e-01],
#        [-1.54166304e-01],
#        [-1.36429042e+00],
#        [-3.64648966e-01],
#        [-9.22694519e-01],
#        [-7.58940247e-01],
#        [-9.04878365e-01],
#        [-1.08182983e+00],
#        [-5.21621676e-01],
#        [ 9.32430600e-01],
#        [ 1.27744090e+00],
#        [ 1.37939868e+00],
#        [ 1.37939868e+00],
#        [ 1.03475943e+00],
#        [-1.27266268e+00],
#        [ 4.62796449e-01],
#        [ 1.14462928e+00],
#        [ 1.22075701e+00],
#        [ 1.43580093e+00],
#        [-1.02298771e+00],
#        [-1.05676650e+00],
#        [-5.59763052e-01],
#        [-7.58940247e-01],
#        [-3.46623715e-02],
#        [ 1.86780224e-01],
#        [-5.15772181e-01],
#        [-5.97739995e-01],
#        [ 4.14971640e-01],
#        [ 1.04960385e+00],
#        [-8.97892654e-01],
#        [ 3.45865811e-01],
#        [ 2.25187695e-02],
#        [ 2.86994127e-01],
#        [-5.36078907e-01],
#        [ 7.75095020e-01],
#        [-1.27266268e+00],
#        [-1.15692643e+00],
#        [-1.37597620e+00],
#        [ 6.60064797e-01],
#        [ 9.42697031e-01],
#        [-5.36078907e-01],
#        [ 6.74731264e-02],
#        [ 9.32430600e-01],
#        [-1.27266268e+00],
#        [-9.18503310e-01],
#        [-5.15772181e-01],
#        [ 8.32545402e-01],
#        [ 9.93043577e-01],
#        [ 4.14971640e-01],
#        [ 1.31922113e+00],
#        [-1.20787928e+00],
#        [-1.63869730e-01],
#        [ 4.15532911e-01],
#        [-1.44985264e+00],
#        [ 1.30533553e+00],
#        [-4.24738021e-01],
#        [ 7.55823134e-01],
#        [-7.50119090e-01],
#        [ 9.32430600e-01],
#        [-1.84343478e-01],
#        [-1.08182983e+00],
#        [-1.54166304e-01],
#        [-1.40535774e+00],
#        [ 1.44702914e+00],
#        [ 1.39799803e+00],
#        [ 1.03475943e+00],
#        [-3.85453547e-01],
#        [-3.63319004e-01],
#        [ 4.62796449e-01],
#        [-7.50119090e-01],
#        [-5.15772181e-01],
#        [ 4.15532911e-01],
#        [ 2.70346477e-01],
#        [ 7.75095020e-01],
#        [ 2.65519657e-01],
#        [ 1.04960385e+00],
#        [ 2.25187695e-02],
#        [ 1.62014849e+00],
#        [-3.64648966e-01],
#        [-8.02410432e-01],
#        [ 8.31223753e-01],
#        [-1.54166304e-01],
#        [-5.59763052e-01],
#        [ 1.31922113e+00],
#        [-3.64648966e-01],
#        [ 1.39226705e-01],
#        [-8.97892654e-01],
#        [ 5.73986455e-01],
#        [ 1.35486532e+00],
#        [ 1.27744090e+00],
#        [-1.40535774e+00],
#        [ 1.44702914e+00],
#        [ 1.44702914e+00],
#        [-1.36429042e+00],
#        [-3.46623715e-02],
#        [-2.99187881e-01],
#        [-1.33059033e+00],
#        [ 2.28435924e-01],
#        [ 1.27744090e+00],
#        [ 8.31223753e-01],
#        [-1.47371279e+00],
#        [ 1.43580093e+00],
#        [ 1.03475943e+00],
#        [ 7.75095020e-01],
#        [ 1.28615767e+00],
#        [ 5.17837754e-01],
#        [-1.57212980e+00],
#        [ 9.76066844e-01],
#        [-1.11836716e-01],
#        [-4.11611269e-01],
#        [-1.21801511e+00],
#        [ 8.31223753e-01],
#        [ 1.37191625e+00],
#        [ 8.32545402e-01],
#        [-5.85435504e-01],
#        [-1.29097509e-01],
#        [ 7.81700467e-01],
#        [ 4.12048306e-01],
#        [-7.29879997e-01],
#        [ 1.03957183e+00],
#        [ 4.62796449e-01],
#        [ 8.02823556e-01],
#        [ 1.44702914e+00],
#        [ 1.47471360e+00],
#        [ 3.48205465e-01],
#        [ 1.35486532e+00],
#        [-9.18503310e-01],
#        [ 1.37191625e+00],
#        [-7.29879997e-01],
#        [ 3.87458426e-01],
#        [-2.75107593e-01],
#        [ 4.15532911e-01],
#        [-1.57358463e+00],
#        [-1.19359320e+00],
#        [ 6.74731264e-02],
#        [ 1.00274723e+00],
#        [-4.11611269e-01],
#        [-1.05676650e+00],
#        [ 8.02823556e-01],
#        [-1.08182983e+00],
#        [ 2.28435924e-01],
#        [ 1.50127618e+00],
#        [-7.58940247e-01],
#        [-4.24738021e-01],
#        [-1.57212980e+00],
#        [ 1.10390156e+00],
#        [-4.43399369e-01],
#        [-9.18503310e-01],
#        [-5.21621676e-01],
#        [ 8.32545402e-01],
#        [ 9.41640484e-01],
#        [-1.28104385e+00],
#        [ 1.27408086e+00],
#        [-3.64648966e-01],
#        [ 4.67863442e-01],
#        [ 1.40749270e+00],
#        [ 9.32430600e-01],
#        [-1.35067387e+00],
#        [ 3.48205465e-01],
#        [-1.36429042e+00],
#        [ 1.50127618e+00],
#        [-3.64748654e-01],
#        [-2.99187881e-01],
#        [ 1.35486532e+00],
#        [ 8.02823556e-01],
#        [ 1.04960385e+00],
#        [-7.29879997e-01],
#        [-9.95921302e-01],
#        [ 3.87458426e-01],
#        [ 9.07524131e-01],
#        [ 1.39236683e+00],
#        [-1.74493859e+00],
#        [ 2.65519657e-01],
#        [ 1.22075701e+00],
#        [-3.64748654e-01],
#        [ 1.04960385e+00],
#        [ 1.00115933e+00],
#        [-3.80903463e-02],
#        [ 2.25187695e-02],
#        [-3.46623715e-02],
#        [-1.46523851e+00],
#        [ 1.39226705e-01],
#        [-1.36429042e+00],
#        [ 7.18378258e-01],
#        [-1.46523851e+00],
#        [ 1.62014849e+00],
#        [-1.29097509e-01],
#        [-1.28104385e+00],
#        [-5.95116619e-01],
#        [ 9.41640484e-01],
#        [-1.29097509e-01],
#        [ 8.32545402e-01],
#        [-1.28104385e+00],
#        [ 1.28615767e+00],
#        [-1.53175495e+00],
#        [-2.75107593e-01],
#        [-5.85435504e-01],
#        [ 1.03957183e+00],
#        [-1.47371279e+00],
#        [-1.37597620e+00],
#        [-4.25227595e-01],
#        [-1.47371279e+00],
#        [-1.35067387e+00],
#        [ 1.03957183e+00],
#        [ 1.11307902e+00],
#        [ 8.31223753e-01],
#        [-1.35067387e+00],
#        [ 1.20061574e+00],
#        [-3.85453547e-01],
#        [ 9.07524131e-01],
#        [ 4.15532911e-01],
#        [-1.11836716e-01],
#        [ 1.37939868e+00],
#        [-2.99187881e-01],
#        [-3.80903463e-02],
#        [ 1.43580093e+00],
#        [-1.39140608e+00],
#        [ 1.36953727e-01],
#        [ 5.17837754e-01],
#        [-5.15772181e-01],
#        [-1.37597620e+00],
#        [-1.11836716e-01],
#        [ 9.85899779e-01],
#        [ 4.62796449e-01],
#        [ 8.02823556e-01],
#        [ 9.41640484e-01],
#        [ 1.39799803e+00],
#        [ 3.87458426e-01],
#        [-1.74493859e+00],
#        [ 1.37939868e+00],
#        [-9.92671849e-01],
#        [-1.43069628e+00],
#        [-1.17697967e+00],
#        [ 4.15214402e-01],
#        [ 1.35486532e+00],
#        [-7.01969147e-01],
#        [-4.85968229e-01],
#        [-1.37597620e+00],
#        [-3.64648966e-01],
#        [ 9.54376292e-01],
#        [ 6.60064797e-01],
#        [ 2.57560056e-02],
#        [ 9.54376292e-01],
#        [ 1.39226705e-01],
#        [-4.24738021e-01],
#        [-9.95921302e-01],
#        [-3.64648966e-01],
#        [ 9.93043577e-01],
#        [-5.59763052e-01],
#        [-5.15772181e-01],
#        [-3.46623715e-02],
#        [ 1.04960385e+00],
#        [-1.63869730e-01],
#        [-1.63869730e-01],
#        [ 4.62796449e-01],
#        [-5.85435504e-01],
#        [ 1.86780224e-01],
#        [-1.73154424e+00],
#        [ 3.87458426e-01],
#        [-9.22694519e-01],
#        [-1.29097509e-01],
#        [ 4.15214402e-01],
#        [-3.63319004e-01],
#        [-1.47371279e+00],
#        [ 4.62796449e-01],
#        [ 1.00228507e+00],
#        [-1.84343478e-01],
#        [ 1.43580093e+00],
#        [ 1.31922113e+00],
#        [-5.59763052e-01],
#        [-1.29097509e-01],
#        [-9.45249641e-01],
#        [-3.46623715e-02],
#        [-1.73714097e+00],
#        [ 2.65519657e-01],
#        [-5.97739995e-01],
#        [-8.39523638e-01],
#        [ 7.81700467e-01],
#        [ 6.31337800e-02],
#        [ 1.03957183e+00],
#        [-7.01969147e-01],
#        [-7.50119090e-01],
#        [ 1.40749270e+00],
#        [-1.73714097e+00],
#        [-1.46523851e+00],
#        [-1.63869730e-01],
#        [-9.45249641e-01],
#        [-5.97739995e-01],
#        [-9.18503310e-01],
#        [-9.22694519e-01],
#        [-5.15772181e-01],
#        [ 7.18378258e-01],
#        [-5.85435504e-01],
#        [ 1.00228507e+00],
#        [ 9.71918741e-01],
#        [-4.25227595e-01],
#        [ 1.10390156e+00],
#        [-9.92671849e-01],
#        [-1.47371279e+00],
#        [-1.66067950e+00],
#        [-5.85435504e-01],
#        [ 5.88584223e-01],
#        [ 2.57560056e-02],
#        [ 8.32545402e-01],
#        [-4.24738021e-01],
#        [ 1.03957183e+00],
#        [ 1.39799803e+00],
#        [ 2.86994127e-01],
#        [ 1.04960385e+00],
#        [-7.01969147e-01],
#        [-1.08085196e+00],
#        [-4.25227595e-01],
#        [-1.20787928e+00],
#        [ 9.71918741e-01],
#        [ 3.23092585e-01],
#        [ 7.55823134e-01],
#        [-5.29177237e-01],
#        [ 1.08544127e+00],
#        [ 1.10390156e+00],
#        [-1.35067387e+00],
#        [-1.27266268e+00],
#        [-1.39140608e+00],
#        [ 1.40413128e+00],
#        [ 1.39236683e+00],
#        [ 1.03475943e+00],
#        [ 1.10390156e+00],
#        [-1.54166304e-01],
#        [-1.11836716e-01],
#        [-7.29879997e-01],
#        [-3.85453547e-01],
#        [-5.95116619e-01],
#        [-5.29003566e-01],
#        [-4.43399369e-01],
#        [-5.85435504e-01],
#        [ 1.03475943e+00],
#        [-1.73714097e+00],
#        [-2.40778404e-01],
#        [ 5.88584223e-01],
#        [-5.97739995e-01],
#        [ 6.64063803e-01],
#        [-1.73154424e+00],
#        [ 4.15214402e-01],
#        [ 9.41640484e-01],
#        [ 1.27744090e+00],
#        [-7.57526877e-03],
#        [ 1.00274723e+00],
#        [-8.02410432e-01],
#        [ 3.48205465e-01],
#        [-1.37597620e+00],
#        [-1.43069628e+00],
#        [-1.43069628e+00],
#        [-1.17697967e+00],
#        [ 1.30533553e+00],
#        [ 6.31337800e-02],
#        [-1.57358463e+00],
#        [ 6.53394308e-01],
#        [-1.05676650e+00],
#        [ 1.20061574e+00],
#        [-3.97293795e-01],
#        [-1.05676650e+00],
#        [-1.17697967e+00],
#        [ 2.86994127e-01],
#        [ 9.71918741e-01],
#        [ 1.37939868e+00],
#        [ 1.42821598e-01],
#        [ 1.40413128e+00],
#        [-5.29003566e-01],
#        [-7.58940247e-01],
#        [-1.53175495e+00],
#        [ 1.20061574e+00],
#        [ 1.28615767e+00],
#        [-1.04969386e+00],
#        [-9.18503310e-01],
#        [-3.64748654e-01],
#        [ 1.44702914e+00],
#        [ 2.57560056e-02],
#        [-4.85968229e-01],
#        [-9.92671849e-01],
#        [ 1.39236683e+00],
#        [-1.40535774e+00],
#        [ 9.71918741e-01],
#        [-5.29003566e-01],
#        [ 1.27408086e+00],
#        [ 3.23092585e-01],
#        [-3.63319004e-01],
#        [ 1.39799803e+00],
#        [-1.37597620e+00],
#        [-1.63869730e-01],
#        [ 6.53394308e-01],
#        [-3.64648966e-01],
#        [-1.36429042e+00],
#        [-5.59763052e-01],
#        [-3.64748654e-01],
#        [ 1.47471360e+00],
#        [-1.73154424e+00],
#        [-1.73154424e+00],
#        [ 6.74731264e-02],
#        [ 3.23092585e-01],
#        [ 6.64063803e-01],
#        [-1.02298771e+00],
#        [-1.54993781e+00],
#        [ 4.62796449e-01],
#        [-3.97293795e-01],
#        [-1.57212980e+00],
#        [ 1.11307902e+00],
#        [-4.25227595e-01],
#        [-1.15692643e+00],
#        [ 1.47471360e+00],
#        [ 5.73986455e-01],
#        [ 1.39226705e-01],
#        [-9.18503310e-01],
#        [ 8.31223753e-01],
#        [-4.24738021e-01],
#        [-1.46523851e+00],
#        [-1.04969386e+00],
#        [-1.15692643e+00],
#        [-2.01409020e-01],
#        [ 1.44702914e+00],
#        [-1.63869730e-01],
#        [-1.19359320e+00],
#        [-2.75107593e-01],
#        [-8.97892654e-01],
#        [ 8.02823556e-01],
#        [ 6.53394308e-01],
#        [-3.64648966e-01],
#        [ 9.54376292e-01],
#        [ 9.85899779e-01],
#        [-1.04969386e+00],
#        [-2.75107593e-01],
#        [-7.29879997e-01],
#        [-3.64748654e-01],
#        [-9.92671849e-01],
#        [ 3.23092585e-01],
#        [-9.95921302e-01],
#        [ 8.31223753e-01],
#        [-5.97739995e-01],
#        [ 2.25187695e-02],
#        [-1.46523851e+00],
#        [ 7.55823134e-01],
#        [-1.04969386e+00],
#        [ 6.64063803e-01],
#        [ 1.44702914e+00],
#        [-1.19359320e+00],
#        [-1.40535774e+00],
#        [ 1.39799803e+00],
#        [-5.29003566e-01],
#        [ 4.15532911e-01],
#        [-1.02298771e+00],
#        [ 1.37939868e+00],
#        [-1.20787928e+00],
#        [ 1.31922113e+00],
#        [-1.39140608e+00],
#        [ 1.52408356e+00],
#        [ 9.54376292e-01],
#        [ 2.70346477e-01],
#        [ 1.10390156e+00],
#        [ 9.93043577e-01],
#        [-1.27266268e+00],
#        [ 1.86780224e-01],
#        [ 2.28435924e-01],
#        [-1.34303174e+00],
#        [ 3.45865811e-01],
#        [ 9.93043577e-01],
#        [ 3.48205465e-01],
#        [ 1.03475943e+00],
#        [ 1.10390156e+00],
#        [-1.66067950e+00],
#        [ 9.76066844e-01],
#        [ 1.40749270e+00],
#        [-1.84343478e-01],
#        [ 1.04960385e+00],
#        [ 9.93043577e-01],
#        [-1.73154424e+00],
#        [-1.84343478e-01],
#        [ 1.39226705e-01],
#        [ 1.35486532e+00],
#        [-1.54166304e-01],
#        [ 3.48205465e-01],
#        [-4.25227595e-01],
#        [-1.44985264e+00],
#        [-1.08182983e+00],
#        [-1.28104385e+00],
#        [-1.43069628e+00],
#        [-5.85435504e-01],
#        [ 2.70346477e-01],
#        [ 9.42697031e-01],
#        [-3.64648966e-01],
#        [-9.18503310e-01],
#        [-4.24738021e-01],
#        [ 2.28435924e-01],
#        [-9.92671849e-01],
#        [ 1.04960385e+00],
#        [ 8.32545402e-01],
#        [ 1.62014849e+00],
#        [-8.02410432e-01],
#        [-1.08085196e+00],
#        [-5.97739995e-01],
#        [-3.64748654e-01],
#        [-8.48777450e-01],
#        [ 1.03957183e+00],
#        [ 2.28435924e-01],
#        [ 2.57560056e-02],
#        [-1.63869730e-01],
#        [ 1.00228507e+00],
#        [ 1.50127618e+00],
#        [ 1.20061574e+00],
#        [ 7.75095020e-01],
#        [-3.64648966e-01],
#        [ 9.85899779e-01],
#        [-1.62071732e+00],
#        [ 5.17837754e-01],
#        [-1.53175495e+00],
#        [ 2.65519657e-01],
#        [ 1.36953727e-01],
#        [-1.73154424e+00],
#        [ 5.17837754e-01],
#        [ 1.35486532e+00],
#        [-9.04878365e-01],
#        [ 1.86780224e-01],
#        [ 1.40413128e+00],
#        [ 8.31223753e-01],
#        [-1.35067387e+00],
#        [-3.97293795e-01],
#        [-3.85453547e-01],
#        [-1.66067950e+00],
#        [-9.04878365e-01],
#        [ 1.47471360e+00],
#        [-3.64648966e-01],
#        [-1.27266268e+00],
#        [-3.64748654e-01],
#        [ 1.14462928e+00],
#        [-1.54993781e+00],
#        [ 2.86994127e-01],
#        [-2.99187881e-01],
#        [-7.29879997e-01],
#        [-1.39140608e+00],
#        [-2.01409020e-01],
#        [-1.46523851e+00],
#        [-1.74493859e+00],
#        [-7.57526877e-03],
#        [-4.85968229e-01],
#        [ 1.50127618e+00],
#        [-4.11611269e-01],
#        [-8.97892654e-01],
#        [-2.75107593e-01],
#        [ 3.45865811e-01],
#        [ 1.41734616e+00],
#        [ 2.65519657e-01],
#        [ 7.18378258e-01],
#        [ 1.21300931e+00],
#        [ 1.04960385e+00],
#        [-2.40778404e-01],
#        [ 1.00228507e+00],
#        [ 4.12048306e-01],
#        [-5.29003566e-01],
#        [ 1.31922113e+00],
#        [ 9.85899779e-01],
#        [-1.34303174e+00],
#        [-1.62776348e+00],
#        [ 7.75095020e-01],
#        [-8.02410432e-01],
#        [-9.18503310e-01],
#        [ 4.12048306e-01],
#        [ 1.50127618e+00],
#        [-1.27266268e+00],
#        [ 2.65519657e-01],
#        [-5.29177237e-01],
#        [ 7.75095020e-01],
#        [-2.99187881e-01],
#        [-3.64648966e-01],
#        [ 1.86780224e-01],
#        [-3.97293795e-01],
#        [ 1.52408356e+00],
#        [ 4.49983364e-01],
#        [-1.05931124e+00],
#        [-1.63869730e-01],
#        [ 1.50127618e+00],
#        [ 7.55823134e-01],
#        [-1.05931124e+00],
#        [ 1.53890257e+00],
#        [ 7.18378258e-01],
#        [ 1.53890257e+00],
#        [ 8.31223753e-01],
#        [ 7.55823134e-01],
#        [ 7.81700467e-01],
#        [ 7.81700467e-01],
#        [ 6.60064797e-01],
#        [ 1.30533553e+00],
#        [ 1.08544127e+00],
#        [-3.46623715e-02],
#        [-1.15692643e+00],
#        [ 1.37191625e+00],
#        [-1.73714097e+00],
#        [ 9.32430600e-01],
#        [ 1.11307902e+00],
#        [-7.58940247e-01],
#        [-9.18503310e-01],
#        [ 3.45865811e-01],
#        [ 4.15532911e-01],
#        [-3.64748654e-01],
#        [-9.04878365e-01],
#        [-9.22694519e-01],
#        [ 4.67863442e-01],
#        [-1.29097509e-01],
#        [-1.05931124e+00],
#        [ 1.11307902e+00],
#        [-1.44264034e+00],
#        [-1.84343478e-01],
#        [ 2.70346477e-01],
#        [ 1.86780224e-01],
#        [ 1.22075701e+00],
#        [-1.02298771e+00],
#        [ 1.34835784e+00],
#        [-1.04969386e+00],
#        [-1.57212980e+00],
#        [-3.85453547e-01],
#        [ 3.87458426e-01],
#        [-9.92671849e-01],
#        [-4.11611269e-01],
#        [ 9.85899779e-01],
#        [ 9.85899779e-01],
#        [-1.37597620e+00],
#        [ 3.48205465e-01],
#        [-1.08085196e+00],
#        [-5.29177237e-01],
#        [ 1.47471360e+00],
#        [-3.85453547e-01],
#        [ 9.32430600e-01],
#        [ 6.74731264e-02],
#        [ 7.75095020e-01],
#        [-7.01969147e-01],
#        [ 4.62796449e-01],
#        [-7.88040423e+00],
#        [-1.84343478e-01],
#        [ 8.32545402e-01],
#        [-1.46523851e+00],
#        [ 7.81700467e-01],
#        [-3.64648966e-01],
#        [ 1.39236683e+00],
#        [-1.62776348e+00],
#        [-1.15692643e+00],
#        [ 5.88584223e-01],
#        [ 1.50127618e+00],
#        [-3.97293795e-01],
#        [-9.04878365e-01],
#        [-8.11329880e-01],
#        [ 4.15214402e-01],
#        [-9.18503310e-01],
#        [ 1.30533553e+00],
#        [-1.39140608e+00],
#        [-3.97293795e-01],
#        [-9.22694519e-01],
#        [ 1.43580093e+00],
#        [-4.25227595e-01],
#        [-1.27266268e+00],
#        [ 9.71918741e-01],
#        [-3.63319004e-01],
#        [ 9.41640484e-01],
#        [ 1.37191625e+00],
#        [-9.45249641e-01],
#        [ 1.42821598e-01],
#        [ 1.20061574e+00],
#        [ 1.03475943e+00],
#        [-5.21621676e-01],
#        [ 6.60064797e-01],
#        [ 9.32430600e-01],
#        [ 1.00274723e+00],
#        [-1.53175495e+00],
#        [ 3.87458426e-01],
#        [-8.97892654e-01],
#        [-1.15692643e+00],
#        [-1.04969386e+00],
#        [ 1.00228507e+00],
#        [ 5.73986455e-01],
#        [-1.35067387e+00],
#        [-4.11611269e-01],
#        [ 5.73986455e-01],
#        [-5.36078907e-01],
#        [-1.54166304e-01],
#        [-1.02298771e+00],
#        [ 9.71918741e-01],
#        [-5.21621676e-01],
#        [ 1.00274723e+00],
#        [-5.59763052e-01],
#        [ 1.62014849e+00],
#        [ 1.21300931e+00],
#        [-1.39140608e+00],
#        [ 2.28435924e-01],
#        [-1.66067950e+00],
#        [ 1.27744090e+00],
#        [-5.59763052e-01],
#        [ 8.32545402e-01],
#        [ 1.40413128e+00],
#        [ 5.73986455e-01],
#        [ 1.42821598e-01],
#        [ 9.54376292e-01],
#        [ 1.04960385e+00],
#        [ 1.40749270e+00],
#        [ 6.60064797e-01],
#        [ 1.40413128e+00],
#        [ 1.42821598e-01],
#        [ 1.03957183e+00],
#        [-9.22694519e-01],
#        [ 1.20061574e+00],
#        [ 3.45865811e-01],
#        [-9.18503310e-01],
#        [ 9.42697031e-01],
#        [ 4.67863442e-01],
#        [-3.97293795e-01],
#        [ 8.32545402e-01],
#        [-5.95116619e-01],
#        [-5.15772181e-01],
#        [ 1.03957183e+00],
#        [-1.20787928e+00],
#        [-3.63319004e-01],
#        [-8.39523638e-01],
#        [-1.74493859e+00],
#        [-9.95921302e-01],
#        [-1.34303174e+00],
#        [ 1.36953727e-01],
#        [-3.64748654e-01],
#        [-5.36078907e-01],
#        [-1.28104385e+00],
#        [-9.92671849e-01],
#        [-4.25227595e-01],
#        [-5.95116619e-01],
#        [-1.33059033e+00],
#        [ 1.04969471e+00],
#        [ 2.86994127e-01],
#        [-1.05931124e+00],
#        [ 9.54376292e-01],
#        [-1.46523851e+00],
#        [ 3.48205465e-01],
#        [-5.21621676e-01],
#        [ 9.93043577e-01],
#        [ 1.39799803e+00],
#        [-1.57358463e+00],
#        [ 1.03957183e+00],
#        [-3.97293795e-01],
#        [-1.05676650e+00],
#        [ 1.55171236e+00],
#        [ 1.44702914e+00],
#        [ 1.40413128e+00],
#        [ 1.04960385e+00],
#        [ 2.70346477e-01],
#        [-1.40535774e+00],
#        [-1.15692643e+00],
#        [-5.15772181e-01],
#        [ 3.45865811e-01],
#        [-5.97739995e-01],
#        [ 5.88584223e-01],
#        [ 1.21300931e+00],
#        [ 1.39226705e-01],
#        [-1.08182983e+00],
#        [ 1.03957183e+00],
#        [-1.02298771e+00],
#        [ 9.42697031e-01],
#        [ 9.41640484e-01],
#        [ 9.71918741e-01],
#        [ 9.76066844e-01],
#        [-1.57358463e+00],
#        [-3.80903463e-02],
#        [-1.05676650e+00],
#        [-1.63869730e-01],
#        [-1.43069628e+00],
#        [-1.28104385e+00],
#        [ 4.12048306e-01],
#        [ 5.73986455e-01],
#        [ 3.45865811e-01],
#        [-1.15692643e+00],
#        [-8.48777450e-01],
#        [ 1.27408086e+00],
#        [-4.24738021e-01],
#        [-2.40778404e-01],
#        [ 2.70346477e-01],
#        [ 1.04969471e+00],
#        [-1.39140608e+00],
#        [ 1.35486532e+00],
#        [ 1.50127618e+00],
#        [ 7.55823134e-01],
#        [-1.44264034e+00],
#        [-5.95116619e-01],
#        [-1.47371279e+00],
#        [ 5.17837754e-01],
#        [-5.36078907e-01],
#        [ 1.20061574e+00],
#        [-4.43399369e-01],
#        [ 6.31337800e-02],
#        [-1.57358463e+00],
#        [ 1.42821598e-01],
#        [ 1.43580093e+00],
#        [ 1.10390156e+00],
#        [-1.27266268e+00],
#        [-5.97739995e-01],
#        [ 1.53890257e+00],
#        [ 1.08544127e+00],
#        [ 9.54376292e-01],
#        [ 1.53890257e+00],
#        [ 4.14971640e-01],
#        [-1.73154424e+00],
#        [ 4.67863442e-01],
#        [ 3.45865811e-01],
#        [ 1.10390156e+00],
#        [ 7.75095020e-01],
#        [-2.99187881e-01],
#        [ 1.10390156e+00],
#        [ 1.35486532e+00],
#        [ 1.21300931e+00],
#        [-1.17697967e+00],
#        [ 2.57560056e-02],
#        [ 6.53394308e-01],
#        [ 1.04969471e+00],
#        [ 1.11307902e+00],
#        [ 1.36953727e-01],
#        [-2.99187881e-01],
#        [-5.95116619e-01],
#        [-9.95921302e-01],
#        [ 6.31337800e-02],
#        [ 9.93043577e-01],
#        [ 5.73986455e-01],
#        [-1.43069628e+00],
#        [ 4.15214402e-01],
#        [-1.04969386e+00],
#        [-1.73154424e+00],
#        [-1.44985264e+00],
#        [ 9.41640484e-01],
#        [ 9.07524131e-01],
#        [ 3.87458426e-01],
#        [-8.11329880e-01],
#        [ 1.00228507e+00],
#        [ 1.40413128e+00],
#        [-1.53175495e+00],
#        [ 1.03957183e+00],
#        [-2.75107593e-01],
#        [-1.17697967e+00],
#        [ 7.81700467e-01],
#        [-8.11329880e-01],
#        [-8.11329880e-01],
#        [-1.28104385e+00],
#        [-1.19359320e+00],
#        [-8.48777450e-01],
#        [-4.85968229e-01],
#        [-1.44264034e+00],
#        [-1.44264034e+00],
#        [-5.85435504e-01],
#        [-1.62071732e+00],
#        [ 4.67863442e-01],
#        [ 1.31922113e+00],
#        [ 1.62014849e+00],
#        [ 2.57560056e-02],
#        [ 6.53394308e-01],
#        [-1.43069628e+00],
#        [-5.21621676e-01],
#        [-2.75107593e-01],
#        [-5.95116619e-01],
#        [ 1.21300931e+00],
#        [-5.85435504e-01],
#        [-4.85968229e-01],
#        [ 1.37191625e+00],
#        [-1.20787928e+00],
#        [-1.28104385e+00],
#        [ 4.14971640e-01],
#        [-5.95116619e-01],
#        [ 1.44702914e+00],
#        [-7.01969147e-01],
#        [ 1.39226705e-01],
#        [-8.02410432e-01],
#        [ 6.60064797e-01]])

# %%
from tqdm import tqdm
mosaic_list_of_images =[]
mosaic_label = []
fore_idx=[]
for j in tqdm(range(desired_num+1000)):
    np.random.seed(j)
    fg_class  = np.random.randint(0,2)
    fg_idx = 0
    a = []
    for i in range(m):
        if i == fg_idx:
            b = np.random.choice(np.where(idx[fg_class]==True)[0],size=1)
            a.append(x[b])
#             print("foreground "+str(fg_class)+" present at " + str(fg_idx))
        else:
            bg_class = np.random.randint(2,3)
            b = np.random.choice(np.where(idx[bg_class]==True)[0],size=1)
            a.append(x[b])
#             print("background "+str(bg_class)+" present at " + str(i))
    a = np.concatenate(a,axis=0)
    mosaic_list_of_images.append(np.reshape(a,(m,1)))
    mosaic_label.append(fg_class)
    fore_idx.append(fg_idx)
    # if(j%(int(desired_num/4))==0):
      # print("25% done")
# Out:
# 100%|██████████| 11000/11000 [14:45<00:00, 12.43it/s]

# %%
mosaic_list_of_images = np.concatenate(mosaic_list_of_images,axis=1).T
mosaic_list_of_images.shape
# Out:
# (11000, 1000)

# %%
np.sum(mosaic_list_of_images[0:tr_j], axis=1).shape, np.sum(mosaic_list_of_images[0:tr_j], axis=1)
# Out:
# ((10000,), array([-28.68551108, -15.90152114,  -7.402185  , ...,  26.10665475,
#         -21.62784745, -33.88051644]))

# %%
train = np.sum(mosaic_list_of_images[0:tr_j], axis=1)/m
train[0], train.shape
# Out:
# (-0.02868551108379297, (10000,))

# %%
test = mosaic_list_of_images[tr_j:tr_k,0]/m
test[0], test.shape
# Out:
# (-0.011792700456441407, (1000,))

# %%
avg_image_dataset_1 , labels_1,  fg_index_1 = np.sum(mosaic_list_of_images[0:tr_j], axis=1)/m , mosaic_label[0:tr_j], fore_idx[0:tr_j] 


test_dataset , labels , fg_index = mosaic_list_of_images[tr_j:tr_k,0]/m , mosaic_label[tr_j : tr_k], fore_idx[tr_j : tr_k]

# %%
avg_image_dataset_1[0], test_dataset[0], avg_image_dataset_1.shape, test_dataset.shape
# Out:
# (-0.02868551108379297, -0.011792700456441407, (10000,), (1000,))

# %%
avg_image_dataset_1 = avg_image_dataset_1.reshape(desired_num,1)
test_dataset = test_dataset.reshape(1000, 1)
avg_image_dataset_1.shape, test_dataset.shape
# Out:
# ((10000, 1), (1000, 1))

# %%
# avg_image_dataset_1 = torch.stack(avg_image_dataset_1, axis = 0)

# mean = torch.mean(avg_image_dataset_1, keepdims= True, axis = 0)
# std = torch.std(avg_image_dataset_1, keepdims= True, axis = 0)

# avg_image_dataset_1 = (avg_image_dataset_1 - mean) / std 

# print(torch.mean(avg_image_dataset_1, keepdims= True, axis = 0))
# print(torch.std(avg_image_dataset_1, keepdims= True, axis = 0))
# print("=="*40)


# test_dataset = torch.stack(test_dataset, axis = 0)
# mean = torch.mean(test_dataset, keepdims= True, axis = 0)
# std = torch.std(test_dataset, keepdims= True, axis = 0)
# test_dataset = (test_dataset - mean) / std

# print(torch.mean(test_dataset, keepdims= True, axis = 0))
# print(torch.std(test_dataset, keepdims= True, axis = 0))
# print("=="*40)

# %%
x1 = (avg_image_dataset_1)
y1 = np.array(labels_1)

# idx1 = []
# for i in range(3):
#   idx1.append(y1 == i)

# for i in range(3):
#     z = np.zeros(x1[idx1[i]].shape[0])
#     plt.scatter(x1[idx1[i]],z,label="class_"+str(i))
# plt.legend()

plt.scatter(x1[y1==0], y1[y1==0]*0, label='class 0')
plt.scatter(x1[y1==1], y1[y1==1]*0, label='class 1')
# plt.scatter(x1[y1==2], y1[y1==2]*0, label='class 2')
plt.legend()
plt.title("dataset1 CIN with alpha = 1/"+str(m))
# Out:
# Text(0.5, 1.0, 'dataset1 CIN with alpha = 1/1000')

# %%
x1 = (avg_image_dataset_1)
y1 = np.array(labels_1)

idx_1 = y1==0
idx_2 = np.where(idx_1==True)[0]
idx_3 = np.where(idx_1==False)[0]
color = ['#1F77B4','orange', 'brown']

true_point = len(idx_2)
plt.scatter(x1[idx_2[:25]], y1[idx_2[:25]]*0, label='class 0', c= color[0], marker='o')
plt.scatter(x1[idx_3[:25]], y1[idx_3[:25]]*0, label='class 1', c= color[1], marker='o')

plt.scatter(x1[idx_3[50:75]], y1[idx_3[50:75]]*0,  c= color[1], marker='o')
plt.scatter(x1[idx_2[50:75]], y1[idx_2[50:75]]*0,  c= color[0], marker='o')


plt.legend()
plt.xticks( fontsize=14, fontweight = 'bold')
plt.yticks( fontsize=14, fontweight = 'bold')
plt.xlabel("X", fontsize=14, fontweight = 'bold')
# plt.savefig(fp_cin+"ds1_alpha_04.png", bbox_inches="tight")
# plt.savefig(fp_cin+"ds1_alpha_04.pdf", bbox_inches="tight")
# Out:
# Text(0.5, 0, 'X')

# %%
avg_image_dataset_1[0:10]
# Out:
# array([[-0.02868551],
#        [-0.01590152],
#        [-0.00740218],
#        [-0.02920548],
#        [-0.02111228],
#        [ 0.00957134],
#        [ 0.02444853],
#        [-0.00660391],
#        [-0.03580124],
#        [-0.01728289]])

# %%
x1 = (test_dataset)
y1 = np.array(labels)

# idx1 = []
# for i in range(3):
#   idx1.append(y1 == i)

# for i in range(3):
#     z = np.zeros(x1[idx1[i]].shape[0])
#     plt.scatter(x1[idx1[i]],z,label="class_"+str(i))
# plt.legend()

plt.scatter(x1[y1==0], y1[y1==0]*0, label='class 0')
plt.scatter(x1[y1==1], y1[y1==1]*0, label='class 1')
# plt.scatter(x1[y1==2], y1[y1==2]*0, label='class 2')
plt.legend()
plt.title("test dataset1 ")
# Out:
# Text(0.5, 1.0, 'test dataset1 ')

# %%
test_dataset[0:10]
# Out:
# array([[-0.0117927 ],
#        [-0.00666623],
#        [-0.00815147],
#        [-0.00691113],
#        [-0.00833677],
#        [-0.01120413],
#        [-0.00922916],
#        [-0.01032831],
#        [-0.00598783],
#        [-0.00846234]])

# %%
class MosaicDataset(Dataset):
  """MosaicDataset dataset."""

  def __init__(self, mosaic_list_of_images, mosaic_label):
    """
      Args:
        csv_file (string): Path to the csv file with annotations.
        root_dir (string): Directory with all the images.
        transform (callable, optional): Optional transform to be applied
            on a sample.
    """
    self.mosaic = mosaic_list_of_images
    self.label = mosaic_label
    #self.fore_idx = fore_idx
    
  def __len__(self):
    return len(self.label)

  def __getitem__(self, idx):
    return self.mosaic[idx] , self.label[idx] #, self.fore_idx[idx]

# %%
avg_image_dataset_1[0].shape, avg_image_dataset_1[0]
# Out:
# ((1,), array([-0.02868551]))

# %%
batch = 200

traindata_1 = MosaicDataset(avg_image_dataset_1, labels_1 )
trainloader_1 = DataLoader( traindata_1 , batch_size= batch ,shuffle=True)

# %%
testdata_1 = MosaicDataset(test_dataset, labels )
testloader_1 = DataLoader( testdata_1 , batch_size= batch ,shuffle=False)

# %%
class Whatnet(nn.Module):
    def __init__(self):
        super(Whatnet,self).__init__()
        self.linear1 = nn.Linear(1,2)
        # self.linear2 = nn.Linear(50,10)
        # self.linear3 = nn.Linear(10,3)
        torch.nn.init.xavier_normal_(self.linear1.weight)
        torch.nn.init.zeros_(self.linear1.bias)

    def forward(self,x):
        # x = F.relu(self.linear1(x))
        # x = F.relu(self.linear2(x))
        x = (self.linear1(x))

        return x

# %%
def calculate_loss(dataloader,model,criter):
  model.eval()
  r_loss = 0
  with torch.no_grad():
    for i, data in enumerate(dataloader, 0):
      inputs, labels = data
      inputs, labels = inputs.to("cuda"),labels.to("cuda")
      outputs = model(inputs)
      loss = criter(outputs, labels)
      r_loss += loss.item()
  return r_loss/(i+1)

# %%
def test_all(number, testloader,net):
    correct = 0
    total = 0
    out = []
    pred = []
    with torch.no_grad():
        for data in testloader:
            images, labels = data
            images, labels = images.to("cuda"),labels.to("cuda")
            out.append(labels.cpu().numpy())
            outputs= net(images)
            _, predicted = torch.max(outputs.data, 1)
            pred.append(predicted.cpu().numpy())
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
    
    pred = np.concatenate(pred, axis = 0)
    out = np.concatenate(out, axis = 0)
    print("unique out: ",  np.unique(out), "unique pred: ", np.unique(pred) )
    print("correct: ", correct, "total ",  total)
    print('Accuracy of the network on the %d test dataset %d: %.2f %%' % (total, number , 100 * correct / total))

# %%
def train_all(trainloader, ds_number, testloader_list):
    
    print("--"*40)
    print("training on data set  ", ds_number)
    
    torch.manual_seed(12)
    net = Whatnet().double()
    net = net.to("cuda")
    
    criterion_net = nn.CrossEntropyLoss()
    optimizer_net = optim.Adam(net.parameters(), lr=0.0005 ) #, momentum=0.9)
    
    acti = []
    loss_curi = []
    epochs = 1500
    running_loss = calculate_loss(trainloader,net,criterion_net)
    loss_curi.append(running_loss)
    print('epoch: [%d ] loss: %.3f' %(0,running_loss)) 
    for epoch in range(epochs): # loop over the dataset multiple times
        ep_lossi = []

        running_loss = 0.0
        net.train()
        for i, data in enumerate(trainloader, 0):
            # get the inputs
            inputs, labels = data
            inputs, labels = inputs.to("cuda"),labels.to("cuda")

            # zero the parameter gradients
            optimizer_net.zero_grad()

            # forward + backward + optimize
            outputs = net(inputs)
            loss = criterion_net(outputs, labels)
            # print statistics
            running_loss += loss.item()
            loss.backward()
            optimizer_net.step()

        running_loss = calculate_loss(trainloader,net,criterion_net)
        if(epoch%200 == 0):
          print('epoch: [%d] loss: %.3f' %(epoch + 1,running_loss)) 
        loss_curi.append(running_loss)   #loss per epoch
        if running_loss<=0.05:
          print('epoch: [%d] loss: %.3f' %(epoch + 1,running_loss))
          break

    print('Finished Training')
    
    correct = 0
    total = 0
    with torch.no_grad():
        for data in trainloader:
            images, labels = data
            images, labels = images.to("cuda"), labels.to("cuda")
            outputs = net(images)
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

    print('Accuracy of the network on the %d train images: %.2f %%' % (total,  100 * correct / total))
    
    for i, j in enumerate(testloader_list):
        test_all(i+1, j,net)
    
    print("--"*40)
    
    return loss_curi, net

# %%
train_loss_all=[]

testloader_list= [ testloader_1 ]

# %%
loss, net = train_all(trainloader_1, 1, testloader_list)
train_loss_all.append(loss)
# Out:
# --------------------------------------------------------------------------------
# training on data set   1
# epoch: [0 ] loss: 0.693
# epoch: [1] loss: 0.693
# epoch: [201] loss: 0.692
# epoch: [401] loss: 0.692
# epoch: [601] loss: 0.692
# epoch: [801] loss: 0.692
# epoch: [1001] loss: 0.692
# epoch: [1201] loss: 0.692
# epoch: [1401] loss: 0.692
# Finished Training
# Accuracy of the network on the 10000 train images: 51.91 %
# unique out:  [0 1] unique pred:  [0 1]
# correct:  895 total  1000
# Accuracy of the network on the 1000 test dataset 1: 89.50 %
# --------------------------------------------------------------------------------

# %%
net.linear1.weight, net.linear1.bias
# Out:
# (Parameter containing:
#  tensor([[-1.3456],
#          [ 1.6697]], device='cuda:0', dtype=torch.float64, requires_grad=True),
#  Parameter containing:
#  tensor([-0.0140,  0.0140], device='cuda:0', dtype=torch.float64,
#         requires_grad=True))

# %%
# %matplotlib inline

# %%
for i,j in enumerate(train_loss_all):
    plt.plot(j,label ="dataset "+str(i+1))
    

plt.xlabel("Epochs")
plt.ylabel("Training_loss")

plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
